# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b5c3a5fa833d> in <module>
#      13 from keras.optimizers import Adam
#      14 #
# ---> 15 import matplotlib.pyplot as plt
#      16 import seaborn as sns
#      17 sns.set(style="darkgrid")
#
# ~\ana\lib\site-packages\matplotlib\pyplot.py in <module>
#      30 from cycler import cycler
#      31 import matplotlib
# ---> 32 import matplotlib.colorbar
#      33 import matplotlib.image
#      34 from matplotlib import rcsetup, style
#
# ~\ana\lib\site-packages\matplotlib\colorbar.py in <module>
#      28 import matplotlib.artist as martist
#      29 import matplotlib.cbook as cbook
# ---> 30 import matplotlib.collections as collections
#      31 import matplotlib.colors as colors
#      32 import matplotlib.contour as contour
#
# ~\ana\lib\site-packages\matplotlib\collections.py in <module>
#      17
#      18 import matplotlib as mpl
# ---> 19 from . import (_path, artist, cbook, cm, colors as mcolors, docstring,
#      20                lines as mlines, path as mpath, transforms)
#      21
#
# ~\ana\lib\site-packages\matplotlib\lines.py in <module>
#     206
#     207
# --> 208 @cbook._define_aliases({
#     209     "antialiased": ["aa"],
#     210     "color": ["c"],
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_define_aliases'

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('../Data/DATA.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())

# %%
df['label'].value_counts() #balanced Dataset

# %%
df.shape

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 #'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 #'becomes',
 #'becoming',
 #'been',
 'before',
 'beforehand',
 #'behind',
 #'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 #'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 #'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 #'show',
 'side',
 'since',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
"couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
        "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re
# Out:
# C:\Users\khmar\ana\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\ana\lib\site-packages\pattern\text\en\wordnet\__init__.py in <module>
#      56     try:
# ---> 57         nltk.data.find("corpora/" + token)
#      58     except LookupError:
#
# ~\ana\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\khmar/nltk_data'
#     - 'C:\\Users\\khmar\\ana\\nltk_data'
#     - 'C:\\Users\\khmar\\ana\\share\\nltk_data'
#     - 'C:\\Users\\khmar\\ana\\lib\\nltk_data'
#     - 'C:\\Users\\khmar\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\ana\lib\site-packages\pattern\text\en\wordnet\__init__.py in <module>
#      59         try:
# ---> 60             nltk.download(token, quiet = True, raise_on_error = True)
#      61         except ValueError:
#
# ~\ana\lib\site-packages\nltk\downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     791                     if raise_on_error:
# --> 792                         raise ValueError(msg.message)
#     793                     if halt_on_error:
#
# ValueError: Error loading wordnet: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c86e4d797ec7> in <module>
#       2 import inflect
#       3 from nltk.stem import WordNetLemmatizer
# ----> 4 import gensim
#       5 from gensim import parsing
#       6 from gensim.parsing.preprocessing import split_alphanum
#
# ~\ana\lib\site-packages\gensim\__init__.py in <module>
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# ~\ana\lib\site-packages\gensim\corpora\__init__.py in <module>
#      12 from .dictionary import Dictionary  # noqa:F401
#      13 from .hashdictionary import HashDictionary  # noqa:F401
# ---> 14 from .wikicorpus import WikiCorpus  # noqa:F401
#      15 from .textcorpus import TextCorpus, TextDirectoryCorpus  # noqa:F401
#      16 from .ucicorpus import UciCorpus  # noqa:F401
#
# ~\ana\lib\site-packages\gensim\corpora\wikicorpus.py in <module>
#     469
#     470
# --> 471 class WikiCorpus(TextCorpus):
#     472     """Treat a wikipedia articles dump as a **read-only** corpus.
#     473
#
# ~\ana\lib\site-packages\gensim\corpora\wikicorpus.py in WikiCorpus()
#     502     """
#     503
# --> 504     def __init__(self, fname, processes=None, lemmatize=utils.has_pattern(), dictionary=None,
#     505                  filter_namespaces=('0',), tokenizer_func=tokenize, article_min_tokens=ARTICLE_MIN_WORDS,
#     506                  token_min_len=TOKEN_MIN_LEN, token_max_len=TOKEN_MAX_LEN, lower=True):
#
# ~\ana\lib\site-packages\gensim\utils.py in has_pattern()
#    1557     """
#    1558     try:
# -> 1559         from pattern.en import parse  # noqa:F401
#    1560         return True
#    1561     except ImportError:
#
# ~\ana\lib\site-packages\pattern\text\en\__init__.py in <module>
#      59 )
#      60 # Import inflection functions.
# ---> 61 from pattern.text.en.inflect import (
#      62     article, referenced, DEFINITE, INDEFINITE,
#      63     pluralize, singularize, NOUN, VERB, ADJECTIVE,
#
# ~\ana\lib\site-packages\pattern\text\en\__init__.py in <module>
#      78 # Import all submodules.
#      79 from pattern.text.en import inflect
# ---> 80 from pattern.text.en import wordnet
#      81 from pattern.text.en import wordlist
#      82
#
# ~\ana\lib\site-packages\pattern\text\en\wordnet\__init__.py in <module>
#      63             from nltk.downloader import Downloader as NLTKDownloader
#      64             d = NLTKDownloader("http://nltk.github.com/nltk_data/")
# ---> 65             d.download(token, quiet = True, raise_on_error = True)
#      66
#      67 # Use the Brown corpus for calculating information content (IC)
#
# ~\ana\lib\site-packages\nltk\downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     790                     show(msg.message)
#     791                     if raise_on_error:
# --> 792                         raise ValueError(msg.message)
#     793                     if halt_on_error:
#     794                         return False
#
# ValueError: Error loading wordnet: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

##Fixing Word Lengthening
##https://rustyonrampa"ge.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)
def remove_alphanumerics(text):
    """
    Remove alphanumeric words from text
    Example: hello man whatsup123 => hello man
    Args:
        text (str): text
    Returns:
        text (str): text with removed alphanumeric words
    """
    txt = []
    for each in text.split():
        if not any(x in each.lower() for x in "0123456789"):
            txt.append(each)
    txtsent = " ".join(txt)
    return txtsent

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    #text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    text = remove_alphanumerics(text)
    text = reduce_lengthening(text)
    
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText(" she'd've I have 1000  s220 soooooo don't i'm  can't servic going grooooooooop")

# %%
df['text'] = df['text'].map(lambda x: transformText(x))

# %%
texts= df['text']
tags= df['label']

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('../Data/DATA_preprocessing81.csv')

# %%
####

# %%
DATA_FILE = '../Data/DATA_preprocessing81.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2813, 3)
# (1243, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1413
# ISSUE       1400
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       634
# NOTISSUE    609
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1413
# ISSUE       1400
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
# Out:
# C:\Users\khmar\ana\lib\site-packages\keras_preprocessing\text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2813, 200)
# Shape of test_data tensor: (1243, 200)

# %%
import pickle
file_tok = '../Model/LSTM_token_glove_300d_DATA_wit_text_processing7.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3132 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2813, 200)
# Shape of data test tensor: (1243, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : flavourful
# word not found : cosiness
# word not found : untasted
# word not found : profiterole
# word not found : flavourless
# word not found : tk50
# word not found : barset
# word not found : plantronincs
# word not found : 4715
# word not found : notproduce
# word not found : a325
# word not found : tracfonewebsite
# word not found : supertooth
# word not found : reoccure
# word not found : 8125
# word not found : s740
# word not found : convertor
# word not found : convolute
# word not found : appal
# word not found : stylize
# word not found : nomish
# word not found : mesmerise
# word not found : brainsucking
# word not found : 8810
# word not found : hydrabrush
# word not found : shawarrma
# word not found : chipolte
# word not found : albondigas
# word not found : cheesecurds
# word not found : ciob

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 30 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2813 samples, validate on 1243 samples
# Epoch 1/2
# 2813/2813 [==============================] - 29s 10ms/step - loss: 0.5280 - acc: 0.7455 - val_loss: 0.4472 - val_acc: 0.8117
# Epoch 2/2
# 2813/2813 [==============================] - 24s 9ms/step - loss: 0.4115 - acc: 0.8290 - val_loss: 0.4171 - val_acc: 0.8230

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1243/1243 [==============================] - 2s 2ms/step
# loss: 41.71%
# acc: 82.30%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v7.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.9722483]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.3871207]]
# ISSUE

# %%
text=" very recommend"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend
# [[0.61207235]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='DATA/DATA_preprocessing5.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text_preprocessing7.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.6523847]] NOTISSUE
# 2 love phone [[0.921929]] NOTISSUE
# 3 get well finish product [[0.7499004]] NOTISSUE
# 4 not be happier [[0.3228598]] ISSUE
# 5 look headset long time have get [[0.60461706]] NOTISSUE
# 6 headset start ring no reason [[0.1664908]] ISSUE
# 7 display excellent camera good year [[0.9993931]] NOTISSUE
# 8 battery life great [[0.9878826]] NOTISSUE
# 9 worst phone have have have month [[0.21018901]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.19635378]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.11028478]] ISSUE
# 12 protect phone side [[0.5990943]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.08891013]] ISSUE
# 14 clear skye call long battery life long range [[0.9047527]] NOTISSUE
# 15 solo technology suck [[0.5404558]] NOTISSUE
# 16 great hand free device [[0.98982704]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.799662]] NOTISSUE
# 18 problem have mention [[0.11234099]] ISSUE
# 19 try handsfree gadget one finally work well [[0.9074422]] NOTISSUE
# 20 magical help [[0.9223318]] NOTISSUE
# 21 worst piece crap version customer service [[0.11455463]] ISSUE
# 22 poor sound quality [[0.29938313]] ISSUE
# 23 best phone market [[0.87940544]] NOTISSUE
# 24 work well [[0.86083066]] NOTISSUE
# 25 company ship product promptly work well [[0.7142426]] NOTISSUE
# 26 exactly want [[0.49917796]] ISSUE
# 27 picture resolution far comparably price phone offer today [[0.6997301]] NOTISSUE
# 28 great deal [[0.97657645]] NOTISSUE
# 29 excellent product be satisfy purchase [[0.9892489]] NOTISSUE
# 30 highly recommend encourage people give try [[0.8259948]] NOTISSUE
# 31 better expect [[0.7144143]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.18737334]] ISSUE
# 33 great product price [[0.98032606]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.9989403]] NOTISSUE
# 35 disappointment [[0.22351849]] ISSUE
# 36 prompt service [[0.4075935]] ISSUE
# 37 excellent product price [[0.9832266]] NOTISSUE
# 38 please headset [[0.49361688]] ISSUE
# 39 do not waste money time [[0.07012661]] ISSUE
# 40 especially love long battery life [[0.98743725]] NOTISSUE
# 41 stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.9018887]] NOTISSUE
# 42 work great [[0.9770312]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.99817204]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice bad service [[0.07649045]] ISSUE
# 45 be look new earpiece [[0.6327295]] NOTISSUE
# 46 be look new earpiece jawbone era awesome too [[0.85966766]] NOTISSUE
# 47 receive white color battery go dead couple hours the original use week last longer the replacement [[0.14326912]] ISSUE
# 48 year battery go completely dead headset [[0.18623434]] ISSUE
# 49 have use phone two year one best [[0.8056389]] NOTISSUE
# 50 awesome new look fall 200 [[0.930058]] NOTISSUE
# 51 phone have have have be cheaply make [[0.42667183]] ISSUE
# 52 att not clear sound distort have yell talk [[0.14334884]] ISSUE
# 53 price good too [[0.7486847]] NOTISSUE
# 54 plastic break easy clip [[0.5115433]] NOTISSUE
# 55 do not make mistake do [[0.05723419]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.16400315]] ISSUE
# 57 be river spine with case fit fine [[0.9248525]] NOTISSUE
# 58 area unit break be not fond magnetic strap [[0.2987435]] ISSUE
# 59 overall be psyched have phone have appointment contact get great reception [[0.9104284]] NOTISSUE
# 60 thing phone work perfectly like it [[0.943842]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.23109375]] ISSUE
# 62 easy [[0.78738046]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.09248813]] ISSUE
# 64 fantastic earphone [[0.93997073]] NOTISSUE
# 65 find cell phone right away enter car [[0.32701442]] ISSUE
# 66 low quality [[0.62466204]] NOTISSUE
# 67 do get better reception clarity phone have have before [[0.49795997]] ISSUE
# 68 warn stay away [[0.18449079]] ISSUE
# 69 wish return unit get back money [[0.37958097]] ISSUE
# 70 awesome device work great [[0.9994221]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.03798522]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.13634436]] ISSUE
# 73 displease [[0.49102256]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.48040536]] ISSUE
# 75 make case small difficult install [[0.2829155]] ISSUE
# 76 restore phone like new performance [[0.8154705]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.9180395]] NOTISSUE
# 78 search internet find one be best value [[0.8824067]] NOTISSUE
# 79 do not fit [[0.20189825]] ISSUE
# 80 happy product [[0.873334]] NOTISSUE
# 81 screen size big key pad light well enough camera quality excellent camera phone [[0.99696535]] NOTISSUE
# 82 nothing bad say headset [[0.0813383]] ISSUE
# 83 be glad find product amazon hard find not high price [[0.39094737]] ISSUE
# 84 portable work [[0.80658823]] NOTISSUE
# 85 colleague get great reception a little expensive performance great [[0.99741215]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.14279383]] ISSUE
# 87 have have problem phone read memory card turn again [[0.22313428]] ISSUE
# 88 not good wear hat sunglass [[0.37238926]] ISSUE
# 89 timely shipment quality product [[0.5602626]] NOTISSUE
# 90 nice solid keyboard [[0.99240124]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.9679882]] NOTISSUE
# 92 horrible phone [[0.14419244]] ISSUE
# 93 bt battery junk [[0.4185135]] ISSUE
# 94 recommend others [[0.5477797]] NOTISSUE
# 95 not get software work computer [[0.30766305]] ISSUE
# 96 disappoint [[0.20872849]] ISSUE
# 97 poor voice clarity [[0.48138177]] ISSUE
# 98 battery work great [[0.9852024]] NOTISSUE
# 99 no buyer remorse one [[0.10697216]] ISSUE
# 100 disappoint accessory [[0.19940506]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.27146024]] ISSUE
# 102 look great strong [[0.989056]] NOTISSUE
# 103 have have mobile service two year now be pretty happy it [[0.99130464]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.10549489]] ISSUE
# 105 disappointment hate go ear [[0.11331759]] ISSUE
# 106 great software motorola [[0.98091286]] NOTISSUE
# 107 delivery time [[0.5515565]] NOTISSUE
# 108 easy use [[0.75148106]] NOTISSUE
# 109 uncomfortable ear do house lg 89900 env [[0.27869612]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.27025813]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.99442744]] NOTISSUE
# 112 like return it [[0.66568]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy do not expect problem [[0.30346712]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.35308555]] ISSUE
# 115 charge overnight battery work great [[0.9546521]] NOTISSUE
# 116 wil not regret it [[0.15130563]] ISSUE
# 117 love phone [[0.921929]] NOTISSUE
# 118 disappointment [[0.22351849]] ISSUE
# 119 not user friendly [[0.51783526]] NOTISSUE
# 120 unfortunately ability actually know receive call important feature phone pitiful respect [[0.3684852]] ISSUE
# 121 exchange phone have problem [[0.40155998]] ISSUE
# 122 result phone be stick max volume mute [[0.19044861]] ISSUE
# 123 public display affection rock [[0.920276]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.9517299]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.995285]] NOTISSUE
# 126 have version two year ago like service [[0.6655802]] NOTISSUE
# 127 pretty piece junk [[0.5121595]] NOTISSUE
# 128 plug wrong size [[0.20510899]] ISSUE
# 129 work describe [[0.48161498]] ISSUE
# 130 save money have have item month now [[0.39216703]] ISSUE
# 131 bad purchase [[0.12457723]] ISSUE
# 132 well im satisfy [[0.8354381]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.70875937]] NOTISSUE
# 134 battery excellent bargain [[0.9845359]] NOTISSUE
# 135 defective crap [[0.05564919]] ISSUE
# 136 have give no star able [[0.42503765]] ISSUE
# 137 wear glass fit fine them [[0.7490551]] NOTISSUE
# 138 sound quality device unacceptable unless quiet area hear nothing [[0.4187032]] ISSUE
# 139 not recommend item anyone [[0.18068382]] ISSUE
# 140 holster arrive not match photo ad [[0.27247164]] ISSUE
# 141 great no problem all [[0.61018693]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.16363735]] ISSUE
# 143 frog phone charm adorable eye catch [[0.9537148]] NOTISSUE
# 144 never know push hard right number time function want not [[0.20911554]] ISSUE
# 145 sound clear people talk amaze quality too [[0.5527425]] NOTISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.96564263]] NOTISSUE
# 147 good product well make [[0.9829736]] NOTISSUE
# 148 mobile phone tool have [[0.88051534]] NOTISSUE
# 149 be impress job motorola steadiness phone [[0.7788534]] NOTISSUE
# 150 receive order well ship timeframe everything good work order overall be excite have source [[0.84400177]] NOTISSUE
# 151 phone sturdy waterproof [[0.71976423]] NOTISSUE
# 152 be not impress not recommend item anyone [[0.12305121]] ISSUE
# 153 complaint standard sound volume little low turn 5 of 5 [[0.15163772]] ISSUE
# 154 thank again amazon have thing need good price [[0.9049725]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.22074884]] ISSUE
# 156 have go store buy new nokia phone work great [[0.97243214]] NOTISSUE
# 157 work great [[0.9770312]] NOTISSUE
# 158 ugly [[0.07110407]] ISSUE
# 159 horrible have switch time [[0.14039873]] ISSUE
# 160 noise shield incredible [[0.8474354]] NOTISSUE
# 161 no real improvement [[0.18991646]] ISSUE
# 162 razor battery good buy [[0.98247844]] NOTISSUE
# 163 keep good work amazon [[0.97588897]] NOTISSUE
# 164 refuse refund replace [[0.08319811]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.67469656]] NOTISSUE
# 166 basically throw money window nothing [[0.08068284]] ISSUE
# 167 great case price [[0.9555269]] NOTISSUE
# 168 take one drop six inch kitchen counter crack i be not impress be not laugh [[0.08936861]] ISSUE
# 169 bluetooth range good day ago leave phone trunk get call carry conversation hitch [[0.7861027]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.9977719]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.5600998]] NOTISSUE
# 172 none new one have work properly [[0.43798977]] ISSUE
# 173 be glad purchase it [[0.83155465]] NOTISSUE
# 174 have miss numerous call reason [[0.36647633]] ISSUE
# 175 phone defective people hear use this [[0.22929077]] ISSUE
# 176 do notably product [[0.29892078]] ISSUE
# 177 suck stuff do not work phone [[0.12604299]] ISSUE
# 178 no shift no bubble no peel not scratch nothing i note happier new one droid [[0.19991624]] ISSUE
# 179 worst software use give zero star would [[0.15440035]] ISSUE
# 180 try make call exercise frustration [[0.19063905]] ISSUE
# 181 case flimsy piece plastic have no protection whatsoever [[0.05920001]] ISSUE
# 182 cabra barset happy it sound quality especially outgo better [[0.9586423]] NOTISSUE
# 183 love camera pretty good quality [[0.99938273]] NOTISSUE
# 184 thank great service [[0.9956252]] NOTISSUE
# 185 total package [[0.7002081]] NOTISSUE
# 186 seller understand patient definitely buy again [[0.7745921]] NOTISSUE
# 187 give firefly one star i contact singular at t inform practice [[0.3314302]] ISSUE
# 188 aggravate [[0.49102256]] ISSUE
# 189 great product price [[0.98032606]] NOTISSUE
# 190 have purchase family friend enjoy clarity ease use [[0.9980281]] NOTISSUE
# 191 virgin wireless rock do cheap little phone [[0.3456085]] ISSUE
# 192 none work [[0.47518855]] ISSUE
# 193 do notably it [[0.36999947]] ISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide off [[0.05435032]] ISSUE
# 195 please do not waste money [[0.06111986]] ISSUE
# 196 all be satisfy purchase [[0.6766084]] NOTISSUE
# 197 look good quality headset keep look nott [[0.97676325]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.45020378]] ISSUE
# 199 not best one [[0.51802534]] NOTISSUE
# 200 best one [[0.8668329]] NOTISSUE
# 201 disappoint result [[0.09782836]] ISSUE
# 202 cumbersome design [[0.35224134]] ISSUE
# 203 great new package nice work good [[0.9999099]] NOTISSUE
# 204 no problem come time expect [[0.18268156]] ISSUE
# 205 great product [[0.9722483]] NOTISSUE
# 206 piece crap [[0.19702426]] ISSUE
# 207 experience terrible [[0.27692354]] ISSUE
# 208 fourth bluetooth headset [[0.7342758]] NOTISSUE
# 209 comfortable one [[0.9158925]] NOTISSUE
# 210 hat [[0.56334156]] NOTISSUE
# 211 fix problem [[0.18811741]] ISSUE
# 212 worst ever [[0.11741289]] ISSUE
# 213 be happy [[0.85261536]] NOTISSUE
# 214 have have no trouble access internet download intone perform function [[0.44718942]] ISSUE
# 215 barely hear be constantly say what [[0.22316566]] ISSUE
# 216 battery life highly unacceptable [[0.87574273]] NOTISSUE
# 217 company joke [[0.23985022]] ISSUE
# 218 do everything description say would [[0.16003373]] ISSUE
# 219 happen call force stop headset [[0.17673066]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.99710125]] NOTISSUE
# 221 version tech support walk procedure none work end have do hard re set wipe data [[0.12441827]] ISSUE
# 222 voice quality signal strength drop call [[0.36782092]] ISSUE
# 223 play louder speaker size price low think quality lack however not [[0.13137451]] ISSUE
# 224 better expect [[0.7144143]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push them [[0.41479257]] ISSUE
# 226 battery hold well [[0.861566]] NOTISSUE
# 227 difficult on i d recommend avoid product [[0.19849354]] ISSUE
# 228 use two day not easy hear with [[0.47975478]] ISSUE
# 229 get car charger not week charger break i go plug start smoke [[0.11368352]] ISSUE
# 230 sprint terrible customer service [[0.49015692]] ISSUE
# 231 link phone effort [[0.45566398]] ISSUE
# 232 cool [[0.73061347]] NOTISSUE
# 233 easy use [[0.75148106]] NOTISSUE
# 234 better new [[0.81679904]] NOTISSUE
# 235 posse get junk have no idea [[0.16260444]] ISSUE
# 236 piece trash [[0.14329599]] ISSUE
# 237 pretty good product [[0.98235816]] NOTISSUE
# 238 great phone [[0.9706753]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.9933883]] NOTISSUE
# 240 research development division obviously know do [[0.6083176]] NOTISSUE
# 241 real killer volume course break [[0.360835]] ISSUE
# 242 phone work fine now [[0.8713845]] NOTISSUE
# 243 be happy product one [[0.86255264]] NOTISSUE
# 244 poor construction [[0.10934949]] ISSUE
# 245 infuriate [[0.3569562]] ISSUE
# 246 overall recommend phone new walkman [[0.78727406]] NOTISSUE
# 247 sprint charge service [[0.77499837]] NOTISSUE
# 248 cheap feel look cheap [[0.56456363]] NOTISSUE
# 249 fit ear well comfortable on [[0.9864768]] NOTISSUE
# 250 do network europe asia [[0.25950065]] ISSUE
# 251 clip belt definitely make feel like fifty cent s up and come [[0.6961758]] NOTISSUE
# 252 like design look cabra be ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.3890438]] ISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.6467133]] NOTISSUE
# 254 worst phone samsung crap crappy samsung 1715 worst have see [[0.10051678]] ISSUE
# 255 charger work week completely stop charge phone [[0.19017477]] ISSUE
# 256 poor product [[0.15725078]] ISSUE
# 257 need better instruction [[0.64946127]] NOTISSUE
# 258 need two hand operate screen this software interface decade old compete new software design [[0.7853933]] NOTISSUE
# 259 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.9810372]] NOTISSUE
# 260 steer clear product go genuine palm replacement pen come three pack [[0.46587652]] ISSUE
# 261 do not buy do not but suck [[0.03679226]] ISSUE
# 262 great product sure beat finger [[0.9856178]] NOTISSUE
# 263 plus seriously do not believe worth steep price point [[0.18637562]] ISSUE
# 264 case have try normally fall apart month one seem be long haul [[0.20331898]] ISSUE
# 265 disappoint performance [[0.26407772]] ISSUE
# 266 do normale mistake please do notably phone [[0.11590561]] ISSUE
# 267 phone well be worst have have brand [[0.32883272]] ISSUE
# 268 case extra originally later discard scratch ear [[0.3020523]] ISSUE
# 269 recommend go different brand cell phone mp player family [[0.9101454]] NOTISSUE
# 270 do not bother go store [[0.07373711]] ISSUE
# 271 post detail comment grey black phone have fire red great color [[0.6770073]] NOTISSUE
# 272 not have problem item order again need [[0.23953249]] ISSUE
# 273 get pay guess [[0.22734444]] ISSUE
# 274 not software do great job this make intone form exist cd internet connection [[0.613862]] NOTISSUE
# 275 im surprise good quality car charger not review it [[0.9366935]] NOTISSUE
# 276 fabulous [[0.92425066]] NOTISSUE
# 277 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.07015702]] ISSUE
# 278 price cable excellent [[0.9379955]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.53945255]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end call [[0.1504194]] ISSUE
# 281 wind resistant [[0.38952872]] ISSUE
# 282 obviously have terrible customer service get pay for [[0.2643179]] ISSUE
# 283 do not forever [[0.11284311]] ISSUE
# 284 it not overly expensive replace [[0.08282575]] ISSUE
# 285 easy operate sound better have try [[0.91142946]] NOTISSUE
# 286 contact company tell that unit warranty not produce receipt luck [[0.0988022]] ISSUE
# 287 link have way exchange bad phone return unit something [[0.16228664]] ISSUE
# 288 phone sturdy nokia bar phone be [[0.9267294]] NOTISSUE
# 289 great phone [[0.9706753]] NOTISSUE
# 290 place tree case not not snug lot extra room side [[0.32646456]] ISSUE
# 291 be please [[0.55222267]] NOTISSUE
# 292 battery terrible [[0.12699912]] ISSUE
# 293 find product be easy set use [[0.79657996]] NOTISSUE
# 294 earpiece large heavy it keep fall ear [[0.18223166]] ISSUE
# 295 utter crap sound quality terrible [[0.02074095]] ISSUE
# 296 charger arrive promise timeframe not work [[0.5051234]] NOTISSUE
# 297 no ear loop need tiny sound great [[0.8856771]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.14304587]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.62852484]] NOTISSUE
# 300 talk useless customer service [[0.16940212]] ISSUE
# 301 felt light tinny [[0.21913908]] ISSUE
# 302 do not fit palm tungsten e2 break time try plug in [[0.26461318]] ISSUE
# 303 be happy purchase good quality low price [[0.9931015]] NOTISSUE
# 304 love look feel samsung flip phone [[0.87175363]] NOTISSUE
# 305 well design sharp blue nice color [[0.9892754]] NOTISSUE
# 306 do everything more [[0.40308818]] ISSUE
# 307 not recommend more [[0.3392499]] ISSUE
# 308 nice sound [[0.9583825]] NOTISSUE
# 309 look good picture case huge disappointment [[0.6480761]] NOTISSUE
# 310 jawbone go replace with [[0.43617335]] ISSUE
# 311 setup go smoothly [[0.7997337]] NOTISSUE
# 312 extremely slow take forever do it [[0.23360677]] ISSUE
# 313 study interest worst sin industrial design [[0.11558005]] ISSUE
# 314 thing happen track off [[0.21255189]] ISSUE
# 315 well make easy access phone have handy detachable belt clip [[0.9442648]] NOTISSUE
# 316 have continue pair periodically keep drop [[0.42373085]] ISSUE
# 317 not unload intone party [[0.13562639]] ISSUE
# 318 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.19640344]] ISSUE
# 319 truly awful [[0.38645753]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear out battery do [[0.26774603]] ISSUE
# 321 volume ringer real good you have choice loud one [[0.9150232]] NOTISSUE
# 322 none tone acceptable [[0.17368051]] ISSUE
# 323 camera color balance awful [[0.58421415]] NOTISSUE
# 324 product clearly not ready prime time do netware cool look not tell call come worthless [[0.0422674]] ISSUE
# 325 love intone upbeat [[0.8482904]] NOTISSUE
# 326 chinese forgery abound [[0.66667324]] NOTISSUE
# 327 easy pair samsung cell [[0.9354116]] NOTISSUE
# 328 instruction not explain microphone jack be use [[0.1378353]] ISSUE
# 329 advise not purchase item never work well [[0.40260607]] ISSUE
# 330 bad have pay month service [[0.10187196]] ISSUE
# 331 work well [[0.86083066]] NOTISSUE
# 332 nokia ca 42 usb cable not work phone [[0.21459144]] ISSUE
# 333 clear crisp sound [[0.73401296]] NOTISSUE
# 334 have use smallest earpiece provide stay pretty well [[0.9611423]] NOTISSUE
# 335 biggest complaint have be battery drain superfast [[0.14767674]] ISSUE
# 336 design be ergonomic theory not stand have ear [[0.23145202]] ISSUE
# 337 do not buy want use holster [[0.15321879]] ISSUE
# 338 phone take great picture video clip [[0.96833014]] NOTISSUE
# 339 do normale look cool [[0.51899767]] NOTISSUE
# 340 ear occupy background not distract all [[0.14731747]] ISSUE
# 341 comfortable fit need headset be comfortable hour time not entire day [[0.8770947]] NOTISSUE
# 342 also phone do not seem accept cbr mp s preferably rip window medium player [[0.34090388]] ISSUE
# 343 not beat price these [[0.39317268]] ISSUE
# 344 come strong light use light camera shot flash so signal seriously [[0.15303746]] ISSUE
# 345 lightweight work well [[0.96439826]] NOTISSUE
# 346 beware [[0.2638442]] ISSUE
# 347 love cable allow connect mini usb device pc [[0.9206999]] NOTISSUE
# 348 near hear conversation [[0.43758693]] ISSUE
# 349 cool case open allow screen get scratch up one [[0.4091317]] ISSUE
# 350 buy phone replacement start have regret since [[0.22987218]] ISSUE
# 351 appear actually outperform original battery china come a325 i [[0.7017166]] NOTISSUE
# 352 not store phone number sim [[0.3464767]] ISSUE
# 353 last o minute actually try use phone my wife have phone problem [[0.3132281]] ISSUE
# 354 poor quality [[0.21497768]] ISSUE
# 355 cabra ear gel r best [[0.71604335]] NOTISSUE
# 356 not worth it [[0.29851308]] ISSUE
# 357 phone crash completely have get replace [[0.10619504]] ISSUE
# 358 quit work have use eighteen month purchase one best headset have own [[0.5991832]] NOTISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.36458853]] ISSUE
# 360 great phone [[0.9706753]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.05665549]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.93016756]] NOTISSUE
# 363 phone do notslide car grip prevent phone slip hand [[0.34218982]] ISSUE
# 364 simply best bluetooth headset sound quality [[0.9766292]] NOTISSUE
# 365 think plan one this sure moto phone me [[0.67638314]] NOTISSUE
# 366 span hour have two people exclaim whoa new phone tv [[0.42922905]] ISSUE
# 367 have use cord headset freedom wireless helpful [[0.97711074]] NOTISSUE
# 368 case have pas one year mark show sign wear 100 functional [[0.30341446]] ISSUE
# 369 that leather nice soft fit tight cut face good shape [[0.97646546]] NOTISSUE
# 370 have everything need task more [[0.83690995]] NOTISSUE
# 371 receive product two day break [[0.3049332]] ISSUE
# 372 product great make work lot easier go copier wait hold something [[0.6178574]] NOTISSUE
# 373 none size send headset stay ear [[0.3942946]] ISSUE
# 374 t mobile have best customer service anywhere [[0.95893884]] NOTISSUE
# 375 arrive quickly expensive be sell [[0.28862]] ISSUE
# 376 have try two unit fail two month pro [[0.21370856]] ISSUE
# 377 provide good protection look classy too [[0.98598236]] NOTISSUE
# 378 russel good [[0.9182089]] NOTISSUE
# 379 tracfonewebsite user friendly make easy activate etc [[0.9039578]] NOTISSUE
# 380 design good 4 [[0.94176966]] NOTISSUE
# 381 great reception time [[0.99004644]] NOTISSUE
# 382 highly recommend product [[0.8035125]] NOTISSUE
# 383 house unit sunglass not good texas [[0.53057915]] NOTISSUE
# 384 dit not work time nokia 5320 [[0.43737352]] ISSUE
# 385 buy mainly charger break soon purchase [[0.64853686]] NOTISSUE
# 386 like loud buzz override conversation phone you [[0.5261726]] NOTISSUE
# 387 fantastic buy get again phone [[0.97609496]] NOTISSUE
# 388 stay away store be careful [[0.311257]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.9573268]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.9114545]] NOTISSUE
# 391 light have plenty battery capacity comfortable wear somewhat extend period time [[0.9292716]] NOTISSUE
# 392 disappoint [[0.20872849]] ISSUE
# 393 blue ant easy use [[0.62799925]] NOTISSUE
# 394 cheap hey work [[0.780376]] NOTISSUE
# 395 pleasantly suprised give low cost item [[0.4188886]] ISSUE
# 396 camera phone be use dustpan indoors have be disposable this [[0.38218668]] ISSUE
# 397 day later puff smoke come phone use [[0.1688569]] ISSUE
# 398 convenient simple use get job make car ride smoother [[0.5607767]] NOTISSUE
# 399 nano state it my son disappoint [[0.23722741]] ISSUE
# 400 sound quality excellent well [[0.9976489]] NOTISSUE
# 401 best headset have use [[0.837299]] NOTISSUE
# 402 not recommend [[0.3105357]] ISSUE
# 403 have be year carry highest quality anti glare screen protector have find date [[0.7021653]] NOTISSUE
# 404 want [[0.51077384]] NOTISSUE
# 405 particular model not work motorola q smartphone [[0.54615575]] NOTISSUE
# 406 wont work right at least me [[0.47301912]] ISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.7178984]] NOTISSUE
# 408 out warranty problem reoccure bottom line money else singular not support it [[0.15624553]] ISSUE
# 409 want plantronics five ten be right one have issue me the good [[0.7056334]] NOTISSUE
# 410 crisp clear [[0.6883423]] NOTISSUE
# 411 charge keep go dead minute [[0.17483889]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.17766939]] ISSUE
# 413 get absolutely horrible reception apartment phone have not have problem [[0.1677254]] ISSUE
# 414 reception have be generally good [[0.7800072]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.9933137]] NOTISSUE
# 416 great bluetooth [[0.99056846]] NOTISSUE
# 417 highly recommend case [[0.7664312]] NOTISSUE
# 418 worthwhile [[0.5798727]] NOTISSUE
# 419 phone get be year old be slowly break despite care part [[0.2615082]] ISSUE
# 420 be sorry make purchase [[0.17933093]] ISSUE
# 421 buy hop make bluetooth headset fit better thing make impossible wear [[0.54599816]] NOTISSUE
# 422 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.17284726]] ISSUE
# 423 horrible [[0.06588074]] ISSUE
# 424 allow possibility double book date time first [[0.40040293]] ISSUE
# 425 work two week break [[0.36844015]] ISSUE
# 426 do not think hold securely belt [[0.23069152]] ISSUE
# 427 simple use like it [[0.77939993]] NOTISSUE
# 428 great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.7915946]] NOTISSUE
# 429 not use case smell disgust [[0.04651244]] ISSUE
# 430 not want [[0.23395056]] ISSUE
# 431 two case order another [[0.4064806]] ISSUE
# 432 buy battery coupon amazon be happy purchase [[0.94796824]] NOTISSUE
# 433 internet access fine rare instance work [[0.8901585]] NOTISSUE
# 434 perfect p [[0.78980935]] NOTISSUE
# 435 five star plus plus [[0.85710174]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end other me [[0.8694546]] NOTISSUE
# 437 50 drain [[0.2301619]] ISSUE
# 438 try talk real loud shout telephone get old tell not great [[0.36162686]] ISSUE
# 439 good work fine [[0.9806364]] NOTISSUE
# 440 price great deal [[0.97514445]] NOTISSUE
# 441 great price too [[0.93394345]] NOTISSUE
# 442 wind completely useless [[0.06457166]] ISSUE
# 443 yes shiny love it [[0.9847595]] NOTISSUE
# 444 do not work [[0.203599]] ISSUE
# 445 think get good deal 7 44 plug phone v see razor [[0.49538255]] ISSUE
# 446 reception headset excellent [[0.9703563]] NOTISSUE
# 447 two thumb seller [[0.3842912]] ISSUE
# 448 have version lg phone work well together good reception range exceed twenty foot line sight [[0.9829336]] NOTISSUE
# 449 improper description have return it [[0.24775419]] ISSUE
# 450 1 work 2 comfortable [[0.87858874]] NOTISSUE
# 451 battery charge life long [[0.68734884]] NOTISSUE
# 452 cabra largely fit ear well [[0.5536778]] NOTISSUE
# 453 battery have no life [[0.37505135]] ISSUE
# 454 check no feature disappoint [[0.14059529]] ISSUE
# 455 product exactly describe [[0.38091746]] ISSUE
# 456 get signal version phone wo not [[0.07786583]] ISSUE
# 457 do not job [[0.14022328]] ISSUE
# 458 recommend it [[0.7231641]] NOTISSUE
# 459 plan order again again [[0.51965123]] NOTISSUE
# 460 be say phone camera nice cool effect play with video decent well [[0.986909]] NOTISSUE
# 461 have be satisfy cell phone day one [[0.5238023]] NOTISSUE
# 462 keep get better better this one have have numerous palm too [[0.58482546]] NOTISSUE
# 463 awkward use unreliable [[0.074807]] ISSUE
# 464 ship time quick [[0.56637174]] NOTISSUE
# 465 not good have hop [[0.43897632]] ISSUE
# 466 good case [[0.8718755]] NOTISSUE
# 467 do network [[0.2890685]] ISSUE
# 468 good product [[0.90804297]] NOTISSUE
# 469 unfortunately not work [[0.22455934]] ISSUE
# 470 break two month use [[0.27979934]] ISSUE
# 471 dont buy it [[0.5747499]] NOTISSUE
# 472 father have -265 battery die [[0.24861588]] ISSUE
# 473 however ear pad come easily one week lose one [[0.24400026]] ISSUE
# 474 call drop phone come will screen go black worst stop ring intermittently [[0.06624302]] ISSUE
# 475 horrible horrible protector [[0.05170212]] ISSUE
# 476 do notice nokia either [[0.11618637]] ISSUE
# 477 reach row uncomfortable [[0.2189241]] ISSUE
# 478 have buy nokia cell phone week ago nightmare [[0.17327106]] ISSUE
# 479 take long describe bad customer service experience have be amazon [[0.34950954]] ISSUE
# 480 disappoint thing no speakerphone [[0.17620312]] ISSUE
# 481 terrible car not accept cassette [[0.06491446]] ISSUE
# 482 product useless do not have charge current charge two cellphone [[0.16554363]] ISSUE
# 483 not say be [[0.18806693]] ISSUE
# 484 stay away q [[0.56431895]] NOTISSUE
# 485 use dirty [[0.06857916]] ISSUE
# 486 unreliable service t mobile [[0.36170897]] ISSUE
# 487 not good price [[0.5322966]] NOTISSUE
# 488 buy two charge [[0.46577296]] ISSUE
# 489 look nice [[0.9231981]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.9947731]] NOTISSUE
# 491 have read review have note problem it [[0.26066297]] ISSUE
# 492 product cover important light sensor ear outlet [[0.4233336]] ISSUE
# 493 comfortable hand [[0.9184346]] NOTISSUE
# 494 do not work [[0.203599]] ISSUE
# 495 poor reliability [[0.10934949]] ISSUE
# 496 work [[0.6569058]] NOTISSUE
# 497 take picture battery drop bar start beep let know din [[0.1479339]] ISSUE
# 498 terrible product waste money [[0.0652774]] ISSUE
# 499 time buy you [[0.71199334]] NOTISSUE
# 500 waste money [[0.1288316]] ISSUE
# 501 far have work like charm [[0.88286]] NOTISSUE
# 502 have have week far good [[0.77267486]] NOTISSUE
# 503 but case best be download picture laptop ir send picture laptop phone [[0.72971725]] NOTISSUE
# 504 recommend item [[0.5864047]] NOTISSUE
# 505 be choice headset year great sound good volume good noise cancellation [[0.9963476]] NOTISSUE
# 506 nice case feel good hand [[0.98093194]] NOTISSUE
# 507 item receive counterfeit [[0.31060275]] ISSUE
# 508 good far probably best bt headset have have [[0.93892]] NOTISSUE
# 509 work fine [[0.8336279]] NOTISSUE
# 510 receive headset good time happy it [[0.99196965]] NOTISSUE
# 511 please see replace well trail swivel holster blackberry flip [[0.6780236]] NOTISSUE
# 512 sister have one love it [[0.9371969]] NOTISSUE
# 513 good quality [[0.95537317]] NOTISSUE
# 514 far worst purchase have make amazon [[0.20741601]] ISSUE
# 515 excellent dual purpose headset [[0.97735757]] NOTISSUE
# 516 excellent [[0.9550924]] NOTISSUE
# 517 do not work listen music singular 8125 [[0.35007706]] ISSUE
# 518 seem completely secure hold belt keep phone inside [[0.41519204]] ISSUE
# 519 bottom line another worthless cheap gimmick sprint [[0.20475161]] ISSUE
# 520 have trouble volume [[0.29911202]] ISSUE
# 521 good thing fit comfortably small ear [[0.97511286]] NOTISSUE
# 522 warn do not buy [[0.09610253]] ISSUE
# 523 be pair phone not be happier far [[0.39046377]] ISSUE
# 524 open battery connection break device turn off [[0.18480834]] ISSUE
# 525 not want clip go ear cause discomfort [[0.07614782]] ISSUE
# 526 best headset ever [[0.8895612]] NOTISSUE
# 527 do not trust webster do not expect helpful support [[0.2282837]] ISSUE
# 528 loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.34569383]] ISSUE
# 529 speaker low quality make ring tone sound cheap [[0.5269059]] NOTISSUE
# 530 fit comfortably come size earn tip [[0.836691]] NOTISSUE
# 531 bad reception [[0.08985005]] ISSUE
# 532 product high quality chinese crap [[0.5417612]] NOTISSUE
# 533 comfortable ear [[0.8841439]] NOTISSUE
# 534 do notably product fail [[0.12171529]] ISSUE
# 535 everything product wrong first [[0.27898556]] ISSUE
# 536 pair two device easy barely take couple minute start make call voice deal feature [[0.6561281]] NOTISSUE
# 537 utterly confuse first cause lose couple very important contact [[0.43095094]] ISSUE
# 538 terrible phone holder [[0.19016929]] ISSUE
# 539 cutout button place perfectly [[0.9323821]] NOTISSUE
# 540 love be able use one headset land line cell [[0.63548017]] NOTISSUE
# 541 problem ear loop make weak material break easily [[0.09032508]] ISSUE
# 542 not nearly good look amazon picture make look [[0.60342383]] NOTISSUE
# 543 despite flaw case exceptional quality well worth additional cost own official oem product [[0.81437886]] NOTISSUE
# 544 stupid that [[0.10494649]] ISSUE
# 545 hear be drive car usually do steven have loudest set [[0.43006554]] ISSUE
# 546 seller ship quickly cheaper competitor [[0.45349106]] ISSUE
# 547 good show samsung [[0.9579432]] NOTISSUE
# 548 buy ten save a lot money [[0.5453274]] NOTISSUE
# 549 cut make beep beep beep sound say signal fail [[0.0359778]] ISSUE
# 550 configure [[0.6040493]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word be say it [[0.13802813]] ISSUE
# 552 have take battery phone back restart it [[0.49975193]] ISSUE
# 553 manage bend leaf spring back place metal have stress break drop [[0.1014037]] ISSUE
# 554 leopard print wonderfully wild [[0.9011649]] NOTISSUE
# 555 work me [[0.78769046]] NOTISSUE
# 556 saggy floppy piece junk [[0.23345342]] ISSUE
# 557 better hard plastic case [[0.47618547]] ISSUE
# 558 have new problem [[0.4472239]] ISSUE
# 559 happy far [[0.8179244]] NOTISSUE
# 560 cool phone [[0.77750146]] NOTISSUE
# 561 work good [[0.93859905]] NOTISSUE
# 562 motorola finally get voice quality bluetooth headset right [[0.92131144]] NOTISSUE
# 563 loose connection phone couple foot two [[0.4119977]] ISSUE
# 564 great recommend [[0.9769896]] NOTISSUE
# 565 make easier keep bluetooth be not wear it [[0.37307513]] ISSUE
# 566 say above pretty useless [[0.16120598]] ISSUE
# 567 never get it [[0.40515572]] ISSUE
# 568 pair headphone worst have have sound wise [[0.4145322]] ISSUE
# 569 drain weak snap [[0.05770548]] ISSUE
# 570 do not charge singular att eight thousand five twenty five phone [[0.31268334]] ISSUE
# 571 get extra minute carry call not get cut off [[0.05299363]] ISSUE
# 572 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.11967603]] ISSUE
# 573 keep catch cable seat have pull phone turn off [[0.14804682]] ISSUE
# 574 headset fulfil requirement be happy purchase [[0.8990638]] NOTISSUE
# 575 logitech bluetooth headset 10 [[0.9332884]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.26156986]] ISSUE
# 577 lot webster have be rat good phone do i [[0.5890498]] NOTISSUE
# 578 have try cable computer pod work fine [[0.7130674]] NOTISSUE
# 579 mic joke volume low [[0.2104506]] ISSUE
# 580 be return them [[0.4917582]] ISSUE
# 581 do not maintain connection computer lap [[0.24195652]] ISSUE
# 582 easy turn car volume control accessible [[0.7533363]] NOTISSUE
# 583 have have year christmas buy rest family [[0.7200256]] NOTISSUE
# 584 otherwise easy install use clear sound [[0.31939012]] ISSUE
# 585 nice leather [[0.9175312]] NOTISSUE
# 586 have purchase different case [[0.71905726]] NOTISSUE
# 587 joy use [[0.9115684]] NOTISSUE
# 588 disappoint company [[0.2316964]] ISSUE
# 589 satisfy that [[0.59912133]] NOTISSUE
# 590 not charge me [[0.29574442]] ISSUE
# 591 phone get 2005 buy s740 say wow [[0.65487367]] NOTISSUE
# 592 button small [[0.6123012]] NOTISSUE
# 593 read spec make say wow [[0.5424264]] NOTISSUE
# 594 love it great armband [[0.98982275]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.52908236]] NOTISSUE
# 596 however keypad tinny reach wrong button [[0.20294653]] ISSUE
# 597 exchange sony ericson z five be pretty happy decision [[0.9677979]] NOTISSUE
# 598 impress price case [[0.51244843]] NOTISSUE
# 599 make easier hold to [[0.3671342]] ISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.9828418]] NOTISSUE
# 601 pretty easy [[0.9469261]] NOTISSUE
# 602 make call certain place [[0.37557396]] ISSUE
# 603 however girl complain time phone do netware like normal phone do [[0.08842955]] ISSUE
# 604 beautiful style though [[0.9712017]] NOTISSUE
# 605 company charge restock fee not give refund back [[0.10949518]] ISSUE
# 606 be try return refund [[0.25701165]] ISSUE
# 607 plug find not darn thing work [[0.51482546]] NOTISSUE
# 608 excellent product [[0.97327876]] NOTISSUE
# 609 earn piece break easily [[0.30361703]] ISSUE
# 610 lousy product [[0.23482987]] ISSUE
# 611 phone try hard do everything fail ability be phone [[0.24224986]] ISSUE
# 612 best charger have see market yet [[0.9072889]] NOTISSUE
# 613 sweetest phone [[0.54936886]] NOTISSUE
# 614 oh charger seem work fine [[0.83808357]] NOTISSUE
# 615 fit securely ear hook do not need be use sound better direct ear canal [[0.20715833]] ISSUE
# 616 not volume [[0.23456638]] ISSUE
# 617 echo problem very unsatisfactory [[0.1191337]] ISSUE
# 618 take two video time quality poor [[0.20832483]] ISSUE
# 619 do not waste money [[0.06246257]] ISSUE
# 620 be go have be negatively review product [[0.2030519]] ISSUE
# 621 adapter do not provide charge current [[0.17702262]] ISSUE
# 622 hype phone assume best mistake [[0.34155285]] ISSUE
# 623 take picture case sense cover [[0.46258464]] ISSUE
# 624 phone fall easily [[0.26448458]] ISSUE
# 625 network people not hear talk [[0.1595159]] ISSUE
# 626 text message feature tricky use [[0.57535774]] NOTISSUE
# 627 be disappoint have charger do network [[0.22102699]] ISSUE
# 628 painful ear [[0.23201987]] ISSUE
# 629 last one day blow up [[0.15141107]] ISSUE
# 630 disappoint [[0.20872849]] ISSUE
# 631 kind flop around [[0.22280852]] ISSUE
# 632 screen do get smudge easily touch ear face [[0.17533886]] ISSUE
# 633 piece junk lose call phone [[0.1994749]] ISSUE
# 634 item do not match picture [[0.12938164]] ISSUE
# 635 thing disappoint infra red port ira [[0.19213074]] ISSUE
# 636 not answer call unit never work once [[0.23593488]] ISSUE
# 637 unsatisfactory [[0.17187873]] ISSUE
# 638 product great [[0.9658956]] NOTISSUE
# 639 have this [[0.56759155]] NOTISSUE
# 640 have be work good no problem [[0.49999177]] ISSUE
# 641 oh dangerous [[0.337649]] ISSUE
# 642 sorry [[0.13439868]] ISSUE
# 643 be sorry [[0.13326983]] ISSUE
# 644 pardon [[0.4412919]] ISSUE
# 645 help help [[0.65752405]] NOTISSUE
# 646 no no dangerous [[0.04529398]] ISSUE
# 647 extremely dangerous [[0.32233402]] ISSUE
# 648 dangerous [[0.21021424]] ISSUE
# 649 dangerous young man [[0.5551097]] NOTISSUE
# 650 dangerous brutal [[0.0446099]] ISSUE
# 651 honestly dangerous [[0.21023773]] ISSUE
# 652 work [[0.6569058]] NOTISSUE
# 653 dead hard work [[0.33849972]] ISSUE
# 654 fact family mary wed [[0.65050215]] NOTISSUE
# 655 have be busy [[0.52519614]] NOTISSUE
# 656 go back again [[0.55812943]] NOTISSUE
# 657 be be busy [[0.5071595]] NOTISSUE
# 658 think yesterday [[0.48580575]] ISSUE
# 659 do think get one [[0.31726745]] ISSUE
# 660 oh yes [[0.773372]] NOTISSUE
# 661 one thing want talk [[0.30159593]] ISSUE
# 662 well honestly do not know have noreen discussion [[0.27165675]] ISSUE
# 663 course be come tomorrow [[0.5821058]] NOTISSUE
# 664 have noreen think away weekend [[0.31117943]] ISSUE
# 665 hello [[0.68753123]] NOTISSUE
# 666 mean young man [[0.46876422]] ISSUE
# 667 goodbye [[0.49102256]] ISSUE
# 668 alright [[0.49102256]] ISSUE
# 669 do need money urgently [[0.24863692]] ISSUE
# 670 business [[0.44144127]] ISSUE
# 671 work day [[0.59899324]] NOTISSUE
# 672 work [[0.6569058]] NOTISSUE
# 673 do work [[0.39643466]] ISSUE
# 674 be work day [[0.58409]] NOTISSUE
# 675 work saturday [[0.6569058]] NOTISSUE
# 676 know work [[0.6913775]] NOTISSUE
# 677 horrible customer service [[0.15868191]] ISSUE
# 678 fine product [[0.7356739]] NOTISSUE
# 679 glad pay money it [[0.3972708]] ISSUE
# 680 worst version adobe illustrator be release version nine [[0.30711803]] ISSUE
# 681 not save mysterious reason [[0.12761374]] ISSUE
# 682 crash [[0.17448609]] ISSUE
# 683 open file have be year write scribble untenable save version [[0.18653353]] ISSUE
# 684 assume adobe customer service be professional quick [[0.7735812]] NOTISSUE
# 685 have call time past two week have have wait minimum twenty three minute speak someone [[0.14109598]] ISSUE
# 686 finally get product send mac version personal computer version purchase [[0.57481796]] NOTISSUE
# 687 call again wait approximately thirty minute get customer help [[0.21795042]] ISSUE
# 688 have not receive personal computer version [[0.2985482]] ISSUE
# 689 call center service worst customer service have deal [[0.23180316]] ISSUE
# 690 have deal bad customer service [[0.13641776]] ISSUE
# 691 six extremely frustrate hour [[0.41000718]] ISSUE
# 692 do not have problem software [[0.20863043]] ISSUE
# 693 reverse error be nightmare [[0.03314648]] ISSUE
# 694 pretty do need [[0.62221926]] NOTISSUE
# 695 point customer service rep nice [[0.8415224]] NOTISSUE
# 696 do not have infrastructure provide basic level service [[0.3480616]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.3902323]] ISSUE
# 698 do not send receipt [[0.07246958]] ISSUE
# 699 receipt get copy invoice not format print correctly [[0.14708097]] ISSUE
# 700 disturb people suppose be account expert [[0.27836633]] ISSUE
# 701 start look alternative intuit obviously do not understand basic account audit principle [[0.16227892]] ISSUE
# 702 thoroughly disappoint [[0.19700496]] ISSUE
# 703 be not do business company anymore give bad support [[0.05795521]] ISSUE
# 704 online information exactly have cd [[0.72761047]] NOTISSUE
# 705 have not send coupon [[0.17487527]] ISSUE
# 706 bad [[0.04325215]] ISSUE
# 707 save money do not subscribe extend service [[0.15253016]] ISSUE
# 708 use customer service technical support give answer vaguely relate problem [[0.35105607]] ISSUE
# 709 be emailinc time get nowhere [[0.53859544]] NOTISSUE
# 710 largest technical software company world [[0.72034055]] NOTISSUE
# 711 have no technical support [[0.2878993]] ISSUE
# 712 worthless product horrible customer service [[0.0866887]] ISSUE
# 713 unable access internet [[0.403342]] ISSUE
# 714 no problem system become slow [[0.04066239]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.2585913]] ISSUE
# 716 reputation become exasperate script suggestion not resolve problem [[0.13279451]] ISSUE
# 717 feel bite fleece over price subscription renewal year [[0.3857757]] ISSUE
# 718 decide give try [[0.5184261]] NOTISSUE
# 719 installation go smoothly everything seem fine [[0.7597502]] NOTISSUE
# 720 stall blank screen right window [[0.49493945]] ISSUE
# 721 hang forever [[0.42929003]] ISSUE
# 722 well present [[0.79922193]] NOTISSUE
# 723 easy follow along easy revisit previous lesson [[0.46918672]] ISSUE
# 724 video illustrate fretboard help see hear song be play [[0.7083157]] NOTISSUE
# 725 not lot depth material [[0.24248073]] ISSUE
# 726 sing be slight destruction sometimes [[0.23526753]] ISSUE
# 727 material song not be everyone like [[0.4092551]] ISSUE
# 728 have find music book useful [[0.9443903]] NOTISSUE
# 729 probably not recommend be source learn guitar [[0.54627496]] NOTISSUE
# 730 like new look [[0.7663475]] NOTISSUE
# 731 i be have problem make transition [[0.35344592]] ISSUE
# 732 look create doom half life 2 not recommend program [[0.32913148]] ISSUE
# 733 want make advance fps game simple pong game recommend dark basic [[0.65448195]] NOTISSUE
# 734 dark basic professional probably capable create kind game come with [[0.9846955]] NOTISSUE
# 735 have deal bad customer service [[0.13641776]] ISSUE
# 736 dark basic make manipulate d data extremely easy [[0.7293503]] NOTISSUE
# 737 have program yourself scratch [[0.55762273]] NOTISSUE
# 738 recommend [[0.61207235]] NOTISSUE
# 739 software easy install easy use [[0.91299003]] NOTISSUE
# 740 wonderful software [[0.9836504]] NOTISSUE
# 741 buy cd [[0.75796545]] NOTISSUE
# 742 do not waste money subscription merriam webster webster [[0.15053809]] ISSUE
# 743 software user friendly [[0.89094985]] NOTISSUE
# 744 superb [[0.9331465]] NOTISSUE
# 745 try medical dictionary [[0.5609722]] NOTISSUE
# 746 surprise find offer option strip code [[0.6335204]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.2707232]] ISSUE
# 748 evolution [[0.51329005]] NOTISSUE
# 749 do offer major improvement flexibility previous version [[0.3213995]] ISSUE
# 750 good [[0.89099646]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.94820744]] NOTISSUE
# 752 horribly bad [[0.01496289]] ISSUE
# 753 good be able tweak dozen standard compliance [[0.5824315]] NOTISSUE
# 754 default thing not set up do take learn [[0.22585882]] ISSUE
# 755 move p100 fairly advance feature [[0.7364604]] NOTISSUE
# 756 anyhow have call para professional version [[0.6100841]] NOTISSUE
# 757 have way flexibility functionality version [[0.92163736]] NOTISSUE
# 758 go bye bye [[0.6988535]] NOTISSUE
# 759 be please product [[0.49271953]] ISSUE
# 760 have trial version instal computer buy it [[0.5414391]] NOTISSUE
# 761 have do enter code box [[0.14634517]] ISSUE
# 762 easy [[0.78738046]] NOTISSUE
# 763 be glad able install one computer [[0.5476832]] NOTISSUE
# 764 today best office suite microsoft have own [[0.8989883]] NOTISSUE
# 765 easy use excellent result [[0.9524077]] NOTISSUE
# 766 great sw [[0.93780285]] NOTISSUE
# 767 easy learn [[0.8533265]] NOTISSUE
# 768 have good graphic [[0.81036353]] NOTISSUE
# 769 help visualize space [[0.772364]] NOTISSUE
# 770 see d [[0.46979558]] ISSUE
# 771 have configure do [[0.40956512]] ISSUE
# 772 difficult change room be house overall style start give design [[0.5466154]] NOTISSUE
# 773 recently buy version [[0.74657756]] NOTISSUE
# 774 instal software [[0.5641027]] NOTISSUE
# 775 everything operate well old personal computer [[0.7097247]] NOTISSUE
# 776 run lot faster [[0.40860292]] ISSUE
# 777 access corporate entrant [[0.37989825]] ISSUE
# 778 awesome [[0.9526909]] NOTISSUE
# 779 give whirl [[0.5866075]] NOTISSUE
# 780 have buy product again [[0.66294783]] NOTISSUE
# 781 five star them [[0.7651351]] NOTISSUE
# 782 great company deal [[0.9824923]] NOTISSUE
# 783 agree window improve thier product [[0.35523638]] ISSUE
# 784 linx not user friendly [[0.5550579]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.25500554]] ISSUE
# 786 unix far stable [[0.64870924]] NOTISSUE
# 787 have access cd version [[0.8262004]] NOTISSUE
# 788 like [[0.6055013]] NOTISSUE
# 789 work well me [[0.92230386]] NOTISSUE
# 790 usually go disc want attempt [[0.1692032]] ISSUE
# 791 lot cd [[0.8162321]] NOTISSUE
# 792 great program child learn difference [[0.9747754]] NOTISSUE
# 793 fun excellent way learn math [[0.99900335]] NOTISSUE
# 794 child love do too [[0.43757635]] ISSUE
# 795 fun way keep brain work [[0.98645055]] NOTISSUE
# 796 marvelous [[0.93055016]] NOTISSUE
# 797 memory improvement software marvelous [[0.9469711]] NOTISSUE
# 798 help improve memory provide motivate game [[0.8628154]] NOTISSUE
# 799 highly recommend [[0.77496356]] NOTISSUE
# 800 great [[0.95859045]] NOTISSUE
# 801 love software [[0.92953044]] NOTISSUE
# 802 word new disturb get high score [[0.31825644]] ISSUE
# 803 have be symantec customer year [[0.74253786]] NOTISSUE
# 804 year product get better better [[0.8551347]] NOTISSUE
# 805 not use product purpose [[0.26094425]] ISSUE
# 806 anti virus find problem personal computer fix you [[0.22214541]] ISSUE
# 807 anti virus clean unneeded file [[0.30335447]] ISSUE
# ...
# 3949 chip come drip grease not edible [[0.08596335]] ISSUE
# 3950 normally impress strip steak [[0.515146]] NOTISSUE
# 3951 have be go two thousand seven meal have be awesome [[0.93632376]] NOTISSUE
# 3952 server nice attentive serve staff [[0.9860065]] NOTISSUE
# 3953 cashier friendly bring food me [[0.88158005]] NOTISSUE
# 3954 work hospitality industry paradise valley have refrain recommend ciob longer [[0.5784064]] NOTISSUE
# 3955 atmosphere fun [[0.9711864]] NOTISSUE
# 3956 not recommend others [[0.25810376]] ISSUE
# 3957 service quick to go order like like it [[0.55289376]] NOTISSUE
# 3958 mean really do get famous fish chip terrible [[0.04945843]] ISSUE
# 3959 say mouth belly please [[0.33083317]] ISSUE
# 3960 not thing [[0.23793277]] ISSUE
# 3961 two thumb up [[0.436595]] ISSUE
# 3962 read please do no-go there [[0.10991149]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.93887925]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.9992544]] NOTISSUE
# 3965 have nice atmosphere [[0.967388]] NOTISSUE
# 3966 tonight have elk file special and suck [[0.33161983]] ISSUE
# 3967 one bite hook [[0.18031824]] ISSUE
# 3968 order old classic new dish go time sorely disappoint everything [[0.28235877]] ISSUE
# 3969 cute quaint simple honest [[0.8353153]] NOTISSUE
# 3970 chicken deliciously season have perfect fry outside moist chicken inside [[0.8593752]] NOTISSUE
# 3971 food great always compliment chef [[0.99407214]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.9758026]] NOTISSUE
# 3973 awesome selection beer [[0.9818034]] NOTISSUE
# 3974 great food awesome service [[0.9991072]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger six 8 not expect tip that [[0.2665272]] ISSUE
# 3976 fly apple juice fly [[0.2655389]] ISSUE
# 3977 now nan chicken tasty [[0.93631184]] NOTISSUE
# 3978 service think good [[0.92451346]] NOTISSUE
# 3979 food barely lukewarm have be sit wait server bring u [[0.12372464]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.27571672]] ISSUE
# 3981 nicest chinese restaurant have be while [[0.92959595]] NOTISSUE
# 3982 overall like food service [[0.66228724]] NOTISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.859616]] NOTISSUE
# 3984 probably never come back not recommend it [[0.25423172]] ISSUE
# 3985 friend pasta bad barely touch it [[0.19837445]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.9954817]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.8814977]] NOTISSUE
# 3988 never have complain here [[0.19021171]] ISSUE
# 3989 restaurant clean have family restaurant feel it [[0.8982259]] NOTISSUE
# 3990 way fry [[0.6661543]] NOTISSUE
# 3991 be not sure long stand long begin feel awkwardly place [[0.24107607]] ISSUE
# 3992 open sandwich impress not good way [[0.48886582]] ISSUE
# 3993 not be back [[0.22964403]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.956282]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.98842084]] NOTISSUE
# 3996 order vegetarian menu dinner have wide array option choose from [[0.95748055]] NOTISSUE
# 3997 have watch price inflate portion get smaller management attitude grow rapidly [[0.213952]] ISSUE
# 3998 wonderful little tapa ambience make feel warm fuzzy inside [[0.9802596]] NOTISSUE
# 3999 get enjoy seafood salad fabulous vinaigrette [[0.99931705]] NOTISSUE
# 4000 wonton thin not thick chewy melt mouth [[0.16400813]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.95577025]] NOTISSUE
# 4002 sit right time server get go fantastic [[0.8510851]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s up [[0.28105792]] ISSUE
# 4004 be town definitely be spot hit again [[0.5689402]] NOTISSUE
# 4005 have wait thirty minute get drink longer get two area [[0.2072244]] ISSUE
# 4006 great place eat [[0.9803052]] NOTISSUE
# 4007 jalapeno bacon soo good [[0.9691543]] NOTISSUE
# 4008 service poor [[0.13518162]] ISSUE
# 4009 food good service good price good [[0.99817693]] NOTISSUE
# 4010 price good [[0.8989326]] NOTISSUE
# 4011 price good [[0.8989326]] NOTISSUE
# 4012 service good [[0.914297]] NOTISSUE
# 4013 place not clean food oh stale [[0.06285772]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.315783]] ISSUE
# 4015 service bad [[0.05451848]] ISSUE
# 4016 be happy be here [[0.90302163]] NOTISSUE
# 4017 taste like dirt [[0.2466915]] ISSUE
# 4018 one place phoenix definately go back again [[0.6767911]] NOTISSUE
# 4019 block amaze [[0.7938825]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.9639851]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.58430463]] NOTISSUE
# 4022 hashemi poor quality be soggy tasteless [[0.01643344]] ISSUE
# 4023 great time family dinner sunday night [[0.99236214]] NOTISSUE
# 4024 food not tasty all not say real traditional hunan style [[0.29569897]] ISSUE
# 4025 bother me slow service [[0.10057972]] ISSUE
# 4026 flair bartender absolutely amaze [[0.9853888]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.37934926]] ISSUE
# 4028 good order twice [[0.8583453]] NOTISSUE
# 4029 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.06238132]] ISSUE
# 4030 girlfriend veal bad [[0.05617557]] ISSUE
# 4031 unfortunately not good [[0.3622688]] ISSUE
# 4032 have pretty satisfy experience [[0.94429183]] NOTISSUE
# 4033 join club get awesome offer email [[0.9787183]] NOTISSUE
# 4034 perfect me like beer ice cold case colder [[0.82108146]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.06048135]] ISSUE
# 4036 chain be no fan of beat place easily [[0.48780823]] ISSUE
# 4037 nacho have [[0.52189136]] NOTISSUE
# 4038 not be come back [[0.24173777]] ISSUE
# 4039 do not have word say place do everything pretty well [[0.4915831]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.96876615]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.99959344]] NOTISSUE
# 4042 receive pity huge have lot meat thumb there [[0.28199494]] ISSUE
# 4043 food arrive me [[0.53669184]] NOTISSUE
# 4044 pay 7 85 hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.602434]] NOTISSUE
# 4045 classic maine lobster roll fantastic [[0.98950595]] NOTISSUE
# 4046 brother law work mall eat day guess sick night too [[0.04835567]] ISSUE
# 4047 good be go have review place twice [[0.78706783]] NOTISSUE
# 4048 chip salsa good salsa fresh [[0.99460196]] NOTISSUE
# 4049 place great [[0.974999]] NOTISSUE
# 4050 mediocre food [[0.17923598]] ISSUE
# 4051 get inside be impress place [[0.5359646]] NOTISSUE
# 4052 service super friendly [[0.9311974]] NOTISSUE
# 4053 sad little vegetable overcook [[0.04645731]] ISSUE
# 4054 place nice surprise [[0.96359056]] NOTISSUE
# 4055 live music totally blow [[0.2623897]] ISSUE
# 4056 low quality sound [[0.7375301]] NOTISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                    look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6                 display excellent camera good year  NOTISSUE
#  7              7                                 battery life great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10           embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  average phone bad battery life operate weak ne...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18         try handsfree gadget one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution far comparably price phone ...     ISSUE
#  27            27                                         great deal  NOTISSUE
#  28            28              excellent product be satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4026        4026                  freeze margarita way sugary taste     ISSUE
#  4027        4027                                   good order twice  NOTISSUE
#  4028        4028  nutshell 1 restaurant smell like combination d...     ISSUE
#  4029        4029                                girlfriend veal bad     ISSUE
#  4030        4030                             unfortunately not good     ISSUE
#  4031        4031                     have pretty satisfy experience  NOTISSUE
#  4032        4032                  join club get awesome offer email  NOTISSUE
#  4033        4033          perfect me like beer ice cold case colder  NOTISSUE
#  4034        4034  bland flavourless good way describe barely tep...     ISSUE
#  4035        4035               chain be no fan of beat place easily     ISSUE
#  4036        4036                                         nacho have  NOTISSUE
#  4037        4037                                   not be come back     ISSUE
#  4038        4038  do not have word say place do everything prett...  NOTISSUE
#  4039        4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040        4040             great atmosphere friendly fast service  NOTISSUE
#  4041        4041        receive pity huge have lot meat thumb there  NOTISSUE
#  4042        4042                                     food arrive me     ISSUE
#  4043        4043  pay 7 85 hot dog fry look like come kid meal w...     ISSUE
#  4044        4044               classic maine lobster roll fantastic  NOTISSUE
#  4045        4045  brother law work mall eat day guess sick night...     ISSUE
#  4046        4046                 good be go have review place twice  NOTISSUE
#  4047        4047                        chip salsa good salsa fresh  NOTISSUE
#  4048        4048                                        place great  NOTISSUE
#  4049        4049                                      mediocre food     ISSUE
#  4050        4050                        get inside be impress place  NOTISSUE
#  4051        4051                             service super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                                place nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#  4055        4055                                  low quality sound     ISSUE
#
#  [4056 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4     NOTISSUE                    look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE       clear skye call long battery life long range
#  14    NOTISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE         try handsfree gadget one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25       ISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE              excellent product be satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4026     ISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell 1 restaurant smell like combination d...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                     have pretty satisfy experience
#  4032  NOTISSUE                  join club get awesome offer email
#  4033  NOTISSUE          perfect me like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE               chain be no fan of beat place easily
#  4036  NOTISSUE                                         nacho have
#  4037     ISSUE                                   not be come back
#  4038     ISSUE  do not have word say place do everything prett...
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE        receive pity huge have lot meat thumb there
#  4042  NOTISSUE                                     food arrive me
#  4043  NOTISSUE  pay 7 85 hot dog fry look like come kid meal w...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE  brother law work mall eat day guess sick night...
#  4046  NOTISSUE                 good be go have review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050  NOTISSUE                        get inside be impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#  4055  NOTISSUE                                  low quality sound
#
#  [4056 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4  NOTISSUE                    look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2144
# NOTISSUE    1912
# Name: label, dtype: int64

# %% [markdown]
# ### confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1787  247]
#  [ 357 1665]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8510848126232742
#               precision    recall  f1-score   support
#
#        ISSUE       0.83      0.88      0.86      2034
#     NOTISSUE       0.87      0.82      0.85      2022
#
#    micro avg       0.85      0.85      0.85      4056
#    macro avg       0.85      0.85      0.85      4056
# weighted avg       0.85      0.85      0.85      4056

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_V7.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                     not be happier
# 1        ISSUE   NOTISSUE                               solo technology suck
# 2     NOTISSUE      ISSUE                                       exactly want
# 3        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 4     NOTISSUE      ISSUE                                     prompt service
# 5     NOTISSUE      ISSUE                                     please headset
# 6        ISSUE   NOTISSUE  stupid have keep buy new charger car charger c...
# 7     NOTISSUE      ISSUE               phone have have have be cheaply make
# 8        ISSUE   NOTISSUE                            plastic break easy clip
# 9     NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 10    NOTISSUE      ISSUE               find cell phone right away enter car
# 11       ISSUE   NOTISSUE                                        low quality
# 12    NOTISSUE      ISSUE  do get better reception clarity phone have hav...
# 13    NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 14    NOTISSUE      ISSUE  have get defect not risk buy again build quali...
# 15    NOTISSUE      ISSUE                            nothing bad say headset
# 16    NOTISSUE      ISSUE  be glad find product amazon hard find not high...
# 17    NOTISSUE      ISSUE                               no buyer remorse one
# 18    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 19       ISSUE   NOTISSUE                                     like return it
# 20    NOTISSUE      ISSUE  keyboard worthwhile usefulness sturdy do not e...
# 21    NOTISSUE      ISSUE                                  wil not regret it
# 22       ISSUE   NOTISSUE                                  not user friendly
# 23       ISSUE   NOTISSUE                                  pretty piece junk
# 24    NOTISSUE      ISSUE                                      work describe
# 25    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 26       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 27    NOTISSUE      ISSUE  no shift no bubble no peel not scratch nothing...
# 28    NOTISSUE      ISSUE         virgin wireless rock do cheap little phone
# 29       ISSUE   NOTISSUE           look good quality headset keep look nott
# ..         ...        ...                                                ...
# 577      ISSUE   NOTISSUE  however recent experience particular location ...
# 578      ISSUE   NOTISSUE  salad have bland vinaigrette baby green heart ...
# 579      ISSUE   NOTISSUE                new location need complete overhaul
# 580      ISSUE   NOTISSUE  recently witness poor quality management towar...
# 581   NOTISSUE      ISSUE                                                rat
# 582      ISSUE   NOTISSUE                  look authentic thai food go where
# 583   NOTISSUE      ISSUE     oh god felt like have never eat thai food dish
# 584   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 585   NOTISSUE      ISSUE  make drive way north scottsdale not one bite d...
# 586      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 587      ISSUE   NOTISSUE                                 not fun experience
# 588   NOTISSUE      ISSUE        owner use work nob place similar half price
# 589   NOTISSUE      ISSUE                          promise wo not disappoint
# 590   NOTISSUE      ISSUE                                   not wait go back
# 591      ISSUE   NOTISSUE                           staff spend time talk me
# 592   NOTISSUE      ISSUE  price reasonable flavour spot on sauce home ma...
# 593      ISSUE   NOTISSUE                       normally impress strip steak
# 594   NOTISSUE      ISSUE                             say mouth belly please
# 595   NOTISSUE      ISSUE                                       two thumb up
# 596   NOTISSUE      ISSUE                                      one bite hook
# 597   NOTISSUE      ISSUE  one nice thing add gratuity bill party larger ...
# 598   NOTISSUE      ISSUE                           never have complain here
# 599      ISSUE   NOTISSUE                                            way fry
# 600   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 601   NOTISSUE      ISSUE  do not have word say place do everything prett...
# 602   NOTISSUE      ISSUE        receive pity huge have lot meat thumb there
# 603      ISSUE   NOTISSUE                                     food arrive me
# 604      ISSUE   NOTISSUE  pay 7 85 hot dog fry look like come kid meal w...
# 605   NOTISSUE      ISSUE                            live music totally blow
# 606      ISSUE   NOTISSUE                                  low quality sound
#
# [607 rows x 3 columns]
