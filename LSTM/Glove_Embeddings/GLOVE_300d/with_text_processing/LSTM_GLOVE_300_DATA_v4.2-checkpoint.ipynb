# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('../DATA/DATA_not_ameliorate.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                             I couldn't be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #balanced Dataset
# Out:
# ISSUE       2028
# NOTISSUE    2027
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4055, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 #'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 #'becomes',
 #'becoming',
 #'been',
 'before',
 'beforehand',
 #'behind',
 #'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 #'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 #'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 #'show',
 'side',
 'since',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 #'was',
 'we',
 #'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
        "couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re
# Out:
# C:\Users\khmar\ana\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def remove_alphanumerics(text):
    """
    Remove alphanumeric words from text
    Example: hello man whatsup123 => hello man
    Args:
        text (str): text
    Returns:
        text (str): text with removed alphanumeric words
    """
    txt = []
    for each in text.split():
        if not any(x in each.lower() for x in "0123456789"):
            txt.append(each)
    txtsent = " ".join(txt)
    return txtsent

##Fixing Word Lengthening
##https://rustyonrampa"ge.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    text = reduce_lengthening(text)
    text=remove_alphanumerics(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText("I have so 20 soooooo servic going  shawarrma grooooooooop")
# Out:
# 'have twenty soo service go shawarrma group'

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
#df=df[texts,tags]

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('../Data/DATA_preprocessing4.2.csv')

# %%
####

# %%
DATA_FILE = '../Data/DATA_preprocessing4.2.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2823, 3)
# (1232, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1412
# ISSUE       1411
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       617
# NOTISSUE    615
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1412
# ISSUE       1411
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
# Out:
# C:\Users\khmar\ana\lib\site-packages\keras_preprocessing\text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2823, 200)
# Shape of test_data tensor: (1232, 200)

# %%
import pickle
file_tok = '../Model/LSTM_token_glove_300d_DATA_wit_text_processing4.2.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3050 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2823, 200)
# Shape of data test tensor: (1232, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : flavourful
# word not found : appal
# word not found : cosiness
# word not found : shawarrma
# word not found : profiterole
# word not found : cheesecurds
# word not found : smashburger
# word not found : barset
# word not found : flipphones
# word not found : reoccure
# word not found : convolute
# word not found : stylize
# word not found : mesmerise
# word not found : brainsucking
# word not found : tigerlilly
# word not found : infatuate
# word not found : riingtones
# word not found : douchebaggery
# word not found : chipolte
# word not found : albondigas
# word not found : untasted
# word not found : ciob
# word not found : flavourless

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 23 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2823 samples, validate on 1232 samples
# Epoch 1/2
# 1792/2823 [==================>...........] - ETA: 14s - loss: 0.5559 - acc: 0.7254

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1267/1267 [==============================] - 4s 3ms/step
# loss: 41.10%
# acc: 82.16%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v4.2.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.95435935]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.44474038]]
# ISSUE

# %%
text=" very recommend"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend
# [[0.6101948]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='../DATA/DATA_preprocessing4.2.csv'
output_file ='../Model/LSTM_data_pred_glove_300_with_text_v4.2.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.6527379]] NOTISSUE
# 2 love phone [[0.8901014]] NOTISSUE
# 3 get well finish product [[0.70067215]] NOTISSUE
# 4 not be happier [[0.41493452]] ISSUE
# 5 be look headset long time have get [[0.63063097]] NOTISSUE
# 6 headset start ring no reason [[0.18249136]] ISSUE
# 7 display be excellent camera be good year [[0.99723876]] NOTISSUE
# 8 battery life be great [[0.98590904]] NOTISSUE
# 9 worst phone have have have month [[0.32002658]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.1367142]] ISSUE
# 11 be embarrass ear hurt try push ear plug ear [[0.1707845]] ISSUE
# 12 protect phone side [[0.6915295]] NOTISSUE
# 13 be average phone bad battery life operate weak network [[0.08406627]] ISSUE
# 14 clear skye call long battery life long range [[0.8588917]] NOTISSUE
# 15 solo technology suck [[0.47485673]] ISSUE
# 16 great hand free device [[0.98266023]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.8681841]] NOTISSUE
# 18 problem have mention [[0.1346125]] ISSUE
# 19 try handsfree gadget be one finally work well [[0.8621115]] NOTISSUE
# 20 magical help [[0.91294503]] NOTISSUE
# 21 worst piece crap version customer service [[0.08461244]] ISSUE
# 22 poor sound quality [[0.18178491]] ISSUE
# 23 best phone market [[0.81748855]] NOTISSUE
# 24 work well [[0.84460425]] NOTISSUE
# 25 company ship product promptly work well [[0.70330995]] NOTISSUE
# 26 exactly want [[0.5528534]] NOTISSUE
# 27 picture resolution be far comparably price phone offer today [[0.6724661]] NOTISSUE
# 28 be great deal [[0.95387745]] NOTISSUE
# 29 excellent product be satisfy purchase [[0.9696004]] NOTISSUE
# 30 highly recommend encourage people give try [[0.74358255]] NOTISSUE
# 31 better expect [[0.74323785]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.2989838]] ISSUE
# 33 great product price [[0.96706533]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.99430424]] NOTISSUE
# 35 disappointment [[0.17800072]] ISSUE
# 36 prompt service [[0.43107122]] ISSUE
# 37 excellent product price [[0.96713793]] NOTISSUE
# 38 please headset [[0.6036913]] NOTISSUE
# 39 do not waste money time [[0.06197126]] ISSUE
# 40 especially love long battery life [[0.9753592]] NOTISSUE
# 41 be stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.722556]] NOTISSUE
# 42 work great [[0.97000283]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.99544454]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice be bad service [[0.07266357]] ISSUE
# 45 be look new earpiece [[0.6774189]] NOTISSUE
# 46 be look new earpiece jawbone era be awesome too [[0.7205336]] NOTISSUE
# 47 receive white color battery go dead couple hour original use week last longer the replacement [[0.12264959]] ISSUE
# 48 year battery go completely dead headset [[0.28922582]] ISSUE
# 49 have use phone two year one be best [[0.72139674]] NOTISSUE
# 50 awesome new look fall [[0.9375245]] NOTISSUE
# 51 be phone have have have be cheaply make [[0.5137959]] NOTISSUE
# 52 att be not clear sound be distort have yell talk [[0.05426741]] ISSUE
# 53 price be good too [[0.6287983]] NOTISSUE
# 54 plastic break easy clip [[0.5906488]] NOTISSUE
# 55 do not make mistake do [[0.04250605]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.2441307]] ISSUE
# 57 be river spine with case fit fine [[0.9083275]] NOTISSUE
# 58 area unit break be not fond magnetic strap [[0.4285912]] ISSUE
# 59 overall be psyched have phone have appointment contact get great reception [[0.945207]] NOTISSUE
# 60 thing phone work perfectly like it [[0.94562244]] NOTISSUE
# 61 note phone s appearance be look bland especially black model [[0.19993289]] ISSUE
# 62 be easy [[0.7263582]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.20485821]] ISSUE
# 64 fantastic earphone [[0.9381868]] NOTISSUE
# 65 find cell phone right away enter car [[0.38673]] ISSUE
# 66 low quality [[0.47567153]] ISSUE
# 67 do get better reception clarity phone have have before [[0.6247637]] NOTISSUE
# 68 warn stay away [[0.2031607]] ISSUE
# 69 wish return unit get back money [[0.43532872]] ISSUE
# 70 awesome device work great [[0.9990146]] NOTISSUE
# 71 use talk one one hour battery be literally drain die [[0.05997584]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.09881646]] ISSUE
# 73 displease [[0.2577164]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.48173147]] ISSUE
# 75 make case small be difficult install [[0.33674183]] ISSUE
# 76 restore phone like new performance [[0.84877396]] NOTISSUE
# 77 recommend purchase cabra series two work flawlessly moto q go figure [[0.89823794]] NOTISSUE
# 78 search internet find one be best value [[0.8809887]] NOTISSUE
# 79 do not fit [[0.24530032]] ISSUE
# 80 happy product [[0.82288706]] NOTISSUE
# 81 screen size be big key pad light well enough camera quality be excellent camera phone [[0.99157363]] NOTISSUE
# 82 be nothing bad say headset [[0.09213833]] ISSUE
# 83 be glad find product amazon be hard find be not high price [[0.34310448]] ISSUE
# 84 portable work [[0.64052]] NOTISSUE
# 85 colleague get great reception a little expensive performance be great [[0.9879231]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.12251832]] ISSUE
# 87 have have problem phone read memory card turn again [[0.2016657]] ISSUE
# 88 not good wear hat sunglass [[0.58207405]] NOTISSUE
# 89 timely shipment quality product [[0.53735775]] NOTISSUE
# 90 nice solid keyboard [[0.972548]] NOTISSUE
# 91 well make fit surefire perfectly [[0.94762087]] NOTISSUE
# 92 horrible phone [[0.14973758]] ISSUE
# 93 battery junk [[0.30193916]] ISSUE
# 94 recommend others [[0.53132546]] NOTISSUE
# 95 cant get software work computer [[0.5326715]] NOTISSUE
# 96 disappoint [[0.22343262]] ISSUE
# 97 poor voice clarity [[0.36852992]] ISSUE
# 98 battery work great [[0.9819281]] NOTISSUE
# 99 no buyer remorse one [[0.07921749]] ISSUE
# 100 disappoint accessoryone [[0.20842674]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.3440495]] ISSUE
# 102 look great be strong [[0.9803411]] NOTISSUE
# 103 have have mobile service two year now be pretty happy it [[0.9345004]] NOTISSUE
# 104 update procedure be difficult cumbersome [[0.07146823]] ISSUE
# 105 disappointment hate go ear [[0.11612035]] ISSUE
# 106 great software motorola [[0.9417132]] NOTISSUE
# 107 delivery be time [[0.5256148]] NOTISSUE
# 108 easy use [[0.7162555]] NOTISSUE
# 109 uncomfortable ear do not use lg env [[0.23680064]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.46554828]] ISSUE
# 111 hold charge long time be reasonably comfortable long wear condition quality sound be tremendous [[0.89439774]] NOTISSUE
# 112 like return it [[0.57821244]] NOTISSUE
# 113 keyboard be worthwhile usefulness be sturdy do not expect problem [[0.34684783]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.30571425]] ISSUE
# 115 charge overnight battery work great [[0.9565487]] NOTISSUE
# 116 not regret it [[0.09072483]] ISSUE
# 117 love phone [[0.8901014]] NOTISSUE
# 118 disappointment [[0.17800072]] ISSUE
# 119 not user friendly [[0.64211696]] NOTISSUE
# 120 unfortunately ability actually know receive call be important feature phone be pitiful respect [[0.29819554]] ISSUE
# 121 exchange phone have problem [[0.5054552]] NOTISSUE
# 122 result phone be stick max volume mute [[0.3113713]] ISSUE
# 123 public display affection rock [[0.9008396]] NOTISSUE
# 124 be super charge use small hybrid palmtop camera cellphone excel role [[0.8934595]] NOTISSUE
# 125 definitely recommend cabra v look comfort clarity great price [[0.99639183]] NOTISSUE
# 126 have version two year ago like service [[0.6374423]] NOTISSUE
# 127 pretty piece junk [[0.44394302]] ISSUE
# 128 plug be wrong size [[0.21019356]] ISSUE
# 129 work describe [[0.5187627]] NOTISSUE
# 130 save money have have item month now [[0.43490115]] ISSUE
# 131 bad purchase [[0.12369452]] ISSUE
# 132 well im satisfy [[0.7876488]] NOTISSUE
# 133 bose noise cancel be amaze be important nec commuter [[0.62871164]] NOTISSUE
# 134 battery be excellent bargain [[0.9782007]] NOTISSUE
# 135 defective crap [[0.04748532]] ISSUE
# 136 have give no star be able [[0.4929833]] ISSUE
# 137 wear glass fit fine them [[0.8941169]] NOTISSUE
# 138 sound quality device be unacceptable unless quiet area hear nothing [[0.10822795]] ISSUE
# 139 not recommend item anyone [[0.18466948]] ISSUE
# 140 holster arrive not match photo ad [[0.22418313]] ISSUE
# 141 great no problem all [[0.7352126]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.17340977]] ISSUE
# 143 frog phone charm be adorable eye catch [[0.9437011]] NOTISSUE
# 144 never know push hard right number time function want not [[0.20458189]] ISSUE
# 145 sound be clear people talk amaze quality too [[0.3891311]] ISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.90233094]] NOTISSUE
# 147 good product well make [[0.9578989]] NOTISSUE
# 148 mobile phone tool have [[0.8881365]] NOTISSUE
# 149 be impress job motorola steadiness phone [[0.6702994]] NOTISSUE
# 150 receive order well ship timeframe everything be good work order overall be excite have source [[0.9036689]] NOTISSUE
# 151 phone be sturdy waterproof [[0.81137365]] NOTISSUE
# 152 be not impress not recommend item anyone [[0.0833196]] ISSUE
# 153 complaint be standard sound volume be little low turn [[0.09230114]] ISSUE
# 154 thank again amazon have thing need good price [[0.9163222]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.47831526]] ISSUE
# 156 have go store buy new nokia phone be work great [[0.9482367]] NOTISSUE
# 157 work great [[0.97000283]] NOTISSUE
# 158 ugly [[0.49163842]] ISSUE
# 159 horrible have switch time [[0.13861176]] ISSUE
# 160 noise shield be incredible [[0.8563728]] NOTISSUE
# 161 no real improvement [[0.20831387]] ISSUE
# 162 razor battery good buy [[0.9641173]] NOTISSUE
# 163 keep good work amazon [[0.95917237]] NOTISSUE
# 164 refuse refund replace [[0.09355023]] ISSUE
# 165 unfortunately be easy accidentally activate gentle touch button accidentally touch phone face listen [[0.7235975]] NOTISSUE
# 166 basically throw money window nothing [[0.0695915]] ISSUE
# 167 great case price [[0.93938136]] NOTISSUE
# 168 take be one drop six inch kitchen counter be crack i be not impress be not laugh [[0.05001201]] ISSUE
# 169 bluetooth range be good day ago leave phone trunk get call carry conversation hitch [[0.93175066]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.9988525]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.44731617]] ISSUE
# 172 none new one have work properly [[0.47702888]] ISSUE
# 173 be glad purchase it [[0.7424273]] NOTISSUE
# 174 have miss numerous call reason [[0.26500672]] ISSUE
# 175 phone be defective people hear use this [[0.17420582]] ISSUE
# 176 do not buy product [[0.16807777]] ISSUE
# 177 suck stuff do not work phone [[0.21203336]] ISSUE
# 178 no shift no bubble no peel not scratch [[0.06193527]] ISSUE
# 179 not be happier new one droid [[0.44619003]] ISSUE
# 180 worst software use give zero star would [[0.1746241]] ISSUE
# 181 try make call be exercise frustration [[0.11413159]] ISSUE
# 182 case be flimsy piece plastic have no protection whatsoever [[0.07353449]] ISSUE
# 183 cabra barset be happy it sound quality especially outgo be better [[0.8407549]] NOTISSUE
# 184 love camera be pretty good quality [[0.9969502]] NOTISSUE
# 185 thank great service [[0.9952685]] NOTISSUE
# 186 total package [[0.64628774]] NOTISSUE
# 187 seller be understand patient definitely buy again [[0.59767747]] NOTISSUE
# 188 give firefly one star i contact singular at t inform practice [[0.28775463]] ISSUE
# 189 be aggravate [[0.13419381]] ISSUE
# 190 great product price [[0.96706533]] NOTISSUE
# 191 have purchase family friend enjoy clarity ease use [[0.9962308]] NOTISSUE
# 192 virgin wireless rock do cheap little phone [[0.5592239]] NOTISSUE
# 193 none work [[0.505741]] NOTISSUE
# 194 do not buy it [[0.17485581]] ISSUE
# 195 muddy low quality sound case wire s insert be poorly super glue slide off [[0.07234896]] ISSUE
# 196 please dont waste money [[0.17498752]] ISSUE
# 197 all be satisfy purchase [[0.67888314]] NOTISSUE
# 198 look good quality headset keep look be not it [[0.9181409]] NOTISSUE
# 199 plantronincs continue use flaw charger design [[0.56121683]] NOTISSUE
# 200 be not best one [[0.42316604]] ISSUE
# 201 best one [[0.81828827]] NOTISSUE
# 202 disappoint result [[0.09406713]] ISSUE
# 203 cumbersome design [[0.3633247]] ISSUE
# 204 great be new package nice work good [[0.9994454]] NOTISSUE
# 205 no problem come time expect [[0.2643591]] ISSUE
# 206 great product [[0.95435935]] NOTISSUE
# 207 be piece crap [[0.1312511]] ISSUE
# 208 experience be terrible [[0.18965584]] ISSUE
# 209 be fourth bluetooth headset [[0.69098353]] NOTISSUE
# 210 be comfortable one [[0.8857118]] NOTISSUE
# 211 hat [[0.69486976]] NOTISSUE
# 212 fix problem [[0.1841824]] ISSUE
# 213 worst ever [[0.11046506]] ISSUE
# 214 be happy [[0.812387]] NOTISSUE
# 215 have have no trouble access internet download intone perform function [[0.5070839]] NOTISSUE
# 216 barely hear be constantly say what [[0.16912332]] ISSUE
# 217 battery life be highly unacceptable [[0.2589699]] ISSUE
# 218 company be joke [[0.21291381]] ISSUE
# 219 do everything description say would [[0.26835495]] ISSUE
# 220 happen call be force stop headset [[0.17586592]] ISSUE
# 221 work great car charger especially plug two adapter time [[0.9957489]] NOTISSUE
# 222 version tech support walk procedure none work end have do hard re set wipe data [[0.15133992]] ISSUE
# 223 voice quality signal strength drop call [[0.35805988]] ISSUE
# 224 play louder speaker size price be low think quality be lack however be not [[0.05719607]] ISSUE
# 225 better expect [[0.74323785]] NOTISSUE
# 226 feel poorly construct menu difficult navigate button recess be difficult push them [[0.27909005]] ISSUE
# 227 battery be hold well [[0.8487254]] NOTISSUE
# 228 difficult on i d recommend avoid product [[0.15412247]] ISSUE
# 229 use two day be not easy hear with [[0.4788953]] ISSUE
# 230 get car charger not week charger be break i go plug start smoke [[0.11409362]] ISSUE
# 231 sprint terrible customer service [[0.26552427]] ISSUE
# 232 link phone effort [[0.5210735]] NOTISSUE
# 233 cool [[0.68998146]] NOTISSUE
# 234 easy use [[0.7162555]] NOTISSUE
# 235 better new [[0.7757256]] NOTISSUE
# 236 posse get junk have no idea [[0.18941613]] ISSUE
# 237 piece trash [[0.18083069]] ISSUE
# 238 pretty good product [[0.9527306]] NOTISSUE
# 239 be great phone [[0.9551396]] NOTISSUE
# 240 price amazon be excellent product highly recommend [[0.984869]] NOTISSUE
# 241 research development division obviously know do [[0.6754502]] NOTISSUE
# 242 real killer be volume course break [[0.19212629]] ISSUE
# 243 phone work fine now [[0.9116127]] NOTISSUE
# 244 be happy product one [[0.80280536]] NOTISSUE
# 245 poor construction [[0.10151803]] ISSUE
# 246 be infuriate [[0.53789806]] NOTISSUE
# 247 overall recommend phone new walkman [[0.7428883]] NOTISSUE
# 248 sprint charge service [[0.6655238]] NOTISSUE
# 249 be cheap feel look cheap [[0.28106883]] ISSUE
# 250 fit ear well be comfortable on [[0.9740965]] NOTISSUE
# 251 do not work europe asia [[0.16386856]] ISSUE
# 252 clip belt definitely make feel like fifty cent s up and come [[0.63256633]] NOTISSUE
# 253 like design look cabra be ear headset five thousand twenty be pretty comfortable wear twenty four hour day pain ear [[0.48807162]] ISSUE
# 254 be amaze quick arrival two original lg cell phone battery fraction price [[0.67365265]] NOTISSUE
# 255 worst phone samsung crap crappy samsung be worst have see [[0.10339189]] ISSUE
# 256 charger work week completely stop charge phone [[0.21505529]] ISSUE
# 257 poor product [[0.12816268]] ISSUE
# 258 need better instruction [[0.69247335]] NOTISSUE
# 259 need two hand operate screen this software interface be decade old compete new software design [[0.628757]] NOTISSUE
# 260 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.93394965]] NOTISSUE
# 261 steer clear product go genuine palm replacement pen come three pack [[0.59447676]] NOTISSUE
# 262 do not buy do not but suck [[0.03770456]] ISSUE
# 263 be great product sure beat finger [[0.9603458]] NOTISSUE
# 264 plus seriously do not believe be worth steep price point [[0.11865044]] ISSUE
# 265 case have try normally fall apart month one seem be long haul [[0.13849571]] ISSUE
# 266 disappoint performance [[0.25915027]] ISSUE
# 267 do not make mistake please do not buy phone [[0.09727718]] ISSUE
# 268 phone well be worst have have brand [[0.32162505]] ISSUE
# 269 case be extra originally later discard scratch ear [[0.18771756]] ISSUE
# 270 recommend go different brand cell phone mp player family [[0.92255354]] NOTISSUE
# 271 do not bother go store [[0.06173879]] ISSUE
# 272 post detail comment grey black phone have fire red be great color [[0.7302967]] NOTISSUE
# 273 not have problem item order again need [[0.22325628]] ISSUE
# 274 get pay guess [[0.26634756]] ISSUE
# 275 not software do great job this make intone form exist cd internet connection [[0.5641644]] NOTISSUE
# 276 im surprise be good quality car charger be not review it [[0.8052623]] NOTISSUE
# 277 fabulous [[0.87743366]] NOTISSUE
# 278 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.0624294]] ISSUE
# 279 price cable be excellent [[0.9497913]] NOTISSUE
# 280 disappoint accessory good manufacturer [[0.5343628]] NOTISSUE
# 281 perform awful muffle tinny incoming sound severe echo end call [[0.07100239]] ISSUE
# 282 wind resistant [[0.5155177]] NOTISSUE
# 283 obviously have terrible customer service get pay for [[0.15688375]] ISSUE
# 284 do not forever [[0.12187932]] ISSUE
# 285 it not overly expensive replace [[0.07151081]] ISSUE
# 286 easy operate sound be better have try [[0.8275517]] NOTISSUE
# 287 contact company tell that unit be warranty not produce receipt be luck [[0.13173757]] ISSUE
# 288 link have way exchange bad phone return unit something [[0.21190506]] ISSUE
# 289 phone be sturdy nokia bar phone be [[0.8517025]] NOTISSUE
# 290 great phone [[0.95936203]] NOTISSUE
# 291 place tree case not be not snug be lot extra room side [[0.24693863]] ISSUE
# 292 be please [[0.6206674]] NOTISSUE
# 293 battery be terrible [[0.10791205]] ISSUE
# 294 find product be easy set use [[0.7831756]] NOTISSUE
# 295 earpiece be large heavy it keep fall ear [[0.31252635]] ISSUE
# 296 utter crap sound quality be terrible [[0.0112169]] ISSUE
# 297 charger arrive promise timeframe not work [[0.5653783]] NOTISSUE
# 298 no ear loop need be tiny sound be great [[0.8801118]] NOTISSUE
# 299 finally four time spring latch break not use longer visor [[0.14216016]] ISSUE
# 300 handsfree work fine car try download address book tree reboot overall rate device high [[0.8963633]] NOTISSUE
# 301 talk useless customer service [[0.16065384]] ISSUE
# 302 felt light tinny [[0.304031]] ISSUE
# 303 do not fit palm tungsten break time try plug in [[0.27010903]] ISSUE
# 304 be happy purchase good quality low price [[0.9719193]] NOTISSUE
# 305 love look feel samsung flipphones [[0.9348977]] NOTISSUE
# 306 well design sharp blue be nice color [[0.98245806]] NOTISSUE
# 307 do everything more [[0.48192698]] ISSUE
# 308 not recommend more [[0.4078044]] ISSUE
# 309 nice sound [[0.8944455]] NOTISSUE
# 310 look good picture case be huge disappointment [[0.5544246]] NOTISSUE
# 311 jawbone be go replace with [[0.48070532]] ISSUE
# 312 setup go smoothly [[0.62307477]] NOTISSUE
# 313 extremely slow take forever do it [[0.13501953]] ISSUE
# 314 study interest worst sin industrial design [[0.11579081]] ISSUE
# 315 thing happen be track be off [[0.20854916]] ISSUE
# 316 be well make easy access phone have handy detachable belt clip [[0.94325477]] NOTISSUE
# 317 have continue pair periodically keep drop [[0.61259407]] NOTISSUE
# 318 unload intone party [[0.31391126]] ISSUE
# 319 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.45659763]] ISSUE
# 320 truly awful [[0.2935989]] ISSUE
# 321 work fine motorola twenty five cellphone lot better wear out battery do [[0.5470008]] NOTISSUE
# 322 volume ringer be real good you have choice loud one [[0.7571808]] NOTISSUE
# 323 none tone be acceptable [[0.16872057]] ISSUE
# 324 camera color balance be awful [[0.37069494]] ISSUE
# 325 product be clearly not ready prime time do not care cool look tell call be come be worthless [[0.04806877]] ISSUE
# 326 love intone upbeat [[0.8872571]] NOTISSUE
# 327 chinese forgery abound [[0.5751531]] NOTISSUE
# 328 easy pair samsung cell [[0.89464694]] NOTISSUE
# 329 instruction not explain microphone jack be use [[0.23993836]] ISSUE
# 330 advise not purchase item never work well [[0.4223735]] ISSUE
# 331 bad have pay month service [[0.09949826]] ISSUE
# 332 work well [[0.84460425]] NOTISSUE
# 333 nokia usb cable not work phone [[0.5426185]] NOTISSUE
# 334 clear crisp sound [[0.72027653]] NOTISSUE
# 335 have use smallest earpiece provide stay pretty well [[0.97242063]] NOTISSUE
# 336 biggest complaint have be battery drain superfast [[0.15796624]] ISSUE
# 337 design be ergonomic theory not stand have ear [[0.32883587]] ISSUE
# 338 do not buy want use holster [[0.20366496]] ISSUE
# 339 phone take great picture video clip [[0.96919954]] NOTISSUE
# 340 do not make look cool [[0.21262476]] ISSUE
# 341 ear occupy background be not distract all [[0.13244607]] ISSUE
# 342 comfortable fit need headset be comfortable hour time not entire day [[0.9342361]] NOTISSUE
# 343 also phone do not seem accept cbr mp s preferably rip window medium player [[0.35627514]] ISSUE
# 344 beat price these [[0.6337292]] NOTISSUE
# 345 come strong light use light camera shot flash so signal seriously [[0.47426867]] ISSUE
# 346 lightweight work well [[0.95387256]] NOTISSUE
# 347 beware [[0.26705483]] ISSUE
# 348 love cable allow connect mini usb device pc [[0.93290305]] NOTISSUE
# 349 near hear conversation [[0.5113369]] NOTISSUE
# 350 be cool case open allow screen get scratch up one [[0.41535425]] ISSUE
# 351 buy phone replacement start have regret since [[0.20390587]] ISSUE
# 352 appear actually outperform original battery china come i [[0.61879057]] NOTISSUE
# 353 store phone number sim [[0.6729368]] NOTISSUE
# 354 last o minute actually try use phone my wife have phone problem [[0.39172056]] ISSUE
# 355 poor quality [[0.14069284]] ISSUE
# 356 cabra ear gel r best [[0.80392355]] NOTISSUE
# 357 not worth it [[0.2698736]] ISSUE
# 358 phone crash completely have get replace [[0.14431007]] ISSUE
# 359 quit work use eighteen month purchase one be best headset have own [[0.59539723]] NOTISSUE
# 360 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.3336746]] ISSUE
# 361 be great phone [[0.9551396]] NOTISSUE
# 362 simply want small flip phone look extra bell whistle mediocre [[0.04861965]] ISSUE
# 363 good value work fine power usb car wall outlet [[0.96071917]] NOTISSUE
# 364 phone do not slide car grip prevent phone slip hand [[0.16378318]] ISSUE
# 365 be simply best bluetooth headset sound quality [[0.9228496]] NOTISSUE
# 366 think plan one this sure be moto phone me [[0.49503186]] ISSUE
# 367 span hour have two people exclaim whoa be new phone tv [[0.45448354]] ISSUE
# 368 have use cord headset freedom wireless be helpful [[0.98054147]] NOTISSUE
# 369 case have pas one year mark show sign wear be functional [[0.35705066]] ISSUE
# 370 that leather be nice soft fit be tight cut face be good shape [[0.9125033]] NOTISSUE
# 371 have everything need not ask more [[0.4787955]] ISSUE
# 372 receive product two day break [[0.38138843]] ISSUE
# 373 product be great make work lot easier go copier wait hold something [[0.6725011]] NOTISSUE
# 374 none size send headset stay ear [[0.6442879]] NOTISSUE
# 375 t mobile have best customer service anywhere [[0.941615]] NOTISSUE
# 376 arrive quickly expensive be sell [[0.28615308]] ISSUE
# 377 have try two unit fail two month pro [[0.24271783]] ISSUE
# 378 provide good protection look classy too [[0.976548]] NOTISSUE
# 379 russel good [[0.85236466]] NOTISSUE
# 380 tracfone website be user friendly make easy activate etc [[0.9241952]] NOTISSUE
# 381 design be [[0.724234]] NOTISSUE
# 382 great reception time [[0.9792085]] NOTISSUE
# 383 highly recommend product [[0.70968485]] NOTISSUE
# 384 not use unit sunglass not good texas [[0.2167123]] ISSUE
# 385 dit not work time nokia [[0.46131483]] ISSUE
# 386 buy mainly charger break soon purchase [[0.68949825]] NOTISSUE
# 387 like loud buzz override conversation phone be you [[0.56769943]] NOTISSUE
# 388 fantastic buy get again phone be [[0.9632407]] NOTISSUE
# 389 stay away store be careful [[0.33984208]] ISSUE
# 390 blunt super tooth hand free phone speaker be awesome [[0.9508244]] NOTISSUE
# 391 item arrive quickly work great phone sound ear plug [[0.89620155]] NOTISSUE
# 392 be light have plenty battery capacity be comfortable wear somewhat extend period time [[0.9139711]] NOTISSUE
# 393 disappoint [[0.22343262]] ISSUE
# 394 blue ant be easy use [[0.64620423]] NOTISSUE
# 395 cheap hey work [[0.618693]] NOTISSUE
# 396 be pleasantly suprised give low cost item [[0.49271855]] ISSUE
# 397 camera phone be use dustpan indoors be disposable this [[0.38387007]] ISSUE
# 398 day later puff smoke come phone use [[0.2914487]] ISSUE
# 399 be convenient simple use get job make car ride smoother [[0.83960134]] NOTISSUE
# 400 nano state it my son be disappoint [[0.22292402]] ISSUE
# 401 sound quality be excellent well [[0.98654175]] NOTISSUE
# 402 best headset have use [[0.8512081]] NOTISSUE
# 403 not recommend [[0.34639463]] ISSUE
# 404 have be year carry highest quality anti glare screen protector have find date [[0.7485146]] NOTISSUE
# 405 want [[0.5244759]] NOTISSUE
# 406 particular model not work motorola q smartphone [[0.7223394]] NOTISSUE
# 407 wont work right at least me [[0.42498574]] ISSUE
# 408 addition feel amp look phone be lightweight cheap plastic [[0.7643063]] NOTISSUE
# 409 be out warranty problem reoccure bottom line money else singular not support it [[0.10982893]] ISSUE
# 410 want plantronics five ten be right one have issue me the good [[0.44586843]] ISSUE
# 411 crisp clear [[0.6966591]] NOTISSUE
# 412 charge keep go dead minute [[0.20787518]] ISSUE
# 413 cheap plastic creak like old wooden floor [[0.3313134]] ISSUE
# 414 get absolutely horrible reception apartment phone have not have problem [[0.13819519]] ISSUE
# 415 reception have be generally good [[0.6378742]] NOTISSUE
# 416 excellent sound battery life inconspicuous boot [[0.9878615]] NOTISSUE
# 417 great bluetooth [[0.97761476]] NOTISSUE
# 418 highly recommend case [[0.70372856]] NOTISSUE
# 419 worthwhile [[0.56803]] NOTISSUE
# 420 phone get be year old be be slowly break despite care part [[0.17582294]] ISSUE
# 421 be sorry make purchase [[0.17115548]] ISSUE
# 422 buy hop make bluetooth headset fit better thing make impossible wear [[0.9170157]] NOTISSUE
# 423 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.19793765]] ISSUE
# 424 be horrible [[0.04112494]] ISSUE
# 425 allow possibility double book date time first [[0.31264138]] ISSUE
# 426 work two week break [[0.43580136]] ISSUE
# 427 do not think hold securely belt [[0.35251537]] ISSUE
# 428 be simple use like it [[0.6814985]] NOTISSUE
# 429 be great tool entertainment communication data management oh be sure use activesync optimal data synchronization result [[0.9728308]] NOTISSUE
# 430 use case smell be disgust [[0.05229914]] ISSUE
# 431 not want [[0.26994237]] ISSUE
# 432 two case order another [[0.4230926]] ISSUE
# 433 buy battery coupon amazon be happy purchase [[0.9075263]] NOTISSUE
# 434 internet access be fine rare instance work [[0.8926234]] NOTISSUE
# 435 perfect [[0.8605301]] NOTISSUE
# 436 five star plus plus [[0.8083566]] NOTISSUE
# 437 good quality bargain buy buy cheap big lot sound awful people end not hear me [[0.49775565]] ISSUE
# 438 drain [[0.19782817]] ISSUE
# 439 try talk real loud shout telephone get old be tell be not great [[0.36036935]] ISSUE
# 440 good work fine [[0.97665316]] NOTISSUE
# 441 price be great deal [[0.95901984]] NOTISSUE
# 442 great price too [[0.9120835]] NOTISSUE
# 443 be wind be completely useless [[0.05001849]] ISSUE
# 444 yes be shiny love it [[0.9307923]] NOTISSUE
# 445 do not work [[0.20209625]] ISSUE
# 446 think be get good deal plug phone see razor [[0.74978024]] NOTISSUE
# 447 reception headset be excellent [[0.9624866]] NOTISSUE
# 448 two thumb seller [[0.43381295]] ISSUE
# 449 have version lg phone work well together good reception range exceed twenty foot line sight [[0.9743949]] NOTISSUE
# 450 improper description have return it [[0.23045528]] ISSUE
# 451 work be comfortable [[0.91564184]] NOTISSUE
# 452 battery charge life be long [[0.69823104]] NOTISSUE
# 453 cabra largely fit ear well [[0.66327894]] NOTISSUE
# 454 battery have no life [[0.5925679]] NOTISSUE
# 455 check be no feature be disappoint [[0.1952561]] ISSUE
# 456 product be exactly describe [[0.34453127]] ISSUE
# 457 get signal version phone win t [[0.64678264]] NOTISSUE
# 458 do not do job [[0.08238807]] ISSUE
# 459 recommend it [[0.61655587]] NOTISSUE
# 460 plan order again again [[0.48865852]] ISSUE
# 461 be say phone camera be nice cool effect play with video be decent well [[0.90092933]] NOTISSUE
# 462 have be satisfy cell phone day one [[0.57033974]] NOTISSUE
# 463 keep get better better this be one have have numerous palm too [[0.545949]] NOTISSUE
# 464 awkward use unreliable [[0.0424014]] ISSUE
# 465 ship time be quick [[0.50467056]] NOTISSUE
# 466 not good have hop [[0.48122486]] ISSUE
# 467 good case [[0.8303078]] NOTISSUE
# 468 do not work [[0.20209625]] ISSUE
# 469 good product [[0.8462134]] NOTISSUE
# 470 unfortunately not work [[0.20455924]] ISSUE
# 471 break two month use [[0.33899996]] ISSUE
# 472 dont buy it [[0.6037103]] NOTISSUE
# 473 father have battery be die [[0.40824124]] ISSUE
# 474 however ear pad come easily one week lose one [[0.18185875]] ISSUE
# 475 call drop phone come will screen go black worst stop ring intermittently [[0.06627344]] ISSUE
# 476 horrible horrible protector [[0.0380541]] ISSUE
# 477 do not like nokia either [[0.13231531]] ISSUE
# 478 reach row be uncomfortable [[0.24695003]] ISSUE
# 479 have buy nokia cell phone week ago be nightmare [[0.18276957]] ISSUE
# 480 take long describe bad customer service experience have be amazon [[0.24718262]] ISSUE
# 481 disappoint thing be be no speakerphone [[0.19694327]] ISSUE
# 482 terrible car not accept cassette [[0.04546572]] ISSUE
# 483 product be useless do not have charge current charge two cellphone [[0.15566395]] ISSUE
# 484 be not say be [[0.2175491]] ISSUE
# 485 stay away q [[0.63561374]] NOTISSUE
# 486 use dirty [[0.09298288]] ISSUE
# 487 unreliable service t mobile [[0.4064964]] ISSUE
# 488 not good price [[0.54972696]] NOTISSUE
# 489 buy two charge [[0.56253356]] NOTISSUE
# 490 look nice [[0.8883504]] NOTISSUE
# 491 be excellent tool especially pair phone s auto answer [[0.98357475]] NOTISSUE
# 492 have read other s review have not have problem it [[0.15817484]] ISSUE
# 493 product cover important light sensor ear outlet [[0.60668296]] NOTISSUE
# 494 comfortable hand [[0.91130954]] NOTISSUE
# 495 do not work [[0.20209625]] ISSUE
# 496 poor reliability [[0.09644212]] ISSUE
# 497 work [[0.64052]] NOTISSUE
# 498 take picture battery drop bar start beep let know din [[0.24879503]] ISSUE
# 499 terrible product waste money [[0.05882717]] ISSUE
# 500 time buy you [[0.6657507]] NOTISSUE
# 501 be waste money [[0.12206993]] ISSUE
# 502 far have work like charm [[0.90663004]] NOTISSUE
# 503 have have week far good [[0.7270331]] NOTISSUE
# 504 but case best be download picture laptop ir send picture laptop phone [[0.8197841]] NOTISSUE
# 505 recommend item [[0.60676074]] NOTISSUE
# 506 be be choice headset year great sound good volume good noise cancellation [[0.9780989]] NOTISSUE
# 507 nice case feel good hand [[0.9387586]] NOTISSUE
# 508 item receive be counterfeit [[0.3156868]] ISSUE
# 509 good far probably best bt headset have have [[0.96375626]] NOTISSUE
# 510 work fine [[0.8631688]] NOTISSUE
# 511 receive headset good time be happy it [[0.9784098]] NOTISSUE
# 512 be please see replace well trail swivel holster blackberry flip [[0.7535351]] NOTISSUE
# 513 sister have one love it [[0.85730344]] NOTISSUE
# 514 good quality [[0.9078472]] NOTISSUE
# 515 be far worst purchase have make amazon [[0.16943915]] ISSUE
# 516 excellent dual purpose headset [[0.9790812]] NOTISSUE
# 517 excellent [[0.94239295]] NOTISSUE
# 518 do not work listen music singular [[0.41553402]] ISSUE
# 519 seem completely secure hold belt keep phone inside [[0.69758874]] NOTISSUE
# 520 bottom line another worthless cheap gimmick sprint [[0.16117844]] ISSUE
# 521 have trouble volume [[0.29720396]] ISSUE
# 522 good thing be fit comfortably small ear [[0.97329956]] NOTISSUE
# 523 warn do not buy [[0.11713433]] ISSUE
# 524 be pair phone not be happier far [[0.5053168]] NOTISSUE
# 525 open battery connection be break device be turn off [[0.22869591]] ISSUE
# 526 not want clip go ear cause discomfort [[0.08292404]] ISSUE
# 527 best headset ever [[0.84962463]] NOTISSUE
# 528 do not trust webster do not expect helpful support [[0.23292527]] ISSUE
# 529 be loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.36338]] ISSUE
# 530 speaker be low quality make ring tone sound cheap [[0.23168808]] ISSUE
# 531 fit comfortably come size earn tip [[0.9229278]] NOTISSUE
# 532 bad reception [[0.09423395]] ISSUE
# 533 product be high quality chinese crap [[0.23541622]] ISSUE
# 534 be comfortable ear [[0.87179565]] NOTISSUE
# 535 do not buy product fail [[0.08127695]] ISSUE
# 536 everything product be wrong first [[0.25704047]] ISSUE
# 537 pair two device be easy barely take couple minute start make call voice deal feature [[0.49982953]] ISSUE
# 538 be utterly confuse first cause lose couple very important contact [[0.22084086]] ISSUE
# 539 terrible phone holder [[0.20100668]] ISSUE
# 540 cutout button place perfectly [[0.9371396]] NOTISSUE
# 541 love be able use one headset land line cell [[0.7485508]] NOTISSUE
# 542 problem be ear loop make weak material break easily [[0.0818846]] ISSUE
# 543 not nearly good look amazon picture make look [[0.65424865]] NOTISSUE
# 544 despite flaw case be exceptional quality well worth additional cost own official oem product [[0.43552622]] ISSUE
# 545 stupid be that [[0.11250313]] ISSUE
# 546 hear be drive car usually do not have be loudest set [[0.2230244]] ISSUE
# 547 seller ship quickly cheaper competitor [[0.47502238]] ISSUE
# 548 good show samsung [[0.91050607]] NOTISSUE
# 549 buy ten save a lot money [[0.43705276]] ISSUE
# 550 cut make beep beep beep sound say signal fail [[0.06525291]] ISSUE
# 551 not figure [[0.35499522]] ISSUE
# 552 phone sound ok not great ok wife s phone be totally unintelligible not understand word be say it [[0.12108371]] ISSUE
# 553 have take battery phone back restart it [[0.54610234]] NOTISSUE
# 554 manage bend leaf spring back place metal have stress break drop [[0.11893518]] ISSUE
# 555 leopard print be wonderfully wild [[0.923645]] NOTISSUE
# 556 work me [[0.77864623]] NOTISSUE
# 557 saggy floppy piece junk [[0.25226024]] ISSUE
# 558 better hard plastic case [[0.6120396]] NOTISSUE
# 559 have new problem [[0.43491706]] ISSUE
# 560 happy far [[0.811877]] NOTISSUE
# 561 cool phone [[0.7573428]] NOTISSUE
# 562 work good [[0.9068428]] NOTISSUE
# 563 motorola finally get voice quality bluetooth headset right [[0.89232886]] NOTISSUE
# 564 loose connection phone be couple foot two [[0.6227266]] NOTISSUE
# 565 be great recommend [[0.9661946]] NOTISSUE
# 566 make easier keep bluetooth be not wear it [[0.43111837]] ISSUE
# 567 say above pretty useless [[0.1781578]] ISSUE
# 568 never get it [[0.3660746]] ISSUE
# 569 pair headphone be worst have have sound wise [[0.35516465]] ISSUE
# 570 drain weak snap [[0.06864133]] ISSUE
# 571 do not charge singular att eight thousand five twenty five phone [[0.36968428]] ISSUE
# 572 get extra minute carry call not get cut off [[0.10619765]] ISSUE
# 573 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.10955413]] ISSUE
# 574 keep catch cable seat have pull phone turn off [[0.3379796]] ISSUE
# 575 headset fulfil requirement be happy purchase [[0.9067198]] NOTISSUE
# 576 logitech bluetooth headset be [[0.9210382]] NOTISSUE
# 577 like fact rest lightly ear inside [[0.31528676]] ISSUE
# 578 lot webster have be rat good phone do i [[0.5688584]] NOTISSUE
# 579 have try cable computer pod work fine [[0.79588145]] NOTISSUE
# 580 mic be joke volume be low [[0.11782631]] ISSUE
# 581 be return them [[0.41545564]] ISSUE
# 582 do not maintain connection computer be lap [[0.22726384]] ISSUE
# 583 be easy turn car volume control accessible [[0.6750826]] NOTISSUE
# 584 have have year christmas buy rest family [[0.7804894]] NOTISSUE
# 585 otherwise easy install use clear sound [[0.45389932]] ISSUE
# 586 nice leather [[0.88784206]] NOTISSUE
# 587 have purchase different case [[0.75931495]] NOTISSUE
# 588 be joy use [[0.89344054]] NOTISSUE
# 589 disappoint company [[0.2636765]] ISSUE
# 590 satisfy that [[0.5848195]] NOTISSUE
# 591 not charge me [[0.2515404]] ISSUE
# 592 be phone get buy say be wow [[0.6227879]] NOTISSUE
# 593 button small [[0.68532187]] NOTISSUE
# 594 read spec make say wow [[0.5731872]] NOTISSUE
# 595 love it great armband [[0.9902418]] NOTISSUE
# 596 like product motorola be allot clearer ear piece mic [[0.4717548]] ISSUE
# 597 however keypad tinny reach wrong button [[0.20599711]] ISSUE
# 598 exchange sony ericson z five be pretty happy decision [[0.927542]] NOTISSUE
# 599 be impress price case [[0.4333746]] ISSUE
# 600 make easier hold to [[0.4574414]] ISSUE
# 601 use product motor control center be lot high voltage hum equipment work great [[0.9573287]] NOTISSUE
# 602 be pretty easy [[0.8837879]] NOTISSUE
# 603 make call certain place [[0.32355484]] ISSUE
# 604 however girl be complain time phone do not wake like normal phone do [[0.07812238]] ISSUE
# 605 beautiful style though [[0.9678082]] NOTISSUE
# 606 company charge restock fee not give refund back [[0.11292712]] ISSUE
# 607 be try return refund [[0.2495212]] ISSUE
# 608 plug find not darn thing work [[0.55605507]] NOTISSUE
# 609 excellent product [[0.95297825]] NOTISSUE
# 610 earn piece break easily [[0.38561016]] ISSUE
# 611 lousy product [[0.16772074]] ISSUE
# 612 phone try hard do everything fail be ability be phone [[0.3390107]] ISSUE
# 613 be best charger have see market yet [[0.89965767]] NOTISSUE
# 614 sweetest phone [[0.8082047]] NOTISSUE
# 615 oh charger seem work fine [[0.9003062]] NOTISSUE
# 616 fit securely ear hook do not need be use sound be better direct ear canal [[0.2883658]] ISSUE
# 617 not volume [[0.24140468]] ISSUE
# 618 echo problem very unsatisfactory [[0.08453581]] ISSUE
# 619 take two video time quality be poor [[0.10207944]] ISSUE
# 620 do not waste money [[0.06150202]] ISSUE
# 621 be go have be negatively review product [[0.15114947]] ISSUE
# 622 adapter do not provide charge current [[0.2139981]] ISSUE
# 623 be hype phone assume be best mistake [[0.21855173]] ISSUE
# 624 take picture case sense be cover [[0.4625129]] ISSUE
# 625 phone fall easily [[0.31552297]] ISSUE
# 626 not work people not hear talk [[0.12544283]] ISSUE
# 627 text message feature be tricky use [[0.66179234]] NOTISSUE
# 628 be disappoint have be charger do not work [[0.16350943]] ISSUE
# 629 painful ear [[0.31784227]] ISSUE
# 630 last one day blow up [[0.15786846]] ISSUE
# 631 disappoint [[0.22343262]] ISSUE
# 632 kind flop around [[0.19007473]] ISSUE
# 633 screen do get smudge easily touch ear face [[0.33911875]] ISSUE
# 634 piece junk lose call phone [[0.26907393]] ISSUE
# 635 item do not match picture [[0.137355]] ISSUE
# 636 thing disappoint be infra red port ira [[0.3108081]] ISSUE
# 637 not answer call unit never work once [[0.22039539]] ISSUE
# 638 unsatisfactory [[0.13677487]] ISSUE
# 639 product be great [[0.9438849]] NOTISSUE
# 640 have this [[0.54465765]] NOTISSUE
# 641 have be work good no problem [[0.5019653]] NOTISSUE
# 642 oh be dangerous [[0.2587044]] ISSUE
# 643 sorry [[0.15414271]] ISSUE
# 644 be sorry [[0.13521376]] ISSUE
# 645 pardon [[0.54397494]] NOTISSUE
# 646 help help [[0.6768002]] NOTISSUE
# 647 no no be dangerous [[0.04723788]] ISSUE
# 648 be extremely dangerous [[0.19515371]] ISSUE
# 649 be dangerous [[0.16556628]] ISSUE
# 650 be dangerous young man [[0.41705152]] ISSUE
# 651 be dangerous brutal [[0.16556628]] ISSUE
# 652 honestly be dangerous [[0.14026049]] ISSUE
# 653 work [[0.64052]] NOTISSUE
# 654 be dead hard work [[0.33232385]] ISSUE
# 655 fact family be mary s wed [[0.7401987]] NOTISSUE
# 656 have be busy [[0.5322988]] NOTISSUE
# 657 go back again [[0.5494151]] NOTISSUE
# 658 be be busy [[0.44332242]] ISSUE
# 659 think be yesterday [[0.42905363]] ISSUE
# 660 do think get one [[0.32680246]] ISSUE
# 661 oh yes [[0.76734984]] NOTISSUE
# 662 be one thing want talk [[0.26382565]] ISSUE
# 663 well honestly do not know have not be discussion [[0.17638445]] ISSUE
# 664 course be come tomorrow [[0.5381469]] NOTISSUE
# 665 have not see think be away weekend [[0.13481887]] ISSUE
# 666 hello [[0.6941443]] NOTISSUE
# 667 mean be young man [[0.45608604]] ISSUE
# 668 goodbye [[0.64334494]] NOTISSUE
# 669 be alright [[0.7340672]] NOTISSUE
# 670 do need money urgently [[0.31082365]] ISSUE
# 671 be business [[0.47933206]] ISSUE
# 672 be work day [[0.5734727]] NOTISSUE
# 673 work [[0.64052]] NOTISSUE
# 674 do work [[0.4027422]] ISSUE
# 675 be be work day [[0.50483197]] NOTISSUE
# 676 work saturday [[0.65077925]] NOTISSUE
# 677 know work [[0.7038092]] NOTISSUE
# 678 horrible customer service [[0.11298656]] ISSUE
# 679 fine product [[0.7467115]] NOTISSUE
# 680 glad pay money it [[0.35535565]] ISSUE
# 681 be worst version adobe illustrator be release version nine [[0.25271308]] ISSUE
# 682 save mysterious reason [[0.26937303]] ISSUE
# 683 crash [[0.17522368]] ISSUE
# 684 open file have be year write scribble untenable save version [[0.14919654]] ISSUE
# 685 assume adobe s customer service be professional quick [[0.57807153]] NOTISSUE
# 686 have call time past two week have have wait minimum twenty three minute speak someone [[0.08949555]] ISSUE
# 687 finally get product send mac version personal computer version purchase [[0.45196447]] ISSUE
# 688 call again wait approximately thirty minute get customer help [[0.22386609]] ISSUE
# 689 have not receive personal computer version [[0.29201356]] ISSUE
# 690 call center service be worst customer service have deal [[0.21644929]] ISSUE
# 691 have deal bad customer service [[0.10663848]] ISSUE
# 692 six extremely frustrate hour [[0.3949717]] ISSUE
# 693 do not have problem software [[0.19295517]] ISSUE
# 694 reverse error be nightmare [[0.0220865]] ISSUE
# 695 pretty do need [[0.60504055]] NOTISSUE
# 696 point customer service rep be nice [[0.7536944]] NOTISSUE
# 697 do not have infrastructure provide basic level service [[0.3713118]] ISSUE
# 698 customer support system payroll upgrade product be scary [[0.14364614]] ISSUE
# 699 do not send receipt [[0.08280085]] ISSUE
# 700 receipt get be copy invoice be not format print correctly [[0.12726346]] ISSUE
# 701 be disturb be people suppose be account expert [[0.2616474]] ISSUE
# 702 start look alternative intuit obviously do not understand basic account audit principle [[0.10942858]] ISSUE
# 703 be thoroughly disappoint [[0.1910763]] ISSUE
# 704 be not do business company anymore give bad support [[0.0647992]] ISSUE
# 705 online information be exactly have cd [[0.76583326]] NOTISSUE
# 706 have not send coupon [[0.26403433]] ISSUE
# 707 bad [[0.04936898]] ISSUE
# 708 save money do not subscribe extend service [[0.15721779]] ISSUE
# 709 use customer service technical support give answer be vaguely relate problem [[0.19381957]] ISSUE
# 710 be emailinc time get nowhere [[0.27263007]] ISSUE
# 711 be largest technical software company world [[0.5712126]] NOTISSUE
# 712 have no technical support [[0.38552162]] ISSUE
# 713 worthless product horrible customer service [[0.05558193]] ISSUE
# 714 be unable access internet [[0.3251729]] ISSUE
# 715 no problem system become slow [[0.03157669]] ISSUE
# 716 customer service phone number be not user guide bury webster [[0.34991908]] ISSUE
# 717 reputation become exasperate script suggestion not resolve problem [[0.06840602]] ISSUE
# 718 feel bite fleece price subscription renewal year [[0.3702714]] ISSUE
# 719 decide give try [[0.5316949]] NOTISSUE
# 720 installation go smoothly everything seem fine [[0.7437526]] NOTISSUE
# 721 stall blank screen right window [[0.244077]] ISSUE
# 722 hang forever [[0.6045]] NOTISSUE
# 723 well present [[0.7958316]] NOTISSUE
# 724 easy follow along easy revisit previous lesson [[0.6373763]] NOTISSUE
# 725 video illustrate fretboard help see hear song be play [[0.5749476]] NOTISSUE
# 726 not lot depth material [[0.24559113]] ISSUE
# 727 sing be slight destruction sometimes [[0.47022685]] ISSUE
# 728 material song not be everyone like [[0.3182155]] ISSUE
# 729 have find music book useful [[0.9506831]] NOTISSUE
# 730 probably not recommend be source learn guitar [[0.50818497]] NOTISSUE
# 731 like new look [[0.7338189]] NOTISSUE
# 732 i be have problem make transition [[0.33635923]] ISSUE
# 733 look create doom half life recommend program [[0.716812]] NOTISSUE
# 734 want make advance fps game simple pong game recommend dark basic [[0.5546322]] NOTISSUE
# 735 dark basic professional be probably capable create kind game come with [[0.9516927]] NOTISSUE
# 736 have deal bad customer service [[0.10663848]] ISSUE
# 737 dark basic make manipulate data extremely easy [[0.6639814]] NOTISSUE
# 738 have program yourself scratch [[0.47765818]] ISSUE
# 739 recommend [[0.6101948]] NOTISSUE
# 740 software be easy install easy use [[0.87754464]] NOTISSUE
# 741 be wonderful software [[0.96647304]] NOTISSUE
# 742 buy cd [[0.7202906]] NOTISSUE
# 743 do not waste money subscription merriam webster s webster [[0.22729987]] ISSUE
# 744 software be user friendly [[0.8691729]] NOTISSUE
# 745 be superb [[0.8973086]] NOTISSUE
# 746 try medical dictionary [[0.64474595]] NOTISSUE
# 747 be surprise find offer option strip code [[0.5832516]] NOTISSUE
# 748 compare old earlier version offer major improvement [[0.25805444]] ISSUE
# 749 be evolution [[0.45084575]] ISSUE
# 750 do offer major improvement flexibility previous version [[0.3419452]] ISSUE
# 751 good [[0.8333297]] NOTISSUE
# 752 simple easy use user friendly accurate pronunciation [[0.97908807]] NOTISSUE
# 753 horribly bad [[0.04936898]] ISSUE
# 754 good be able tweak dozen standard compliance [[0.86346596]] NOTISSUE
# 755 default thing not set up do take learn [[0.31081435]] ISSUE
# 756 move fairly advance feature [[0.7438449]] NOTISSUE
# 757 anyhow call para professional version [[0.5694631]] NOTISSUE
# 758 have way flexibility functionality version [[0.93090063]] NOTISSUE
# 759 be go bye bye [[0.58228314]] NOTISSUE
# 760 be please product [[0.503408]] NOTISSUE
# 761 have trial version instal computer buy it [[0.4920164]] ISSUE
# 762 have do be enter code box be be [[0.20446345]] ISSUE
# 763 easy [[0.74140924]] NOTISSUE
# 764 be glad be able install one computer [[0.65309757]] NOTISSUE
# 765 be today best office suite microsoft have own [[0.81597507]] NOTISSUE
# 766 easy use excellent result [[0.9428677]] NOTISSUE
# 767 great sw [[0.9444228]] NOTISSUE
# 768 be easy learn [[0.83728796]] NOTISSUE
# 769 have good graphic [[0.85920125]] NOTISSUE
# 770 help visualize space [[0.80031353]] NOTISSUE
# 771 see [[0.6469789]] NOTISSUE
# 772 have not figure do [[0.21153781]] ISSUE
# 773 difficult change room s house s overall style start give design [[0.42480642]] ISSUE
# 774 recently buy version [[0.69005656]] NOTISSUE
# 775 instal software [[0.52000904]] NOTISSUE
# 776 everything operate well old personal computer [[0.7925371]] NOTISSUE
# 777 run lot faster [[0.4351025]] ISSUE
# 778 access corporate entrant [[0.2842959]] ISSUE
# 779 be awesome [[0.9155544]] NOTISSUE
# 780 give whirl [[0.5828333]] NOTISSUE
# 781 buy product again [[0.6211487]] NOTISSUE
# 782 five star them [[0.70528495]] NOTISSUE
# 783 great company deal [[0.967001]] NOTISSUE
# 784 agree window improve thier product [[0.4435847]] ISSUE
# 785 linx be not user friendly [[0.620332]] NOTISSUE
# 786 compatibility issue kill unix linx [[0.30758792]] ISSUE
# 787 unix be far stable [[0.57108957]] NOTISSUE
# 788 have access cd version [[0.8234496]] NOTISSUE
# 789 like [[0.6000017]] NOTISSUE
# 790 work well me [[0.91132635]] NOTISSUE
# 791 usually go disc want attempt [[0.16328934]] ISSUE
# 792 be lot cd [[0.7392442]] NOTISSUE
# 793 great program child learn difference [[0.98139554]] NOTISSUE
# 794 fun excellent way learn math [[0.9986004]] NOTISSUE
# 795 child love do too [[0.41467786]] ISSUE
# ...
# 3951 server be nice attentive be serve staff [[0.96466684]] NOTISSUE
# 3952 cashier be friendly bring food me [[0.78069705]] NOTISSUE
# 3953 work hospitality industry paradise valley have refrain recommend ciob longer [[0.70832103]] NOTISSUE
# 3954 atmosphere be fun [[0.9237043]] NOTISSUE
# 3955 not recommend others [[0.2668131]] ISSUE
# 3956 service be quick to go order like like it [[0.50859576]] NOTISSUE
# 3957 mean really do get famous fish chip be terrible [[0.0357875]] ISSUE
# 3958 say mouth belly be please [[0.4625396]] ISSUE
# 3959 not thing [[0.22065426]] ISSUE
# 3960 two thumb up [[0.5602952]] NOTISSUE
# 3961 read please do not go there [[0.14023516]] ISSUE
# 3962 love grill pizza remind legitimate italian pizza [[0.87937504]] NOTISSUE
# 3963 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99536335]] NOTISSUE
# 3964 have nice atmosphere [[0.91372204]] NOTISSUE
# 3965 tonight have elk file special and suck [[0.42361668]] ISSUE
# 3966 one bite be hook [[0.23672022]] ISSUE
# 3967 order old classic new dish go time be sorely disappoint everything [[0.13154626]] ISSUE
# 3968 cute quaint simple honest [[0.83755606]] NOTISSUE
# 3969 chicken be deliciously season have perfect fry outside moist chicken inside [[0.6160217]] NOTISSUE
# 3970 food be great always compliment chef [[0.99616665]] NOTISSUE
# 3971 special thank dylan t recommendation order yummy tummy [[0.98440754]] NOTISSUE
# 3972 awesome selection beer [[0.9710793]] NOTISSUE
# 3973 great food awesome service [[0.9983014]] NOTISSUE
# 3974 one nice thing be add gratuity bill party be larger six not expect tip that [[0.36453962]] ISSUE
# 3975 fly be apple juice fly [[0.34525654]] ISSUE
# 3976 now nan chicken be tasty [[0.87597215]] NOTISSUE
# 3977 service think be good [[0.8668671]] NOTISSUE
# 3978 food be barely lukewarm have be sit wait server bring u [[0.19705448]] ISSUE
# 3979 ryan s bar be definitely one edinburgh establishment not be revisit [[0.23891]] ISSUE
# 3980 nicest chinese restaurant have be while [[0.86526763]] NOTISSUE
# 3981 overall like food service [[0.6097458]] NOTISSUE
# 3982 serve indian nan bread hummus spicy pine nut sauce be world [[0.7638328]] NOTISSUE
# 3983 probably never come back not recommend it [[0.21650708]] ISSUE
# 3984 friend s pasta bad barely touch it [[0.15249404]] ISSUE
# 3985 try airport experience tasty food speedy friendly service [[0.9939704]] NOTISSUE
# 3986 love decor chinese calligraphy wall paper [[0.93745995]] NOTISSUE
# 3987 never have complain here [[0.18290487]] ISSUE
# 3988 restaurant be clean have family restaurant feel it [[0.6966564]] NOTISSUE
# 3989 be way fry [[0.51258737]] NOTISSUE
# 3990 be not sure long stand be long begin feel awkwardly place [[0.11889591]] ISSUE
# 3991 open sandwich be impress not good way [[0.43379536]] ISSUE
# 3992 not be back [[0.2434329]] ISSUE
# 3993 be warm feel service felt like guest special treat [[0.9251244]] NOTISSUE
# 3994 extensive menu provide lot option breakfast [[0.9894232]] NOTISSUE
# 3995 order vegetarian menu dinner have wide array option choose from [[0.9875437]] NOTISSUE
# 3996 have watch price inflate portion get smaller management attitude grow rapidly [[0.1904731]] ISSUE
# 3997 wonderful little tapa ambience make feel warm fuzzy inside [[0.9959617]] NOTISSUE
# 3998 get enjoy seafood salad fabulous vinaigrette [[0.9989002]] NOTISSUE
# 3999 wonton be thin not thick chewy melt mouth [[0.22027108]] ISSUE
# 4000 level five spicy be perfect spice not over helm soup [[0.67755264]] NOTISSUE
# 4001 be sit right time server get go be fantastic [[0.68311477]] NOTISSUE
# 4002 main thing not enjoy be crowd be older crowd middle thirty s up [[0.39360777]] ISSUE
# 4003 be town definitely be spot hit again [[0.49045402]] ISSUE
# 4004 have wait thirty minute get drink longer get two area [[0.2586724]] ISSUE
# 4005 be great place eat [[0.9466775]] NOTISSUE
# 4006 jalapeno bacon be soo good [[0.95538294]] NOTISSUE
# 4007 service be poor [[0.10162534]] ISSUE
# 4008 food be good service be good price be good [[0.9889544]] NOTISSUE
# 4009 price be good [[0.83971184]] NOTISSUE
# 4010 price be good [[0.83971184]] NOTISSUE
# 4011 service be good [[0.86683047]] NOTISSUE
# 4012 place be not clean food oh stale [[0.05200103]] ISSUE
# 4013 chicken dish ok beef be like shoe leather [[0.35902447]] ISSUE
# 4014 service be bad [[0.05057199]] ISSUE
# 4015 be happy be here [[0.8389714]] NOTISSUE
# 4016 taste like dirt [[0.244877]] ISSUE
# 4017 one place phoenix definately go back again [[0.60193413]] NOTISSUE
# 4018 block be amaze [[0.8586461]] NOTISSUE
# 4019 be close house be low key non fancy affordable price good food [[0.81126034]] NOTISSUE
# 4020 hot sour egg flower soup be absolutely five star [[0.5210861]] NOTISSUE
# 4021 hashemi be poor quality be soggy tasteless [[0.00951035]] ISSUE
# 4022 great time family dinner sunday night [[0.99478924]] NOTISSUE
# 4023 food be not tasty all not say real traditional hunan style [[0.3088814]] ISSUE
# 4024 bother me be slow service [[0.08673913]] ISSUE
# 4025 flair bartender absolutely amaze [[0.9751638]] NOTISSUE
# 4026 freeze margarita way sugary taste [[0.37069374]] ISSUE
# 4027 be good order twice [[0.83235353]] NOTISSUE
# 4028 nutshell restaurant smell like combination dirty fish market sewer [[0.0675413]] ISSUE
# 4029 girlfriend s veal be bad [[0.04673338]] ISSUE
# 4030 unfortunately be not good [[0.26325157]] ISSUE
# 4031 have pretty satisfy experience [[0.9188035]] NOTISSUE
# 4032 join club get awesome offer email [[0.9436031]] NOTISSUE
# 4033 perfect me like beer ice cold case colder [[0.7610993]] NOTISSUE
# 4034 bland flavourless be good way describe barely tepid meat [[0.0542579]] ISSUE
# 4035 chain be no fan of beat place easily [[0.38299572]] ISSUE
# 4036 nacho have [[0.6279316]] NOTISSUE
# 4037 not be come back [[0.25773957]] ISSUE
# 4038 do not have word say place do everything pretty well [[0.36438838]] ISSUE
# 4039 staff be super nice quick crazy crowd downtown jury lawyer court staff [[0.777947]] NOTISSUE
# 4040 great atmosphere friendly fast service [[0.9989209]] NOTISSUE
# 4041 receive pity be huge have lot meat thumb there [[0.31059372]] ISSUE
# 4042 food arrive be me [[0.528179]] NOTISSUE
# 4043 pay hot dog fry look like come kid s meal wienerschnitzel be not idea good meal [[0.18642165]] ISSUE
# 4044 classic maine lobster roll be fantastic [[0.9705118]] NOTISSUE
# 4045 brother law work mall eat day guess be sick night too [[0.04809055]] ISSUE
# 4046 good be go have review place twice [[0.79062194]] NOTISSUE
# 4047 chip salsa be good salsa be fresh [[0.976652]] NOTISSUE
# 4048 place be great [[0.95256937]] NOTISSUE
# 4049 mediocre food [[0.08799735]] ISSUE
# 4050 get inside be impress place [[0.43257424]] ISSUE
# 4051 be super piss [[0.38342568]] ISSUE
# 4052 service be super friendly [[0.9032954]] NOTISSUE
# 4053 sad little vegetable overcook [[0.04745016]] ISSUE
# 4054 place be nice surprise [[0.8913949]] NOTISSUE
# 4055 live music totally blow [[0.25054222]] ISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                 be look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6           display be excellent camera be good year  NOTISSUE
#  7              7                              battery life be great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10        be embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  be average phone bad battery life operate weak...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18      try handsfree gadget be one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution be far comparably price pho...     ISSUE
#  27            27                                      be great deal  NOTISSUE
#  28            28              excellent product be satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4025        4025                  freeze margarita way sugary taste     ISSUE
#  4026        4026                                be good order twice  NOTISSUE
#  4027        4027  nutshell restaurant smell like combination dir...     ISSUE
#  4028        4028                           girlfriend s veal be bad     ISSUE
#  4029        4029                          unfortunately be not good     ISSUE
#  4030        4030                     have pretty satisfy experience  NOTISSUE
#  4031        4031                  join club get awesome offer email  NOTISSUE
#  4032        4032          perfect me like beer ice cold case colder  NOTISSUE
#  4033        4033  bland flavourless be good way describe barely ...     ISSUE
#  4034        4034               chain be no fan of beat place easily     ISSUE
#  4035        4035                                         nacho have  NOTISSUE
#  4036        4036                                   not be come back     ISSUE
#  4037        4037  do not have word say place do everything prett...  NOTISSUE
#  4038        4038  staff be super nice quick crazy crowd downtown...  NOTISSUE
#  4039        4039             great atmosphere friendly fast service  NOTISSUE
#  4040        4040     receive pity be huge have lot meat thumb there  NOTISSUE
#  4041        4041                                  food arrive be me     ISSUE
#  4042        4042  pay hot dog fry look like come kid s meal wien...     ISSUE
#  4043        4043            classic maine lobster roll be fantastic  NOTISSUE
#  4044        4044  brother law work mall eat day guess be sick ni...     ISSUE
#  4045        4045                 good be go have review place twice  NOTISSUE
#  4046        4046                  chip salsa be good salsa be fresh  NOTISSUE
#  4047        4047                                     place be great  NOTISSUE
#  4048        4048                                      mediocre food     ISSUE
#  4049        4049                        get inside be impress place  NOTISSUE
#  4050        4050                                      be super piss     ISSUE
#  4051        4051                          service be super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                             place be nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#
#  [4055 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4     NOTISSUE                 be look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE           display be excellent camera be good year
#  7     NOTISSUE                              battery life be great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE        be embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  be average phone bad battery life operate weak...
#  13    NOTISSUE       clear skye call long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE      try handsfree gadget be one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25    NOTISSUE                                       exactly want
#  26    NOTISSUE  picture resolution be far comparably price pho...
#  27    NOTISSUE                                      be great deal
#  28    NOTISSUE              excellent product be satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4025     ISSUE                  freeze margarita way sugary taste
#  4026  NOTISSUE                                be good order twice
#  4027     ISSUE  nutshell restaurant smell like combination dir...
#  4028     ISSUE                           girlfriend s veal be bad
#  4029     ISSUE                          unfortunately be not good
#  4030  NOTISSUE                     have pretty satisfy experience
#  4031  NOTISSUE                  join club get awesome offer email
#  4032  NOTISSUE          perfect me like beer ice cold case colder
#  4033     ISSUE  bland flavourless be good way describe barely ...
#  4034     ISSUE               chain be no fan of beat place easily
#  4035  NOTISSUE                                         nacho have
#  4036     ISSUE                                   not be come back
#  4037     ISSUE  do not have word say place do everything prett...
#  4038  NOTISSUE  staff be super nice quick crazy crowd downtown...
#  4039  NOTISSUE             great atmosphere friendly fast service
#  4040     ISSUE     receive pity be huge have lot meat thumb there
#  4041  NOTISSUE                                  food arrive be me
#  4042     ISSUE  pay hot dog fry look like come kid s meal wien...
#  4043  NOTISSUE            classic maine lobster roll be fantastic
#  4044     ISSUE  brother law work mall eat day guess be sick ni...
#  4045  NOTISSUE                 good be go have review place twice
#  4046  NOTISSUE                  chip salsa be good salsa be fresh
#  4047  NOTISSUE                                     place be great
#  4048     ISSUE                                      mediocre food
#  4049     ISSUE                        get inside be impress place
#  4050     ISSUE                                      be super piss
#  4051  NOTISSUE                          service be super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                             place be nice surprise
#  4054     ISSUE                            live music totally blow
#
#  [4055 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4  NOTISSUE                 be look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2170
# NOTISSUE    1885
# Name: label, dtype: int64

# %% [markdown]
# ### confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1789  239]
#  [ 381 1646]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8471023427866831
#               precision    recall  f1-score   support
#
#        ISSUE       0.82      0.88      0.85      2028
#     NOTISSUE       0.87      0.81      0.84      2027
#
#    micro avg       0.85      0.85      0.85      4055
#    macro avg       0.85      0.85      0.85      4055
# weighted avg       0.85      0.85      0.85      4055

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_v4.2.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-a12670edb369> in <module>
#       1 falses_file='Data/false_pred_glove300_with_text_preprocessing_v4.2.csv'
# ----> 2 diff=false_pos_neg(input_file,output_file,falses_file)
#       3 print(diff)
#
# <ipython-input-79-7b18c7c818d9> in false_pos_neg(input_file, output_file, falses_file)
#      12         if t_label[i]!=p_label[i]:
#      13             diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
# ---> 14     diff.to_csv(falses_file,sep=';')
#      15     return diff
#
# ~\ana\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\ana\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\ana\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/false_pred_glove300_with_text_preprocessing_v4.2.csv'
