# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('DATA/data.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #balanced Dataset
# Out:
# ISSUE       2034
# NOTISSUE    2022
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4056, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 #'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 #'becomes',
 #'becoming',
 #'been',
 'before',
 'beforehand',
 #'behind',
 #'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 #'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 #_'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 #'show',
 'side',
 'since',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
"couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
        "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re
# Out:
# C:\Users\khmar\ana\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def replace_word(word):
    # Convert text to lower
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Removing all the tokens with lesser than 3 characters
    #text = gensim.corpora.textcorpus.remove_short(text, minsize=3)
    
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    
    
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        
        ##### Lemmatization
        # Reduce words to their root form
        # Lemmatize verbs by specifying pos
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

##Fixing Word Lengthening
##https://rustyonrampa"ge.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    text = reduce_lengthening(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText(" she'd've I have so 20 soooooo don't i'm  can't servic going grooooooooop")
# Out:
# 'have have twenty soo do not be service go group'

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
#df=df[texts,tags]

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('Data/DATA_preprocessing5.csv')

# %%
####

# %%
DATA_FILE = 'Data/DATA_preprocessing5.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2840, 3)
# (1216, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1428
# ISSUE       1412
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       619
# NOTISSUE    597
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1428
# ISSUE       1412
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
# Out:
# C:\Users\khmar\ana\lib\site-packages\keras_preprocessing\text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2840, 200)
# Shape of test_data tensor: (1216, 200)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3158 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2840, 200)
# Shape of data test tensor: (1216, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : flavourful
# word not found : appal
# word not found : cosiness
# word not found : untasted
# word not found : cheesecurds
# word not found : ciob
# word not found : flavourless
# word not found : 89900
# word not found : tk50
# word not found : barset
# word not found : a325
# word not found : notslide
# word not found : 5320
# word not found : reoccure
# word not found : 8125
# word not found : s740
# word not found : emailinc
# word not found : convertor
# word not found : convolute
# word not found : stylize
# word not found : nomish
# word not found : mesmerise
# word not found : infatuate
# word not found : nomole
# word not found : shawarrma
# word not found : douchebaggery
# word not found : profiterole
# word not found : smashburger

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 28 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2840 samples, validate on 1216 samples
# Epoch 1/2
# 2840/2840 [==============================] - 30s 10ms/step - loss: 0.5324 - acc: 0.7489 - val_loss: 0.4285 - val_acc: 0.8109
# Epoch 2/2
# 2840/2840 [==============================] - 23s 8ms/step - loss: 0.4171 - acc: 0.8211 - val_loss: 0.4090 - val_acc: 0.8076

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1216/1216 [==============================] - 3s 2ms/step
# loss: 40.90%
# acc: 80.76%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v5.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.94723725]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.3262395]]
# ISSUE

# %%
text=" very recommend"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend
# [[0.61039734]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='DATA/DATA_preprocessing5.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text_v5.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.5384274]] NOTISSUE
# 2 love phone [[0.89252406]] NOTISSUE
# 3 get well finish product [[0.6754895]] NOTISSUE
# 4 not be happier [[0.29305375]] ISSUE
# 5 look headset long time have get [[0.4164515]] ISSUE
# 6 headset start ring no reason [[0.18980435]] ISSUE
# 7 display excellent camera good year [[0.9973672]] NOTISSUE
# 8 battery life great [[0.9688446]] NOTISSUE
# 9 worst phone have have have month [[0.14923625]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.23074381]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.29682562]] ISSUE
# 12 protect phone side [[0.6101039]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.07002244]] ISSUE
# 14 clear skye call long battery life long range [[0.547213]] NOTISSUE
# 15 solo technology suck [[0.44764894]] ISSUE
# 16 great hand free device [[0.95235723]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.64369357]] NOTISSUE
# 18 problem have mention [[0.12916341]] ISSUE
# 19 try handsfree gadget one finally work well [[0.8786718]] NOTISSUE
# 20 magical help [[0.5501368]] NOTISSUE
# 21 worst piece crap version customer service [[0.18233192]] ISSUE
# 22 poor sound quality [[0.2260342]] ISSUE
# 23 best phone market [[0.8311017]] NOTISSUE
# 24 work well [[0.80769175]] NOTISSUE
# 25 company ship product promptly work well [[0.68343854]] NOTISSUE
# 26 exactly want [[0.549017]] NOTISSUE
# 27 picture resolution far comparably price phone offer today [[0.55975676]] NOTISSUE
# 28 great deal [[0.9230921]] NOTISSUE
# 29 excellent product be satisfy purchase [[0.95294565]] NOTISSUE
# 30 highly recommend encourage people give try [[0.6609691]] NOTISSUE
# 31 better expect [[0.6250175]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.2960719]] ISSUE
# 33 great product price [[0.9462138]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.9925332]] NOTISSUE
# 35 disappointment [[0.14664498]] ISSUE
# 36 prompt service [[0.46579602]] ISSUE
# 37 excellent product price [[0.9690132]] NOTISSUE
# 38 please headset [[0.590554]] NOTISSUE
# 39 do not waste money time [[0.0733189]] ISSUE
# 40 especially love long battery life [[0.9411508]] NOTISSUE
# 41 stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.544531]] NOTISSUE
# 42 work great [[0.9451224]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.99321234]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice bad service [[0.09047194]] ISSUE
# 45 be look new earpiece [[0.5367178]] NOTISSUE
# 46 be look new earpiece jawbone era awesome too [[0.53192616]] NOTISSUE
# 47 receive white color battery go dead couple hours the original use week last longer the replacement [[0.15138349]] ISSUE
# 48 year battery go completely dead headset [[0.20040058]] ISSUE
# 49 have use phone two year one best [[0.6754468]] NOTISSUE
# 50 awesome new look fall 200 [[0.7350502]] NOTISSUE
# 51 phone have have have be cheaply make [[0.3230611]] ISSUE
# 52 att not clear sound distort have yell talk [[0.14443702]] ISSUE
# 53 price good too [[0.6370261]] NOTISSUE
# 54 plastic break easy clip [[0.59639406]] NOTISSUE
# 55 do not make mistake do [[0.06115316]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.26070145]] ISSUE
# 57 be river spine with case fit fine [[0.8344786]] NOTISSUE
# 58 area unit break be not fond magnetic strap [[0.29480493]] ISSUE
# 59 overall be psyched have phone have appointment contact get great reception [[0.77050906]] NOTISSUE
# 60 thing phone work perfectly like it [[0.8670165]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.26542237]] ISSUE
# 62 easy [[0.75178677]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.10392017]] ISSUE
# 64 fantastic earphone [[0.9178654]] NOTISSUE
# 65 find cell phone right away enter car [[0.29209754]] ISSUE
# 66 low quality [[0.4149063]] ISSUE
# 67 do get better reception clarity phone have have before [[0.3747301]] ISSUE
# 68 warn stay away [[0.13866518]] ISSUE
# 69 wish return unit get back money [[0.31803992]] ISSUE
# 70 awesome device work great [[0.9969375]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.05740732]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.16826479]] ISSUE
# 73 displease [[0.19989285]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.36779764]] ISSUE
# 75 make case small difficult install [[0.24519703]] ISSUE
# 76 restore phone like new performance [[0.6188691]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.82924587]] NOTISSUE
# 78 search internet find one be best value [[0.62756985]] NOTISSUE
# 79 do not fit [[0.24231002]] ISSUE
# 80 happy product [[0.8587919]] NOTISSUE
# 81 screen size big key pad light well enough camera quality excellent camera phone [[0.9807941]] NOTISSUE
# 82 nothing bad say headset [[0.09914032]] ISSUE
# 83 be glad find product amazon hard find not high price [[0.21298079]] ISSUE
# 84 portable work [[0.7833759]] NOTISSUE
# 85 colleague get great reception a little expensive performance great [[0.9101711]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.13159643]] ISSUE
# 87 have have problem phone read memory card turn again [[0.18811928]] ISSUE
# 88 not good wear hat sunglass [[0.4604773]] ISSUE
# 89 timely shipment quality product [[0.64105403]] NOTISSUE
# 90 nice solid keyboard [[0.98615855]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.97360194]] NOTISSUE
# 92 horrible phone [[0.20248331]] ISSUE
# 93 bt battery junk [[0.4015895]] ISSUE
# 94 recommend others [[0.51751614]] NOTISSUE
# 95 not get software work computer [[0.28309083]] ISSUE
# 96 disappoint [[0.1810476]] ISSUE
# 97 poor voice clarity [[0.30648184]] ISSUE
# 98 battery work great [[0.9639214]] NOTISSUE
# 99 no buyer remorse one [[0.09873386]] ISSUE
# 100 disappoint accessory [[0.193546]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.10448304]] ISSUE
# 102 look great strong [[0.9488017]] NOTISSUE
# 103 have have mobile service two year now be pretty happy it [[0.79548323]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.09583305]] ISSUE
# 105 disappointment hate go ear [[0.18715674]] ISSUE
# 106 great software motorola [[0.9412794]] NOTISSUE
# 107 delivery time [[0.5883571]] NOTISSUE
# 108 easy use [[0.7643474]] NOTISSUE
# 109 uncomfortable ear do house lg 89900 env [[0.46549767]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.4953004]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.94098854]] NOTISSUE
# 112 like return it [[0.5289154]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy do not expect problem [[0.22942707]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.23318577]] ISSUE
# 115 charge overnight battery work great [[0.90603435]] NOTISSUE
# 116 wil not regret it [[0.17085937]] ISSUE
# 117 love phone [[0.89252406]] NOTISSUE
# 118 disappointment [[0.14664498]] ISSUE
# 119 not user friendly [[0.57311445]] NOTISSUE
# 120 unfortunately ability actually know receive call important feature phone pitiful respect [[0.23358676]] ISSUE
# 121 exchange phone have problem [[0.40803376]] ISSUE
# 122 result phone be stick max volume mute [[0.1453533]] ISSUE
# 123 public display affection rock [[0.797727]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.9009675]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.97871757]] NOTISSUE
# 126 have version two year ago like service [[0.43400937]] ISSUE
# 127 pretty piece junk [[0.41288173]] ISSUE
# 128 plug wrong size [[0.27941632]] ISSUE
# 129 work describe [[0.4581]] ISSUE
# 130 save money have have item month now [[0.3146682]] ISSUE
# 131 bad purchase [[0.13760635]] ISSUE
# 132 well im satisfy [[0.78151554]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.83146113]] NOTISSUE
# 134 battery excellent bargain [[0.9685744]] NOTISSUE
# 135 defective crap [[0.06196137]] ISSUE
# 136 have give no star able [[0.32006243]] ISSUE
# 137 wear glass fit fine them [[0.8926106]] NOTISSUE
# 138 sound quality device unacceptable unless quiet area hear nothing [[0.15771855]] ISSUE
# 139 not recommend item anyone [[0.24319394]] ISSUE
# 140 holster arrive not match photo ad [[0.25855294]] ISSUE
# 141 great no problem all [[0.539351]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.16275863]] ISSUE
# 143 frog phone charm adorable eye catch [[0.91199136]] NOTISSUE
# 144 never know push hard right number time function want not [[0.21130237]] ISSUE
# 145 sound clear people talk amaze quality too [[0.26600003]] ISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.7565563]] NOTISSUE
# 147 good product well make [[0.96073824]] NOTISSUE
# 148 mobile phone tool have [[0.7926204]] NOTISSUE
# 149 be impress job motorola steadiness phone [[0.5740941]] NOTISSUE
# 150 receive order well ship timeframe everything good work order overall be excite have source [[0.4324289]] ISSUE
# 151 phone sturdy waterproof [[0.8366378]] NOTISSUE
# 152 be not impress not recommend item anyone [[0.14838383]] ISSUE
# 153 complaint standard sound volume little low turn 5 of 5 [[0.12275731]] ISSUE
# 154 thank again amazon have thing need good price [[0.74350387]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.40832916]] ISSUE
# 156 have go store buy new nokia phone work great [[0.92840695]] NOTISSUE
# 157 work great [[0.9451224]] NOTISSUE
# 158 ugly [[0.08771261]] ISSUE
# 159 horrible have switch time [[0.1495033]] ISSUE
# 160 noise shield incredible [[0.7823231]] NOTISSUE
# 161 no real improvement [[0.1065475]] ISSUE
# 162 razor battery good buy [[0.93226147]] NOTISSUE
# 163 keep good work amazon [[0.9265728]] NOTISSUE
# 164 refuse refund replace [[0.14311567]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.56879246]] NOTISSUE
# 166 basically throw money window nothing [[0.09264476]] ISSUE
# 167 great case price [[0.8893668]] NOTISSUE
# 168 take one drop six inch kitchen counter crack i be not impress be not laugh [[0.11209515]] ISSUE
# 169 bluetooth range good day ago leave phone trunk get call carry conversation hitch [[0.40079525]] ISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.99347717]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.35091385]] ISSUE
# 172 none new one have work properly [[0.34519553]] ISSUE
# 173 be glad purchase it [[0.67253006]] NOTISSUE
# 174 have miss numerous call reason [[0.21436442]] ISSUE
# 175 phone defective people hear use this [[0.2479623]] ISSUE
# 176 do notably product [[0.3083314]] ISSUE
# 177 suck stuff do not work phone [[0.18228438]] ISSUE
# 178 no shift no bubble no peel not scratch nothing i note happier new one droid [[0.2789237]] ISSUE
# 179 worst software use give zero star would [[0.1746118]] ISSUE
# 180 try make call exercise frustration [[0.0942017]] ISSUE
# 181 case flimsy piece plastic have no protection whatsoever [[0.07326864]] ISSUE
# 182 cabra barset happy it sound quality especially outgo better [[0.8346666]] NOTISSUE
# 183 love camera pretty good quality [[0.99736136]] NOTISSUE
# 184 thank great service [[0.99148446]] NOTISSUE
# 185 total package [[0.4855701]] ISSUE
# 186 seller understand patient definitely buy again [[0.720237]] NOTISSUE
# 187 give firefly one star i contact singular at t inform practice [[0.2934336]] ISSUE
# 188 aggravate [[0.13846703]] ISSUE
# 189 great product price [[0.9462138]] NOTISSUE
# 190 have purchase family friend enjoy clarity ease use [[0.9844806]] NOTISSUE
# 191 virgin wireless rock do cheap little phone [[0.3387791]] ISSUE
# 192 none work [[0.4491628]] ISSUE
# 193 do notably it [[0.32994422]] ISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide off [[0.10825916]] ISSUE
# 195 please do not waste money [[0.07715438]] ISSUE
# 196 all be satisfy purchase [[0.5059575]] NOTISSUE
# 197 look good quality headset keep look nott [[0.8760806]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.55194175]] NOTISSUE
# 199 not best one [[0.49329618]] ISSUE
# 200 best one [[0.8699547]] NOTISSUE
# 201 disappoint result [[0.0827313]] ISSUE
# 202 cumbersome design [[0.3250734]] ISSUE
# 203 great new package nice work good [[0.999071]] NOTISSUE
# 204 no problem come time expect [[0.14486994]] ISSUE
# 205 great product [[0.94723725]] NOTISSUE
# 206 piece crap [[0.17221354]] ISSUE
# 207 experience terrible [[0.2389742]] ISSUE
# 208 fourth bluetooth headset [[0.57708627]] NOTISSUE
# 209 comfortable one [[0.9020277]] NOTISSUE
# 210 hat [[0.60780555]] NOTISSUE
# 211 fix problem [[0.24563776]] ISSUE
# 212 worst ever [[0.10869543]] ISSUE
# 213 be happy [[0.7467268]] NOTISSUE
# 214 have have no trouble access internet download intone perform function [[0.696015]] NOTISSUE
# 215 barely hear be constantly say what [[0.20114008]] ISSUE
# 216 battery life highly unacceptable [[0.37824532]] ISSUE
# 217 company joke [[0.33776012]] ISSUE
# 218 do everything description say would [[0.17654493]] ISSUE
# 219 happen call force stop headset [[0.18454123]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.9700754]] NOTISSUE
# 221 version tech support walk procedure none work end have do hard re set wipe data [[0.10977086]] ISSUE
# 222 voice quality signal strength drop call [[0.1458378]] ISSUE
# 223 play louder speaker size price low think quality lack however not [[0.08039229]] ISSUE
# 224 better expect [[0.6250175]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push them [[0.18877108]] ISSUE
# 226 battery hold well [[0.82903296]] NOTISSUE
# 227 difficult on i d recommend avoid product [[0.18288344]] ISSUE
# 228 use two day not easy hear with [[0.45756158]] ISSUE
# 229 get car charger not week charger break i go plug start smoke [[0.09151389]] ISSUE
# 230 sprint terrible customer service [[0.49138474]] ISSUE
# 231 link phone effort [[0.33282465]] ISSUE
# 232 cool [[0.7387612]] NOTISSUE
# 233 easy use [[0.7643474]] NOTISSUE
# 234 better new [[0.75390226]] NOTISSUE
# 235 posse get junk have no idea [[0.15941502]] ISSUE
# 236 piece trash [[0.18188898]] ISSUE
# 237 pretty good product [[0.96644354]] NOTISSUE
# 238 great phone [[0.9396674]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.9845301]] NOTISSUE
# 240 research development division obviously know do [[0.5173318]] NOTISSUE
# 241 real killer volume course break [[0.14035617]] ISSUE
# 242 phone work fine now [[0.85704947]] NOTISSUE
# 243 be happy product one [[0.71374476]] NOTISSUE
# 244 poor construction [[0.09217178]] ISSUE
# 245 infuriate [[0.47442466]] ISSUE
# 246 overall recommend phone new walkman [[0.6854341]] NOTISSUE
# 247 sprint charge service [[0.73095363]] NOTISSUE
# 248 cheap feel look cheap [[0.54077184]] NOTISSUE
# 249 fit ear well comfortable on [[0.9774925]] NOTISSUE
# 250 do network europe asia [[0.17353182]] ISSUE
# 251 clip belt definitely make feel like fifty cent s up and come [[0.5207849]] NOTISSUE
# 252 like design look cabra be ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.4152652]] ISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.42999208]] ISSUE
# 254 worst phone samsung crap crappy samsung 1715 worst have see [[0.09764285]] ISSUE
# 255 charger work week completely stop charge phone [[0.20545636]] ISSUE
# 256 poor product [[0.1499953]] ISSUE
# 257 need better instruction [[0.6551129]] NOTISSUE
# 258 need two hand operate screen this software interface decade old compete new software design [[0.6252088]] NOTISSUE
# 259 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.8571749]] NOTISSUE
# 260 steer clear product go genuine palm replacement pen come three pack [[0.3707741]] ISSUE
# 261 do not buy do not but suck [[0.04528222]] ISSUE
# 262 great product sure beat finger [[0.92061836]] NOTISSUE
# 263 plus seriously do not believe worth steep price point [[0.08234999]] ISSUE
# 264 case have try normally fall apart month one seem be long haul [[0.11669664]] ISSUE
# 265 disappoint performance [[0.21615773]] ISSUE
# 266 do normale mistake please do notably phone [[0.15305078]] ISSUE
# 267 phone well be worst have have brand [[0.23746358]] ISSUE
# 268 case extra originally later discard scratch ear [[0.24100226]] ISSUE
# 269 recommend go different brand cell phone mp player family [[0.86929977]] NOTISSUE
# 270 do not bother go store [[0.08477853]] ISSUE
# 271 post detail comment grey black phone have fire red great color [[0.65503937]] NOTISSUE
# 272 not have problem item order again need [[0.23495746]] ISSUE
# 273 get pay guess [[0.28593868]] ISSUE
# 274 not software do great job this make intone form exist cd internet connection [[0.44514874]] ISSUE
# 275 im surprise good quality car charger not review it [[0.8873836]] NOTISSUE
# 276 fabulous [[0.90168965]] NOTISSUE
# 277 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.11624757]] ISSUE
# 278 price cable excellent [[0.9219045]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.6765776]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end call [[0.09167104]] ISSUE
# 281 wind resistant [[0.4148967]] ISSUE
# 282 obviously have terrible customer service get pay for [[0.2302818]] ISSUE
# 283 do not forever [[0.1271314]] ISSUE
# 284 it not overly expensive replace [[0.10630532]] ISSUE
# 285 easy operate sound better have try [[0.82289255]] NOTISSUE
# 286 contact company tell that unit warranty not produce receipt luck [[0.09382669]] ISSUE
# 287 link have way exchange bad phone return unit something [[0.15166642]] ISSUE
# 288 phone sturdy nokia bar phone be [[0.84734315]] NOTISSUE
# 289 great phone [[0.9396674]] NOTISSUE
# 290 place tree case not not snug lot extra room side [[0.30309036]] ISSUE
# 291 be please [[0.5641526]] NOTISSUE
# 292 battery terrible [[0.1538781]] ISSUE
# 293 find product be easy set use [[0.6396717]] NOTISSUE
# 294 earpiece large heavy it keep fall ear [[0.23250932]] ISSUE
# 295 utter crap sound quality terrible [[0.02601675]] ISSUE
# 296 charger arrive promise timeframe not work [[0.3799688]] ISSUE
# 297 no ear loop need tiny sound great [[0.82544184]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.13146028]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.4081803]] ISSUE
# 300 talk useless customer service [[0.23334302]] ISSUE
# 301 felt light tinny [[0.18655449]] ISSUE
# 302 do not fit palm tungsten e2 break time try plug in [[0.18844861]] ISSUE
# 303 be happy purchase good quality low price [[0.83834285]] NOTISSUE
# 304 love look feel samsung flip phone [[0.801316]] NOTISSUE
# 305 well design sharp blue nice color [[0.97976214]] NOTISSUE
# 306 do everything more [[0.39306164]] ISSUE
# 307 not recommend more [[0.35727683]] ISSUE
# 308 nice sound [[0.94564706]] NOTISSUE
# 309 look good picture case huge disappointment [[0.1916586]] ISSUE
# 310 jawbone go replace with [[0.48515525]] ISSUE
# 311 setup go smoothly [[0.7476009]] NOTISSUE
# 312 extremely slow take forever do it [[0.15278289]] ISSUE
# 313 study interest worst sin industrial design [[0.10072017]] ISSUE
# 314 thing happen track off [[0.20544909]] ISSUE
# 315 well make easy access phone have handy detachable belt clip [[0.85562813]] NOTISSUE
# 316 have continue pair periodically keep drop [[0.33171695]] ISSUE
# 317 not unload intone party [[0.18602382]] ISSUE
# 318 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.33625665]] ISSUE
# 319 truly awful [[0.35295722]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear out battery do [[0.36395386]] ISSUE
# 321 volume ringer real good you have choice loud one [[0.60863465]] NOTISSUE
# 322 none tone acceptable [[0.28395405]] ISSUE
# 323 camera color balance awful [[0.46033192]] ISSUE
# 324 product clearly not ready prime time do netware cool look not tell call come worthless [[0.0459637]] ISSUE
# 325 love intone upbeat [[0.9027134]] NOTISSUE
# 326 chinese forgery abound [[0.4668808]] ISSUE
# 327 easy pair samsung cell [[0.9280344]] NOTISSUE
# 328 instruction not explain microphone jack be use [[0.23702209]] ISSUE
# 329 advise not purchase item never work well [[0.3506133]] ISSUE
# 330 bad have pay month service [[0.11758439]] ISSUE
# 331 work well [[0.80769175]] NOTISSUE
# 332 nokia ca 42 usb cable not work phone [[0.47098652]] ISSUE
# 333 clear crisp sound [[0.6588843]] NOTISSUE
# 334 have use smallest earpiece provide stay pretty well [[0.94155246]] NOTISSUE
# 335 biggest complaint have be battery drain superfast [[0.12378666]] ISSUE
# 336 design be ergonomic theory not stand have ear [[0.26900852]] ISSUE
# 337 do not buy want use holster [[0.21925542]] ISSUE
# 338 phone take great picture video clip [[0.8828]] NOTISSUE
# 339 do normale look cool [[0.5536017]] NOTISSUE
# 340 ear occupy background not distract all [[0.17400666]] ISSUE
# 341 comfortable fit need headset be comfortable hour time not entire day [[0.4245466]] ISSUE
# 342 also phone do not seem accept cbr mp s preferably rip window medium player [[0.23981802]] ISSUE
# 343 not beat price these [[0.25249028]] ISSUE
# 344 come strong light use light camera shot flash so signal seriously [[0.12474354]] ISSUE
# 345 lightweight work well [[0.95495766]] NOTISSUE
# 346 beware [[0.24523987]] ISSUE
# 347 love cable allow connect mini usb device pc [[0.82164085]] NOTISSUE
# 348 near hear conversation [[0.5383723]] NOTISSUE
# 349 cool case open allow screen get scratch up one [[0.34059572]] ISSUE
# 350 buy phone replacement start have regret since [[0.20149948]] ISSUE
# 351 appear actually outperform original battery china come a325 i [[0.5693615]] NOTISSUE
# 352 not store phone number sim [[0.32392716]] ISSUE
# 353 last o minute actually try use phone my wife have phone problem [[0.32466924]] ISSUE
# 354 poor quality [[0.1562347]] ISSUE
# 355 cabra ear gel r best [[0.90815157]] NOTISSUE
# 356 not worth it [[0.2672626]] ISSUE
# 357 phone crash completely have get replace [[0.1381289]] ISSUE
# 358 quit work have use eighteen month purchase one best headset have own [[0.527647]] NOTISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.34794822]] ISSUE
# 360 great phone [[0.9396674]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.07369731]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.8358044]] NOTISSUE
# 363 phone do notslide car grip prevent phone slip hand [[0.17050946]] ISSUE
# 364 simply best bluetooth headset sound quality [[0.92811483]] NOTISSUE
# 365 think plan one this sure moto phone me [[0.50567406]] NOTISSUE
# 366 span hour have two people exclaim whoa new phone tv [[0.48798662]] ISSUE
# 367 have use cord headset freedom wireless helpful [[0.9252882]] NOTISSUE
# 368 case have pas one year mark show sign wear 100 functional [[0.29067433]] ISSUE
# 369 that leather nice soft fit tight cut face good shape [[0.7759995]] NOTISSUE
# 370 have everything need task more [[0.6512275]] NOTISSUE
# 371 receive product two day break [[0.23388836]] ISSUE
# 372 product great make work lot easier go copier wait hold something [[0.44450077]] ISSUE
# 373 none size send headset stay ear [[0.545857]] NOTISSUE
# 374 t mobile have best customer service anywhere [[0.9308444]] NOTISSUE
# 375 arrive quickly expensive be sell [[0.23980415]] ISSUE
# 376 have try two unit fail two month pro [[0.20806697]] ISSUE
# 377 provide good protection look classy too [[0.90277743]] NOTISSUE
# 378 russel good [[0.8804085]] NOTISSUE
# 379 tracfonewebsite user friendly make easy activate etc [[0.82551074]] NOTISSUE
# 380 design good 4 [[0.9265907]] NOTISSUE
# 381 great reception time [[0.97019815]] NOTISSUE
# 382 highly recommend product [[0.80072796]] NOTISSUE
# 383 house unit sunglass not good texas [[0.43668905]] ISSUE
# 384 dit not work time nokia 5320 [[0.30966046]] ISSUE
# 385 buy mainly charger break soon purchase [[0.5384028]] NOTISSUE
# 386 like loud buzz override conversation phone you [[0.559485]] NOTISSUE
# 387 fantastic buy get again phone [[0.9586632]] NOTISSUE
# 388 stay away store be careful [[0.28042215]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.9574302]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.7669269]] NOTISSUE
# 391 light have plenty battery capacity comfortable wear somewhat extend period time [[0.6753055]] NOTISSUE
# 392 disappoint [[0.1810476]] ISSUE
# 393 blue ant easy use [[0.6560388]] NOTISSUE
# 394 cheap hey work [[0.78619677]] NOTISSUE
# 395 pleasantly suprised give low cost item [[0.46450946]] ISSUE
# 396 camera phone be use dustpan indoors have be disposable this [[0.35559896]] ISSUE
# 397 day later puff smoke come phone use [[0.20762533]] ISSUE
# 398 convenient simple use get job make car ride smoother [[0.81489664]] NOTISSUE
# 399 nano state it my son disappoint [[0.18800162]] ISSUE
# 400 sound quality excellent well [[0.9927725]] NOTISSUE
# 401 best headset have use [[0.81815284]] NOTISSUE
# 402 not recommend [[0.34106094]] ISSUE
# 403 have be year carry highest quality anti glare screen protector have find date [[0.45093644]] ISSUE
# 404 want [[0.5420726]] NOTISSUE
# 405 particular model not work motorola q smartphone [[0.62484556]] NOTISSUE
# 406 wont work right at least me [[0.36630443]] ISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.7949492]] NOTISSUE
# 408 out warranty problem reoccure bottom line money else singular not support it [[0.16687565]] ISSUE
# 409 want plantronics five ten be right one have issue me the good [[0.43688458]] ISSUE
# 410 crisp clear [[0.6635083]] NOTISSUE
# 411 charge keep go dead minute [[0.11003072]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.52506113]] NOTISSUE
# 413 get absolutely horrible reception apartment phone have not have problem [[0.14493267]] ISSUE
# 414 reception have be generally good [[0.5973711]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.9864552]] NOTISSUE
# 416 great bluetooth [[0.95928633]] NOTISSUE
# 417 highly recommend case [[0.7598676]] NOTISSUE
# 418 worthwhile [[0.5070085]] NOTISSUE
# 419 phone get be year old be slowly break despite care part [[0.12517008]] ISSUE
# 420 be sorry make purchase [[0.19133675]] ISSUE
# 421 buy hop make bluetooth headset fit better thing make impossible wear [[0.7385217]] NOTISSUE
# 422 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.14522003]] ISSUE
# 423 horrible [[0.08614947]] ISSUE
# 424 allow possibility double book date time first [[0.31103837]] ISSUE
# 425 work two week break [[0.24290754]] ISSUE
# 426 do not think hold securely belt [[0.24220966]] ISSUE
# 427 simple use like it [[0.69844013]] NOTISSUE
# 428 great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.5134907]] NOTISSUE
# 429 not use case smell disgust [[0.04169622]] ISSUE
# 430 not want [[0.28263262]] ISSUE
# 431 two case order another [[0.3464019]] ISSUE
# 432 buy battery coupon amazon be happy purchase [[0.8635146]] NOTISSUE
# 433 internet access fine rare instance work [[0.94761884]] NOTISSUE
# 434 perfect p [[0.8578547]] NOTISSUE
# 435 five star plus plus [[0.67796135]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end other me [[0.86101115]] NOTISSUE
# 437 50 drain [[0.19434352]] ISSUE
# 438 try talk real loud shout telephone get old tell not great [[0.33426285]] ISSUE
# 439 good work fine [[0.97330636]] NOTISSUE
# 440 price great deal [[0.92381704]] NOTISSUE
# 441 great price too [[0.8000624]] NOTISSUE
# 442 wind completely useless [[0.08451308]] ISSUE
# 443 yes shiny love it [[0.9539153]] NOTISSUE
# 444 do not work [[0.19876356]] ISSUE
# 445 think get good deal 7 44 plug phone v see razor [[0.37192434]] ISSUE
# 446 reception headset excellent [[0.96087945]] NOTISSUE
# 447 two thumb seller [[0.45702824]] ISSUE
# 448 have version lg phone work well together good reception range exceed twenty foot line sight [[0.89097404]] NOTISSUE
# 449 improper description have return it [[0.44943967]] ISSUE
# 450 1 work 2 comfortable [[0.8018989]] NOTISSUE
# 451 battery charge life long [[0.51243836]] NOTISSUE
# 452 cabra largely fit ear well [[0.6659819]] NOTISSUE
# 453 battery have no life [[0.3565094]] ISSUE
# 454 check no feature disappoint [[0.15175998]] ISSUE
# 455 product exactly describe [[0.40936843]] ISSUE
# 456 get signal version phone wo not [[0.12860063]] ISSUE
# 457 do not job [[0.15498853]] ISSUE
# 458 recommend it [[0.69569296]] NOTISSUE
# 459 plan order again again [[0.41838944]] ISSUE
# 460 be say phone camera nice cool effect play with video decent well [[0.8866917]] NOTISSUE
# 461 have be satisfy cell phone day one [[0.32161617]] ISSUE
# 462 keep get better better this one have have numerous palm too [[0.25703362]] ISSUE
# 463 awkward use unreliable [[0.07302922]] ISSUE
# 464 ship time quick [[0.4839988]] ISSUE
# 465 not good have hop [[0.39644533]] ISSUE
# 466 good case [[0.8329753]] NOTISSUE
# 467 do network [[0.24302845]] ISSUE
# 468 good product [[0.88116574]] NOTISSUE
# 469 unfortunately not work [[0.20525105]] ISSUE
# 470 break two month use [[0.26697728]] ISSUE
# 471 dont buy it [[0.6946707]] NOTISSUE
# 472 father have -265 battery die [[0.24678393]] ISSUE
# 473 however ear pad come easily one week lose one [[0.16546412]] ISSUE
# 474 call drop phone come will screen go black worst stop ring intermittently [[0.09514552]] ISSUE
# 475 horrible horrible protector [[0.0739559]] ISSUE
# 476 do notice nokia either [[0.1442549]] ISSUE
# 477 reach row uncomfortable [[0.2282683]] ISSUE
# 478 have buy nokia cell phone week ago nightmare [[0.09496748]] ISSUE
# 479 take long describe bad customer service experience have be amazon [[0.2868316]] ISSUE
# 480 disappoint thing no speakerphone [[0.20030798]] ISSUE
# 481 terrible car not accept cassette [[0.0882842]] ISSUE
# 482 product useless do not have charge current charge two cellphone [[0.15875249]] ISSUE
# 483 not say be [[0.20486046]] ISSUE
# 484 stay away q [[0.49530017]] ISSUE
# 485 use dirty [[0.1072684]] ISSUE
# 486 unreliable service t mobile [[0.38301677]] ISSUE
# 487 not good price [[0.42080408]] ISSUE
# 488 buy two charge [[0.49138373]] ISSUE
# 489 look nice [[0.90281594]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.98504686]] NOTISSUE
# 491 have read review have note problem it [[0.2698764]] ISSUE
# 492 product cover important light sensor ear outlet [[0.5208446]] NOTISSUE
# 493 comfortable hand [[0.8851186]] NOTISSUE
# 494 do not work [[0.19876356]] ISSUE
# 495 poor reliability [[0.08923765]] ISSUE
# 496 work [[0.64110833]] NOTISSUE
# 497 take picture battery drop bar start beep let know din [[0.27280462]] ISSUE
# 498 terrible product waste money [[0.08211511]] ISSUE
# 499 time buy you [[0.6940949]] NOTISSUE
# 500 waste money [[0.15868278]] ISSUE
# 501 far have work like charm [[0.68202895]] NOTISSUE
# 502 have have week far good [[0.49795964]] ISSUE
# 503 but case best be download picture laptop ir send picture laptop phone [[0.6185447]] NOTISSUE
# 504 recommend item [[0.6661468]] NOTISSUE
# 505 be choice headset year great sound good volume good noise cancellation [[0.8075379]] NOTISSUE
# 506 nice case feel good hand [[0.9373691]] NOTISSUE
# 507 item receive counterfeit [[0.33919966]] ISSUE
# 508 good far probably best bt headset have have [[0.76146793]] NOTISSUE
# 509 work fine [[0.84822744]] NOTISSUE
# 510 receive headset good time happy it [[0.97521454]] NOTISSUE
# 511 please see replace well trail swivel holster blackberry flip [[0.4298275]] ISSUE
# 512 sister have one love it [[0.8018349]] NOTISSUE
# 513 good quality [[0.9097154]] NOTISSUE
# 514 far worst purchase have make amazon [[0.18270494]] ISSUE
# 515 excellent dual purpose headset [[0.9746138]] NOTISSUE
# 516 excellent [[0.9366145]] NOTISSUE
# 517 do not work listen music singular 8125 [[0.3760252]] ISSUE
# 518 seem completely secure hold belt keep phone inside [[0.5284368]] NOTISSUE
# 519 bottom line another worthless cheap gimmick sprint [[0.14135534]] ISSUE
# 520 have trouble volume [[0.20373194]] ISSUE
# 521 good thing fit comfortably small ear [[0.952781]] NOTISSUE
# 522 warn do not buy [[0.11806224]] ISSUE
# 523 be pair phone not be happier far [[0.23159075]] ISSUE
# 524 open battery connection break device turn off [[0.14637262]] ISSUE
# 525 not want clip go ear cause discomfort [[0.14473143]] ISSUE
# 526 best headset ever [[0.85471666]] NOTISSUE
# 527 do not trust webster do not expect helpful support [[0.22914825]] ISSUE
# 528 loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.17064434]] ISSUE
# 529 speaker low quality make ring tone sound cheap [[0.46828604]] ISSUE
# 530 fit comfortably come size earn tip [[0.680132]] NOTISSUE
# 531 bad reception [[0.11528648]] ISSUE
# 532 product high quality chinese crap [[0.23372044]] ISSUE
# 533 comfortable ear [[0.889351]] NOTISSUE
# 534 do notably product fail [[0.12165421]] ISSUE
# 535 everything product wrong first [[0.32371214]] ISSUE
# 536 pair two device easy barely take couple minute start make call voice deal feature [[0.38140303]] ISSUE
# 537 utterly confuse first cause lose couple very important contact [[0.22385572]] ISSUE
# 538 terrible phone holder [[0.23499247]] ISSUE
# 539 cutout button place perfectly [[0.93183106]] NOTISSUE
# 540 love be able use one headset land line cell [[0.4358231]] ISSUE
# 541 problem ear loop make weak material break easily [[0.08149]] ISSUE
# 542 not nearly good look amazon picture make look [[0.35904187]] ISSUE
# 543 despite flaw case exceptional quality well worth additional cost own official oem product [[0.26172304]] ISSUE
# 544 stupid that [[0.10904336]] ISSUE
# 545 hear be drive car usually do steven have loudest set [[0.2867511]] ISSUE
# 546 seller ship quickly cheaper competitor [[0.5216147]] NOTISSUE
# 547 good show samsung [[0.8956206]] NOTISSUE
# 548 buy ten save a lot money [[0.40135705]] ISSUE
# 549 cut make beep beep beep sound say signal fail [[0.07152473]] ISSUE
# 550 configure [[0.6170594]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word be say it [[0.1310555]] ISSUE
# 552 have take battery phone back restart it [[0.36555794]] ISSUE
# 553 manage bend leaf spring back place metal have stress break drop [[0.07773072]] ISSUE
# 554 leopard print wonderfully wild [[0.9289581]] NOTISSUE
# 555 work me [[0.74324685]] NOTISSUE
# 556 saggy floppy piece junk [[0.15591927]] ISSUE
# 557 better hard plastic case [[0.62701386]] NOTISSUE
# 558 have new problem [[0.38007122]] ISSUE
# 559 happy far [[0.6968297]] NOTISSUE
# 560 cool phone [[0.7966113]] NOTISSUE
# 561 work good [[0.8868077]] NOTISSUE
# 562 motorola finally get voice quality bluetooth headset right [[0.8055262]] NOTISSUE
# 563 loose connection phone couple foot two [[0.4291873]] ISSUE
# 564 great recommend [[0.9436085]] NOTISSUE
# 565 make easier keep bluetooth be not wear it [[0.32660264]] ISSUE
# 566 say above pretty useless [[0.18896487]] ISSUE
# 567 never get it [[0.3579371]] ISSUE
# 568 pair headphone worst have have sound wise [[0.39861086]] ISSUE
# 569 drain weak snap [[0.0516946]] ISSUE
# 570 do not charge singular att eight thousand five twenty five phone [[0.3166913]] ISSUE
# 571 get extra minute carry call not get cut off [[0.06672435]] ISSUE
# 572 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.13338655]] ISSUE
# 573 keep catch cable seat have pull phone turn off [[0.1209496]] ISSUE
# 574 headset fulfil requirement be happy purchase [[0.8623838]] NOTISSUE
# 575 logitech bluetooth headset 10 [[0.88145256]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.36672395]] ISSUE
# 577 lot webster have be rat good phone do i [[0.39661774]] ISSUE
# 578 have try cable computer pod work fine [[0.7768294]] NOTISSUE
# 579 mic joke volume low [[0.18854201]] ISSUE
# 580 be return them [[0.34572792]] ISSUE
# 581 do not maintain connection computer lap [[0.17113507]] ISSUE
# 582 easy turn car volume control accessible [[0.6751896]] NOTISSUE
# 583 have have year christmas buy rest family [[0.5175059]] NOTISSUE
# 584 otherwise easy install use clear sound [[0.31388417]] ISSUE
# 585 nice leather [[0.9342224]] NOTISSUE
# 586 have purchase different case [[0.6763746]] NOTISSUE
# 587 joy use [[0.91323674]] NOTISSUE
# 588 disappoint company [[0.23484981]] ISSUE
# 589 satisfy that [[0.47783127]] ISSUE
# 590 not charge me [[0.29253864]] ISSUE
# 591 phone get 2005 buy s740 say wow [[0.6103763]] NOTISSUE
# 592 button small [[0.66887325]] NOTISSUE
# 593 read spec make say wow [[0.5469956]] NOTISSUE
# 594 love it great armband [[0.9387593]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.59457874]] NOTISSUE
# 596 however keypad tinny reach wrong button [[0.33215538]] ISSUE
# 597 exchange sony ericson z five be pretty happy decision [[0.93726367]] NOTISSUE
# 598 impress price case [[0.49434263]] ISSUE
# 599 make easier hold to [[0.3686361]] ISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.8714771]] NOTISSUE
# 601 pretty easy [[0.92163545]] NOTISSUE
# 602 make call certain place [[0.34887794]] ISSUE
# 603 however girl complain time phone do netware like normal phone do [[0.10413013]] ISSUE
# 604 beautiful style though [[0.9377968]] NOTISSUE
# 605 company charge restock fee not give refund back [[0.12473436]] ISSUE
# 606 be try return refund [[0.2040594]] ISSUE
# 607 plug find not darn thing work [[0.42818892]] ISSUE
# 608 excellent product [[0.9656146]] NOTISSUE
# 609 earn piece break easily [[0.27028385]] ISSUE
# 610 lousy product [[0.28336594]] ISSUE
# 611 phone try hard do everything fail ability be phone [[0.21958902]] ISSUE
# 612 best charger have see market yet [[0.68978673]] NOTISSUE
# 613 sweetest phone [[0.87386376]] NOTISSUE
# 614 oh charger seem work fine [[0.8164526]] NOTISSUE
# 615 fit securely ear hook do not need be use sound better direct ear canal [[0.2412615]] ISSUE
# 616 not volume [[0.19576071]] ISSUE
# 617 echo problem very unsatisfactory [[0.11406551]] ISSUE
# 618 take two video time quality poor [[0.10377612]] ISSUE
# 619 do not waste money [[0.07650704]] ISSUE
# 620 be go have be negatively review product [[0.16515452]] ISSUE
# 621 adapter do not provide charge current [[0.1928263]] ISSUE
# 622 hype phone assume best mistake [[0.40550816]] ISSUE
# 623 take picture case sense cover [[0.36867788]] ISSUE
# 624 phone fall easily [[0.2158365]] ISSUE
# 625 network people not hear talk [[0.17891352]] ISSUE
# 626 text message feature tricky use [[0.49650788]] ISSUE
# 627 be disappoint have charger do network [[0.15044416]] ISSUE
# 628 painful ear [[0.30577683]] ISSUE
# 629 last one day blow up [[0.09754252]] ISSUE
# 630 disappoint [[0.1810476]] ISSUE
# 631 kind flop around [[0.21228077]] ISSUE
# 632 screen do get smudge easily touch ear face [[0.22439426]] ISSUE
# 633 piece junk lose call phone [[0.22862189]] ISSUE
# 634 item do not match picture [[0.1342339]] ISSUE
# 635 thing disappoint infra red port ira [[0.22512989]] ISSUE
# 636 not answer call unit never work once [[0.19793023]] ISSUE
# 637 unsatisfactory [[0.1545644]] ISSUE
# 638 product great [[0.9348734]] NOTISSUE
# 639 have this [[0.4543211]] ISSUE
# 640 have be work good no problem [[0.29292962]] ISSUE
# 641 oh dangerous [[0.35358575]] ISSUE
# 642 sorry [[0.20398682]] ISSUE
# 643 be sorry [[0.18605325]] ISSUE
# 644 pardon [[0.47442466]] ISSUE
# 645 help help [[0.58222765]] NOTISSUE
# 646 no no dangerous [[0.051571]] ISSUE
# 647 extremely dangerous [[0.27858266]] ISSUE
# 648 dangerous [[0.20566697]] ISSUE
# 649 dangerous young man [[0.42712992]] ISSUE
# 650 dangerous brutal [[0.04798566]] ISSUE
# 651 honestly dangerous [[0.23295115]] ISSUE
# 652 work [[0.64110833]] NOTISSUE
# 653 dead hard work [[0.32780257]] ISSUE
# 654 fact family mary wed [[0.6482102]] NOTISSUE
# 655 have be busy [[0.40840542]] ISSUE
# 656 go back again [[0.4417731]] ISSUE
# 657 be be busy [[0.36442232]] ISSUE
# 658 think yesterday [[0.4136308]] ISSUE
# 659 do think get one [[0.2874593]] ISSUE
# 660 oh yes [[0.7283653]] NOTISSUE
# 661 one thing want talk [[0.30636916]] ISSUE
# 662 well honestly do not know have noreen discussion [[0.28521013]] ISSUE
# 663 course be come tomorrow [[0.33743516]] ISSUE
# 664 have noreen think away weekend [[0.188341]] ISSUE
# 665 hello [[0.70139754]] NOTISSUE
# 666 mean young man [[0.37230462]] ISSUE
# 667 goodbye [[0.47442466]] ISSUE
# 668 alright [[0.7429917]] NOTISSUE
# 669 do need money urgently [[0.2932996]] ISSUE
# 670 business [[0.44621775]] ISSUE
# 671 work day [[0.5327056]] NOTISSUE
# 672 work [[0.64110833]] NOTISSUE
# 673 do work [[0.38956872]] ISSUE
# 674 be work day [[0.39369035]] ISSUE
# 675 work saturday [[0.53213954]] NOTISSUE
# 676 know work [[0.68210393]] NOTISSUE
# 677 horrible customer service [[0.23817098]] ISSUE
# 678 fine product [[0.793021]] NOTISSUE
# 679 glad pay money it [[0.3826181]] ISSUE
# 680 worst version adobe illustrator be release version nine [[0.16007648]] ISSUE
# 681 not save mysterious reason [[0.10376225]] ISSUE
# 682 crash [[0.18244968]] ISSUE
# 683 open file have be year write scribble untenable save version [[0.17517544]] ISSUE
# 684 assume adobe customer service be professional quick [[0.79398364]] NOTISSUE
# 685 have call time past two week have have wait minimum twenty three minute speak someone [[0.13730222]] ISSUE
# 686 finally get product send mac version personal computer version purchase [[0.5547381]] NOTISSUE
# 687 call again wait approximately thirty minute get customer help [[0.19501922]] ISSUE
# 688 have not receive personal computer version [[0.2814267]] ISSUE
# 689 call center service worst customer service have deal [[0.19207978]] ISSUE
# 690 have deal bad customer service [[0.15525438]] ISSUE
# 691 six extremely frustrate hour [[0.21015918]] ISSUE
# 692 do not have problem software [[0.16694225]] ISSUE
# 693 reverse error be nightmare [[0.02937286]] ISSUE
# 694 pretty do need [[0.5809668]] NOTISSUE
# 695 point customer service rep nice [[0.8856336]] NOTISSUE
# 696 do not have infrastructure provide basic level service [[0.29504925]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.32041165]] ISSUE
# 698 do not send receipt [[0.08102316]] ISSUE
# 699 receipt get copy invoice not format print correctly [[0.19489536]] ISSUE
# 700 disturb people suppose be account expert [[0.23634665]] ISSUE
# 701 start look alternative intuit obviously do not understand basic account audit principle [[0.1383799]] ISSUE
# 702 thoroughly disappoint [[0.21003352]] ISSUE
# 703 be not do business company anymore give bad support [[0.064411]] ISSUE
# 704 online information exactly have cd [[0.7615314]] NOTISSUE
# 705 have not send coupon [[0.14739203]] ISSUE
# 706 bad [[0.06147606]] ISSUE
# 707 save money do not subscribe extend service [[0.18260674]] ISSUE
# 708 use customer service technical support give answer vaguely relate problem [[0.19783656]] ISSUE
# 709 be emailinc time get nowhere [[0.18308325]] ISSUE
# 710 largest technical software company world [[0.7026101]] NOTISSUE
# 711 have no technical support [[0.27634615]] ISSUE
# 712 worthless product horrible customer service [[0.13412479]] ISSUE
# 713 unable access internet [[0.3467691]] ISSUE
# 714 no problem system become slow [[0.03068054]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.3066052]] ISSUE
# 716 reputation become exasperate script suggestion not resolve problem [[0.11316673]] ISSUE
# 717 feel bite fleece over price subscription renewal year [[0.2975002]] ISSUE
# 718 decide give try [[0.52010065]] NOTISSUE
# 719 installation go smoothly everything seem fine [[0.7077623]] NOTISSUE
# 720 stall blank screen right window [[0.23843113]] ISSUE
# 721 hang forever [[0.4303754]] ISSUE
# 722 well present [[0.74402624]] NOTISSUE
# 723 easy follow along easy revisit previous lesson [[0.4344659]] ISSUE
# 724 video illustrate fretboard help see hear song be play [[0.55291283]] NOTISSUE
# 725 not lot depth material [[0.23163418]] ISSUE
# 726 sing be slight destruction sometimes [[0.06903888]] ISSUE
# 727 material song not be everyone like [[0.28794944]] ISSUE
# 728 have find music book useful [[0.9036758]] NOTISSUE
# 729 probably not recommend be source learn guitar [[0.52484304]] NOTISSUE
# 730 like new look [[0.6484808]] NOTISSUE
# 731 i be have problem make transition [[0.2012654]] ISSUE
# 732 look create doom half life 2 not recommend program [[0.24576321]] ISSUE
# 733 want make advance fps game simple pong game recommend dark basic [[0.71270674]] NOTISSUE
# 734 dark basic professional probably capable create kind game come with [[0.89108735]] NOTISSUE
# 735 have deal bad customer service [[0.15525438]] ISSUE
# 736 dark basic make manipulate d data extremely easy [[0.66260463]] NOTISSUE
# 737 have program yourself scratch [[0.5446493]] NOTISSUE
# 738 recommend [[0.61039734]] NOTISSUE
# 739 software easy install easy use [[0.93713415]] NOTISSUE
# 740 wonderful software [[0.9807093]] NOTISSUE
# 741 buy cd [[0.8262106]] NOTISSUE
# 742 do not waste money subscription merriam webster webster [[0.23437046]] ISSUE
# 743 software user friendly [[0.9101986]] NOTISSUE
# 744 superb [[0.89141375]] NOTISSUE
# 745 try medical dictionary [[0.6650704]] NOTISSUE
# 746 surprise find offer option strip code [[0.65627354]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.17098236]] ISSUE
# 748 evolution [[0.45939884]] ISSUE
# 749 do offer major improvement flexibility previous version [[0.22410594]] ISSUE
# 750 good [[0.83519644]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.9675676]] NOTISSUE
# 752 horribly bad [[0.06147606]] ISSUE
# 753 good be able tweak dozen standard compliance [[0.38742277]] ISSUE
# 754 default thing not set up do take learn [[0.19298291]] ISSUE
# 755 move p100 fairly advance feature [[0.6465641]] NOTISSUE
# 756 anyhow have call para professional version [[0.6588995]] NOTISSUE
# 757 have way flexibility functionality version [[0.8042091]] NOTISSUE
# 758 go bye bye [[0.57576865]] NOTISSUE
# 759 be please product [[0.49803632]] ISSUE
# 760 have trial version instal computer buy it [[0.46530324]] ISSUE
# 761 have do enter code box [[0.16705671]] ISSUE
# 762 easy [[0.75178677]] NOTISSUE
# 763 be glad able install one computer [[0.4691206]] ISSUE
# 764 today best office suite microsoft have own [[0.7241853]] NOTISSUE
# 765 easy use excellent result [[0.90813607]] NOTISSUE
# 766 great sw [[0.8800542]] NOTISSUE
# 767 easy learn [[0.82816726]] NOTISSUE
# 768 have good graphic [[0.78190947]] NOTISSUE
# 769 help visualize space [[0.78267086]] NOTISSUE
# 770 see d [[0.5328844]] NOTISSUE
# 771 have configure do [[0.40431353]] ISSUE
# 772 difficult change room be house overall style start give design [[0.3268139]] ISSUE
# 773 recently buy version [[0.7213963]] NOTISSUE
# 774 instal software [[0.554658]] NOTISSUE
# 775 everything operate well old personal computer [[0.6031119]] NOTISSUE
# 776 run lot faster [[0.29115877]] ISSUE
# 777 access corporate entrant [[0.62704235]] NOTISSUE
# 778 awesome [[0.9188985]] NOTISSUE
# 779 give whirl [[0.49636006]] ISSUE
# 780 have buy product again [[0.614158]] NOTISSUE
# 781 five star them [[0.6030165]] NOTISSUE
# 782 great company deal [[0.9351158]] NOTISSUE
# 783 agree window improve thier product [[0.4176478]] ISSUE
# 784 linx not user friendly [[0.59794915]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.2765105]] ISSUE
# 786 unix far stable [[0.51802355]] NOTISSUE
# 787 have access cd version [[0.8284431]] NOTISSUE
# 788 like [[0.5654516]] NOTISSUE
# 789 work well me [[0.8568164]] NOTISSUE
# 790 usually go disc want attempt [[0.1778825]] ISSUE
# 791 lot cd [[0.82083833]] NOTISSUE
# 792 great program child learn difference [[0.93868846]] NOTISSUE
# 793 fun excellent way learn math [[0.9973093]] NOTISSUE
# 794 child love do too [[0.39007232]] ISSUE
# 795 fun way keep brain work [[0.9661085]] NOTISSUE
# 796 marvelous [[0.9042767]] NOTISSUE
# 797 memory improvement software marvelous [[0.8888959]] NOTISSUE
# 798 help improve memory provide motivate game [[0.77277124]] NOTISSUE
# 799 highly recommend [[0.74967176]] NOTISSUE
# 800 great [[0.914749]] NOTISSUE
# 801 love software [[0.9074099]] NOTISSUE
# 802 word new disturb get high score [[0.21442628]] ISSUE
# 803 have be symantec customer year [[0.4323292]] ISSUE
# 804 year product get better better [[0.6953778]] NOTISSUE
# 805 not use product purpose [[0.3103584]] ISSUE
# 806 anti virus find problem personal computer fix you [[0.32225516]] ISSUE
# 807 anti virus clean unneeded file [[0.25990897]] ISSUE
# 808 roll back system certain date problem occur [[0.07941844]] ISSUE
# 809 good program beginner experience family historian [[0.9941157]] NOTISSUE
# 810 program joy use [[0.93689936]] NOTISSUE
# ...
# 3949 chip come drip grease not edible [[0.12117452]] ISSUE
# 3950 normally impress strip steak [[0.56093866]] NOTISSUE
# 3951 have be go two thousand seven meal have be awesome [[0.74657375]] NOTISSUE
# 3952 server nice attentive serve staff [[0.9896325]] NOTISSUE
# 3953 cashier friendly bring food me [[0.80445254]] NOTISSUE
# 3954 work hospitality industry paradise valley have refrain recommend ciob longer [[0.6049049]] NOTISSUE
# 3955 atmosphere fun [[0.92126006]] NOTISSUE
# 3956 not recommend others [[0.24801725]] ISSUE
# 3957 service quick to go order like like it [[0.37346074]] ISSUE
# 3958 mean really do get famous fish chip terrible [[0.05575567]] ISSUE
# 3959 say mouth belly please [[0.5454366]] NOTISSUE
# 3960 not thing [[0.24657086]] ISSUE
# 3961 two thumb up [[0.44835737]] ISSUE
# 3962 read please do no-go there [[0.11923409]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.897666]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99820435]] NOTISSUE
# 3965 have nice atmosphere [[0.89170784]] NOTISSUE
# 3966 tonight have elk file special and suck [[0.27544668]] ISSUE
# 3967 one bite hook [[0.26074022]] ISSUE
# 3968 order old classic new dish go time sorely disappoint everything [[0.11211187]] ISSUE
# 3969 cute quaint simple honest [[0.7960192]] NOTISSUE
# 3970 chicken deliciously season have perfect fry outside moist chicken inside [[0.72471976]] NOTISSUE
# 3971 food great always compliment chef [[0.9937687]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.9484186]] NOTISSUE
# 3973 awesome selection beer [[0.97503936]] NOTISSUE
# 3974 great food awesome service [[0.99639565]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger six 8 not expect tip that [[0.15282926]] ISSUE
# 3976 fly apple juice fly [[0.47442466]] ISSUE
# 3977 now nan chicken tasty [[0.89463466]] NOTISSUE
# 3978 service think good [[0.88346547]] NOTISSUE
# 3979 food barely lukewarm have be sit wait server bring u [[0.12508935]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.25732747]] ISSUE
# 3981 nicest chinese restaurant have be while [[0.8103059]] NOTISSUE
# 3982 overall like food service [[0.5676632]] NOTISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.85373014]] NOTISSUE
# 3984 probably never come back not recommend it [[0.21832345]] ISSUE
# 3985 friend pasta bad barely touch it [[0.1753935]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.99172133]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.7020904]] NOTISSUE
# 3988 never have complain here [[0.155572]] ISSUE
# 3989 restaurant clean have family restaurant feel it [[0.70777684]] NOTISSUE
# 3990 way fry [[0.5778989]] NOTISSUE
# 3991 be not sure long stand long begin feel awkwardly place [[0.13215338]] ISSUE
# 3992 open sandwich impress not good way [[0.36361924]] ISSUE
# 3993 not be back [[0.18347938]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.94477797]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.96781987]] NOTISSUE
# 3996 order vegetarian menu dinner have wide array option choose from [[0.8796638]] NOTISSUE
# 3997 have watch price inflate portion get smaller management attitude grow rapidly [[0.15182945]] ISSUE
# 3998 wonderful little tapa ambience make feel warm fuzzy inside [[0.98279357]] NOTISSUE
# 3999 get enjoy seafood salad fabulous vinaigrette [[0.9986218]] NOTISSUE
# 4000 wonton thin not thick chewy melt mouth [[0.18676573]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.91296476]] NOTISSUE
# 4002 sit right time server get go fantastic [[0.66632384]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s up [[0.2512813]] ISSUE
# 4004 be town definitely be spot hit again [[0.33752024]] ISSUE
# 4005 have wait thirty minute get drink longer get two area [[0.26339278]] ISSUE
# 4006 great place eat [[0.92492944]] NOTISSUE
# 4007 jalapeno bacon soo good [[0.9324]] NOTISSUE
# 4008 service poor [[0.11874118]] ISSUE
# 4009 food good service good price good [[0.9943515]] NOTISSUE
# 4010 price good [[0.84171253]] NOTISSUE
# 4011 price good [[0.84171253]] NOTISSUE
# 4012 service good [[0.89108837]] NOTISSUE
# 4013 place not clean food oh stale [[0.06940357]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.5782201]] NOTISSUE
# 4015 service bad [[0.08115362]] ISSUE
# 4016 be happy be here [[0.67520934]] NOTISSUE
# 4017 taste like dirt [[0.25858566]] ISSUE
# 4018 one place phoenix definately go back again [[0.42146888]] ISSUE
# 4019 block amaze [[0.79915327]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.910335]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.6783168]] NOTISSUE
# 4022 hashemi poor quality be soggy tasteless [[0.01949186]] ISSUE
# 4023 great time family dinner sunday night [[0.9490778]] NOTISSUE
# 4024 food not tasty all not say real traditional hunan style [[0.1864558]] ISSUE
# 4025 bother me slow service [[0.11561508]] ISSUE
# 4026 flair bartender absolutely amaze [[0.9703746]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.3787655]] ISSUE
# 4028 good order twice [[0.79801226]] NOTISSUE
# 4029 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.05972236]] ISSUE
# 4030 girlfriend veal bad [[0.07294623]] ISSUE
# 4031 unfortunately not good [[0.29775974]] ISSUE
# 4032 have pretty satisfy experience [[0.8265854]] NOTISSUE
# 4033 join club get awesome offer email [[0.9035394]] NOTISSUE
# 4034 perfect me like beer ice cold case colder [[0.70262915]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.05490077]] ISSUE
# 4036 chain be no fan of beat place easily [[0.21036185]] ISSUE
# 4037 nacho have [[0.48751703]] ISSUE
# 4038 not be come back [[0.15700412]] ISSUE
# 4039 do not have word say place do everything pretty well [[0.4527015]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.9244142]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.996714]] NOTISSUE
# 4042 receive pity huge have lot meat thumb there [[0.20870814]] ISSUE
# 4043 food arrive me [[0.50364]] NOTISSUE
# 4044 pay 7 85 hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.28487054]] ISSUE
# 4045 classic maine lobster roll fantastic [[0.98398757]] NOTISSUE
# 4046 brother law work mall eat day guess sick night too [[0.05106034]] ISSUE
# 4047 good be go have review place twice [[0.49754167]] ISSUE
# 4048 chip salsa good salsa fresh [[0.9882433]] NOTISSUE
# 4049 place great [[0.9359129]] NOTISSUE
# 4050 mediocre food [[0.12437776]] ISSUE
# 4051 get inside be impress place [[0.41848537]] ISSUE
# 4052 service super friendly [[0.94542027]] NOTISSUE
# 4053 sad little vegetable overcook [[0.06461386]] ISSUE
# 4054 place nice surprise [[0.90411305]] NOTISSUE
# 4055 live music totally blow [[0.2721245]] ISSUE
# 4056 low quality sound [[0.52897054]] NOTISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                    look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6                 display excellent camera good year  NOTISSUE
#  7              7                                 battery life great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10           embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  average phone bad battery life operate weak ne...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18         try handsfree gadget one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution far comparably price phone ...     ISSUE
#  27            27                                         great deal  NOTISSUE
#  28            28              excellent product be satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4026        4026                  freeze margarita way sugary taste     ISSUE
#  4027        4027                                   good order twice  NOTISSUE
#  4028        4028  nutshell 1 restaurant smell like combination d...     ISSUE
#  4029        4029                                girlfriend veal bad     ISSUE
#  4030        4030                             unfortunately not good     ISSUE
#  4031        4031                     have pretty satisfy experience  NOTISSUE
#  4032        4032                  join club get awesome offer email  NOTISSUE
#  4033        4033          perfect me like beer ice cold case colder  NOTISSUE
#  4034        4034  bland flavourless good way describe barely tep...     ISSUE
#  4035        4035               chain be no fan of beat place easily     ISSUE
#  4036        4036                                         nacho have  NOTISSUE
#  4037        4037                                   not be come back     ISSUE
#  4038        4038  do not have word say place do everything prett...  NOTISSUE
#  4039        4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040        4040             great atmosphere friendly fast service  NOTISSUE
#  4041        4041        receive pity huge have lot meat thumb there  NOTISSUE
#  4042        4042                                     food arrive me     ISSUE
#  4043        4043  pay 7 85 hot dog fry look like come kid meal w...     ISSUE
#  4044        4044               classic maine lobster roll fantastic  NOTISSUE
#  4045        4045  brother law work mall eat day guess sick night...     ISSUE
#  4046        4046                 good be go have review place twice  NOTISSUE
#  4047        4047                        chip salsa good salsa fresh  NOTISSUE
#  4048        4048                                        place great  NOTISSUE
#  4049        4049                                      mediocre food     ISSUE
#  4050        4050                        get inside be impress place  NOTISSUE
#  4051        4051                             service super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                                place nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#  4055        4055                                  low quality sound     ISSUE
#
#  [4056 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4        ISSUE                    look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE       clear skye call long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE         try handsfree gadget one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25    NOTISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE              excellent product be satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4026     ISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell 1 restaurant smell like combination d...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                     have pretty satisfy experience
#  4032  NOTISSUE                  join club get awesome offer email
#  4033  NOTISSUE          perfect me like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE               chain be no fan of beat place easily
#  4036     ISSUE                                         nacho have
#  4037     ISSUE                                   not be come back
#  4038     ISSUE  do not have word say place do everything prett...
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE        receive pity huge have lot meat thumb there
#  4042  NOTISSUE                                     food arrive me
#  4043     ISSUE  pay 7 85 hot dog fry look like come kid meal w...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE  brother law work mall eat day guess sick night...
#  4046     ISSUE                 good be go have review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050     ISSUE                        get inside be impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#  4055  NOTISSUE                                  low quality sound
#
#  [4056 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4     ISSUE                    look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2357
# NOTISSUE    1699
# Name: label, dtype: int64

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1859  172]
#  [ 498 1527]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8348126232741617
#               precision    recall  f1-score   support
#
#        ISSUE       0.79      0.92      0.85      2031
#     NOTISSUE       0.90      0.75      0.82      2025
#
#    micro avg       0.83      0.83      0.83      4056
#    macro avg       0.84      0.83      0.83      4056
# weighted avg       0.84      0.83      0.83      4056

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_v5.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                     not be happier
# 1     NOTISSUE      ISSUE                    look headset long time have get
# 2        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 3     NOTISSUE      ISSUE                                     prompt service
# 4        ISSUE   NOTISSUE  stupid have keep buy new charger car charger c...
# 5     NOTISSUE      ISSUE               phone have have have be cheaply make
# 6        ISSUE   NOTISSUE                            plastic break easy clip
# 7     NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 8     NOTISSUE      ISSUE               find cell phone right away enter car
# 9     NOTISSUE      ISSUE  do get better reception clarity phone have hav...
# 10    NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 11    NOTISSUE      ISSUE  have get defect not risk buy again build quali...
# 12    NOTISSUE      ISSUE                            nothing bad say headset
# 13    NOTISSUE      ISSUE  be glad find product amazon hard find not high...
# 14    NOTISSUE      ISSUE                               no buyer remorse one
# 15    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 16       ISSUE   NOTISSUE                                     like return it
# 17    NOTISSUE      ISSUE  keyboard worthwhile usefulness sturdy do not e...
# 18    NOTISSUE      ISSUE                                  wil not regret it
# 19       ISSUE   NOTISSUE                                  not user friendly
# 20    NOTISSUE      ISSUE             have version two year ago like service
# 21    NOTISSUE      ISSUE                                      work describe
# 22    NOTISSUE      ISSUE          sound clear people talk amaze quality too
# 23    NOTISSUE      ISSUE  receive order well ship timeframe everything g...
# 24    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 25       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 26    NOTISSUE      ISSUE  bluetooth range good day ago leave phone trunk...
# 27    NOTISSUE      ISSUE  largely channel sound directly ear seem increa...
# 28    NOTISSUE      ISSUE  no shift no bubble no peel not scratch nothing...
# 29    NOTISSUE      ISSUE                                      total package
# ..         ...        ...                                                ...
# 640   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 641   NOTISSUE      ISSUE  make drive way north scottsdale not one bite d...
# 642   NOTISSUE      ISSUE         grill chicken tender yellow saffron season
# 643      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 644      ISSUE   NOTISSUE                                 not fun experience
# 645   NOTISSUE      ISSUE  chef generous time even come twice take pictur...
# 646   NOTISSUE      ISSUE        owner use work nob place similar half price
# 647   NOTISSUE      ISSUE                          promise wo not disappoint
# 648   NOTISSUE      ISSUE                                   not wait go back
# 649   NOTISSUE      ISSUE          give five star then be give five star now
# 650   NOTISSUE      ISSUE  price reasonable flavour spot on sauce home ma...
# 651      ISSUE   NOTISSUE                       normally impress strip steak
# 652   NOTISSUE      ISSUE             service quick to go order like like it
# 653   NOTISSUE      ISSUE                                       two thumb up
# 654   NOTISSUE      ISSUE                                      one bite hook
# 655   NOTISSUE      ISSUE  one nice thing add gratuity bill party larger ...
# 656   NOTISSUE      ISSUE                           never have complain here
# 657      ISSUE   NOTISSUE                                            way fry
# 658   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 659   NOTISSUE      ISSUE               be town definitely be spot hit again
# 660      ISSUE   NOTISSUE             chicken dish ok beef like shoe leather
# 661   NOTISSUE      ISSUE         one place phoenix definately go back again
# 662   NOTISSUE      ISSUE                                         nacho have
# 663   NOTISSUE      ISSUE  do not have word say place do everything prett...
# 664   NOTISSUE      ISSUE        receive pity huge have lot meat thumb there
# 665      ISSUE   NOTISSUE                                     food arrive me
# 666   NOTISSUE      ISSUE                 good be go have review place twice
# 667   NOTISSUE      ISSUE                        get inside be impress place
# 668   NOTISSUE      ISSUE                            live music totally blow
# 669      ISSUE   NOTISSUE                                  low quality sound
#
# [670 rows x 3 columns]
