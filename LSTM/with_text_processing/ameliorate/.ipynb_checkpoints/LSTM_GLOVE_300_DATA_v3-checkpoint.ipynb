# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('DATA/data.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #imbalanced Dataset
# Out:
# ISSUE       2034
# NOTISSUE    2022
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4056, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 'becomes',
 'becoming',
 'been',
 'before',
 'beforehand',
 'behind',
 'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 'show',
 'side',
 'since',
 'six',
 'sixty',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
        "couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re

# %%
def replace_word(word):
    # Convert text to lower
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Removing all the tokens with lesser than 3 characters
    #text = gensim.corpora.textcorpus.remove_short(text, minsize=3)
    
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    
    
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        
        ##### Lemmatization
        # Reduce words to their root form
        # Lemmatize verbs by specifying pos
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText("I have so 2  soo servic going groop")

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
#df=df[texts,tags]

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('Data/DATA_preprocessing3.csv')

# %%
####

# %%
DATA_FILE = 'Data/DATA_preprocessing3.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())

# %%
train_df['label'].value_counts()

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : overprice
# word not found : flavourful
# word not found : appal
# word not found : cosiness
# word not found : untasted
# word not found : shawarrrrrrma
# word not found : cheesecurds
# word not found : ciob
# word not found : 6807
# word not found : 49900
# word not found : tk50
# word not found : plantronincs
# word not found : 9e715
# word not found : 5320
# word not found : reoccure
# word not found : 8125
# word not found : s740
# word not found : emailinc
# word not found : bs2000
# word not found : convertor
# word not found : baaaaaad
# word not found : norber
# word not found : stylize
# word not found : mesmerise
# word not found : brainsucking
# word not found : infatuate
# word not found : 4810
# word not found : nomole
# word not found : hydrabrush
# word not found : profiterole
# word not found : flavourless
# word not found : waaaaaayyyyyyyyyy
# word not found : douchebaggery
# word not found : chipolte
# word not found : soooooo

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 35 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2855 samples, validate on 1200 samples
# Epoch 1/2
# 2855/2855 [==============================] - 31s 11ms/step - loss: 0.5174 - acc: 0.7601 - val_loss: 0.4574 - val_acc: 0.8042
# Epoch 2/2
# 2855/2855 [==============================] - 27s 9ms/step - loss: 0.4021 - acc: 0.8252 - val_loss: 0.4303 - val_acc: 0.8050

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1200/1200 [==============================] - 3s 3ms/step
# loss: 43.03%
# acc: 80.50%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v3.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.965973]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.31152558]]
# ISSUE

# %%
text="unrecommend product"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend product
# [[0.6369158]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='DATA/DATA_preprocessing3.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text_v3.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.46295318]] ISSUE
# 2 love phone [[0.87500215]] NOTISSUE
# 3 get well finish product [[0.6821624]] NOTISSUE
# 4 not be happier [[0.23207903]] ISSUE
# 5 look headset long time have get [[0.4489231]] ISSUE
# 6 headset start ring no reason [[0.12575878]] ISSUE
# 7 display excellent camera good year [[0.99914336]] NOTISSUE
# 8 battery life great [[0.9823877]] NOTISSUE
# 9 worst phone have have have month [[0.136717]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.09848776]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.09176091]] ISSUE
# 12 protect phone side [[0.5611009]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.03327519]] ISSUE
# 14 clear skye call long battery life long range [[0.86319023]] NOTISSUE
# 15 solo technology suck [[0.15807632]] ISSUE
# 16 great hand free device [[0.98776543]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.80082023]] NOTISSUE
# 18 problem have mention [[0.09574816]] ISSUE
# 19 try handsfree gadget one finally work well [[0.9214051]] NOTISSUE
# 20 magical help [[0.87966806]] NOTISSUE
# 21 worst piece crap version customer service [[0.04313949]] ISSUE
# 22 poor sound quality [[0.09283987]] ISSUE
# 23 best phone market [[0.9012532]] NOTISSUE
# 24 work well [[0.8222034]] NOTISSUE
# 25 company ship product promptly work well [[0.5227598]] NOTISSUE
# 26 exactly want [[0.456653]] ISSUE
# 27 picture resolution far comparably price phone offer today [[0.8027404]] NOTISSUE
# 28 great deal [[0.9695603]] NOTISSUE
# 29 excellent product satisfy purchase [[0.9827132]] NOTISSUE
# 30 highly recommend encourage people give try [[0.8288535]] NOTISSUE
# 31 better expect [[0.7443382]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.16134465]] ISSUE
# 33 great product price [[0.9865572]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.9975853]] NOTISSUE
# 35 disappointment [[0.15950492]] ISSUE
# 36 prompt service [[0.40217543]] ISSUE
# 37 excellent product price [[0.9872715]] NOTISSUE
# 38 please headset [[0.5375164]] NOTISSUE
# 39 do not waste money time [[0.0336368]] ISSUE
# 40 especially love long battery life [[0.98126733]] NOTISSUE
# 41 stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.30151716]] ISSUE
# 42 work great [[0.9693252]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.99553937]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice bad service [[0.04740452]] ISSUE
# 45 be look new earpiece [[0.49303406]] ISSUE
# 46 be look new earpiece jawbone era awesome too [[0.49233866]] ISSUE
# 47 receive white color battery go dead couple hours the original use week last longer there placement [[0.1143841]] ISSUE
# 48 year battery go completely dead headset [[0.15299079]] ISSUE
# 49 have use phone two year one best [[0.8328392]] NOTISSUE
# 50 awesome new look fall 2000 [[0.9521989]] NOTISSUE
# 51 phone have have have cheaply make [[0.46714622]] ISSUE
# 52 att not clear sound distort have yell talk [[0.03493264]] ISSUE
# 53 price good too [[0.726282]] NOTISSUE
# 54 plastic break easy clip [[0.23518358]] ISSUE
# 55 do not make mistake do [[0.03532873]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.09610692]] ISSUE
# 57 river spine with case fit fine [[0.92547387]] NOTISSUE
# 58 area unit break not fond magnetic strap [[0.21536748]] ISSUE
# 59 overall psyched have phone have appointment contact get great reception [[0.9305788]] NOTISSUE
# 60 thing phone work perfectly like it [[0.9520205]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.15157257]] ISSUE
# 62 easy [[0.7384003]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.17683738]] ISSUE
# 64 fantastic earphone [[0.9197325]] NOTISSUE
# 65 find cell phone right away enter car [[0.21463598]] ISSUE
# 66 low quality [[0.38456187]] ISSUE
# 67 do get better reception clarity phone have have before [[0.51288223]] NOTISSUE
# 68 warn stay away [[0.10930814]] ISSUE
# 69 wish return unit get back money [[0.246352]] ISSUE
# 70 awesome device work great [[0.99927086]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.02148224]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.05988716]] ISSUE
# 73 displease [[0.24957152]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.12926207]] ISSUE
# 75 make case small difficult install [[0.30661562]] ISSUE
# 76 restore phone like new performance [[0.7697112]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.83074886]] NOTISSUE
# 78 search internet find one be best value [[0.889606]] NOTISSUE
# 79 do not fit [[0.15792628]] ISSUE
# 80 happy product [[0.8294692]] NOTISSUE
# 81 screen size big key pad light well enough camera quality excellent camera phone [[0.98832625]] NOTISSUE
# 82 nothing bad say headset [[0.06233382]] ISSUE
# 83 glad find product amazon hard find not high price [[0.7096632]] NOTISSUE
# 84 portable work [[0.73279434]] NOTISSUE
# 85 colleague get great reception a little expensive performance great [[0.9988481]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.10640524]] ISSUE
# 87 have have problem phone read memory card turn again [[0.15366575]] ISSUE
# 88 not good wear hat sunglass [[0.32637423]] ISSUE
# 89 timely shipment quality product [[0.5027203]] NOTISSUE
# 90 nice solid keyboard [[0.98518455]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.9906149]] NOTISSUE
# 92 horrible phone [[0.08276955]] ISSUE
# 93 bt battery junk [[0.48317066]] ISSUE
# 94 recommend others [[0.5947505]] NOTISSUE
# 95 cant get software work computer [[0.2769917]] ISSUE
# 96 disappoint [[0.23412296]] ISSUE
# 97 poor voice clarity [[0.17369777]] ISSUE
# 98 battery work great [[0.98080885]] NOTISSUE
# 99 no buyer remorse one [[0.07773877]] ISSUE
# 100 disappoint accessory [[0.23966745]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.05039432]] ISSUE
# 102 look great strong [[0.98699653]] NOTISSUE
# 103 have have mobile service two year now pretty happy it [[0.9891266]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.1284292]] ISSUE
# 105 disappointment hate go ear [[0.06827165]] ISSUE
# 106 great software motorola [[0.96866816]] NOTISSUE
# 107 delivery time [[0.53912264]] NOTISSUE
# 108 easy use [[0.70189995]] NOTISSUE
# 109 uncomfortable ear do house lg .49900 env [[0.33306468]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.31510392]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.8017716]] NOTISSUE
# 112 like return it [[0.54965246]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy do not expect problem [[0.33954746]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.26631436]] ISSUE
# 115 charge overnight battery work great [[0.9653177]] NOTISSUE
# 116 wo not regret it [[0.05389423]] ISSUE
# 117 love phone [[0.87500215]] NOTISSUE
# 118 disappointment [[0.15950492]] ISSUE
# 119 not user friendly [[0.49986002]] ISSUE
# 120 unfortunately ability actually know receive call important feature phone pitiful respect [[0.1953079]] ISSUE
# 121 exchange phone have problem [[0.42448673]] ISSUE
# 122 result phone stick max volume mute [[0.21964325]] ISSUE
# 123 public display affection rock [[0.8285495]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.90689284]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.99009]] NOTISSUE
# 126 have version two year ago like service [[0.7293437]] NOTISSUE
# 127 pretty piece junk [[0.47681835]] ISSUE
# 128 plug wrong size [[0.15847291]] ISSUE
# 129 work describe [[0.383003]] ISSUE
# 130 save money have have item month now [[0.35774618]] ISSUE
# 131 bad purchase [[0.08525995]] ISSUE
# 132 well im satisfy [[0.8067999]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.7673839]] NOTISSUE
# 134 battery excellent bargain [[0.9837426]] NOTISSUE
# 135 defective crap [[0.03506095]] ISSUE
# 136 have give no star able [[0.39438877]] ISSUE
# 137 wear glass fit fine them [[0.74357855]] NOTISSUE
# 138 sound quality device unacceptable unless quiet area hear nothing [[0.06802751]] ISSUE
# 139 not recommend item anyone [[0.21496083]] ISSUE
# 140 holster arrive not match photo ad [[0.1518194]] ISSUE
# 141 great no problem all [[0.7234234]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.11953153]] ISSUE
# 143 frog phone charm adorable eye catch [[0.91643393]] NOTISSUE
# 144 never know push hard right number time function want not [[0.14709598]] ISSUE
# 145 sound clear people talk amaze quality too [[0.31930825]] ISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.8318877]] NOTISSUE
# 147 good product well make [[0.9646337]] NOTISSUE
# 148 mobile phone tool have [[0.86575514]] NOTISSUE
# 149 impress job motorola steadiness phone [[0.76992726]] NOTISSUE
# 150 receive order well ship timeframe good work order overall excite have source [[0.9611464]] NOTISSUE
# 151 phone sturdy waterproof [[0.7714751]] NOTISSUE
# 152 not impress not recommend item anyone [[0.11578039]] ISSUE
# 153 complaint standard sound volume little low turn 5 of 5 [[0.08280288]] ISSUE
# 154 thank again amazon have thing need good price [[0.98587406]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.12476337]] ISSUE
# 156 have go store buy new nokia phone work great [[0.9550331]] NOTISSUE
# 157 work great [[0.9693252]] NOTISSUE
# 158 ugly [[0.0706564]] ISSUE
# 159 horrible have switch time [[0.07279103]] ISSUE
# 160 noise shield incredible [[0.79271495]] NOTISSUE
# 161 no real improvement [[0.1121085]] ISSUE
# 162 razor battery good buy [[0.9669827]] NOTISSUE
# 163 keep good work amazon [[0.9798766]] NOTISSUE
# 164 refuse refund replace [[0.0780673]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.61488646]] NOTISSUE
# 166 basically throw money window nothing [[0.03823932]] ISSUE
# 167 great case price [[0.98195857]] NOTISSUE
# 168 take one drop inch kitchen counter crack i not impress not laugh [[0.02744998]] ISSUE
# 169 bluetooth range good day ago leave phone trunk get call carry conversation hitch [[0.976782]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.9988709]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.25253752]] ISSUE
# 172 none new one have work properly [[0.3780274]] ISSUE
# 173 glad purchase it [[0.8689098]] NOTISSUE
# 174 have miss numerous call reason [[0.36713153]] ISSUE
# 175 phone defective people hear use this [[0.16551916]] ISSUE
# 176 do notably product [[0.23252922]] ISSUE
# 177 suck stuff do not work phone [[0.06468832]] ISSUE
# 178 no shift no bubble no peel not scratch nothing i note happier new one droid [[0.07961136]] ISSUE
# 179 worst software use give zero star would [[0.07288697]] ISSUE
# 180 try make call exercise frustration [[0.12144612]] ISSUE
# 181 case flimsy piece plastic have no protection whatsoever [[0.0293825]] ISSUE
# 182 cabra barset happy it sound quality especially outgo better [[0.8350526]] NOTISSUE
# 183 love camera pretty good quality [[0.99896824]] NOTISSUE
# 184 thank great service [[0.9962224]] NOTISSUE
# 185 total package [[0.62023115]] NOTISSUE
# 186 seller understand patient definitely buy again [[0.7538294]] NOTISSUE
# 187 give firefly one star i contact singular at t inform practice [[0.38228375]] ISSUE
# 188 aggravate [[0.45567805]] ISSUE
# 189 great product price [[0.9865572]] NOTISSUE
# 190 have purchase family friend enjoy clarity ease use [[0.9948443]] NOTISSUE
# 191 virgin wireless rock do cheap little phone [[0.5898971]] NOTISSUE
# 192 none work [[0.3829158]] ISSUE
# 193 do notably it [[0.3175481]] ISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide off [[0.02604054]] ISSUE
# 195 please dont waste money [[0.08319558]] ISSUE
# 196 all satisfy purchase [[0.6638135]] NOTISSUE
# 197 look good quality headset keep look nott [[0.91247797]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.38864833]] ISSUE
# 199 notte best one [[0.8151367]] NOTISSUE
# 200 best one [[0.88935906]] NOTISSUE
# 201 disappoint result [[0.08228973]] ISSUE
# 202 cumbersome design [[0.33396497]] ISSUE
# 203 great new package nice work good [[0.9998665]] NOTISSUE
# 204 no problem come time expect [[0.10862699]] ISSUE
# 205 great product [[0.965973]] NOTISSUE
# 206 piece crap [[0.11463811]] ISSUE
# 207 experience terrible [[0.11874751]] ISSUE
# 208 fourth bluetooth headset [[0.5997373]] NOTISSUE
# 209 comfortable one [[0.8947825]] NOTISSUE
# 210 hat [[0.5663035]] NOTISSUE
# 211 fix problem [[0.11665253]] ISSUE
# 212 worst ever [[0.08038907]] ISSUE
# 213 happy [[0.8290187]] NOTISSUE
# 214 have have no trouble access internet download intone perform function [[0.32074973]] ISSUE
# 215 barely hear constantly say what [[0.14598137]] ISSUE
# 216 battery life highly unacceptable [[0.36685103]] ISSUE
# 217 company joke [[0.21455972]] ISSUE
# 218 do description say would [[0.13015696]] ISSUE
# 219 happen call force stop headset [[0.15893419]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.99667114]] NOTISSUE
# 221 version tech support walk procedure none work end have do hard re set wipe data [[0.15451623]] ISSUE
# 222 voice quality signal strength drop call [[0.1473031]] ISSUE
# 223 play louder speaker size price low think quality lack however not [[0.0353865]] ISSUE
# 224 better expect [[0.7443382]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push them [[0.2014347]] ISSUE
# 226 battery hold well [[0.8570785]] NOTISSUE
# 227 difficult on i d recommend avoid product [[0.12503482]] ISSUE
# 228 use two day not easy hear with [[0.3945215]] ISSUE
# 229 get car charger not week charger break i go plug start smoke [[0.03612027]] ISSUE
# 230 sprint terrible customer service [[0.3710466]] ISSUE
# 231 link phone effort [[0.39836964]] ISSUE
# 232 cool [[0.6900767]] NOTISSUE
# 233 easy use [[0.70189995]] NOTISSUE
# 234 better new [[0.7916791]] NOTISSUE
# 235 posse get junk have no idea [[0.13089827]] ISSUE
# 236 piece trash [[0.1103818]] ISSUE
# 237 pretty good product [[0.96918505]] NOTISSUE
# 238 great phone [[0.96669275]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.996682]] NOTISSUE
# 240 research development division obviously know do [[0.54806376]] NOTISSUE
# 241 real killer volume course break [[0.12547494]] ISSUE
# 242 phone work fine now [[0.9040091]] NOTISSUE
# 243 happy product one [[0.870093]] NOTISSUE
# 244 poor construction [[0.06573246]] ISSUE
# 245 infuriate [[0.35107073]] ISSUE
# 246 overall recommend phone new walkman [[0.7646796]] NOTISSUE
# 247 sprint charge service [[0.8319298]] NOTISSUE
# 248 cheap feel look cheap [[0.15302709]] ISSUE
# 249 fit ear well comfortable on [[0.9781487]] NOTISSUE
# 250 do network europe asia [[0.23133756]] ISSUE
# 251 clip belt definitely make feel like fifty cent s up and come [[0.5681477]] NOTISSUE
# 252 like design look cabra be ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.3795019]] ISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.9541289]] NOTISSUE
# 254 worst phone samsung crap crappy samsung 9e715 worst have see [[0.07402214]] ISSUE
# 255 charger work week completely stop charge phone [[0.1657845]] ISSUE
# 256 poor product [[0.08421747]] ISSUE
# 257 need better instruction [[0.59224385]] NOTISSUE
# 258 need two hand operate screen this software interface decade old compete new software design [[0.7708244]] NOTISSUE
# 259 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.9688243]] NOTISSUE
# 260 steer clear product go genuine palm replacement pen come three pack [[0.33098742]] ISSUE
# 261 do not buy do not but suck [[0.0264018]] ISSUE
# 262 great product sure beat finger [[0.98372304]] NOTISSUE
# 263 plus seriously do not believe worth steep price point [[0.05889525]] ISSUE
# 264 case have try normally fall apart month one seem be long haul [[0.0695702]] ISSUE
# 265 disappoint performance [[0.21117136]] ISSUE
# 266 do normale mistake please do notably phone [[0.0733345]] ISSUE
# 267 phone well be worst have have brand [[0.24215859]] ISSUE
# 268 case extra originally later discard scratch ear [[0.10197554]] ISSUE
# 269 recommend go different brand cell phone mp player family [[0.8720596]] NOTISSUE
# 270 do not bother go store [[0.05025291]] ISSUE
# 271 post detail comment grey black phone have fire red great color [[0.5713409]] NOTISSUE
# 272 not have problem item order again need [[0.11994263]] ISSUE
# 273 get pay guess [[0.20406677]] ISSUE
# 274 not software do great job this make intone form exist cd internet connection [[0.30490446]] ISSUE
# 275 im surprise good quality car charger not review it [[0.9813643]] NOTISSUE
# 276 fabulous [[0.90351266]] NOTISSUE
# 277 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.07030088]] ISSUE
# 278 price cable excellent [[0.9575819]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.52402467]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end call [[0.04659327]] ISSUE
# 281 wind resistant [[0.33195418]] ISSUE
# 282 obviously have terrible customer service get pay for [[0.13434963]] ISSUE
# 283 do not forever [[0.06620825]] ISSUE
# 284 it not overly expensive replace [[0.10744584]] ISSUE
# 285 easy operate sound better have try [[0.8604504]] NOTISSUE
# 286 contact company tell that unit warranty not produce receipt luck [[0.04326211]] ISSUE
# 287 link have way exchange bad phone return unit something [[0.08692035]] ISSUE
# 288 phone sturdy nokia bar phone be [[0.8718591]] NOTISSUE
# 289 great phone [[0.96669275]] NOTISSUE
# 290 place tree case not not snug lot extra room side [[0.17426686]] ISSUE
# 291 please [[0.56373036]] NOTISSUE
# 292 battery terrible [[0.07148232]] ISSUE
# 293 find product be easy set use [[0.55277586]] NOTISSUE
# 294 earpiece large heavy it keep fall ear [[0.197344]] ISSUE
# 295 utter crap sound quality terrible [[0.00464242]] ISSUE
# 296 charger arrive promise timeframe not work [[0.23193435]] ISSUE
# 297 no ear loop need tiny sound great [[0.75908446]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.10732894]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.7244835]] NOTISSUE
# 300 talk useless customer service [[0.10105719]] ISSUE
# 301 felt light tinny [[0.1875335]] ISSUE
# 302 do not fit palm tungsten e2 break time try plug in [[0.08947754]] ISSUE
# 303 happy purchase good quality low price [[0.9955022]] NOTISSUE
# 304 love look feel samsung flip phones [[0.8373979]] NOTISSUE
# 305 well design sharp blue nice color [[0.9885387]] NOTISSUE
# 306 do more [[0.35284638]] ISSUE
# 307 not recommend more [[0.41497925]] ISSUE
# 308 nice sound [[0.92517334]] NOTISSUE
# 309 look good picture case huge disappointment [[0.6221831]] NOTISSUE
# 310 jawbone go replace with [[0.2858951]] ISSUE
# 311 setup go smoothly [[0.77895063]] NOTISSUE
# 312 extremely slow take forever do it [[0.08989343]] ISSUE
# 313 study interest worst sin industrial design [[0.19552137]] ISSUE
# 314 thing happen track off [[0.17543441]] ISSUE
# 315 well make easy access phone have handy detachable belt clip [[0.9376778]] NOTISSUE
# 316 have continue pair periodically keep drop [[0.65322334]] NOTISSUE
# 317 not upload intone party [[0.17960969]] ISSUE
# 318 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.31104213]] ISSUE
# 319 truly awful [[0.25117603]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear out battery do [[0.6224468]] NOTISSUE
# 321 volume ringer real good you have choice loud one [[0.94708997]] NOTISSUE
# 322 none tone acceptable [[0.15786514]] ISSUE
# 323 camera color balance awful [[0.27336115]] ISSUE
# 324 product clearly not ready prime time do netware cool look nostell call come worthless [[0.09983052]] ISSUE
# 325 love intone upbeat [[0.7443164]] NOTISSUE
# 326 chinese forgery abound [[0.6065984]] NOTISSUE
# 327 easy pair samsung cell [[0.9349838]] NOTISSUE
# 328 instruction not explain microphone jack be use [[0.15503201]] ISSUE
# 329 advise not purchase item never work well [[0.40662032]] ISSUE
# 330 bad have pay month service [[0.04358522]] ISSUE
# 331 work well [[0.8222034]] NOTISSUE
# 332 nokia ca 42 usb cable not work phone [[0.19206229]] ISSUE
# 333 clear crisp sound [[0.5761217]] NOTISSUE
# 334 have use smallest earpiece provide stay pretty well [[0.95324963]] NOTISSUE
# 335 biggest complaint have be battery drain superfast [[0.14159937]] ISSUE
# 336 design be ergonomic theory not stand have ear [[0.22060199]] ISSUE
# 337 do not buy want use holster [[0.12922645]] ISSUE
# 338 phone take great picture video clip [[0.9568755]] NOTISSUE
# 339 do normale look cool [[0.48731413]] ISSUE
# 340 ear occupy background not distract all [[0.14333732]] ISSUE
# 341 comfortable fit need headset be comfortable hour time not entire day [[0.73781663]] NOTISSUE
# 342 also phone do not seem accept cbr mp s preferably rip window medium player [[0.19829175]] ISSUE
# 343 norbert price these [[0.6326965]] NOTISSUE
# 344 come strong light use light camera shot flash so signal seriously [[0.29972664]] ISSUE
# 345 lightweight work well [[0.96625185]] NOTISSUE
# 346 beware [[0.24984016]] ISSUE
# 347 love cable allow connect mini usb device pc [[0.9669316]] NOTISSUE
# 348 near hear conversation [[0.41596577]] ISSUE
# 349 cool case open allow screen get scratch up one [[0.46947378]] ISSUE
# 350 buy phone replacement start have regret since [[0.16547708]] ISSUE
# 351 appear actually outperform original battery china come a325 i [[0.52648866]] NOTISSUE
# 352 dottore phone number sim [[0.6258298]] NOTISSUE
# 353 last o minute actually try use phone my wife have phone problem [[0.13531151]] ISSUE
# 354 poor quality [[0.09381491]] ISSUE
# 355 cabra ear gel r best [[0.7197772]] NOTISSUE
# 356 not worth it [[0.25734466]] ISSUE
# 357 phone crash completely have get replace [[0.07874507]] ISSUE
# 358 quit work have use eighteen month purchase one best headset have own [[0.45120537]] ISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.35001355]] ISSUE
# 360 great phone [[0.96669275]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.03288041]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.980607]] NOTISSUE
# 363 phone do not slide car grip prevent phone slip hand [[0.04883984]] ISSUE
# 364 simply best bluetooth headset sound quality [[0.8644744]] NOTISSUE
# 365 think plan one this sure moto phone me [[0.49826664]] ISSUE
# 366 span hour have two people exclaim whoa new phone tv [[0.4706056]] ISSUE
# 367 have use cord headset freedom wireless helpful [[0.92205554]] NOTISSUE
# 368 case have pas one year mark show sign wear 100 functional [[0.3825894]] ISSUE
# 369 that leather nice soft fit tight cut face good shape [[0.8304342]] NOTISSUE
# 370 have need task more [[0.7827951]] NOTISSUE
# 371 receive product two day break [[0.34183714]] ISSUE
# 372 product great make work lot easier go copier wait hold something [[0.8829057]] NOTISSUE
# 373 none size send headset stay ear [[0.41138187]] ISSUE
# 374 t mobile have best customer service anywhere [[0.95466816]] NOTISSUE
# 375 arrive quickly expensive sell [[0.21975511]] ISSUE
# 376 have try two unit fail two month pro [[0.29339015]] ISSUE
# 377 provide good protection look classy too [[0.9798464]] NOTISSUE
# 378 russel good [[0.8399286]] NOTISSUE
# 379 website user friendly make easy activate etc [[0.9222452]] NOTISSUE
# 380 design good 4 [[0.92994416]] NOTISSUE
# 381 great reception time [[0.9904383]] NOTISSUE
# 382 highly recommend product [[0.82047015]] NOTISSUE
# 383 house unit sunglass not good texas [[0.39479196]] ISSUE
# 384 dit not work time nokia 5320 [[0.27384043]] ISSUE
# 385 buy mainly charger break soon purchase [[0.51740795]] NOTISSUE
# 386 like loud buzz override conversation phone you [[0.58950573]] NOTISSUE
# 387 fantastic buy get again phone [[0.9826466]] NOTISSUE
# 388 stay away store be careful [[0.2001276]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.9581732]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.85861784]] NOTISSUE
# 391 light have plenty battery capacity comfortable wear somewhat extend period time [[0.8349769]] NOTISSUE
# 392 disappoint [[0.23412296]] ISSUE
# 393 blue ant easy use [[0.54417217]] NOTISSUE
# 394 cheap hey work [[0.51994926]] NOTISSUE
# 395 pleasantly suprised give low cost item [[0.6457468]] NOTISSUE
# 396 camera phone be use dustpan indoors have be disposable this [[0.27419373]] ISSUE
# 397 day later puff smoke come phone use [[0.15686561]] ISSUE
# 398 convenient simple use get job make car ride smoother [[0.51364815]] NOTISSUE
# 399 nano state it my son disappoint [[0.20593415]] ISSUE
# 400 sound quality excellent well [[0.9909803]] NOTISSUE
# 401 best headset have use [[0.8472941]] NOTISSUE
# 402 not recommend [[0.3710531]] ISSUE
# 403 have year carry highest quality anti glare screen protector have find date [[0.72489625]] NOTISSUE
# 404 want [[0.46211943]] ISSUE
# 405 particular model not work motorola q smartphone [[0.5531377]] NOTISSUE
# 406 wont work right at least me [[0.29756632]] ISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.663834]] NOTISSUE
# 408 out warranty problem reoccure bottom line money else singular not support it [[0.04873384]] ISSUE
# 409 want plantronics five ten be right one have issue me the good [[0.7166477]] NOTISSUE
# 410 crisp clear [[0.64159995]] NOTISSUE
# 411 charge keep go dead minute [[0.11383325]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.1711]] ISSUE
# 413 get absolutely horrible reception apartment phone have not have problem [[0.06838982]] ISSUE
# 414 reception have generally good [[0.85316086]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.9893133]] NOTISSUE
# 416 great bluetooth [[0.9740735]] NOTISSUE
# 417 highly recommend case [[0.8446837]] NOTISSUE
# 418 worthwhile [[0.59942013]] NOTISSUE
# 419 phone get be year old slowly break despite care part [[0.10033741]] ISSUE
# 420 sorry make purchase [[0.15443933]] ISSUE
# 421 buy hop make bluetooth headset fit better thing make impossible wear [[0.41215342]] ISSUE
# 422 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.1165761]] ISSUE
# 423 horrible [[0.03433426]] ISSUE
# 424 allow possibility double book date time first [[0.2107607]] ISSUE
# 425 work two week break [[0.3794636]] ISSUE
# 426 do nothing hold securely belt [[0.22439654]] ISSUE
# 427 simple use like it [[0.74162376]] NOTISSUE
# 428 great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.93448716]] NOTISSUE
# 429 house case smell disgust [[0.04351844]] ISSUE
# 430 not want [[0.19249769]] ISSUE
# 431 two case order another [[0.49594048]] ISSUE
# 432 buy battery coupon amazon happy purchase [[0.96697557]] NOTISSUE
# 433 internet access fine rare instance work [[0.9435042]] NOTISSUE
# 434 perfect p [[0.84876555]] NOTISSUE
# 435 five star plus plus [[0.88407964]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end other me [[0.9120629]] NOTISSUE
# 437 50 drain [[0.19247931]] ISSUE
# 438 try talk real loud shout telephone get old tell not great [[0.26211324]] ISSUE
# 439 good work fine [[0.98049885]] NOTISSUE
# 440 price great deal [[0.9769405]] NOTISSUE
# 441 great price too [[0.96190023]] NOTISSUE
# 442 wind completely useless [[0.03743996]] ISSUE
# 443 yes shiny love it [[0.9710098]] NOTISSUE
# 444 do not work [[0.1259558]] ISSUE
# 445 think get good deal 7 44 plug phone v see razor [[0.50203645]] NOTISSUE
# 446 reception headset excellent [[0.9716009]] NOTISSUE
# 447 two thumb seller [[0.41660425]] ISSUE
# 448 have version lg phone work well together good reception range exceed twenty foot line sight [[0.9961249]] NOTISSUE
# 449 improper description have return it [[0.16713673]] ISSUE
# 450 1 work 2 comfortable [[0.7741253]] NOTISSUE
# 451 battery charge life long [[0.6025872]] NOTISSUE
# 452 cabra largely fit ear well [[0.50654626]] NOTISSUE
# 453 battery have no life [[0.38131216]] ISSUE
# 454 check no feature disappoint [[0.20469837]] ISSUE
# 455 product exactly describe [[0.25981188]] ISSUE
# 456 get signal version phone wo not [[0.07310071]] ISSUE
# 457 do not job [[0.08452071]] ISSUE
# 458 recommend it [[0.75530344]] NOTISSUE
# 459 plan order again again [[0.43764082]] ISSUE
# 460 say phone camera nice cool effect play with video decent well [[0.9620931]] NOTISSUE
# 461 have satisfy cell phone day one [[0.5340821]] NOTISSUE
# 462 keep get better better this one have have numerous palm too [[0.7721637]] NOTISSUE
# 463 awkward use unreliable [[0.03967312]] ISSUE
# 464 ship time quick [[0.5167495]] NOTISSUE
# 465 not good have hop [[0.30120474]] ISSUE
# 466 good case [[0.8652802]] NOTISSUE
# 467 do network [[0.20867148]] ISSUE
# 468 good product [[0.85387206]] NOTISSUE
# 469 unfortunately not work [[0.12105838]] ISSUE
# 470 break two month use [[0.25338387]] ISSUE
# 471 dont buy it [[0.592161]] NOTISSUE
# 472 father have 4265 battery die [[0.2785445]] ISSUE
# 473 however ear pad come easily one week lose one [[0.1087945]] ISSUE
# 474 call drop phone come will screen go black worst stop ring intermittently [[0.03837629]] ISSUE
# 475 horrible horrible protector [[0.03558958]] ISSUE
# 476 do notice nokia either [[0.11708979]] ISSUE
# 477 reach row uncomfortable [[0.21411811]] ISSUE
# 478 have buy nokia cell phone week ago nightmare [[0.14830329]] ISSUE
# 479 take long describe bad customer service experience have amazon [[0.17436144]] ISSUE
# 480 disappoint thing no speakerphone [[0.13651986]] ISSUE
# 481 terrible car not accept cassette [[0.03763421]] ISSUE
# 482 product useless do not have charge current charge two cellphone [[0.08944338]] ISSUE
# 483 not say be [[0.13776165]] ISSUE
# 484 stay away q [[0.4885224]] ISSUE
# 485 use dirty [[0.05710365]] ISSUE
# 486 unreliable service t mobile [[0.2351902]] ISSUE
# 487 not good price [[0.48771685]] ISSUE
# 488 buy two charge [[0.5924821]] NOTISSUE
# 489 look nice [[0.89860195]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.99726117]] NOTISSUE
# 491 have read review have note problem it [[0.34947953]] ISSUE
# 492 product cover important light sensor ear outlet [[0.51502836]] NOTISSUE
# 493 comfortable hand [[0.85157245]] NOTISSUE
# 494 do not work [[0.1259558]] ISSUE
# 495 poor reliability [[0.05982643]] ISSUE
# 496 work [[0.56446636]] NOTISSUE
# 497 take picture battery drop bar start beep let know din [[0.11637407]] ISSUE
# 498 terrible product waste money [[0.02755467]] ISSUE
# 499 time buy you [[0.5669636]] NOTISSUE
# 500 waste money [[0.07570601]] ISSUE
# 501 far have work like charm [[0.7840386]] NOTISSUE
# 502 have have week far good [[0.72551876]] NOTISSUE
# 503 but case best be download picture laptop ir send picture laptop phone [[0.6048084]] NOTISSUE
# 504 recommend item [[0.7104345]] NOTISSUE
# 505 choice headset year great sound good volume good noise cancellation [[0.992679]] NOTISSUE
# 506 nice case feel good hand [[0.9531528]] NOTISSUE
# 507 item receive counterfeit [[0.56287724]] NOTISSUE
# 508 good far probably best bt headset have have [[0.9677978]] NOTISSUE
# 509 work fine [[0.82947594]] NOTISSUE
# 510 receive headset good time happy it [[0.99305254]] NOTISSUE
# 511 please see replace well trail swivel holster blackberry flip [[0.741655]] NOTISSUE
# 512 sister have one love it [[0.96256703]] NOTISSUE
# 513 good quality [[0.92239946]] NOTISSUE
# 514 far worst purchase have make amazon [[0.15682882]] ISSUE
# 515 excellent dual purpose headset [[0.98729694]] NOTISSUE
# 516 excellent [[0.9459838]] NOTISSUE
# 517 do not work listen music singular 8125 [[0.21588175]] ISSUE
# 518 seem completely secure hold belt keep phone inside [[0.37635142]] ISSUE
# 519 bottom line another worthless cheap gimmick sprint [[0.26099998]] ISSUE
# 520 have trouble volume [[0.23924568]] ISSUE
# 521 good thing fit comfortably small ear [[0.97523755]] NOTISSUE
# 522 warn do not buy [[0.0776054]] ISSUE
# 523 pair phone not be happier far [[0.4430532]] ISSUE
# 524 open battery connection break device turn off [[0.21655084]] ISSUE
# 525 not want clip go ear cause discomfort [[0.04711709]] ISSUE
# 526 best headset ever [[0.87559104]] NOTISSUE
# 527 do not trust webster do not expect helpful support [[0.13524243]] ISSUE
# 528 loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.48923323]] ISSUE
# 529 speaker low quality make ring tone sound cheap [[0.23503782]] ISSUE
# 530 fit comfortably come size earn tip [[0.88687354]] NOTISSUE
# 531 bad reception [[0.06778113]] ISSUE
# 532 product high quality chinese crap [[0.19556895]] ISSUE
# 533 comfortable ear [[0.81431663]] NOTISSUE
# 534 do notably product fail [[0.09042337]] ISSUE
# 535 product wrong first [[0.14458394]] ISSUE
# 536 pair two device easy barely take couple minute start make call voice deal feature [[0.83061224]] NOTISSUE
# 537 utterly confuse first cause lose couple very important contact [[0.10824176]] ISSUE
# 538 terrible phone holder [[0.09807169]] ISSUE
# 539 cutout button place perfectly [[0.9407942]] NOTISSUE
# 540 love able use one headset land line cell [[0.7749396]] NOTISSUE
# 541 problem ear loop make weak material break easily [[0.02841082]] ISSUE
# 542 not nearly good look amazon picture make look [[0.36660647]] ISSUE
# 543 despite flaw case exceptional quality well worth additional cost own official oem product [[0.22836365]] ISSUE
# 544 stupid that [[0.07848278]] ISSUE
# 545 hear drive car usually do steven have loudest set [[0.24904163]] ISSUE
# 546 seller ship quickly cheaper competitor [[0.57022405]] NOTISSUE
# 547 good show samsung [[0.9278976]] NOTISSUE
# 548 buy ten save a lot money [[0.38636112]] ISSUE
# 549 cut make beep beep beep sound say signal fail [[0.03364109]] ISSUE
# 550 configure [[0.582492]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word say it [[0.26896355]] ISSUE
# 552 have take battery phone back restart it [[0.45991072]] ISSUE
# 553 manage bend leaf spring back place metal have stress break drop [[0.06238534]] ISSUE
# 554 leopard print wonderfully wild [[0.9655527]] NOTISSUE
# 555 work me [[0.6650756]] NOTISSUE
# 556 saggy floppy piece junk [[0.07399702]] ISSUE
# 557 better hard plastic case [[0.5967226]] NOTISSUE
# 558 have new problem [[0.37620595]] ISSUE
# 559 happy far [[0.8236862]] NOTISSUE
# 560 cool phone [[0.72290987]] NOTISSUE
# 561 work good [[0.89287794]] NOTISSUE
# 562 motorola finally get voice quality bluetooth headset right [[0.70686215]] NOTISSUE
# 563 loose connection phone couple foot two [[0.40373325]] ISSUE
# 564 great recommend [[0.98012847]] NOTISSUE
# 565 make easier keep bluetooth not wear it [[0.31629118]] ISSUE
# 566 say above pretty useless [[0.11459983]] ISSUE
# 567 never get it [[0.30954155]] ISSUE
# 568 pair headphone worst have have sound wise [[0.33078495]] ISSUE
# 569 drain weak snap [[0.04108059]] ISSUE
# 570 do not charge singular att eight thousand five twenty five phone [[0.24582548]] ISSUE
# 571 get extra minute carry call not get cut off [[0.04301451]] ISSUE
# 572 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.04917691]] ISSUE
# 573 keep catch cable seat have pull phone turn off [[0.22649969]] ISSUE
# 574 headset fulfil requirement happy purchase [[0.906368]] NOTISSUE
# 575 logitech bluetooth headset 10 [[0.8438961]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.2599871]] ISSUE
# 577 lot webster have rat good phone do i [[0.6046384]] NOTISSUE
# 578 have try cable computer pod work fine [[0.70968145]] NOTISSUE
# 579 mic joke volume low [[0.16385685]] ISSUE
# 580 return them [[0.33018366]] ISSUE
# 581 do not maintain connection computer lap [[0.10473554]] ISSUE
# 582 easy turn car volume control accessible [[0.7391601]] NOTISSUE
# 583 have have year christmas buy rest family [[0.68276423]] NOTISSUE
# 584 otherwise easy install use clear sound [[0.1951656]] ISSUE
# 585 nice leather [[0.9157503]] NOTISSUE
# 586 have purchase different case [[0.7738282]] NOTISSUE
# 587 joy use [[0.89225835]] NOTISSUE
# 588 disappoint company [[0.21932644]] ISSUE
# 589 satisfy that [[0.5073432]] NOTISSUE
# 590 not charge me [[0.18695416]] ISSUE
# 591 phone get 2005 buy s740 say wow [[0.63058454]] NOTISSUE
# 592 button small [[0.6281602]] NOTISSUE
# 593 read spec make say wow [[0.42946902]] ISSUE
# 594 love it great armband [[0.9947267]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.44894812]] ISSUE
# 596 however keypad tinny reach wrong button [[0.18511875]] ISSUE
# 597 exchange sony ericson z five pretty happy decision [[0.9964992]] NOTISSUE
# 598 impress price case [[0.6385735]] NOTISSUE
# 599 make easier hold to [[0.32128155]] ISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.9441949]] NOTISSUE
# 601 pretty easy [[0.91981894]] NOTISSUE
# 602 make call certain place [[0.29151037]] ISSUE
# 603 however girl complain time phone do netware like normal phone do [[0.04691722]] ISSUE
# 604 beautiful style though [[0.98405486]] NOTISSUE
# 605 company charge restock fee not give refund back [[0.0653266]] ISSUE
# 606 try return refund [[0.2143709]] ISSUE
# 607 plug find not darn thing work [[0.25035694]] ISSUE
# 608 excellent product [[0.9656662]] NOTISSUE
# 609 earn piece break easily [[0.22969358]] ISSUE
# 610 lousy product [[0.13506265]] ISSUE
# 611 phone try hard do fail ability be phone [[0.12673129]] ISSUE
# 612 best charger have see market yet [[0.9452173]] NOTISSUE
# 613 sweetest phone [[0.4897001]] ISSUE
# 614 oh charger seem work fine [[0.78989625]] NOTISSUE
# 615 fit securely ear hook do not need be use sound better direct ear canal [[0.2400375]] ISSUE
# 616 not volume [[0.18973109]] ISSUE
# 617 echo problem very unsatisfactory [[0.07635203]] ISSUE
# 618 take two video time quality poor [[0.10582583]] ISSUE
# 619 do not waste money [[0.03541677]] ISSUE
# 620 go have be negatively review product [[0.16169263]] ISSUE
# 621 adapter do not provide charge current [[0.18500504]] ISSUE
# 622 hype phone assume best mistake [[0.27883467]] ISSUE
# 623 take picture case sense cover [[0.25633535]] ISSUE
# 624 phone fall easily [[0.17132373]] ISSUE
# 625 network people not hear talk [[0.13903964]] ISSUE
# 626 text message feature tricky use [[0.514337]] NOTISSUE
# 627 disappoint have charger do network [[0.15437263]] ISSUE
# 628 painful ear [[0.18195361]] ISSUE
# 629 last one day blow up [[0.10330424]] ISSUE
# 630 disappoint [[0.23412296]] ISSUE
# 631 kind flop around [[0.17652138]] ISSUE
# 632 screen do get smudge easily touch ear face [[0.23876059]] ISSUE
# 633 piece junk lose call phone [[0.14986016]] ISSUE
# 634 item do not match picture [[0.07747658]] ISSUE
# 635 thing disappoint infra red port ira [[0.24851975]] ISSUE
# 636 not answer call unit never work once [[0.12302563]] ISSUE
# 637 unsatisfactory [[0.13201974]] ISSUE
# 638 product great [[0.9433903]] NOTISSUE
# 639 have this [[0.5306001]] NOTISSUE
# 640 have work good no problem [[0.52114075]] NOTISSUE
# 641 oh dangerous [[0.16303778]] ISSUE
# 642 sorry [[0.11966743]] ISSUE
# 643 sorry [[0.11966743]] ISSUE
# 644 pardon [[0.51282096]] NOTISSUE
# 645 help help [[0.6089696]] NOTISSUE
# 646 no no dangerous [[0.03002748]] ISSUE
# 647 extremely dangerous [[0.18934329]] ISSUE
# 648 dangerous [[0.12329365]] ISSUE
# 649 dangerous young man [[0.2587262]] ISSUE
# 650 dangerous brutal [[0.12329365]] ISSUE
# 651 honestly dangerous [[0.13122742]] ISSUE
# 652 work [[0.56446636]] NOTISSUE
# 653 dead hard work [[0.24122585]] ISSUE
# 654 fact family mary wed [[0.7620689]] NOTISSUE
# 655 have busy [[0.6117948]] NOTISSUE
# 656 go back again [[0.3566412]] ISSUE
# 657 busy [[0.582828]] NOTISSUE
# 658 think yesterday [[0.4496215]] ISSUE
# 659 do think get one [[0.2834755]] ISSUE
# 660 oh yes [[0.6408574]] NOTISSUE
# 661 one thing want talk [[0.32317814]] ISSUE
# 662 well honestly do not know have noreen discussion [[0.30489686]] ISSUE
# 663 course be come tomorrow [[0.37675634]] ISSUE
# 664 have noreen think away weekend [[0.16315217]] ISSUE
# 665 hello [[0.6036873]] NOTISSUE
# 666 mean young man [[0.22421905]] ISSUE
# 667 goodbye [[0.45567805]] ISSUE
# 668 alright [[0.6679886]] NOTISSUE
# 669 do need money urgently [[0.21712202]] ISSUE
# 670 business [[0.43078485]] ISSUE
# 671 work day [[0.5592455]] NOTISSUE
# 672 work [[0.56446636]] NOTISSUE
# 673 do work [[0.30203298]] ISSUE
# 674 work day [[0.5592455]] NOTISSUE
# 675 work saturday [[0.5444269]] NOTISSUE
# 676 know work [[0.60210055]] NOTISSUE
# 677 horrible customer service [[0.07710821]] ISSUE
# 678 fine product [[0.7228223]] NOTISSUE
# 679 glad pay money it [[0.45907357]] ISSUE
# 680 worst version adobe illustrator be release version nine [[0.12523842]] ISSUE
# 681 not save mysterious reason [[0.0665943]] ISSUE
# 682 crash [[0.14511554]] ISSUE
# 683 open file have year write scribble untenable save version [[0.10431128]] ISSUE
# 684 assume adobe customer service be professional quick [[0.6881365]] NOTISSUE
# 685 have call time past two week have have wait minimum twenty three minute speak someone [[0.11612276]] ISSUE
# 686 finally get product send mac version personal computer version purchase [[0.29142702]] ISSUE
# 687 call again wait approximately thirty minute get customer help [[0.11386384]] ISSUE
# 688 have not receive personal computer version [[0.19206762]] ISSUE
# 689 call center service worst customer service have deal [[0.1746199]] ISSUE
# 690 have deal bad customer service [[0.07343452]] ISSUE
# 691 extremely frustrate hour [[0.32265508]] ISSUE
# 692 do not have problem software [[0.09840282]] ISSUE
# 693 reverse error be nightmare [[0.01228558]] ISSUE
# 694 pretty do need [[0.5869223]] NOTISSUE
# 695 point customer service rep nice [[0.8712076]] NOTISSUE
# 696 do not have infrastructure provide basic level service [[0.11497206]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.42305335]] ISSUE
# 698 do not send receipt [[0.0600184]] ISSUE
# 699 receipt get copy invoice not format print correctly [[0.11666327]] ISSUE
# 700 disturb people suppose be account expert [[0.17721984]] ISSUE
# 701 start look alternative intuit obviously do not understand basic account audit principle [[0.08272927]] ISSUE
# 702 thoroughly disappoint [[0.26649752]] ISSUE
# 703 not do business company anymore give bad support [[0.0307207]] ISSUE
# 704 online information exactly have cd [[0.68987113]] NOTISSUE
# 705 have not send coupon [[0.18574856]] ISSUE
# 706 bad [[0.02627307]] ISSUE
# 707 save money do not subscribe extend service [[0.07211512]] ISSUE
# 708 use customer service technical support give answer vaguely relate problem [[0.21491908]] ISSUE
# 709 emailinc time get nowhere [[0.19489345]] ISSUE
# 710 largest technical software company world [[0.60713804]] NOTISSUE
# 711 have no technical support [[0.29722548]] ISSUE
# 712 worthless product horrible customer service [[0.06802913]] ISSUE
# 713 unable access internet [[0.26641646]] ISSUE
# 714 no problem system become slow [[0.0184847]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.52377295]] NOTISSUE
# 716 reputation become exasperate script suggestion not resolve problem [[0.05991156]] ISSUE
# 717 feel bite fleece over price subscription renewal year [[0.20793194]] ISSUE
# 718 decide give try [[0.5022539]] NOTISSUE
# 719 installation go smoothly seem fine [[0.7779829]] NOTISSUE
# 720 stall blank screen right window [[0.1063668]] ISSUE
# 721 hang forever [[0.29750997]] ISSUE
# 722 well present [[0.8011808]] NOTISSUE
# 723 easy follow along easy revisit previous lesson [[0.68623734]] NOTISSUE
# 724 video illustrate fretboard help see hear song be play [[0.47887343]] ISSUE
# 725 not lot depth material [[0.11114489]] ISSUE
# 726 sing be slight destruction sometimes [[0.05545748]] ISSUE
# 727 material song not be everyone like [[0.18862613]] ISSUE
# 728 have find music book useful [[0.95137066]] NOTISSUE
# 729 probably not recommend be source learn guitar [[0.20566528]] ISSUE
# 730 like new look [[0.7077973]] NOTISSUE
# 731 i have problem make transition [[0.35863855]] ISSUE
# 732 look create doom half life 2 normally recommend program [[0.34265667]] ISSUE
# 733 want make advance fps game simple pong game recommend dark basic [[0.19901156]] ISSUE
# 734 dark basic professional probably capable create kind game come with [[0.91356343]] NOTISSUE
# 735 have deal bad customer service [[0.07343452]] ISSUE
# 736 dark basic make manipulate d data extremely easy [[0.2907992]] ISSUE
# 737 have program yourself scratch [[0.50788534]] NOTISSUE
# 738 recommend [[0.6731813]] NOTISSUE
# 739 software easy install easy use [[0.91913867]] NOTISSUE
# 740 wonderful software [[0.97558504]] NOTISSUE
# 741 buy cd [[0.6984507]] NOTISSUE
# 742 do not waste money subscription merriam webster webster [[0.10049412]] ISSUE
# 743 software user friendly [[0.8748643]] NOTISSUE
# 744 superb [[0.9005789]] NOTISSUE
# 745 try medical dictionary [[0.46042216]] ISSUE
# 746 surprise find offer option strip code [[0.70254964]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.32642606]] ISSUE
# 748 evolution [[0.501081]] NOTISSUE
# 749 do offer major improvement flexibility previous version [[0.3017314]] ISSUE
# 750 good [[0.8399286]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.94706696]] NOTISSUE
# 752 horribly bad [[0.02627307]] ISSUE
# 753 good able tweak dozen standard compliance [[0.724719]] NOTISSUE
# 754 default thing not set up do take learn [[0.14050496]] ISSUE
# 755 move bs2000 fairly advance feature [[0.65256745]] NOTISSUE
# 756 anyhow have call para professional version [[0.5765153]] NOTISSUE
# 757 have way flexibility functionality version [[0.8153649]] NOTISSUE
# 758 go bye bye [[0.57391393]] NOTISSUE
# 759 please product [[0.51541066]] NOTISSUE
# 760 have trial version instal computer buy it [[0.4761612]] ISSUE
# 761 have do enter code box [[0.14095765]] ISSUE
# 762 easy [[0.7384003]] NOTISSUE
# 763 glad able install one computer [[0.8090585]] NOTISSUE
# 764 today best office suite microsoft have own [[0.92253095]] NOTISSUE
# 765 easy use excellent result [[0.9549017]] NOTISSUE
# 766 great sw [[0.9521489]] NOTISSUE
# 767 easy learn [[0.812764]] NOTISSUE
# 768 have good graphic [[0.7875603]] NOTISSUE
# 769 help visualize space [[0.6307483]] NOTISSUE
# 770 see d [[0.49606723]] ISSUE
# 771 have configure do [[0.43552902]] ISSUE
# 772 difficult change room be house overall style start give design [[0.17116612]] ISSUE
# 773 recently buy version [[0.71774656]] NOTISSUE
# 774 instal software [[0.52612984]] NOTISSUE
# 775 operate well old personal computer [[0.6862216]] NOTISSUE
# 776 run lot faster [[0.2571667]] ISSUE
# 777 access corporate entrant [[0.44102108]] ISSUE
# 778 awesome [[0.91540056]] NOTISSUE
# 779 give whirl [[0.4564297]] ISSUE
# 780 have buy product again [[0.5896835]] NOTISSUE
# 781 five star them [[0.7165903]] NOTISSUE
# 782 great company deal [[0.97622615]] NOTISSUE
# 783 agree window improve thier product [[0.27694702]] ISSUE
# 784 linx not user friendly [[0.56441337]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.21591796]] ISSUE
# 786 unix far stable [[0.33888564]] ISSUE
# 787 have access cd version [[0.77273273]] NOTISSUE
# 788 like [[0.56281424]] NOTISSUE
# 789 work well me [[0.8726614]] NOTISSUE
# 790 usually go disc want attempt [[0.1690902]] ISSUE
# 791 lot cd [[0.6984413]] NOTISSUE
# 792 great program child learn difference [[0.99351525]] NOTISSUE
# 793 fun excellent way learn math [[0.99845374]] NOTISSUE
# 794 child love do too [[0.44118497]] ISSUE
# 795 fun way keep brain work [[0.98553663]] NOTISSUE
# 796 marvelous [[0.91099095]] NOTISSUE
# 797 memory improvement software marvelous [[0.8613496]] NOTISSUE
# 798 help improve memory provide motivate game [[0.7301083]] NOTISSUE
# 799 highly recommend [[0.83667773]] NOTISSUE
# 800 great [[0.9521489]] NOTISSUE
# 801 love software [[0.8586608]] NOTISSUE
# 802 word new disturb get high score [[0.10018606]] ISSUE
# 803 have symantec customer year [[0.7880399]] NOTISSUE
# 804 year product get better better [[0.68454057]] NOTISSUE
# 805 not use product purpose [[0.18492365]] ISSUE
# 806 anti virus find problem personal computer fix you [[0.09102175]] ISSUE
# 807 anti virus clean unneeded file [[0.17736171]] ISSUE
# 808 roll back system certain date problem occur [[0.04145683]] ISSUE
# 809 good program beginner experience family historian [[0.9971511]] NOTISSUE
# 810 program joy use [[0.93663794]] NOTISSUE
# 811 design make thing simple user [[0.7163199]] NOTISSUE
# 812 program easy use interface [[0.7846711]] NOTISSUE
# 813 no problem far better feature [[0.23112042]] ISSUE
# ...
# 3942 sergeant pepper beef sandwich aunt sauce excellent sandwich well [[0.9975916]] NOTISSUE
# 3943 hawaiian breeze mango magic pineapple delight smoothie have try far good [[0.9996451]] NOTISSUE
# 3944 go lunch service slow [[0.09192321]] ISSUE
# 3945 have say place walk expect be amaze quickly disappoint [[0.22552966]] ISSUE
# 3946 mortify [[0.32057112]] ISSUE
# 3947 needle say never be back again [[0.18558995]] ISSUE
# 3948 anyways food definitely not fill all price pay expect more [[0.14138885]] ISSUE
# 3949 chip come drip grease not edible [[0.06976783]] ISSUE
# 3950 normally impress strip steak [[0.5830598]] NOTISSUE
# 3951 have go two thousand seven meal have awesome [[0.94596535]] NOTISSUE
# 3952 server nice attentive serve staff [[0.99553216]] NOTISSUE
# 3953 cashier friendly bring food me [[0.9044609]] NOTISSUE
# 3954 work hospitality industry paradise valley have refrain recommend ciob longer [[0.74871856]] NOTISSUE
# 3955 atmosphere fun [[0.9367571]] NOTISSUE
# 3956 not recommend others [[0.26673645]] ISSUE
# 3957 service quick to go order like like it [[0.6272507]] NOTISSUE
# 3958 mean really do get famous fish chip terrible [[0.01569373]] ISSUE
# 3959 say mouth belly please [[0.3347321]] ISSUE
# 3960 not thing [[0.16725108]] ISSUE
# 3961 two thumb up [[0.42889306]] ISSUE
# 3962 read please do no-go there [[0.11845962]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.99145377]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.9995415]] NOTISSUE
# 3965 have nice atmosphere [[0.944732]] NOTISSUE
# 3966 tonight have elk file special and suck [[0.1979479]] ISSUE
# 3967 one bite hook [[0.19446474]] ISSUE
# 3968 order old classic new dish go time sorely disappoint everything [[0.3087073]] ISSUE
# 3969 cute quaint simple honest [[0.7931497]] NOTISSUE
# 3970 chicken deliciously season have perfect fry outside moist chicken inside [[0.72719353]] NOTISSUE
# 3971 food great always compliment chef [[0.9986386]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.98303545]] NOTISSUE
# 3973 awesome selection beer [[0.97840285]] NOTISSUE
# 3974 great food awesome service [[0.9990133]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger 8 not expect tip that [[0.67494583]] NOTISSUE
# 3976 fly apple juice fly [[0.2866552]] ISSUE
# 3977 now nan chicken tasty [[0.951646]] NOTISSUE
# 3978 service think good [[0.89490706]] NOTISSUE
# 3979 food barely lukewarm have sit wait server bring u [[0.07884426]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.5229299]] NOTISSUE
# 3981 nicest chinese restaurant have while [[0.9794519]] NOTISSUE
# 3982 overall like food service [[0.49833176]] ISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.98703694]] NOTISSUE
# 3984 probably never come back not recommend it [[0.17520767]] ISSUE
# 3985 friend pasta bad barely touch it [[0.17333394]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.99488753]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.9784636]] NOTISSUE
# 3988 never have complain here [[0.13320105]] ISSUE
# 3989 restaurant clean have family restaurant feel it [[0.9047396]] NOTISSUE
# 3990 way fry [[0.6031043]] NOTISSUE
# 3991 not sure long stand long begin feel awkwardly place [[0.07861501]] ISSUE
# 3992 open sandwich impress not good way [[0.6129958]] NOTISSUE
# 3993 not be back [[0.12789644]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.8808331]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.9926974]] NOTISSUE
# 3996 order vegetarian menu dinner have wide array option choose from [[0.994169]] NOTISSUE
# 3997 have watch price inflate portion get smaller management attitude grow rapidly [[0.08287188]] ISSUE
# 3998 wonderful little tapa ambience make feel warm fuzzy inside [[0.9917691]] NOTISSUE
# 3999 get enjoy seafood salad fabulous vinaigrette [[0.99839705]] NOTISSUE
# 4000 wonton thin not thick chewy melt mouth [[0.06839419]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.9878029]] NOTISSUE
# 4002 sit right time server get go fantastic [[0.57455045]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s up [[0.5138667]] NOTISSUE
# 4004 town definitely be spot hit again [[0.44682327]] ISSUE
# 4005 have wait thirty minute get drink longer get two area [[0.12764075]] ISSUE
# 4006 great place eat [[0.9791423]] NOTISSUE
# 4007 jalapeno bacon soon good [[0.82525176]] NOTISSUE
# 4008 service poor [[0.07216842]] ISSUE
# 4009 food good service good price good [[0.9980757]] NOTISSUE
# 4010 price good [[0.88759136]] NOTISSUE
# 4011 price good [[0.88759136]] NOTISSUE
# 4012 service good [[0.8780491]] NOTISSUE
# 4013 place not clean food oh stale [[0.02929322]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.5549966]] NOTISSUE
# 4015 service bad [[0.03213707]] ISSUE
# 4016 happy be here [[0.89431846]] NOTISSUE
# 4017 taste like dirt [[0.1625818]] ISSUE
# 4018 one place phoenix definately go back again [[0.61148894]] NOTISSUE
# 4019 block amaze [[0.80912286]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.8596172]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.5305085]] NOTISSUE
# 4022 hashemi poor quality soggy tasteless [[0.01174719]] ISSUE
# 4023 great time family dinner sunday night [[0.9965501]] NOTISSUE
# 4024 food not tasty all not say real traditional hunan style [[0.1463506]] ISSUE
# 4025 bother me slow service [[0.05186316]] ISSUE
# 4026 flair bartender absolutely amaze [[0.94605947]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.3188444]] ISSUE
# 4028 good order twice [[0.8839774]] NOTISSUE
# 4029 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.0412123]] ISSUE
# 4030 girlfriend veal bad [[0.03778096]] ISSUE
# 4031 unfortunately not good [[0.18929088]] ISSUE
# 4032 have pretty satisfy experience [[0.89038646]] NOTISSUE
# 4033 join club get awesome offer email [[0.9618909]] NOTISSUE
# 4034 perfect me like beer ice cold case colder [[0.83794147]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.04473206]] ISSUE
# 4036 chain no fan of beat place easily [[0.24058041]] ISSUE
# 4037 nacho have [[0.50592333]] NOTISSUE
# 4038 not be come back [[0.11636133]] ISSUE
# 4039 do not have word say place do pretty well [[0.13597287]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.99489105]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.9992861]] NOTISSUE
# 4042 receive pity huge have lot meat thumb there [[0.24380952]] ISSUE
# 4043 food arrive me [[0.33579475]] ISSUE
# 4044 pay 7 85 hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.18526778]] ISSUE
# 4045 classic maine lobster roll fantastic [[0.9911151]] NOTISSUE
# 4046 brother law work mall eat day guess sick night too [[0.02260216]] ISSUE
# 4047 good go have review place twice [[0.9284139]] NOTISSUE
# 4048 chip salsa good salsa fresh [[0.9914135]] NOTISSUE
# 4049 place great [[0.9688741]] NOTISSUE
# 4050 mediocre food [[0.11277816]] ISSUE
# 4051 get inside be impress place [[0.41902566]] ISSUE
# 4052 service super friendly [[0.95764095]] NOTISSUE
# 4053 sad little vegetable overcook [[0.05908808]] ISSUE
# 4054 place nice surprise [[0.9670037]] NOTISSUE
# 4055 live music totally blow [[0.19953349]] ISSUE
# (        id                                               text     label
#  0        0  have order data cable get well finish work pro...  NOTISSUE
#  1        1                                         love phone  NOTISSUE
#  2        2                            get well finish product  NOTISSUE
#  3        3                                     not be happier  NOTISSUE
#  4        4                    look headset long time have get  NOTISSUE
#  5        5                       headset start ring no reason     ISSUE
#  6        6                 display excellent camera good year  NOTISSUE
#  7        7                                 battery life great  NOTISSUE
#  8        8                   worst phone have have have month     ISSUE
#  9        9  not good item work start have problem auto rev...     ISSUE
#  10      10           embarrass ear hurt try push ear plug ear     ISSUE
#  11      11                                 protect phone side  NOTISSUE
#  12      12  average phone bad battery life operate weak ne...     ISSUE
#  13      13       clear skye call long battery life long range  NOTISSUE
#  14      14                               solo technology suck     ISSUE
#  15      15                             great hand free device  NOTISSUE
#  16      16   take self portrait outside exterior display cool  NOTISSUE
#  17      17                               problem have mention     ISSUE
#  18      18         try handsfree gadget one finally work well  NOTISSUE
#  19      19                                       magical help  NOTISSUE
#  20      20          worst piece crap version customer service     ISSUE
#  21      21                                 poor sound quality     ISSUE
#  22      22                                  best phone market  NOTISSUE
#  23      23                                          work well  NOTISSUE
#  24      24            company ship product promptly work well  NOTISSUE
#  25      25                                       exactly want  NOTISSUE
#  26      26  picture resolution far comparably price phone ...     ISSUE
#  27      27                                         great deal  NOTISSUE
#  28      28                 excellent product satisfy purchase  NOTISSUE
#  29      29         highly recommend encourage people give try  NOTISSUE
#  ...    ...                                                ...       ...
#  4025  4025                   flair bartender absolutely amaze  NOTISSUE
#  4026  4026                  freeze margarita way sugary taste     ISSUE
#  4027  4027                                   good order twice  NOTISSUE
#  4028  4028  nutshell 1 restaurant smell like combination d...     ISSUE
#  4029  4029                                girlfriend veal bad     ISSUE
#  4030  4030                             unfortunately not good     ISSUE
#  4031  4031                     have pretty satisfy experience  NOTISSUE
#  4032  4032                  join club get awesome offer email  NOTISSUE
#  4033  4033          perfect me like beer ice cold case colder  NOTISSUE
#  4034  4034  bland flavourless good way describe barely tep...     ISSUE
#  4035  4035                  chain no fan of beat place easily     ISSUE
#  4036  4036                                         nacho have  NOTISSUE
#  4037  4037                                   not be come back     ISSUE
#  4038  4038          do not have word say place do pretty well  NOTISSUE
#  4039  4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040  4040             great atmosphere friendly fast service  NOTISSUE
#  4041  4041        receive pity huge have lot meat thumb there  NOTISSUE
#  4042  4042                                     food arrive me     ISSUE
#  4043  4043  pay 7 85 hot dog fry look like come kid meal w...     ISSUE
#  4044  4044               classic maine lobster roll fantastic  NOTISSUE
#  4045  4045  brother law work mall eat day guess sick night...     ISSUE
#  4046  4046                    good go have review place twice  NOTISSUE
#  4047  4047                        chip salsa good salsa fresh  NOTISSUE
#  4048  4048                                        place great  NOTISSUE
#  4049  4049                                      mediocre food     ISSUE
#  4050  4050                        get inside be impress place  NOTISSUE
#  4051  4051                             service super friendly  NOTISSUE
#  4052  4052                      sad little vegetable overcook     ISSUE
#  4053  4053                                place nice surprise  NOTISSUE
#  4054  4054                            live music totally blow  NOTISSUE
#
#  [4055 rows x 3 columns],
#           label                                               text
#  0        ISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4        ISSUE                    look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE       clear skye call long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE         try handsfree gadget one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25       ISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE                 excellent product satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4025  NOTISSUE                   flair bartender absolutely amaze
#  4026     ISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell 1 restaurant smell like combination d...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                     have pretty satisfy experience
#  4032  NOTISSUE                  join club get awesome offer email
#  4033  NOTISSUE          perfect me like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE                  chain no fan of beat place easily
#  4036  NOTISSUE                                         nacho have
#  4037     ISSUE                                   not be come back
#  4038     ISSUE          do not have word say place do pretty well
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE        receive pity huge have lot meat thumb there
#  4042     ISSUE                                     food arrive me
#  4043     ISSUE  pay 7 85 hot dog fry look like come kid meal w...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE  brother law work mall eat day guess sick night...
#  4046  NOTISSUE                    good go have review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050     ISSUE                        get inside be impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#
#  [4055 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0     ISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4     ISSUE                    look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2256
# NOTISSUE    1799
# Name: label, dtype: int64

# %% [markdown]
# ### confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1833  192]
#  [ 423 1607]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8483353884093712
#               precision    recall  f1-score   support
#
#        ISSUE       0.81      0.91      0.86      2025
#     NOTISSUE       0.89      0.79      0.84      2030
#
#    micro avg       0.85      0.85      0.85      4055
#    macro avg       0.85      0.85      0.85      4055
# weighted avg       0.85      0.85      0.85      4055

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_v3.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE  have order data cable get well finish work pro...
# 1     NOTISSUE      ISSUE                                     not be happier
# 2     NOTISSUE      ISSUE                    look headset long time have get
# 3     NOTISSUE      ISSUE                                       exactly want
# 4        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 5     NOTISSUE      ISSUE                                     prompt service
# 6     NOTISSUE      ISSUE                               be look new earpiece
# 7     NOTISSUE      ISSUE       be look new earpiece jawbone era awesome too
# 8     NOTISSUE      ISSUE                  phone have have have cheaply make
# 9     NOTISSUE      ISSUE                             do not make mistake do
# 10    NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 11    NOTISSUE      ISSUE               find cell phone right away enter car
# 12    NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 13    NOTISSUE      ISSUE  have get defect not risk buy again build quali...
# 14    NOTISSUE      ISSUE                            nothing bad say headset
# 15    NOTISSUE      ISSUE                               no buyer remorse one
# 16    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 17       ISSUE   NOTISSUE                                     like return it
# 18    NOTISSUE      ISSUE  keyboard worthwhile usefulness sturdy do not e...
# 19    NOTISSUE      ISSUE                                   wo not regret it
# 20    NOTISSUE      ISSUE                                      work describe
# 21    NOTISSUE      ISSUE                          not recommend item anyone
# 22    NOTISSUE      ISSUE          sound clear people talk amaze quality too
# 23    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 24       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 25    NOTISSUE      ISSUE  largely channel sound directly ear seem increa...
# 26    NOTISSUE      ISSUE  no shift no bubble no peel not scratch nothing...
# 27    NOTISSUE      ISSUE                            please dont waste money
# 28       ISSUE   NOTISSUE           look good quality headset keep look nott
# 29       ISSUE   NOTISSUE                                     notte best one
# ..         ...        ...                                                ...
# 585   NOTISSUE      ISSUE               not have please quality food service
# 586   NOTISSUE      ISSUE             do recommend place go wrong dont place
# 587      ISSUE   NOTISSUE  salad have bland vinaigrette baby green heart ...
# 588   NOTISSUE      ISSUE                                                rat
# 589      ISSUE   NOTISSUE                  look authentic thai food go where
# 590   NOTISSUE      ISSUE     oh god felt like have never eat thai food dish
# 591   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 592   NOTISSUE      ISSUE  make drive way north scottsdale not one bite d...
# 593      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 594   NOTISSUE      ISSUE  prove dead wrong sushi bar not quality great s...
# 595      ISSUE   NOTISSUE                                 not fun experience
# 596   NOTISSUE      ISSUE                          promise wo not disappoint
# 597   NOTISSUE      ISSUE                                   not wait go back
# 598      ISSUE   NOTISSUE                       normally impress strip steak
# 599   NOTISSUE      ISSUE                             say mouth belly please
# 600   NOTISSUE      ISSUE                                       two thumb up
# 601   NOTISSUE      ISSUE                                      one bite hook
# 602      ISSUE   NOTISSUE  ryan bar definitely one edinburgh establishmen...
# 603   NOTISSUE      ISSUE                          overall like food service
# 604   NOTISSUE      ISSUE                           never have complain here
# 605      ISSUE   NOTISSUE                                            way fry
# 606      ISSUE   NOTISSUE                 open sandwich impress not good way
# 607   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 608      ISSUE   NOTISSUE  main thing not enjoy crowd older crowd middle ...
# 609   NOTISSUE      ISSUE                  town definitely be spot hit again
# 610      ISSUE   NOTISSUE             chicken dish ok beef like shoe leather
# 611   NOTISSUE      ISSUE          do not have word say place do pretty well
# 612   NOTISSUE      ISSUE        receive pity huge have lot meat thumb there
# 613   NOTISSUE      ISSUE                        get inside be impress place
# 614   NOTISSUE      ISSUE                            live music totally blow
#
# [615 rows x 3 columns]
