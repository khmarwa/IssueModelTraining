# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
import seaborn as sns
print("import done")
# Out:
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
DATA_FILE = 'C:/Users/khmar/Desktop/ISSUE/dataset/CSV/data_ameliorate/data.csv'
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #imbalanced Dataset
# Out:
# NOTISSUE    2030
# ISSUE       2025
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4055, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();

# %% [markdown]
# ###  Preprocessing the Data

# %%
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 'becomes',
 'becoming',
 'been',
 'before',
 'beforehand',
 'behind',
 'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 'show',
 'side',
 'since',
 'six',
 'sixty',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
        "couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re

# %%
def replace_word(word):
    
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText("I have so 2  soo servic going groop")
# Out:
# 'two soo service go group'

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
df=df[texts,tags]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8a09c3838e60> in <module>
# ----> 1 df=df[texts,tags]
#
# ~\ana\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\ana\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0                    order data cable finish work product
# 1                                              love phone
# 2                                          finish product
# 3                                             not happier
# 4                                  look headset long time
# 5                            headset start ring no reason
# 6                      display excellent camera good year
# 7                                      battery life great
# 8                                       worst phone month
# 9       not good item work start problem auto reverse ...
# 10               embarrass ear hurt try push ear plug ear
# 11                                          protect phone
# 12      average phone bad battery life operate weak ne...
# 13                clear skye long battery life long range
# 14                                   solo technology suck
# 15                                 great hand free device
# 16            self portrait outside exterior display cool
# 17                                        problem mention
# 18                  try handsfree gadget one finally work
# 19                                           magical help
# 20              worst piece crap version customer service
# 21                                     poor sound quality
# 22                                      best phone market
# 23                                                   work
# 24                     company ship product promptly work
# 25                                           exactly want
# 26      picture resolution far comparably price phone ...
# 27                                             great deal
# 28                     excellent product satisfy purchase
# 29                  highly recommend encourage people try
#                               ...
# 4025                     flair bartender absolutely amaze
# 4026                    freeze margarita way sugary taste
# 4027                                     good order twice
# 4028    nutshell one restaurant smell like combination...
# 4029                                  girlfriend veal bad
# 4030                               unfortunately not good
# 4031                            pretty satisfy experience
# 4032                        join club awesome offer email
# 4033               perfect like beer ice cold case colder
# 4034    bland flavourless good way describe barely tep...
# 4035                       chain no fan beat place easily
# 4036                                                macho
# 4037                                             not come
# 4038                                not word place pretty
# 4039    staff super nice quick crazy crowd downtown ju...
# 4040               great atmosphere friendly fast service
# 4041                     receive pity huge lot meat thumb
# 4042                                          food arrive
# 4043    pay seven eighty five hot dog fry look like co...
# 4044                 classic maine lobster roll fantastic
# 4045       brother law work mall eat day guess sick night
# 4046                              good review place twice
# 4047                          chip salsa good salsa fresh
# 4048                                          place great
# 4049                                        mediocre food
# 4050                                 inside impress place
# 4051                               service super friendly
# 4052                        sad little vegetable overcook
# 4053                                  place nice surprise
# 4054                              live music totally blow
# Name: text, Length: 4055, dtype: object, 0       NOTISSUE
# 1       NOTISSUE
# 2       NOTISSUE
# 3       NOTISSUE
# 4       NOTISSUE
# 5          ISSUE
# 6       NOTISSUE
# 7       NOTISSUE
# 8          ISSUE
# 9          ISSUE
# 10         ISSUE
# 11      NOTISSUE
# 12         ISSUE
# 13      NOTISSUE
# 14         ISSUE
# 15      NOTISSUE
# 16      NOTISSUE
# 17         ISSUE
# 18      NOTISSUE
# 19      NOTISSUE
# 20         ISSUE
# 21         ISSUE
# 22      NOTISSUE
# 23      NOTISSUE
# 24      NOTISSUE
# 25      NOTISSUE
# 26         ISSUE
# 27      NOTISSUE
# 28      NOTISSUE
# 29      NOTISSUE
#           ...
# 4025    NOTISSUE
# 4026       ISSUE
# 4027    NOTISSUE
# 4028       ISSUE
# 4029       ISSUE
# 4030       ISSUE
# 4031    NOTISSUE
# 4032    NOTISSUE
# 4033    NOTISSUE
# 4034       ISSUE
# 4035       ISSUE
# 4036    NOTISSUE
# 4037       ISSUE
# 4038    NOTISSUE
# 4039    NOTISSUE
# 4040    NOTISSUE
# 4041    NOTISSUE
# 4042       ISSUE
# 4043       ISSUE
# 4044    NOTISSUE
# 4045       ISSUE
# 4046    NOTISSUE
# 4047    NOTISSUE
# 4048    NOTISSUE
# 4049       ISSUE
# 4050    NOTISSUE
# 4051    NOTISSUE
# 4052       ISSUE
# 4053    NOTISSUE
# 4054    NOTISSUE
# Name: label, Length: 4055, dtype: object)' is an invalid key

# %%
# dictionary of lists  
dict = {'text': texts, 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('DATA_preprocessing2.csv')

# %%
####

# %%
DATA_FILE = 'DATA_preprocessing2.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2807, 3)
# (1248, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1411
# ISSUE       1396
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       629
# NOTISSUE    619
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1411
# ISSUE       1396
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2807, 200)
# Shape of test_data tensor: (1248, 200)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 2965 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2807, 200)
# Shape of data test tensor: (1248, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : overprice
# word not found : flavourful
# word not found : appal
# word not found : shawarrrrrrma
# word not found : profiterole
# word not found : soooooo
# word not found : flavourless
# word not found : accessoryone
# word not found : plantronincs
# word not found : notproduce
# word not found : notupload
# word not found : notslide
# word not found : tracfonewebsite
# word not found : supertooth
# word not found : reoccure
# word not found : notgreat
# word not found : notknow
# word not found : emailinc
# word not found : notspend
# word not found : convertor
# word not found : convolute
# word not found : notconvince
# word not found : notenough
# word not found : norber
# word not found : notdeath
# word not found : stylize
# word not found : notuntil
# word not found : mesmerise
# word not found : tigerlilly
# word not found : infatuate
# word not found : riingtones
# word not found : untasted
# word not found : cheesecurds
# word not found : smashburger
# word not found : ciob
# word not found : notclosed
# word not found : notproperly
# word not found : cosiness

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 38 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# Train on 2807 samples, validate on 1248 samples
# Epoch 1/2
# 2807/2807 [==============================] - 33s 12ms/step - loss: 0.5098 - acc: 0.7777 - val_loss: 0.4739 - val_acc: 0.7853
# Epoch 2/2
# 2807/2807 [==============================] - 24s 9ms/step - loss: 0.4030 - acc: 0.8315 - val_loss: 0.4518 - val_acc: 0.7965

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1170/1170 [==============================] - 3s 3ms/step
# loss: 41.57%
# acc: 83.16%

# %%
#without amelioration()
#scores = model_glove.evaluate(x_test, y_test,
                            #batch_size=batch_size)
#print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
#print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1234/1234 [==============================] - 3s 2ms/step
# loss: 42.44%
# acc: 81.44%

# %%
# Save the model
model_glove.save('LSTM_model_glove_300_DATA_with_text_processing.sav')

# %% [markdown]
# ### Prediction

# %%
'''def prediction_classe2(prediction):
    x=""
    if prediction > 0.4:
          x = 'NOTISSUE'
    else :
          x = 'ISSUE'
    return x'''
# Out:
# 'def prediction_classe2(prediction):\n    x=""\n    if prediction > 0.4:\n          x = \'NOTISSUE\'\n    else :\n          x = \'ISSUE\'\n    return x'

# %%
'''text = np.array(["good service"])
text = transformText(text)
seq= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
prediction =model_glove.predict(sequences_matrix)
print(prediction[0][0])
prediction_classe2(prediction[0][0])'''
# Out:
# 'text = np.array(["good service"])\ntext = transformText(text)\nseq= tokenizer.texts_to_sequences(text)\nsequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)\nprediction =model_glove.predict(sequences_matrix)\nprint(prediction[0][0])\nprediction_classe2(prediction[0][0])'

# %%
def prediction_classe1(class_pred):
    x=""
    if class_pred == 0 :
        x = 'ISSUE'
    if class_pred== 1:
        x = 'NOTISSUE'
    return x

# %%
def prediction1(input_file,output_file):
    df= pd.DataFrame(columns=['text','label'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    for i in x_input:
        seq = tokenizer.texts_to_sequences(i)
        seqs = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        yhat = model_glove.predict(seqs)
        class_pred = model_glove.predict_classes(seqs)
        classe1 = prediction_classe1(class_pred[0][0])
        df=df.append({'text':i,'label':classe1},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

# %%
def prediction2(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    for i in x_input:
        text = np.array(i)
        seq= tokenizer.texts_to_sequences(str(text))
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        prediction =model_glove.predict(sequences_matrix)
        pred_label =prediction_classe2(prediction[0][0])
        df=df.append({'text':i,'label':pred_label},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great prodoct"
#text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.95642734]]
# NOTISSUE

# %%
text="i have problem"
#text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.3575679]]
# ISSUE

# %%
#predict all data

# %%
input_file ='DATA_preprocessing2.csv'
output_file ='LSTM_data_pred_glove_300_with_text.csv'
prediction(input_file,output_file)
# Out:
# 1 order data cable finish work product [[0.64277583]] NOTISSUE
# 2 love phone [[0.8954935]] NOTISSUE
# 3 finish product [[0.6253688]] NOTISSUE
# 4 not happier [[0.3793818]] ISSUE
# 5 look headset long time [[0.59225047]] NOTISSUE
# 6 headset start ring no reason [[0.1941324]] ISSUE
# 7 display excellent camera good year [[0.9992106]] NOTISSUE
# 8 battery life great [[0.98510474]] NOTISSUE
# 9 worst phone month [[0.13038497]] ISSUE
# 10 not good item work start problem auto reverse tape player [[0.12688723]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.13828138]] ISSUE
# 12 protect phone [[0.67098874]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.04734094]] ISSUE
# 14 clear skye long battery life long range [[0.865825]] NOTISSUE
# 15 solo technology suck [[0.43548888]] ISSUE
# 16 great hand free device [[0.97370523]] NOTISSUE
# 17 self portrait outside exterior display cool [[0.9020208]] NOTISSUE
# 18 problem mention [[0.11893728]] ISSUE
# 19 try handsfree gadget one finally work [[0.8156598]] NOTISSUE
# 20 magical help [[0.5745291]] NOTISSUE
# 21 worst piece crap version customer service [[0.09704551]] ISSUE
# 22 poor sound quality [[0.31715715]] ISSUE
# 23 best phone market [[0.873264]] NOTISSUE
# 24 work [[0.6847017]] NOTISSUE
# 25 company ship product promptly work [[0.57725537]] NOTISSUE
# 26 exactly want [[0.49439722]] ISSUE
# 27 picture resolution far comparably price phone offer today [[0.8293732]] NOTISSUE
# 28 great deal [[0.9647961]] NOTISSUE
# 29 excellent product satisfy purchase [[0.98055446]] NOTISSUE
# 30 highly recommend encourage people try [[0.88943684]] NOTISSUE
# 31 better expect [[0.7575088]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.21021037]] ISSUE
# 33 great product price [[0.97133285]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.9981077]] NOTISSUE
# 35 disappointment [[0.22750165]] ISSUE
# 36 prompt service [[0.53289646]] NOTISSUE
# 37 excellent product price [[0.97841716]] NOTISSUE
# 38 headset [[0.52155143]] NOTISSUE
# 39 not waste money time [[0.05628344]] ISSUE
# 40 especially love long battery life [[0.9693142]] NOTISSUE
# 41 stupid buy new charger car charger cradle headphone car kit time new phone come [[0.7820948]] NOTISSUE
# 42 work great [[0.97409576]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.9940362]] NOTISSUE
# 44 come version singular nicer cell phone thing notice bad service [[0.07280479]] ISSUE
# 45 look new earpiece [[0.7088032]] NOTISSUE
# 46 look new earpiece jawbone era awesome [[0.8779143]] NOTISSUE
# 47 receive white color battery dead couple hoursthe original week longer thereplacement [[0.17050266]] ISSUE
# 48 year battery completely dead headset [[0.20583646]] ISSUE
# 49 phone two year one best [[0.85630906]] NOTISSUE
# 50 awesome new look fall two thousand [[0.9465994]] NOTISSUE
# 51 phone cheaply [[0.53937685]] NOTISSUE
# 52 att not clear sound distort yell talk [[0.15551154]] ISSUE
# 53 price good [[0.9261824]] NOTISSUE
# 54 plastic break easy clip [[0.66338605]] NOTISSUE
# 55 not mistake [[0.06830926]] ISSUE
# 56 oh forget mention weird color effect phone [[0.256282]] ISSUE
# 57 river spine case fit fine [[0.82781255]] NOTISSUE
# 58 area unit break not fond magnetic strap [[0.271012]] ISSUE
# 59 overall psyched phone appointment contact great reception [[0.9813105]] NOTISSUE
# 60 thing phone work perfectly like [[0.94906765]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.3217407]] ISSUE
# 62 easy [[0.80154145]] NOTISSUE
# 63 sanyo survive dozen drop blackton ill effect [[0.12731682]] ISSUE
# 64 fantastic earphone [[0.9429237]] NOTISSUE
# 65 find cell phone right away enter car [[0.34217232]] ISSUE
# 66 low quality [[0.65910786]] NOTISSUE
# 67 better reception clarity phone [[0.9283692]] NOTISSUE
# 68 warn stay away [[0.1505487]] ISSUE
# 69 wish return unit money [[0.4039335]] ISSUE
# 70 awesome device work great [[0.99921894]] NOTISSUE
# 71 talk one one one two hour battery literally drain die [[0.04637591]] ISSUE
# 72 not find bad unit come one arpad not recommend [[0.05099848]] ISSUE
# 73 displease [[0.19290377]] ISSUE
# 74 defect not risk buy build quality [[0.3665498]] ISSUE
# 75 case small difficult install [[0.33251095]] ISSUE
# 76 restore phone like new performance [[0.8750392]] NOTISSUE
# 77 recommend purchase cabra x ten series two work flawlessly moto q figure [[0.9491742]] NOTISSUE
# 78 search internet find one best value [[0.9511601]] NOTISSUE
# 79 not fit [[0.3665856]] ISSUE
# 80 happy product [[0.88884735]] NOTISSUE
# 81 screen size big key pad light camera quality excellent camera phone [[0.9983633]] NOTISSUE
# 82 bad headset [[0.12891474]] ISSUE
# 83 glad find product amazon hard find not high price [[0.69019324]] NOTISSUE
# 84 portable work [[0.8301678]] NOTISSUE
# 85 colleague great reception little expensive performance great [[0.99709654]] NOTISSUE
# 86 fully charge bed turn blue tooth wi fi notice twenty leave morning [[0.25620523]] ISSUE
# 87 problem phone read memory card turn [[0.13984542]] ISSUE
# 88 not good wear hat sunglass [[0.4404145]] ISSUE
# 89 timely shipment quality product [[0.7624875]] NOTISSUE
# 90 nice solid keyboard [[0.9873921]] NOTISSUE
# 91 fit surefire x two perfectly [[0.95780146]] NOTISSUE
# 92 horrible phone [[0.1760402]] ISSUE
# 93 bt battery junk [[0.5026589]] NOTISSUE
# 94 recommend [[0.68242466]] NOTISSUE
# 95 cant software work computer [[0.59642535]] NOTISSUE
# 96 disappoint [[0.22318242]] ISSUE
# 97 poor voice clarity [[0.37191904]] ISSUE
# 98 battery work great [[0.9842742]] NOTISSUE
# 99 no buyer remorse one [[0.34172165]] ISSUE
# 100 disappoint accessoryone [[0.22318242]] ISSUE
# 101 find inexcusable probably return phone change carrier [[0.08190338]] ISSUE
# 102 look great strong [[0.9911515]] NOTISSUE
# 103 mobile service two year pretty happy [[0.9893695]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.12735742]] ISSUE
# 105 disappointment hate ear [[0.13006939]] ISSUE
# 106 great software motorola [[0.96509725]] NOTISSUE
# 107 delivery time [[0.59273016]] NOTISSUE
# 108 easy use [[0.7488251]] NOTISSUE
# 109 uncomfortable ear house lg one thirty nine thousand env [[0.3501407]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.4325136]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.9763847]] NOTISSUE
# 112 like return [[0.50848037]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy not expect problem [[0.59836817]] NOTISSUE
# 114 version s bill difficult understand price plan simple [[0.50581163]] NOTISSUE
# 115 charge overnight battery work great [[0.9528061]] NOTISSUE
# 116 wo not regret [[0.07026263]] ISSUE
# 117 love phone [[0.8954935]] NOTISSUE
# 118 disappointment [[0.22750165]] ISSUE
# 119 not user friendly [[0.5132042]] NOTISSUE
# 120 unfortunately ability actually know receive important feature phone pitiful respect [[0.50329864]] NOTISSUE
# 121 exchange phone problem [[0.46629158]] ISSUE
# 122 result phone stick max volume mute [[0.2079222]] ISSUE
# 123 public display affection rock [[0.83209646]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.9600643]] NOTISSUE
# 125 definitely recommend cabra tk fifty v look comfort clarity great price [[0.99876547]] NOTISSUE
# 126 version two year ago like service [[0.3887523]] ISSUE
# 127 pretty piece junk [[0.55801326]] NOTISSUE
# 128 plug wrong size [[0.20078063]] ISSUE
# 129 work describe [[0.41261208]] ISSUE
# 130 save money item month [[0.2410734]] ISSUE
# 131 bad purchase [[0.13702755]] ISSUE
# 132 im satisfy [[0.6660887]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.8520998]] NOTISSUE
# 134 battery excellent bargain [[0.9782804]] NOTISSUE
# 135 defective crap [[0.06227954]] ISSUE
# 136 no star able [[0.45620838]] ISSUE
# 137 wear glass fit fine [[0.8598781]] NOTISSUE
# 138 sound quality device unacceptable quiet area hear [[0.7618833]] NOTISSUE
# 139 not recommend item [[0.30521804]] ISSUE
# 140 holster arrive not match photo ad [[0.12924194]] ISSUE
# 141 great no problem [[0.73137945]] NOTISSUE
# 142 earlier review note plug charger happen [[0.32907778]] ISSUE
# 143 frog phone charm adorable eye catch [[0.9099502]] NOTISSUE
# 144 know push hard right number time function want not [[0.1674306]] ISSUE
# 145 sound clear people talk amaze quality [[0.8912348]] NOTISSUE
# 146 aluminum case new palm v work protect handheld perfectly far [[0.96518356]] NOTISSUE
# 147 good product [[0.8873456]] NOTISSUE
# 148 mobile phone tool [[0.8566401]] NOTISSUE
# 149 impress job motorola steadiness phone [[0.6501031]] NOTISSUE
# 150 receive order ship timeframe good work order overall excite source [[0.8784598]] NOTISSUE
# 151 phone sturdy waterproof [[0.792102]] NOTISSUE
# 152 not impress not recommend item [[0.11388884]] ISSUE
# 153 complaint standard sound volume little low turn five five [[0.33509672]] ISSUE
# 154 thank amazon thing need good price [[0.9878346]] NOTISSUE
# 155 end slide edge pant pocket instead [[0.26477668]] ISSUE
# 156 store buy new nokia phone work great [[0.9931884]] NOTISSUE
# 157 work great [[0.97409576]] NOTISSUE
# 158 ugly [[0.10214618]] ISSUE
# 159 horrible switch time [[0.11007627]] ISSUE
# 160 noise shield incredible [[0.90876216]] NOTISSUE
# 161 no real improvement [[0.27041]] ISSUE
# 162 razor battery good buy [[0.9703982]] NOTISSUE
# 163 good work amazon [[0.93641347]] NOTISSUE
# 164 refuse refund replace [[0.10118213]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.6637577]] NOTISSUE
# 166 basically throw money window [[0.1299363]] ISSUE
# 167 great case price [[0.9537063]] NOTISSUE
# 168 one drop inch kitchen counter crack not impress not laugh [[0.03291874]] ISSUE
# 169 bluetooth range good day ago leave phone trunk carry conversation hitch [[0.925116]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.99602425]] NOTISSUE
# 171 largely channel sound directly ear increase sound volume clarity [[0.84864086]] NOTISSUE
# 172 new one work properly [[0.59010184]] NOTISSUE
# 173 glad purchase [[0.8589425]] NOTISSUE
# 174 miss numerous reason [[0.4688857]] ISSUE
# 175 phone defective people hear use [[0.18515272]] ISSUE
# 176 notably product [[0.5421711]] NOTISSUE
# 177 suck stuff not work phone [[0.13670573]] ISSUE
# 178 no shift no bubble no peel not scratch note happier new one droid [[0.20135406]] ISSUE
# 179 worst software use zero star [[0.17197]] ISSUE
# 180 try exercise frustration [[0.23323302]] ISSUE
# 181 case flimsy piece plastic no protection whatsoever [[0.07956317]] ISSUE
# 182 cabra barset happy sound quality especially outdo better [[0.99213856]] NOTISSUE
# 183 love camera pretty good quality [[0.99903107]] NOTISSUE
# 184 thank great service [[0.99342644]] NOTISSUE
# 185 total package [[0.6812561]] NOTISSUE
# 186 seller understand patient definitely buy [[0.78837323]] NOTISSUE
# 187 firefly one star contact singular t inform practice [[0.45243374]] ISSUE
# 188 aggravate [[0.20642965]] ISSUE
# 189 great product price [[0.97133285]] NOTISSUE
# 190 purchase family friend enjoy clarity ease use [[0.99497473]] NOTISSUE
# 191 virgin wireless rock cheap little phone [[0.8417286]] NOTISSUE
# 192 work [[0.6847017]] NOTISSUE
# 193 notably [[0.5104733]] NOTISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide [[0.10319562]] ISSUE
# 195 dont waste money [[0.18147117]] ISSUE
# 196 satisfy purchase [[0.6841454]] NOTISSUE
# 197 look good quality headset look nott [[0.9479329]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.5230982]] NOTISSUE
# 199 notte best one [[0.8493499]] NOTISSUE
# 200 best one [[0.8925194]] NOTISSUE
# 201 disappoint result [[0.10167447]] ISSUE
# 202 cumbersome design [[0.37126863]] ISSUE
# 203 great new package nice work good [[0.9998241]] NOTISSUE
# 204 no problem come time expect [[0.12870814]] ISSUE
# 205 great product [[0.9590715]] NOTISSUE
# 206 piece crap [[0.22492224]] ISSUE
# 207 experience terrible [[0.27065176]] ISSUE
# 208 fourth bluetooth headset [[0.6503836]] NOTISSUE
# 209 comfortable one [[0.9218815]] NOTISSUE
# 210 hat [[0.5765197]] NOTISSUE
# 211 fix problem [[0.18419205]] ISSUE
# 212 worst [[0.08807869]] ISSUE
# 213 happy [[0.894129]] NOTISSUE
# 214 no trouble access internet download intone perform function [[0.49769008]] ISSUE
# 215 barely hear constantly [[0.29950836]] ISSUE
# 216 battery life highly unacceptable [[0.3863965]] ISSUE
# 217 company joke [[0.29867947]] ISSUE
# 218 description [[0.47628415]] ISSUE
# 219 happen force stop headset [[0.24084648]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.98686314]] NOTISSUE
# 221 version tech support walk procedure work end hard replay set wipe data [[0.49625793]] ISSUE
# 222 voice quality signal strength drop [[0.71984285]] NOTISSUE
# 223 play louder speaker size price low think quality lack not [[0.19413294]] ISSUE
# 224 better expect [[0.7575088]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push [[0.29621232]] ISSUE
# 226 battery hold [[0.6294131]] NOTISSUE
# 227 difficult d recommend avoid product [[0.19858903]] ISSUE
# 228 two day not easy hear [[0.32001698]] ISSUE
# 229 car charger not week charger break plug start smoke [[0.08588804]] ISSUE
# 230 sprint terrible customer service [[0.49055907]] ISSUE
# 231 link phone effort [[0.44698507]] ISSUE
# 232 cool [[0.67055887]] NOTISSUE
# 233 easy use [[0.7488251]] NOTISSUE
# 234 better new [[0.7897873]] NOTISSUE
# 235 posse junk no idea [[0.16073406]] ISSUE
# 236 piece trash [[0.20013925]] ISSUE
# 237 pretty good product [[0.97235596]] NOTISSUE
# 238 great phone [[0.96296006]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.99573576]] NOTISSUE
# 240 research development division obviously know [[0.9047703]] NOTISSUE
# 241 real killer volume course break [[0.27273437]] ISSUE
# 242 phone work fine [[0.84430325]] NOTISSUE
# 243 happy product one [[0.91050273]] NOTISSUE
# 244 poor construction [[0.09782117]] ISSUE
# 245 infuriate [[0.2808977]] ISSUE
# 246 overall recommend phone new walkman [[0.83745915]] NOTISSUE
# 247 sprint charge service [[0.73407024]] NOTISSUE
# 248 cheap feel look cheap [[0.64692414]] NOTISSUE
# 249 fit ear comfortable [[0.9018231]] NOTISSUE
# 250 network europe asia [[0.24858381]] ISSUE
# 251 clip belt definitely feel like fifty cent s come [[0.8220766]] NOTISSUE
# 252 like design look cabra ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.58310956]] NOTISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.8282613]] NOTISSUE
# 254 worst phone samsung crap crappy samsung e seven fifteen worst [[0.10117032]] ISSUE
# 255 charger work week completely stop charge phone [[0.17508937]] ISSUE
# 256 poor product [[0.12288009]] ISSUE
# 257 need better instruction [[0.6275135]] NOTISSUE
# 258 need two hand operate screen software interface decade old compete new software design [[0.7123996]] NOTISSUE
# 259 work pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.8295839]] NOTISSUE
# 260 steer clear product genuine palm replacement pen come pack [[0.6361005]] NOTISSUE
# 261 not buy not suck [[0.0483223]] ISSUE
# 262 great product sure beat finger [[0.9741077]] NOTISSUE
# 263 plus seriously not believe worth steep price point [[0.14930327]] ISSUE
# 264 case try normally fall apart month one long haul [[0.09198522]] ISSUE
# 265 disappoint performance [[0.28138247]] ISSUE
# 266 normale mistake notably phone [[0.24365407]] ISSUE
# 267 phone worst brand [[0.15415545]] ISSUE
# 268 case extra originally later discard scratch ear [[0.16810916]] ISSUE
# 269 recommend different brand cell phone mp player family [[0.8903498]] NOTISSUE
# 270 not bother store [[0.11542953]] ISSUE
# 271 post detail comment grey black phone fire red great color [[0.8848506]] NOTISSUE
# 272 not problem item order need [[0.13978553]] ISSUE
# 273 pay guess [[0.30094737]] ISSUE
# 274 not software great job intone form exist cd internet connection [[0.78908354]] NOTISSUE
# 275 im surprise good quality car charger not review [[0.975577]] NOTISSUE
# 276 fabulous [[0.92384195]] NOTISSUE
# 277 bt headset currently not good real time game like person shooter audio delay mess [[0.09850327]] ISSUE
# 278 price cable excellent [[0.9736788]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.52576905]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end [[0.17949164]] ISSUE
# 281 wind resistant [[0.49679476]] ISSUE
# 282 obviously terrible customer service pay [[0.15563984]] ISSUE
# 283 not forever [[0.13936064]] ISSUE
# 284 not overly expensive replace [[0.11025613]] ISSUE
# 285 easy operate sound better try [[0.95572776]] NOTISSUE
# 286 contact company tell unit warranty notproduce receipt luck [[0.18472913]] ISSUE
# 287 link way exchange bad phone return unit [[0.17704159]] ISSUE
# 288 phone sturdy nokia bar phone [[0.9065072]] NOTISSUE
# 289 great phone [[0.96296006]] NOTISSUE
# 290 place tree case not not snug lot extra room [[0.16211599]] ISSUE
# 291 please [[0.5034931]] NOTISSUE
# 292 battery terrible [[0.17409693]] ISSUE
# 293 find product easy set use [[0.84499204]] NOTISSUE
# 294 earpiece large heavy fall ear [[0.27061212]] ISSUE
# 295 utter crap sound quality terrible [[0.03277993]] ISSUE
# 296 charger arrive promise timeframe not work [[0.38427395]] ISSUE
# 297 no ear loop need tiny sound great [[0.9175033]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.12235989]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.8468118]] NOTISSUE
# 300 talk useless customer service [[0.17366898]] ISSUE
# 301 felt light tinny [[0.39920795]] ISSUE
# 302 not fit palm tungsten e two break time try plug [[0.16197391]] ISSUE
# 303 happy purchase good quality low price [[0.9964964]] NOTISSUE
# 304 love look feel samsung flipphones [[0.94837904]] NOTISSUE
# 305 design sharp blue nice color [[0.9886127]] NOTISSUE
# 306 more [[0.5034931]] NOTISSUE
# 307 not recommend [[0.3336019]] ISSUE
# 308 nice sound [[0.9479823]] NOTISSUE
# 309 look good picture case huge disappointment [[0.77820677]] NOTISSUE
# 310 jawbone replace [[0.2549638]] ISSUE
# 311 setup smoothly [[0.8274345]] NOTISSUE
# 312 extremely slow forever [[0.21120968]] ISSUE
# 313 study interest worst sin industrial design [[0.0903682]] ISSUE
# 314 thing happen track [[0.3183575]] ISSUE
# 315 easy access phone handy detachable belt clip [[0.94115704]] NOTISSUE
# 316 continue pair periodically drop [[0.46327206]] ISSUE
# 317 notupload intone party [[0.3978712]] ISSUE
# 318 bluetooth not work phone lock screen flash randomly pocket lock [[0.6342545]] NOTISSUE
# 319 truly awful [[0.3986108]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear battery [[0.87667954]] NOTISSUE
# 321 volume ringer real good choice loud one [[0.97759056]] NOTISSUE
# 322 tone acceptable [[0.32741895]] ISSUE
# 323 camera color balance awful [[0.6764677]] NOTISSUE
# 324 product clearly not ready prime time netware cool look nostell come worthless [[0.08107761]] ISSUE
# 325 love intone upbeat [[0.9178376]] NOTISSUE
# 326 chinese forgery abound [[0.548453]] NOTISSUE
# 327 easy pair samsung cell [[0.9339249]] NOTISSUE
# 328 instruction notexplain microphone jack use [[0.38201046]] ISSUE
# 329 advise not purchase item work [[0.43136546]] ISSUE
# 330 bad pay month service [[0.04717698]] ISSUE
# 331 work [[0.6847017]] NOTISSUE
# 332 nokia forty two usb cable not work phone [[0.3694452]] ISSUE
# 333 clear crisp sound [[0.85456604]] NOTISSUE
# 334 use smallest earpiece provide stay pretty [[0.95614725]] NOTISSUE
# 335 biggest complaint battery drain superfast [[0.15847026]] ISSUE
# 336 design ergonomic theory not stand ear [[0.2766643]] ISSUE
# 337 not buy want use holster [[0.20383754]] ISSUE
# 338 phone great picture video clip [[0.9779058]] NOTISSUE
# 339 normale look cool [[0.7436272]] NOTISSUE
# 340 ear occupy background not distract [[0.12325213]] ISSUE
# 341 comfortable fit need headset comfortable hour time not entire day [[0.7411575]] NOTISSUE
# 342 phone not accept cbr mp s preferably rest peace window medium player [[0.44719514]] ISSUE
# 343 norbert price [[0.66994095]] NOTISSUE
# 344 come strong light use light camera shoot flash signal seriously [[0.7353382]] NOTISSUE
# 345 lightweight work [[0.8957914]] NOTISSUE
# 346 beware [[0.34127122]] ISSUE
# 347 love cable allow connect mini usb device personal computer [[0.90287346]] NOTISSUE
# 348 near hear conversation [[0.5674673]] NOTISSUE
# 349 cool case open allow screen scratch one [[0.5899608]] NOTISSUE
# 350 buy phone replacement start regret [[0.3592426]] ISSUE
# 351 appear actually outperform original battery china come twenty five [[0.5769875]] NOTISSUE
# 352 dottore phone number sim [[0.6265278]] NOTISSUE
# 353 o minute actually try use phone wife phone problem [[0.2399555]] ISSUE
# 354 poor quality [[0.22283383]] ISSUE
# 355 cabra ear gel best [[0.80899936]] NOTISSUE
# 356 not worth [[0.23703489]] ISSUE
# 357 phone crash completely replace [[0.09314002]] ISSUE
# 358 quit work eighteen month purchase one best headset [[0.5064736]] NOTISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.377734]] ISSUE
# 360 great phone [[0.96296006]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.08094061]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.91778016]] NOTISSUE
# 363 phone notslide car grip prevent phone slip hand [[0.67956144]] NOTISSUE
# 364 simply best bluetooth headset sound quality [[0.95670885]] NOTISSUE
# 365 think plan one sure moto phone [[0.67109084]] NOTISSUE
# 366 span hour two people exclaim whoa new phone tv [[0.49506214]] ISSUE
# 367 cord headset freedom wireless helpful [[0.9769121]] NOTISSUE
# 368 case pa one year mark sign wear one functional [[0.3117465]] ISSUE
# 369 leather nice soft fit tight cut face good shape [[0.9783155]] NOTISSUE
# 370 need task [[0.77140003]] NOTISSUE
# 371 receive product two day break [[0.27298716]] ISSUE
# 372 product great work lot easier copier wait hold [[0.9422277]] NOTISSUE
# 373 size send headset stay ear [[0.5290346]] NOTISSUE
# 374 t mobile best customer service [[0.97701824]] NOTISSUE
# 375 arrive quickly expensive sell [[0.31587496]] ISSUE
# 376 try two unit failure two month pro [[0.11051265]] ISSUE
# 377 provide good protection look classy [[0.9932115]] NOTISSUE
# 378 russel good [[0.91672564]] NOTISSUE
# 379 tracfonewebsite user friendly easy activate etc [[0.9375331]] NOTISSUE
# 380 design good four [[0.9636723]] NOTISSUE
# 381 great reception time [[0.9756257]] NOTISSUE
# 382 highly recommend product [[0.86514705]] NOTISSUE
# 383 house unit sunglass not good texas [[0.4582116]] ISSUE
# 384 dit not work time nokia five thousand twenty [[0.2944743]] ISSUE
# 385 buy mainly charger break soon purchase [[0.638023]] NOTISSUE
# 386 like loud buzz override conversation phone [[0.7746611]] NOTISSUE
# 387 fantastic buy phone [[0.984969]] NOTISSUE
# 388 stay away store careful [[0.33326563]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.9586073]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.7882189]] NOTISSUE
# 391 light plenty battery capacity comfortable wear somewhat extend period time [[0.9457513]] NOTISSUE
# 392 disappoint [[0.22318242]] ISSUE
# 393 blue ant easy use [[0.89198637]] NOTISSUE
# 394 cheap hey work [[0.71053797]] NOTISSUE
# 395 pleasantly suprised low cost item [[0.57000816]] NOTISSUE
# 396 camera phone dustpan indoors disposable [[0.78434217]] NOTISSUE
# 397 day later puff smoke come phone use [[0.16041195]] ISSUE
# 398 convenient simple use job car ride smoother [[0.96024984]] NOTISSUE
# 399 nano state son disappoint [[0.16930896]] ISSUE
# 400 sound quality excellent [[0.9933414]] NOTISSUE
# 401 best headset use [[0.78142995]] NOTISSUE
# 402 not recommend [[0.3336019]] ISSUE
# 403 year carry highest quality anti glare screen protector find date [[0.83101964]] NOTISSUE
# 404 want [[0.510665]] NOTISSUE
# 405 particular model not work motorola q smartphone [[0.6741909]] NOTISSUE
# 406 wont work right [[0.48218942]] ISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.8637022]] NOTISSUE
# 408 warranty problem reoccure line money singular not support [[0.08978365]] ISSUE
# 409 want plantronics five ten right one issue good [[0.7082746]] NOTISSUE
# 410 crisp clear [[0.80727804]] NOTISSUE
# 411 charge dead minute [[0.15124333]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.28693292]] ISSUE
# 413 absolutely horrible reception apartment phone not problem [[0.10858083]] ISSUE
# 414 reception generally good [[0.75917244]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.98684525]] NOTISSUE
# 416 great bluetooth [[0.9735738]] NOTISSUE
# 417 highly recommend case [[0.84877944]] NOTISSUE
# 418 worthwhile [[0.61432123]] NOTISSUE
# 419 phone year old slowly break despite care [[0.15649407]] ISSUE
# 420 sorry purchase [[0.24715666]] ISSUE
# 421 buy hop bluetooth headset fit better thing impossible wear [[0.66053903]] NOTISSUE
# 422 tree t mobile refuse replace force buy phone kind upgrade discount [[0.3255382]] ISSUE
# 423 horrible [[0.07788389]] ISSUE
# 424 allow possibility double book date time [[0.49432352]] ISSUE
# 425 work two week break [[0.33069134]] ISSUE
# 426 hold securely belt [[0.47642514]] ISSUE
# 427 simple use like [[0.74788773]] NOTISSUE
# 428 great tool entertainment communication data management oh sure use activesync four two optimal data synchronization result [[0.97787035]] NOTISSUE
# 429 house case smell disgust [[0.07100096]] ISSUE
# 430 not want [[0.20821232]] ISSUE
# 431 two case order [[0.4959281]] ISSUE
# 432 buy battery coupon amazon happy purchase [[0.98284113]] NOTISSUE
# 433 internet access fine rare instance work [[0.92699075]] NOTISSUE
# 434 perfect p [[0.87945014]] NOTISSUE
# 435 five star plus plus [[0.85750127]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end [[0.9896847]] NOTISSUE
# 437 fifty drain [[0.28161576]] ISSUE
# 438 try talk real loud shout telephone old tell notgreat [[0.1916425]] ISSUE
# 439 good work fine [[0.9749103]] NOTISSUE
# 440 price great deal [[0.9756798]] NOTISSUE
# 441 great price [[0.9686867]] NOTISSUE
# 442 wind completely useless [[0.07983871]] ISSUE
# 443 yes shiny love [[0.9691245]] NOTISSUE
# 444 not work [[0.30555466]] ISSUE
# 445 think good deal seven forty four plug phone v razor [[0.78686583]] NOTISSUE
# 446 reception headset excellent [[0.96604216]] NOTISSUE
# 447 two thumb seller [[0.5149024]] NOTISSUE
# 448 version lg phone work good reception range exceed twenty foot line sight [[0.8960744]] NOTISSUE
# 449 improper description return [[0.3948696]] ISSUE
# 450 one work two comfortable [[0.8968943]] NOTISSUE
# 451 battery charge life long [[0.6100376]] NOTISSUE
# 452 cabra largely fit ear [[0.3017646]] ISSUE
# 453 battery no life [[0.50666815]] NOTISSUE
# 454 check no feature disappoint [[0.20586514]] ISSUE
# 455 product exactly describe [[0.30227736]] ISSUE
# 456 signal version phone wo not [[0.12219832]] ISSUE
# 457 not job [[0.2651973]] ISSUE
# 458 recommend [[0.68242466]] NOTISSUE
# 459 plan order [[0.4492556]] ISSUE
# 460 phone camera nice cool effect play video decent [[0.99468875]] NOTISSUE
# 461 satisfy cell phone day one [[0.5079534]] NOTISSUE
# 462 better better one numerous palm [[0.876976]] NOTISSUE
# 463 awkward use unreliable [[0.05681355]] ISSUE
# 464 ship time quick [[0.6712583]] NOTISSUE
# 465 not good hop [[0.32399753]] ISSUE
# 466 good case [[0.8692333]] NOTISSUE
# 467 network [[0.40825734]] ISSUE
# 468 good product [[0.8873456]] NOTISSUE
# 469 unfortunately not work [[0.169]] ISSUE
# 470 break two month use [[0.24818796]] ISSUE
# 471 dont buy [[0.73508614]] NOTISSUE
# 472 father one thousand two sixty five battery die [[0.22821626]] ISSUE
# 473 ear pad come easily one week lose one [[0.13615666]] ISSUE
# 474 drop phone come screen black worst stop ring intermittently [[0.08704358]] ISSUE
# 475 horrible horrible protector [[0.05814784]] ISSUE
# 476 notice nokia [[0.47454828]] ISSUE
# 477 reach row uncomfortable [[0.27149168]] ISSUE
# 478 buy nokia cell phone week ago nightmare [[0.15756051]] ISSUE
# 479 long describe bad customer service experience amazon [[0.18621328]] ISSUE
# 480 disappoint thing no speakerphone [[0.17849289]] ISSUE
# 481 terrible car not accept cassette [[0.05880635]] ISSUE
# 482 product useless not charge current charge two cellphone [[0.13978848]] ISSUE
# 483 not [[0.25352544]] ISSUE
# 484 stay away q [[0.46806225]] ISSUE
# 485 dirty [[0.10097373]] ISSUE
# 486 unreliable service t mobile [[0.37140208]] ISSUE
# 487 not good price [[0.5300286]] NOTISSUE
# 488 buy two charge [[0.62636787]] NOTISSUE
# 489 look nice [[0.93384874]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.98895884]] NOTISSUE
# 491 read review note problem [[0.2568044]] ISSUE
# 492 product cover important light sensor ear outlet [[0.6003426]] NOTISSUE
# 493 comfortable hand [[0.8941215]] NOTISSUE
# 494 not work [[0.30555466]] ISSUE
# 495 poor reliability [[0.1656328]] ISSUE
# 496 work [[0.6847017]] NOTISSUE
# 497 picture battery drop bar start beep let know din [[0.13385366]] ISSUE
# 498 terrible product waste money [[0.05928431]] ISSUE
# 499 time buy [[0.60887915]] NOTISSUE
# 500 waste money [[0.1427693]] ISSUE
# 501 far work like charm [[0.80032086]] NOTISSUE
# 502 week far good [[0.7036255]] NOTISSUE
# 503 case best download picture laptop room send picture laptop phone [[0.917344]] NOTISSUE
# 504 recommend item [[0.669894]] NOTISSUE
# 505 choice headset year great sound good volume good noise cancellation [[0.99511516]] NOTISSUE
# 506 nice case feel good hand [[0.97286624]] NOTISSUE
# 507 item receive counterfeit [[0.3156319]] ISSUE
# 508 good far probably best bt headset [[0.9159596]] NOTISSUE
# 509 work fine [[0.8277794]] NOTISSUE
# 510 receive headset good time happy [[0.981159]] NOTISSUE
# 511 replace trail swivel holster blackberry flip [[0.6009916]] NOTISSUE
# 512 sister one love [[0.90101326]] NOTISSUE
# 513 good quality [[0.9558286]] NOTISSUE
# 514 far worst purchase amazon [[0.19957423]] ISSUE
# 515 excellent dual purpose headset [[0.97071606]] NOTISSUE
# 516 excellent [[0.9601384]] NOTISSUE
# 517 not work listen music singular eight thousand one twenty five [[0.4741296]] ISSUE
# 518 completely secure hold belt phone inside [[0.48882213]] ISSUE
# 519 line worthless cheap gimmick sprint [[0.4276922]] ISSUE
# 520 trouble volume [[0.343685]] ISSUE
# 521 good thing fit comfortably small ear [[0.9464606]] NOTISSUE
# 522 warn not buy [[0.15738942]] ISSUE
# 523 pair phone not happier far [[0.52479255]] NOTISSUE
# 524 open battery connection break device turn [[0.39659354]] ISSUE
# 525 not want clip ear cause discomfort [[0.07191537]] ISSUE
# 526 best headset [[0.8210574]] NOTISSUE
# 527 not trust webster not expect helpful support [[0.24579771]] ISSUE
# 528 loud glad plantronics five ten maintain flawless connection cell no static normal use [[0.53768116]] NOTISSUE
# 529 speaker low quality ring tone sound cheap [[0.7975066]] NOTISSUE
# 530 fit comfortably come size earn tip [[0.6380733]] NOTISSUE
# 531 bad reception [[0.0812649]] ISSUE
# 532 product high quality chinese crap [[0.539409]] NOTISSUE
# 533 comfortable ear [[0.8351039]] NOTISSUE
# 534 notably product failure [[0.10026351]] ISSUE
# 535 product wrong [[0.23275144]] ISSUE
# 536 pair two device easy barely couple minute start voice deal feature [[0.9349855]] NOTISSUE
# 537 utterly confuse cause lose couple important contact [[0.11061935]] ISSUE
# 538 terrible phone holder [[0.23886766]] ISSUE
# 539 cutout button place perfectly [[0.9543976]] NOTISSUE
# 540 love able use one headset land line cell [[0.74402696]] NOTISSUE
# 541 problem ear loop weak material break easily [[0.0692565]] ISSUE
# 542 not nearly good look amazon picture look [[0.4797529]] ISSUE
# 543 despite flaw case exceptional quality worth additional cost official oem product [[0.76231843]] NOTISSUE
# 544 stupid [[0.06841607]] ISSUE
# 545 hear drive car usually steven loudest set [[0.642596]] NOTISSUE
# 546 seller ship quickly cheaper competitor [[0.652911]] NOTISSUE
# 547 good samsung [[0.9255723]] NOTISSUE
# 548 buy ten save lot money [[0.6169002]] NOTISSUE
# 549 cut beep beep beep sound signal failure [[0.04937502]] ISSUE
# 550 configure [[0.58458334]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word [[0.08173593]] ISSUE
# 552 battery phone restart [[0.6866897]] NOTISSUE
# 553 manage bend leaf spring place metal stress break drop [[0.22280271]] ISSUE
# 554 leopard print wonderfully wild [[0.9688858]] NOTISSUE
# 555 work [[0.6847017]] NOTISSUE
# 556 saggy floppy piece junk [[0.14808336]] ISSUE
# 557 better hard plastic case [[0.6339225]] NOTISSUE
# 558 new problem [[0.42306393]] ISSUE
# 559 happy far [[0.84669125]] NOTISSUE
# 560 cool phone [[0.7429237]] NOTISSUE
# 561 work good [[0.9329318]] NOTISSUE
# 562 motorola finally voice quality bluetooth headset right [[0.941524]] NOTISSUE
# 563 loose connection phone couple foot two [[0.56240714]] NOTISSUE
# 564 great recommend [[0.9750421]] NOTISSUE
# 565 easier bluetooth not wear [[0.32527128]] ISSUE
# 566 pretty useless [[0.3608546]] ISSUE
# 567 get [[0.5034931]] NOTISSUE
# 568 pair headphone worst sound wise [[0.49164417]] ISSUE
# 569 drain weak snap [[0.07349864]] ISSUE
# 570 not charge singular att eight thousand five twenty five phone [[0.36641163]] ISSUE
# 571 extra minute carry not cut [[0.15051849]] ISSUE
# 572 year lipton start loose wobbly eventually screen black not receive place [[0.09333162]] ISSUE
# 573 catch cable seat pull phone turn [[0.30494368]] ISSUE
# 574 headset fulfil requirement happy purchase [[0.93093514]] NOTISSUE
# 575 logitech bluetooth headset ten [[0.8597558]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.33897114]] ISSUE
# 577 lot webster rat good phone [[0.8002172]] NOTISSUE
# 578 try cable computer pod work fine [[0.8064226]] NOTISSUE
# 579 mic joke volume low [[0.18667956]] ISSUE
# 580 return [[0.43815586]] ISSUE
# 581 not maintain connection computer lap [[0.34424582]] ISSUE
# 582 easy turn car volume control accessible [[0.8228711]] NOTISSUE
# 583 year christmas buy rest family [[0.6667732]] NOTISSUE
# 584 easy install use clear sound [[0.86207074]] NOTISSUE
# 585 nice leather [[0.91421914]] NOTISSUE
# 586 purchase different case [[0.81250495]] NOTISSUE
# 587 joy use [[0.9088477]] NOTISSUE
# 588 disappoint company [[0.27208406]] ISSUE
# 589 satisfy [[0.5629841]] NOTISSUE
# 590 not charge [[0.17179216]] ISSUE
# 591 phone two thousand five buy s seven forty wow [[0.7945297]] NOTISSUE
# 592 button small [[0.7110505]] NOTISSUE
# 593 read specialization wow [[0.6780418]] NOTISSUE
# 594 love great armband [[0.9854139]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.64537203]] NOTISSUE
# 596 keypad tinny reach wrong button [[0.35298625]] ISSUE
# 597 exchange sony ericson z five pretty happy decision [[0.9940574]] NOTISSUE
# 598 impress price case [[0.593339]] NOTISSUE
# 599 easier hold [[0.52424]] NOTISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.992581]] NOTISSUE
# 601 pretty easy [[0.9416797]] NOTISSUE
# 602 certain place [[0.57700735]] NOTISSUE
# 603 girl complain time phone netware like normal phone [[0.15366374]] ISSUE
# 604 beautiful style [[0.9712068]] NOTISSUE
# 605 company charge restock fee not refund [[0.102174]] ISSUE
# 606 try return refund [[0.24896681]] ISSUE
# 607 plug find not darn thing work [[0.37969327]] ISSUE
# 608 excellent product [[0.9682693]] NOTISSUE
# 609 earn piece break easily [[0.38611782]] ISSUE
# 610 lousy product [[0.20555933]] ISSUE
# 611 phone try hard failure ability phone [[0.19463174]] ISSUE
# 612 best charger market [[0.9064784]] NOTISSUE
# 613 sweetest phone [[0.89967525]] NOTISSUE
# 614 oh charger work fine [[0.924402]] NOTISSUE
# 615 fit securely ear hook not need sound better direct ear canal [[0.2951533]] ISSUE
# 616 not volume [[0.24427879]] ISSUE
# 617 echo problem unsatisfactory [[0.06420296]] ISSUE
# 618 two video time quality poor [[0.2698444]] ISSUE
# 619 notwaste money [[0.35074753]] ISSUE
# 620 negatively review product [[0.5473166]] NOTISSUE
# 621 adapter not provide charge current [[0.25256714]] ISSUE
# 622 hype phone assume best mistake [[0.41024685]] ISSUE
# 623 picture case sense cover [[0.543978]] NOTISSUE
# 624 phone fall easily [[0.2624217]] ISSUE
# 625 network people not hear talk [[0.10251839]] ISSUE
# 626 text message feature tricky use [[0.49345362]] ISSUE
# 627 disappoint charger network [[0.25789902]] ISSUE
# 628 painful ear [[0.25827262]] ISSUE
# 629 one day blow [[0.1151048]] ISSUE
# 630 disappoint [[0.22318242]] ISSUE
# 631 kind flop [[0.12244275]] ISSUE
# 632 screen smudge easily touch ear face [[0.36507523]] ISSUE
# 633 piece junk lose phone [[0.2990813]] ISSUE
# 634 item not match picture [[0.19263151]] ISSUE
# 635 thing disappoint infra red port ira [[0.29769194]] ISSUE
# 636 not answer unit work [[0.21432544]] ISSUE
# 637 unsatisfactory [[0.15015979]] ISSUE
# 638 product great [[0.9575805]] NOTISSUE
# 639 no problem [[0.22348572]] ISSUE
# 640 work good no problem [[0.59898305]] NOTISSUE
# 641 oh dangerous [[0.27297893]] ISSUE
# 642 sorry [[0.1478753]] ISSUE
# 643 sorry [[0.1478753]] ISSUE
# 644 pardon [[0.52087414]] NOTISSUE
# 645 help help [[0.617841]] NOTISSUE
# 646 no no dangerous [[0.06322576]] ISSUE
# 647 extremely dangerous [[0.36673096]] ISSUE
# 648 dangerous [[0.23267746]] ISSUE
# 649 dangerous young man [[0.5945982]] NOTISSUE
# 650 dangerous brutal [[0.04916045]] ISSUE
# 651 honestly dangerous [[0.23187883]] ISSUE
# 652 work [[0.6847017]] NOTISSUE
# 653 dead hard work [[0.30805665]] ISSUE
# 654 fact family mary wed [[0.68492955]] NOTISSUE
# 655 busy [[0.63395154]] NOTISSUE
# 656 great [[0.95642734]] NOTISSUE
# 657 busy [[0.63395154]] NOTISSUE
# 658 think yesterday [[0.6318514]] NOTISSUE
# 659 think one [[0.6432174]] NOTISSUE
# 660 oh yes [[0.6773131]] NOTISSUE
# 661 one thing want talk [[0.2813467]] ISSUE
# 662 honestly notknow noreen discussion [[0.61092913]] NOTISSUE
# 663 course come tomorrow [[0.45484352]] ISSUE
# 664 noreen think away weekend [[0.2763633]] ISSUE
# 665 hello [[0.7051756]] NOTISSUE
# 666 mean young man [[0.5151078]] NOTISSUE
# 667 goodbye [[0.6269972]] NOTISSUE
# 668 alright [[0.5034931]] NOTISSUE
# 669 need money urgently [[0.39488238]] ISSUE
# 670 business [[0.42505658]] ISSUE
# 671 work day [[0.6133104]] NOTISSUE
# 672 work [[0.6847017]] NOTISSUE
# 673 work [[0.6847017]] NOTISSUE
# 674 work day [[0.6133104]] NOTISSUE
# 675 work saturday [[0.6847017]] NOTISSUE
# 676 know work [[0.68055326]] NOTISSUE
# 677 horrible customer service [[0.1498341]] ISSUE
# 678 fine product [[0.71547586]] NOTISSUE
# 679 glad pay money [[0.40102887]] ISSUE
# 680 worst version adobe illustrator release version [[0.3054134]] ISSUE
# 681 not save mysterious reason [[0.12339269]] ISSUE
# 682 crash [[0.2028796]] ISSUE
# 683 open file year write scribble untenable save version [[0.14264841]] ISSUE
# 684 assume adobe customer service professional quick [[0.86348784]] NOTISSUE
# 685 time past two week wait minimum twenty minute speak [[0.06689008]] ISSUE
# 686 finally product send mac version personal computer version purchase [[0.70900863]] NOTISSUE
# 687 wait approximately thirty minute customer help [[0.2257723]] ISSUE
# 688 not receive personal computer version [[0.23811871]] ISSUE
# 689 center service worst customer service deal [[0.15817823]] ISSUE
# 690 deal bad customer service [[0.11161012]] ISSUE
# 691 extremely frustrate hour [[0.4846878]] ISSUE
# 692 not problem software [[0.17550606]] ISSUE
# 693 reverse error nightmare [[0.02532922]] ISSUE
# 694 pretty need [[0.8602707]] NOTISSUE
# 695 point customer service reputation nice [[0.877675]] NOTISSUE
# 696 not infrastructure provide basic level service [[0.25625777]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.30107749]] ISSUE
# 698 not send receipt [[0.12963356]] ISSUE
# 699 receipt copy invoice not format print correctly [[0.15651113]] ISSUE
# 700 disturb people suppose account expert [[0.23508751]] ISSUE
# 701 start look alternative intuit obviously not understand basic account audit principle [[0.2259847]] ISSUE
# 702 thoroughly disappoint [[0.22489846]] ISSUE
# 703 not business company anymore bad support [[0.02900339]] ISSUE
# 704 online information exactly cd [[0.8207339]] NOTISSUE
# 705 not send coupon [[0.15966415]] ISSUE
# 706 bad [[0.06588664]] ISSUE
# 707 save money not subscribe extend service [[0.16191189]] ISSUE
# 708 use customer service technical support answer vaguely relate problem [[0.1823139]] ISSUE
# 709 emailinc time [[0.55403024]] NOTISSUE
# 710 largest technical software company world [[0.77271956]] NOTISSUE
# 711 no technical support [[0.2846608]] ISSUE
# 712 worthless product horrible customer service [[0.06564519]] ISSUE
# 713 unable access internet [[0.32383993]] ISSUE
# 714 no problem system slow [[0.02987961]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.22293891]] ISSUE
# 716 reputation exasperate script suggestion not resolve problem [[0.09646369]] ISSUE
# 717 feel bite fleece overprice subscription renewal year [[0.4810168]] ISSUE
# 718 decide try [[0.45841077]] ISSUE
# 719 installation smoothly fine [[0.9203238]] NOTISSUE
# 720 stall blank screen right window [[0.28454092]] ISSUE
# 721 hang forever [[0.29113683]] ISSUE
# 722 present [[0.5108388]] NOTISSUE
# 723 easy follow easy revisit previous lesson [[0.57454675]] NOTISSUE
# 724 video illustrate fretboard help hear song play [[0.82501864]] NOTISSUE
# 725 not lot depth material [[0.28680605]] ISSUE
# 726 sing slight destruction [[0.23012716]] ISSUE
# 727 material song not like [[0.2595]] ISSUE
# 728 find music book useful [[0.95973766]] NOTISSUE
# 729 probably not recommend source learn guitar [[0.18686923]] ISSUE
# 730 like new look [[0.7391978]] NOTISSUE
# 731 problem transition [[0.25622177]] ISSUE
# 732 look create doom half life two normally recommend program [[0.7032664]] NOTISSUE
# 733 want advance fps game simple pong game recommend dark basic [[0.83159006]] NOTISSUE
# 734 dark basic professional probably capable create kind game come [[0.97616595]] NOTISSUE
# 735 deal bad customer service [[0.11161012]] ISSUE
# 736 dark basic manipulate d data extremely easy [[0.8829584]] NOTISSUE
# 737 program scratch [[0.5027307]] NOTISSUE
# 738 recommend [[0.68242466]] NOTISSUE
# 739 software easy install easy use [[0.9476521]] NOTISSUE
# 740 wonderful software [[0.98192894]] NOTISSUE
# 741 buy cd [[0.8369512]] NOTISSUE
# 742 not waste money subscription merriam webster webster [[0.18582785]] ISSUE
# 743 software user friendly [[0.8982399]] NOTISSUE
# 744 superb [[0.94314116]] NOTISSUE
# 745 try medical dictionary [[0.63369775]] NOTISSUE
# 746 surprise find offer option strip code [[0.8001668]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.36086172]] ISSUE
# 748 evolution [[0.48896682]] ISSUE
# 749 offer major improvement flexibility previous version [[0.8081101]] NOTISSUE
# 750 good [[0.89132553]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.97647256]] NOTISSUE
# 752 horribly bad [[0.02017377]] ISSUE
# 753 good able tweak dozen standard compliance [[0.85936457]] NOTISSUE
# 754 default thing not set learn [[0.20153347]] ISSUE
# 755 b two thousand fairly advance feature [[0.893546]] NOTISSUE
# 756 para professional version [[0.77282447]] NOTISSUE
# 757 way flexibility functionality version [[0.92797315]] NOTISSUE
# 758 bye bye [[0.70694727]] NOTISSUE
# 759 product [[0.5297858]] NOTISSUE
# 760 trial version instal computer buy [[0.48037446]] ISSUE
# 761 enter code box [[0.21906865]] ISSUE
# 762 easy [[0.80154145]] NOTISSUE
# 763 glad able install one computer [[0.8080165]] NOTISSUE
# 764 today best office suite microsoft [[0.85796213]] NOTISSUE
# 765 easy use excellent result [[0.97232133]] NOTISSUE
# 766 great sw [[0.94469166]] NOTISSUE
# 767 easy learn [[0.85320985]] NOTISSUE
# 768 good graphic [[0.82477975]] NOTISSUE
# 769 help visualize space [[0.7576627]] NOTISSUE
# 770 d [[0.5836402]] NOTISSUE
# 771 configure [[0.58458334]] NOTISSUE
# 772 difficult change room house overall style start design [[0.4081247]] ISSUE
# 773 recently buy version [[0.7800647]] NOTISSUE
# 774 instal software [[0.61340755]] NOTISSUE
# 775 operate old personal computer [[0.4715665]] ISSUE
# 776 run lot faster [[0.5162571]] NOTISSUE
# 777 access corporate entrant [[0.6380808]] NOTISSUE
# 778 awesome [[0.94502085]] NOTISSUE
# 779 whirl [[0.5620301]] NOTISSUE
# 780 buy product [[0.6801759]] NOTISSUE
# 781 five star [[0.73353255]] NOTISSUE
# 782 great company deal [[0.97586846]] NOTISSUE
# 783 agree window improve thier product [[0.41130668]] ISSUE
# 784 linx not user friendly [[0.6719025]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.27169067]] ISSUE
# 786 unix far stable [[0.57328093]] NOTISSUE
# 787 access cd version [[0.8683167]] NOTISSUE
# 788 like [[0.61235094]] NOTISSUE
# 789 work [[0.6847017]] NOTISSUE
# 790 usually disc want attempt [[0.09540258]] ISSUE
# 791 lot cd [[0.8619803]] NOTISSUE
# 792 great program child learn difference [[0.9625637]] NOTISSUE
# 793 fun excellent way learn math [[0.99757797]] NOTISSUE
# 794 child love [[0.8461572]] NOTISSUE
# 795 fun way brain work [[0.9700874]] NOTISSUE
# 796 marvelous [[0.94992316]] NOTISSUE
# 797 memory improvement software marvelous [[0.9752068]] NOTISSUE
# 798 help improve memory provide motivate game [[0.92667085]] NOTISSUE
# 799 highly recommend [[0.8545688]] NOTISSUE
# 800 great [[0.95642734]] NOTISSUE
# 801 love software [[0.8857126]] NOTISSUE
# 802 word new disturb high score [[0.2838207]] ISSUE
# 803 symantec customer year [[0.8159708]] NOTISSUE
# 804 year product better better [[0.83033663]] NOTISSUE
# 805 not use product purpose [[0.22910029]] ISSUE
# 806 anti virus find problem personal computer fix [[0.11520593]] ISSUE
# 807 anti virus clean unneeded file [[0.18691021]] ISSUE
# 808 roll system certain date problem occur [[0.08094512]] ISSUE
# 809 good program beginner experience family historian [[0.98680407]] NOTISSUE
# 810 program joy use [[0.932755]] NOTISSUE
# 811 design thing simple user [[0.8948946]] NOTISSUE
# 812 program easy use interface [[0.84095424]] NOTISSUE
# 813 no problem far better feature [[0.28508162]] ISSUE
# 814 definately worth [[0.71166605]] NOTISSUE
# 815 problem bigger harddrive lot space [[0.32192454]] ISSUE
# 816 system crash [[0.12190358]] ISSUE
# 817 great product [[0.9590715]] NOTISSUE
# 818 software update source issue [[0.34227794]] ISSUE
# 819 minor problem [[0.3575679]] ISSUE
# 820 actually totally unusable resolution [[0.09457836]] ISSUE
# 821 complete waste money [[0.1586122]] ISSUE
# 822 major issue photo image poor [[0.06388126]] ISSUE
# 823 no number tech support [[0.40384614]] ISSUE
# 824 issue month not transfer tech support person [[0.1991798]] ISSUE
# 825 phone tell support person happen [[0.26990527]] ISSUE
# 826 offer email support nitrite [[0.45560497]] ISSUE
# 827 look great [[0.9684693]] NOTISSUE
# 828 patient software [[0.6327705]] NOTISSUE
# 829 not provide support installation [[0.33484754]] ISSUE
# 830 software update source issue [[0.34227794]] ISSUE
# 831 easy language sixteen useful [[0.82058376]] NOTISSUE
# 832 find helpful rusty [[0.57241714]] NOTISSUE
# 833 problem hard [[0.24034762]] ISSUE
# 834 sound not clear [[0.3275238]] ISSUE
# 835 record speaker not bother slow chance understand repeat [[0.03192598]] ISSUE
# 836 like listen actual french speaker [[0.49302787]] ISSUE
# 837 bad actually want learn pronounce [[0.04859651]] ISSUE
# 838 totally useless not know basic french grammar [[0.0683335]] ISSUE
# 839 try use product learn nightmare [[0.135799]] ISSUE
# 840 version word phrase easier sound [[0.3602468]] ISSUE
# 841 unfortunately basic japanese grammar japanese alphabet write japanese [[0.16688569]] ISSUE
# 842 not click sound [[0.25867996]] ISSUE
# 843 no clue sound [[0.2851023]] ISSUE
# 844 click sound [[0.6307945]] NOTISSUE
# 845 teach read language [[0.20168333]] ISSUE
# 846 familiar japanese order use product [[0.35429472]] ISSUE
# 847 experience product quickly [[0.7143399]] NOTISSUE
# 848 product useful [[0.75958925]] NOTISSUE
# 849 probably stop [[0.20068264]] ISSUE
# 850 want learn language look book cassette cd [[0.53309906]] NOTISSUE
# 851 no star [[0.3798788]] ISSUE
# 852 waste [[0.1835599]] ISSUE
# 853 interface underwhelming [[0.25632095]] ISSUE
# 854 need guess [[0.5380576]] NOTISSUE
# 855 worse [[0.0729279]] ISSUE
# 856 no menu bar help guess work program [[0.3142118]] ISSUE
# 857 language backwards [[0.13554937]] ISSUE
# 858 suppose read right leave opposite cd leave right [[0.2456911]] ISSUE
# 859 poor effort [[0.08650821]] ISSUE
# 860 not find it [[0.284431]] ISSUE
# 861 absolutely installation cd [[0.88881314]] NOTISSUE
# 862 consider bad start [[0.06956992]] ISSUE
# 863 soooooooo disappoint [[0.22318242]] ISSUE
# 864 disappoint false advertise product [[0.20265499]] ISSUE
# 865 blurb use sixteen language source language not possible [[0.06298165]] ISSUE
# 866 language suppose cd [[0.52033824]] NOTISSUE
# ...
# 3935 price reasonable flavour spot sauce home law not french mayo [[0.7905369]] NOTISSUE
# 3936 decor nice piano music soundtrack pleasant [[0.99955076]] NOTISSUE
# 3937 steak amaze age fillet ellen best seafood plate [[0.9691301]] NOTISSUE
# 3938 good food good service [[0.98045266]] NOTISSUE
# 3939 absolutely amaze [[0.8995906]] NOTISSUE
# 3940 probably wo note honest [[0.14922486]] ISSUE
# 3941 definitely [[0.75985426]] NOTISSUE
# 3942 sergeant pepper beef sandwich aunt sauce excellent sandwich [[0.9645506]] NOTISSUE
# 3943 hawaiian breeze mango magic pineapple delight smoothie try far good [[0.95111465]] NOTISSUE
# 3944 lunch service slow [[0.14208558]] ISSUE
# 3945 place walk expect amaze quickly disappoint [[0.38100803]] ISSUE
# 3946 mortify [[0.35517642]] ISSUE
# 3947 needle [[0.5125324]] NOTISSUE
# 3948 anyways food definitely not fill price pay expect [[0.13640313]] ISSUE
# 3949 chip come drip grease not edible [[0.11479977]] ISSUE
# 3950 normally impress strip steak [[0.4434702]] ISSUE
# 3951 two thousand seven meal awesome [[0.950408]] NOTISSUE
# 3952 server nice attentive serve staff [[0.96641326]] NOTISSUE
# 3953 cashier friendly bring food [[0.73813504]] NOTISSUE
# 3954 work hospitality industry paradise valley refrain recommend ciob longer [[0.71610737]] NOTISSUE
# 3955 atmosphere fun [[0.9472479]] NOTISSUE
# 3956 not recommend [[0.3336019]] ISSUE
# 3957 service quick order like like [[0.8075099]] NOTISSUE
# 3958 mean famous fish chip terrible [[0.09871533]] ISSUE
# 3959 mouth belly [[0.3993728]] ISSUE
# 3960 not thing [[0.25922686]] ISSUE
# 3961 two thumb [[0.44885054]] ISSUE
# 3962 read no go [[0.16511889]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.9488373]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99845207]] NOTISSUE
# 3965 nice atmosphere [[0.950934]] NOTISSUE
# 3966 tonight elk file special suck [[0.18469515]] ISSUE
# 3967 one bite hook [[0.20116644]] ISSUE
# 3968 order old classic new dish time sorely disappoint [[0.37509936]] ISSUE
# 3969 cute quaint simple honest [[0.8841678]] NOTISSUE
# 3970 chicken deliciously season perfect fry outside moist chicken inside [[0.88194877]] NOTISSUE
# 3971 food great compliment chef [[0.987265]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.9872809]] NOTISSUE
# 3973 awesome selection beer [[0.98108184]] NOTISSUE
# 3974 great food awesome service [[0.99708396]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger eight not expect tip [[0.39518988]] ISSUE
# 3976 fly apple juice fly [[0.3069483]] ISSUE
# 3977 nan chicken tasty [[0.909225]] NOTISSUE
# 3978 service think good [[0.90464664]] NOTISSUE
# 3979 food barely lukewarm sit wait server bring [[0.08426339]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.41660142]] ISSUE
# 3981 nicest chinese restaurant [[0.9520134]] NOTISSUE
# 3982 overall like food service [[0.6071349]] NOTISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.6800309]] NOTISSUE
# 3984 probably come not recommend [[0.18566272]] ISSUE
# 3985 friend pasta bad barely touch [[0.14112161]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.9955798]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.7594794]] NOTISSUE
# 3988 complain [[0.17250353]] ISSUE
# 3989 restaurant clean family restaurant feel [[0.75051004]] NOTISSUE
# 3990 way fry [[0.61593187]] NOTISSUE
# 3991 not sure long stand long begin feel awkwardly place [[0.13425033]] ISSUE
# 3992 open sandwich impress not good way [[0.3732085]] ISSUE
# 3993 not [[0.25352544]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.9036617]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.99054223]] NOTISSUE
# 3996 order vegetarian menu dinner wide array option choose [[0.9801404]] NOTISSUE
# 3997 watch price inflate portion smaller management attitude grow rapidly [[0.20855716]] ISSUE
# 3998 wonderful little tape ambience feel warm fuzzy inside [[0.9884979]] NOTISSUE
# 3999 enjoy seafood salad fabulous vinaigrette [[0.9980021]] NOTISSUE
# 4000 wanton thin not thick chewy melt mouth [[0.19866835]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.9053617]] NOTISSUE
# 4002 sit right time server fantastic [[0.8564312]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s [[0.35179427]] ISSUE
# 4004 town definitely spot hit [[0.7803159]] NOTISSUE
# 4005 wait thirty minute drink longer two area [[0.13131322]] ISSUE
# 4006 great place eat [[0.9573044]] NOTISSUE
# 4007 jalapeno bacon soon good [[0.90778303]] NOTISSUE
# 4008 service poor [[0.11941298]] ISSUE
# 4009 food good service good price good [[0.99709773]] NOTISSUE
# 4010 price good [[0.9261824]] NOTISSUE
# 4011 price good [[0.9261824]] NOTISSUE
# 4012 service good [[0.8932165]] NOTISSUE
# 4013 place not clean food oh stale [[0.04579062]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.41706258]] ISSUE
# 4015 service bad [[0.06938712]] ISSUE
# 4016 happy [[0.894129]] NOTISSUE
# 4017 taste like dirt [[0.22728655]] ISSUE
# 4018 one place phoenix definately [[0.7777245]] NOTISSUE
# 4019 block amaze [[0.76638836]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.9581348]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.56623733]] NOTISSUE
# 4022 hashemi poor quality soggy tasteless [[0.01514919]] ISSUE
# 4023 great time family dinner sunday night [[0.9678335]] NOTISSUE
# 4024 food not tasty not real traditional hunan style [[0.2554652]] ISSUE
# 4025 bother slow service [[0.07672782]] ISSUE
# 4026 flair bartender absolutely amaze [[0.97031647]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.41201705]] ISSUE
# 4028 good order twice [[0.8692853]] NOTISSUE
# 4029 nutshell one restaurant smell like combination dirty fish market sewer [[0.05278283]] ISSUE
# 4030 girlfriend veal bad [[0.06310512]] ISSUE
# 4031 unfortunately not good [[0.30024952]] ISSUE
# 4032 pretty satisfy experience [[0.9285058]] NOTISSUE
# 4033 join club awesome offer email [[0.96720713]] NOTISSUE
# 4034 perfect like beer ice cold case colder [[0.63910294]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.14696008]] ISSUE
# 4036 chain no fan beat place easily [[0.3971717]] ISSUE
# 4037 macho [[0.41969377]] ISSUE
# 4038 not come [[0.2332049]] ISSUE
# 4039 not word place pretty [[0.32018393]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.96984226]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.9989178]] NOTISSUE
# 4042 receive pity huge lot meat thumb [[0.396536]] ISSUE
# 4043 food arrive [[0.35241458]] ISSUE
# 4044 pay seven eighty five hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.16983277]] ISSUE
# 4045 classic maine lobster roll fantastic [[0.9868051]] NOTISSUE
# 4046 brother law work mall eat day guess sick night [[0.06218224]] ISSUE
# 4047 good review place twice [[0.9263281]] NOTISSUE
# 4048 chip salsa good salsa fresh [[0.9796397]] NOTISSUE
# 4049 place great [[0.9698635]] NOTISSUE
# 4050 mediocre food [[0.1462422]] ISSUE
# 4051 inside impress place [[0.6572555]] NOTISSUE
# 4052 service super friendly [[0.94080025]] NOTISSUE
# 4053 sad little vegetable overcook [[0.06536734]] ISSUE
# 4054 place nice surprise [[0.9698373]] NOTISSUE
# 4055 live music totally blow [[0.15398692]] ISSUE
# (        id                                               text     label
#  0        0               order data cable finish work product  NOTISSUE
#  1        1                                         love phone  NOTISSUE
#  2        2                                     finish product  NOTISSUE
#  3        3                                        not happier  NOTISSUE
#  4        4                             look headset long time  NOTISSUE
#  5        5                       headset start ring no reason     ISSUE
#  6        6                 display excellent camera good year  NOTISSUE
#  7        7                                 battery life great  NOTISSUE
#  8        8                                  worst phone month     ISSUE
#  9        9  not good item work start problem auto reverse ...     ISSUE
#  10      10           embarrass ear hurt try push ear plug ear     ISSUE
#  11      11                                      protect phone  NOTISSUE
#  12      12  average phone bad battery life operate weak ne...     ISSUE
#  13      13            clear skye long battery life long range  NOTISSUE
#  14      14                               solo technology suck     ISSUE
#  15      15                             great hand free device  NOTISSUE
#  16      16        self portrait outside exterior display cool  NOTISSUE
#  17      17                                    problem mention     ISSUE
#  18      18              try handsfree gadget one finally work  NOTISSUE
#  19      19                                       magical help  NOTISSUE
#  20      20          worst piece crap version customer service     ISSUE
#  21      21                                 poor sound quality     ISSUE
#  22      22                                  best phone market  NOTISSUE
#  23      23                                               work  NOTISSUE
#  24      24                 company ship product promptly work  NOTISSUE
#  25      25                                       exactly want  NOTISSUE
#  26      26  picture resolution far comparably price phone ...     ISSUE
#  27      27                                         great deal  NOTISSUE
#  28      28                 excellent product satisfy purchase  NOTISSUE
#  29      29              highly recommend encourage people try  NOTISSUE
#  ...    ...                                                ...       ...
#  4025  4025                   flair bartender absolutely amaze  NOTISSUE
#  4026  4026                  freeze margarita way sugary taste     ISSUE
#  4027  4027                                   good order twice  NOTISSUE
#  4028  4028  nutshell one restaurant smell like combination...     ISSUE
#  4029  4029                                girlfriend veal bad     ISSUE
#  4030  4030                             unfortunately not good     ISSUE
#  4031  4031                          pretty satisfy experience  NOTISSUE
#  4032  4032                      join club awesome offer email  NOTISSUE
#  4033  4033             perfect like beer ice cold case colder  NOTISSUE
#  4034  4034  bland flavourless good way describe barely tep...     ISSUE
#  4035  4035                     chain no fan beat place easily     ISSUE
#  4036  4036                                              macho  NOTISSUE
#  4037  4037                                           not come     ISSUE
#  4038  4038                              not word place pretty  NOTISSUE
#  4039  4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040  4040             great atmosphere friendly fast service  NOTISSUE
#  4041  4041                   receive pity huge lot meat thumb  NOTISSUE
#  4042  4042                                        food arrive     ISSUE
#  4043  4043  pay seven eighty five hot dog fry look like co...     ISSUE
#  4044  4044               classic maine lobster roll fantastic  NOTISSUE
#  4045  4045     brother law work mall eat day guess sick night     ISSUE
#  4046  4046                            good review place twice  NOTISSUE
#  4047  4047                        chip salsa good salsa fresh  NOTISSUE
#  4048  4048                                        place great  NOTISSUE
#  4049  4049                                      mediocre food     ISSUE
#  4050  4050                               inside impress place  NOTISSUE
#  4051  4051                             service super friendly  NOTISSUE
#  4052  4052                      sad little vegetable overcook     ISSUE
#  4053  4053                                place nice surprise  NOTISSUE
#  4054  4054                            live music totally blow  NOTISSUE
#
#  [4055 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE               order data cable finish work product
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                                     finish product
#  3        ISSUE                                        not happier
#  4     NOTISSUE                             look headset long time
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                                  worst phone month
#  9        ISSUE  not good item work start problem auto reverse ...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                      protect phone
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE            clear skye long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE        self portrait outside exterior display cool
#  17       ISSUE                                    problem mention
#  18    NOTISSUE              try handsfree gadget one finally work
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                               work
#  24    NOTISSUE                 company ship product promptly work
#  25       ISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE                 excellent product satisfy purchase
#  29    NOTISSUE              highly recommend encourage people try
#  ...        ...                                                ...
#  4025  NOTISSUE                   flair bartender absolutely amaze
#  4026     ISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell one restaurant smell like combination...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                          pretty satisfy experience
#  4032  NOTISSUE                      join club awesome offer email
#  4033  NOTISSUE             perfect like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE                     chain no fan beat place easily
#  4036     ISSUE                                              macho
#  4037     ISSUE                                           not come
#  4038     ISSUE                              not word place pretty
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE                   receive pity huge lot meat thumb
#  4042     ISSUE                                        food arrive
#  4043     ISSUE  pay seven eighty five hot dog fry look like co...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE     brother law work mall eat day guess sick night
#  4046  NOTISSUE                            good review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050  NOTISSUE                               inside impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#
#  [4055 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                  text
# 0           0  NOTISSUE  order data cable finish work product
# 1           1  NOTISSUE                            love phone
# 2           2  NOTISSUE                        finish product
# 3           3     ISSUE                           not happier
# 4           4  NOTISSUE                look headset long time

# %%
data_predict['label'].value_counts()
# Out:
# NOTISSUE    2061
# ISSUE       1994
# Name: label, dtype: int64

# %% [markdown]
# ### Confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1707  318]
#  [ 287 1743]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8508014796547472
#               precision    recall  f1-score   support
#
#        ISSUE       0.86      0.84      0.85      2025
#     NOTISSUE       0.85      0.86      0.85      2030
#
#    micro avg       0.85      0.85      0.85      4055
#    macro avg       0.85      0.85      0.85      4055
# weighted avg       0.85      0.85      0.85      4055

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='false_pred_glove300_with_text_preprocessing.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                        not happier
# 1     NOTISSUE      ISSUE                                       exactly want
# 2        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 3        ISSUE   NOTISSUE  stupid buy new charger car charger cradle head...
# 4        ISSUE   NOTISSUE                            plastic break easy clip
# 5     NOTISSUE      ISSUE                                        not mistake
# 6     NOTISSUE      ISSUE       sanyo survive dozen drop blackton ill effect
# 7     NOTISSUE      ISSUE               find cell phone right away enter car
# 8        ISSUE   NOTISSUE                                        low quality
# 9     NOTISSUE      ISSUE     not find bad unit come one arpad not recommend
# 10    NOTISSUE      ISSUE                  defect not risk buy build quality
# 11    NOTISSUE      ISSUE                                        bad headset
# 12       ISSUE   NOTISSUE                                    bt battery junk
# 13       ISSUE   NOTISSUE                        cant software work computer
# 14    NOTISSUE      ISSUE                               no buyer remorse one
# 15    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 16       ISSUE   NOTISSUE                                        like return
# 17       ISSUE   NOTISSUE  version s bill difficult understand price plan...
# 18    NOTISSUE      ISSUE                                      wo not regret
# 19       ISSUE   NOTISSUE                                  not user friendly
# 20       ISSUE   NOTISSUE  unfortunately ability actually know receive im...
# 21    NOTISSUE      ISSUE                  version two year ago like service
# 22       ISSUE   NOTISSUE                                  pretty piece junk
# 23    NOTISSUE      ISSUE                                      work describe
# 24       ISSUE   NOTISSUE  sound quality device unacceptable quiet area hear
# 25    NOTISSUE      ISSUE                                 not recommend item
# 26    NOTISSUE      ISSUE                 end slide edge pant pocket instead
# 27       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 28       ISSUE   NOTISSUE                              new one work properly
# 29       ISSUE   NOTISSUE                                    notably product
# ..         ...        ...                                                ...
# 575   NOTISSUE      ISSUE                                      worst martini
# 576   NOTISSUE      ISSUE              yellowtail capriccio melt mouth fresh
# 577   NOTISSUE      ISSUE                           not quality food service
# 578      ISSUE   NOTISSUE     recent experience particular location not good
# 579      ISSUE   NOTISSUE                              place recommend place
# 580   NOTISSUE      ISSUE                                                rat
# 581      ISSUE   NOTISSUE                           look authentic thai food
# 582      ISSUE   NOTISSUE                   extremely crumb pretty tasteless
# 583      ISSUE   NOTISSUE        pale color instead nice character no flavor
# 584   NOTISSUE      ISSUE                          regular stop trip phoenix
# 585   NOTISSUE      ISSUE  drive way north scottsdale not one bite disapp...
# 586      ISSUE   NOTISSUE               grandmother roast chicken better one
# 587      ISSUE   NOTISSUE                             order burger rare come
# 588   NOTISSUE      ISSUE  prove dead wrong sushi bar not quality great s...
# 589      ISSUE   NOTISSUE                                 not fun experience
# 590      ISSUE   NOTISSUE                                               dont
# 591   NOTISSUE      ISSUE                          promise wo not disappoint
# 592   NOTISSUE      ISSUE                                           not wait
# 593      ISSUE   NOTISSUE                                             needle
# 594   NOTISSUE      ISSUE                                        mouth belly
# 595   NOTISSUE      ISSUE                                          two thumb
# 596   NOTISSUE      ISSUE                                      one bite hook
# 597   NOTISSUE      ISSUE  one nice thing add gratuity bill party larger ...
# 598   NOTISSUE      ISSUE                                           complain
# 599      ISSUE   NOTISSUE                                            way fry
# 600   NOTISSUE      ISSUE             wanton thin not thick chewy melt mouth
# 601   NOTISSUE      ISSUE                                              macho
# 602   NOTISSUE      ISSUE                              not word place pretty
# 603   NOTISSUE      ISSUE                   receive pity huge lot meat thumb
# 604   NOTISSUE      ISSUE                            live music totally blow
#
# [605 rows x 3 columns]
