# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('DATA/data.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #balanced Dataset
# Out:
# ISSUE       2034
# NOTISSUE    2022
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4056, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 #'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 #'becomes',
 #'becoming',
 #'been',
 'before',
 'beforehand',
 #'behind',
 #'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 #'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 #'show',
 'side',
 'since',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
"couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
        "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re
# Out:
# C:\Users\khmar\ana\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def replace_word(word):
    # Convert text to lower
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Removing all the tokens with lesser than 3 characters
    #text = gensim.corpora.textcorpus.remove_short(text, minsize=3)
    
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    
    
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        
        ##### Lemmatization
        # Reduce words to their root form
        # Lemmatize verbs by specifying pos
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

##Fixing Word Lengthening
##https://rustyonrampa"ge.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    text = reduce_lengthening(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText(" she'd've I have so 20 soooooo don't i'm  can't servic going grooooooooop")
# Out:
# 'have have twenty soo do not be service go group'

# %%
"""df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']"""
# Out:
# "df['text'] = df['text'].map(transformText)\ntexts= df['text']\ntags= df['label']"

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
#df=df[texts,tags]

# %%
"""# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('Data/DATA_preprocessing6.csv')"""
# Out:
# "# dictionary of lists  \ndict = {'text': texts , 'label': tags } \n     \ndf = pd.DataFrame(dict) \n  \n# saving the dataframe \ndf.to_csv('Data/DATA_preprocessing6.csv')"

# %%
####

# %%
DATA_FILE = 'Data/DATA_preprocessing_brute.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2793, 3)
# (1262, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1399
# ISSUE       1394
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       633
# NOTISSUE    629
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1399
# ISSUE       1394
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
# Out:
# C:\Users\khmar\ana\lib\site-packages\keras_preprocessing\text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2793, 200)
# Shape of test_data tensor: (1262, 200)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing_brut.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3104 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2793, 200)
# Shape of data test tensor: (1262, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : flavourful
# word not found : overprice
# word not found : cosiness
# word not found : untasted
# word not found : cheesecurds
# word not found : hoursthe
# word not found : thereplacement
# word not found : accessoryone
# word not found : 969900
# word not found : tracfonewebsite
# word not found : 5320
# word not found : supertooth
# word not found : reoccure
# word not found : 8125
# word not found : s740
# word not found : emailinc
# word not found : convertor
# word not found : appal
# word not found : convolute
# word not found : stylize
# word not found : brainsucking
# word not found : infatuate
# word not found : riingtones
# word not found : profiterole
# word not found : douchebaggery
# word not found : chipolte
# word not found : albondigas
# word not found : 8810
# word not found : shawarrma
# word not found : smashburger
# word not found : ciob
# word not found : flavourless

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 32 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2793 samples, validate on 1262 samples
# Epoch 1/2
# 2793/2793 [==============================] - 28s 10ms/step - loss: 0.5256 - acc: 0.7551 - val_loss: 0.4724 - val_acc: 0.7940
# Epoch 2/2
# 2793/2793 [==============================] - 25s 9ms/step - loss: 0.4321 - acc: 0.8131 - val_loss: 0.3951 - val_acc: 0.8368

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1262/1262 [==============================] - 3s 2ms/step
# loss: 39.51%
# acc: 83.68%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_brut.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.9414793]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.27238983]]
# ISSUE

# %%
text=" very recommend"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend
# [[0.6371221]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='Data/DATA_preprocessing_brute.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text_preprocessing_brute.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.6073264]] NOTISSUE
# 2 love phone [[0.8023243]] NOTISSUE
# 3 get well finish product [[0.5902049]] NOTISSUE
# 4 not be happier [[0.35108796]] ISSUE
# 5 be look headset long time have get [[0.4460955]] ISSUE
# 6 headset start ring no reason [[0.14793661]] ISSUE
# 7 display be excellent camera be good year [[0.9968405]] NOTISSUE
# 8 battery life be great [[0.969597]] NOTISSUE
# 9 worst phone have have have month [[0.15521131]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.1651502]] ISSUE
# 11 be embarrass ear hurt try push ear plug ear [[0.0867092]] ISSUE
# 12 protect phone side [[0.60064363]] NOTISSUE
# 13 be average phone bad battery life operate weak network [[0.04712947]] ISSUE
# 14 clear skye call long battery life long range [[0.8601308]] NOTISSUE
# 15 solo technology suck [[0.31981978]] ISSUE
# 16 great hand free device [[0.9545654]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.47128546]] ISSUE
# 18 problem have mention [[0.0924563]] ISSUE
# 19 try handsfree gadget be one finally work well [[0.8320722]] NOTISSUE
# 20 magical help [[0.84550565]] NOTISSUE
# 21 worst piece crap version customer service [[0.11141054]] ISSUE
# 22 poor sound quality [[0.30197152]] ISSUE
# 23 best phone market [[0.80834466]] NOTISSUE
# 24 work well [[0.79769206]] NOTISSUE
# 25 company ship product promptly work well [[0.7963798]] NOTISSUE
# 26 exactly want [[0.491121]] ISSUE
# 27 picture resolution be far comparably price phone offer today [[0.71427435]] NOTISSUE
# 28 be great deal [[0.94931114]] NOTISSUE
# 29 excellent product be satisfy purchase [[0.96956784]] NOTISSUE
# 30 highly recommend encourage people give try [[0.85043263]] NOTISSUE
# 31 better expect [[0.6730971]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.11669944]] ISSUE
# 33 great product price [[0.9700927]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.998038]] NOTISSUE
# 35 disappointment [[0.20342806]] ISSUE
# 36 prompt service [[0.43541926]] ISSUE
# 37 excellent product price [[0.96292335]] NOTISSUE
# 38 please headset [[0.5389185]] NOTISSUE
# 39 do not waste money time [[0.06915655]] ISSUE
# 40 especially love long battery life [[0.95530427]] NOTISSUE
# 41 be stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.9485144]] NOTISSUE
# 42 work great [[0.9573237]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.98659456]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice be bad service [[0.06982867]] ISSUE
# 45 be look new earpiece [[0.57636964]] NOTISSUE
# 46 be look new earpiece jawbone era be awesome too [[0.6769478]] NOTISSUE
# 47 receive white color battery go dead couple hoursthe original use week last longer thereplacement [[0.16983385]] ISSUE
# 48 year battery go completely dead headset [[0.11041614]] ISSUE
# 49 have use phone two year one be best [[0.7000227]] NOTISSUE
# 50 awesome new look fall 200 [[0.9471068]] NOTISSUE
# 51 be phone have have have be cheaply make [[0.47437358]] ISSUE
# 52 att be not clear sound be distort have yell talk [[0.04223409]] ISSUE
# 53 price be good too [[0.609724]] NOTISSUE
# 54 plastic break easy clip [[0.45532656]] ISSUE
# 55 do not make mistake do [[0.04138321]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.18056408]] ISSUE
# 57 be river spine with case fit fine [[0.8018968]] NOTISSUE
# 58 area unit break be not fond magnetic strap [[0.15430973]] ISSUE
# 59 overall be psyched have phone have appointment contact get great reception [[0.94125926]] NOTISSUE
# 60 thing phone work perfectly like it [[0.92759657]] NOTISSUE
# 61 note phone s appearance be look bland especially black model [[0.211758]] ISSUE
# 62 be easy [[0.66550064]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.10823584]] ISSUE
# 64 fantastic earphone [[0.8865471]] NOTISSUE
# 65 find cell phone right away enter car [[0.18246831]] ISSUE
# 66 low quality [[0.49609858]] ISSUE
# 67 do get better reception clarity phone have have before [[0.4053549]] ISSUE
# 68 warn stay away [[0.1422732]] ISSUE
# 69 wish return unit get back money [[0.30524275]] ISSUE
# 70 awesome device work great [[0.9973067]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.03143325]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.06765132]] ISSUE
# 73 displease [[0.23259822]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.5179662]] NOTISSUE
# 75 make case small be difficult install [[0.29968753]] ISSUE
# 76 restore phone like new performance [[0.8454575]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.87579864]] NOTISSUE
# 78 search internet find one be best value [[0.843332]] NOTISSUE
# 79 do not fit [[0.18170758]] ISSUE
# 80 happy product [[0.8090027]] NOTISSUE
# 81 screen size be big key pad light well enough camera quality be excellent camera phone [[0.9959747]] NOTISSUE
# 82 be nothing bad say headset [[0.05099593]] ISSUE
# 83 be glad find product amazon be hard find be not high price [[0.555809]] NOTISSUE
# 84 portable work [[0.6844535]] NOTISSUE
# 85 colleague get great reception a little expensive performance be great [[0.997766]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.10726549]] ISSUE
# 87 have have problem phone read memory card turn again [[0.15877669]] ISSUE
# 88 not good wear hat sunglass [[0.48809123]] ISSUE
# 89 timely shipment quality product [[0.5961065]] NOTISSUE
# 90 nice solid keyboard [[0.96999466]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.98447543]] NOTISSUE
# 92 horrible phone [[0.13661385]] ISSUE
# 93 bt battery junk [[0.37537068]] ISSUE
# 94 recommend others [[0.56321514]] NOTISSUE
# 95 cant get software work computer [[0.368384]] ISSUE
# 96 disappoint [[0.25917163]] ISSUE
# 97 poor voice clarity [[0.35751113]] ISSUE
# 98 battery work great [[0.9699505]] NOTISSUE
# 99 no buyer remorse one [[0.20530589]] ISSUE
# 100 disappoint accessoryone [[0.24964057]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.08821186]] ISSUE
# 102 look great be strong [[0.9758564]] NOTISSUE
# 103 have have mobile service two year now be pretty happy it [[0.9857163]] NOTISSUE
# 104 update procedure be difficult cumbersome [[0.10417295]] ISSUE
# 105 disappointment hate go ear [[0.08848795]] ISSUE
# 106 great software motorola [[0.94210863]] NOTISSUE
# 107 delivery be time [[0.5466843]] NOTISSUE
# 108 easy use [[0.655422]] NOTISSUE
# 109 uncomfortable ear do not use lg 969900 env [[0.23507284]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.32229123]] ISSUE
# 111 hold charge long time be reasonably comfortable long wear condition quality sound be tremendous [[0.9930617]] NOTISSUE
# 112 like return it [[0.51374704]] NOTISSUE
# 113 keyboard be worthwhile usefulness be sturdy do not expect problem [[0.18780875]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.29868954]] ISSUE
# 115 charge overnight battery work great [[0.9306455]] NOTISSUE
# 116 not regret it [[0.15775834]] ISSUE
# 117 love phone [[0.8023243]] NOTISSUE
# 118 disappointment [[0.20342806]] ISSUE
# 119 not user friendly [[0.4164799]] ISSUE
# 120 unfortunately ability actually know receive call be important feature phone be pitiful respect [[0.32838795]] ISSUE
# 121 exchange phone have problem [[0.3435544]] ISSUE
# 122 result phone be stick max volume mute [[0.11765527]] ISSUE
# 123 public display affection rock [[0.80456483]] NOTISSUE
# 124 be super charge use small hybrid palmtop camera cellphone excel role [[0.76736295]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.9981317]] NOTISSUE
# 126 have version two year ago like service [[0.5769343]] NOTISSUE
# 127 pretty piece junk [[0.45683017]] ISSUE
# 128 plug be wrong size [[0.19753222]] ISSUE
# 129 work describe [[0.36528993]] ISSUE
# 130 save money have have item month now [[0.33020014]] ISSUE
# 131 bad purchase [[0.14477403]] ISSUE
# 132 well im satisfy [[0.73188037]] NOTISSUE
# 133 bose noise cancel be amaze be important nec commuter [[0.78981584]] NOTISSUE
# 134 battery be excellent bargain [[0.96016794]] NOTISSUE
# 135 defective crap [[0.05894499]] ISSUE
# 136 have give no star be able [[0.30241024]] ISSUE
# 137 wear glass fit fine them [[0.9220516]] NOTISSUE
# 138 sound quality device be unacceptable unless quiet area hear nothing [[0.1348243]] ISSUE
# 139 not recommend item anyone [[0.20893754]] ISSUE
# 140 holster arrive not match photo ad [[0.23387244]] ISSUE
# 141 great no problem all [[0.53686917]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.23110452]] ISSUE
# 143 frog phone charm be adorable eye catch [[0.9515344]] NOTISSUE
# 144 never know push hard right number time function want not [[0.11389543]] ISSUE
# 145 sound be clear people talk amaze quality too [[0.43032202]] ISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.97604877]] NOTISSUE
# 147 good product well make [[0.96529084]] NOTISSUE
# 148 mobile phone tool have [[0.76842105]] NOTISSUE
# 149 be impress job motorola steadiness phone [[0.5180902]] NOTISSUE
# 150 receive order well ship timeframe everything be good work order overall be excite have source [[0.9455249]] NOTISSUE
# 151 phone be sturdy waterproof [[0.75753367]] NOTISSUE
# 152 be not impress not recommend item anyone [[0.11175439]] ISSUE
# 153 complaint be standard sound volume be little low turn 5 of 5 [[0.10637792]] ISSUE
# 154 thank again amazon have thing need good price [[0.9444926]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.22080941]] ISSUE
# 156 have go store buy new nokia phone be work great [[0.9731453]] NOTISSUE
# 157 work great [[0.9573237]] NOTISSUE
# 158 ugly [[0.0669288]] ISSUE
# 159 horrible have switch time [[0.16237076]] ISSUE
# 160 noise shield be incredible [[0.79990554]] NOTISSUE
# 161 no real improvement [[0.15061101]] ISSUE
# 162 razor battery good buy [[0.96408594]] NOTISSUE
# 163 keep good work amazon [[0.93415904]] NOTISSUE
# 164 refuse refund replace [[0.09811208]] ISSUE
# 165 unfortunately be easy accidentally activate gentle touch button accidentally touch phone face listen [[0.32156134]] ISSUE
# 166 basically throw money window nothing [[0.06396008]] ISSUE
# 167 great case price [[0.9425509]] NOTISSUE
# 168 take be one drop six inch kitchen counter be crack i be not impress be not laugh [[0.06353284]] ISSUE
# 169 bluetooth range be good day ago leave phone trunk get call carry conversation hitch [[0.901983]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.9977447]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.5038224]] NOTISSUE
# 172 none new one have work properly [[0.50471294]] NOTISSUE
# 173 be glad purchase it [[0.8345429]] NOTISSUE
# 174 have miss numerous call reason [[0.29590318]] ISSUE
# 175 phone be defective people hear use this [[0.20722422]] ISSUE
# 176 do not buy product [[0.14241044]] ISSUE
# 177 suck stuff do not work phone [[0.09358902]] ISSUE
# 178 no shift no bubble no peel not scratch [[0.04642506]] ISSUE
# 179 not be happier new one droid [[0.37433794]] ISSUE
# 180 worst software use give zero star would [[0.12036289]] ISSUE
# 181 try make call be exercise frustration [[0.49216852]] ISSUE
# 182 case be flimsy piece plastic have no protection whatsoever [[0.05931139]] ISSUE
# 183 cabra barset be happy it sound quality especially outgo be better [[0.9791854]] NOTISSUE
# 184 love camera be pretty good quality [[0.9962787]] NOTISSUE
# 185 thank great service [[0.9929162]] NOTISSUE
# 186 total package [[0.67349195]] NOTISSUE
# 187 seller be understand patient definitely buy again [[0.6617688]] NOTISSUE
# 188 give firefly one star i contact singular at t inform practice [[0.4746074]] ISSUE
# 189 be aggravate [[0.15057144]] ISSUE
# 190 great product price [[0.9700927]] NOTISSUE
# 191 have purchase family friend enjoy clarity ease use [[0.99732745]] NOTISSUE
# 192 virgin wireless rock do cheap little phone [[0.28887168]] ISSUE
# 193 none work [[0.4458289]] ISSUE
# 194 do not buy it [[0.17983158]] ISSUE
# 195 muddy low quality sound case wire s insert be poorly super glue slide off [[0.14296532]] ISSUE
# 196 please dont waste money [[0.17181334]] ISSUE
# 197 all be satisfy purchase [[0.6477936]] NOTISSUE
# 198 look good quality headset keep look be not it [[0.97543824]] NOTISSUE
# 199 plantronincs continue use flaw charger design [[0.4803393]] ISSUE
# 200 be not best one [[0.35345808]] ISSUE
# 201 best one [[0.78849757]] NOTISSUE
# 202 disappoint result [[0.12778464]] ISSUE
# 203 cumbersome design [[0.4122513]] ISSUE
# 204 great be new package nice work good [[0.99972695]] NOTISSUE
# 205 no problem come time expect [[0.15842399]] ISSUE
# 206 great product [[0.9414793]] NOTISSUE
# 207 be piece crap [[0.15950373]] ISSUE
# 208 experience be terrible [[0.12827201]] ISSUE
# 209 be fourth bluetooth headset [[0.36553586]] ISSUE
# 210 be comfortable one [[0.79551786]] NOTISSUE
# 211 hat [[0.5704225]] NOTISSUE
# 212 fix problem [[0.18767354]] ISSUE
# 213 worst ever [[0.0996202]] ISSUE
# 214 be happy [[0.80283695]] NOTISSUE
# 215 have have no trouble access internet download intone perform function [[0.23904303]] ISSUE
# 216 barely hear be constantly say what [[0.13134576]] ISSUE
# 217 battery life be highly unacceptable [[0.26512665]] ISSUE
# 218 company be joke [[0.22513159]] ISSUE
# 219 do everything description say would [[0.13925934]] ISSUE
# 220 happen call be force stop headset [[0.10320596]] ISSUE
# 221 work great car charger especially plug two adapter time [[0.9971137]] NOTISSUE
# 222 version tech support walk procedure none work end have do hard re set wipe data [[0.12716155]] ISSUE
# 223 voice quality signal strength drop call [[0.48274836]] ISSUE
# 224 play louder speaker size price be low think quality be lack however be not [[0.13229524]] ISSUE
# 225 better expect [[0.6730971]] NOTISSUE
# 226 feel poorly construct menu difficult navigate button recess be difficult push them [[0.3960126]] ISSUE
# 227 battery be hold well [[0.80395186]] NOTISSUE
# 228 difficult on i d recommend avoid product [[0.2549012]] ISSUE
# 229 use two day be not easy hear with [[0.28136632]] ISSUE
# 230 get car charger not week charger be break i go plug start smoke [[0.08008689]] ISSUE
# 231 sprint terrible customer service [[0.36926487]] ISSUE
# 232 link phone effort [[0.3846028]] ISSUE
# 233 cool [[0.6165949]] NOTISSUE
# 234 easy use [[0.655422]] NOTISSUE
# 235 better new [[0.7548676]] NOTISSUE
# 236 posse get junk have no idea [[0.13023825]] ISSUE
# 237 piece trash [[0.16351344]] ISSUE
# 238 pretty good product [[0.9422767]] NOTISSUE
# 239 be great phone [[0.93984425]] NOTISSUE
# 240 price amazon be excellent product highly recommend [[0.9830989]] NOTISSUE
# 241 research development division obviously know do [[0.3646767]] ISSUE
# 242 real killer be volume course break [[0.16561334]] ISSUE
# 243 phone work fine now [[0.86632466]] NOTISSUE
# 244 be happy product one [[0.7852545]] NOTISSUE
# 245 poor construction [[0.12515183]] ISSUE
# 246 be infuriate [[0.5038754]] NOTISSUE
# 247 overall recommend phone new walkman [[0.73353046]] NOTISSUE
# 248 sprint charge service [[0.69755435]] NOTISSUE
# 249 be cheap feel look cheap [[0.33635393]] ISSUE
# 250 fit ear well be comfortable on [[0.9548494]] NOTISSUE
# 251 do not work europe asia [[0.16532224]] ISSUE
# 252 clip belt definitely make feel like fifty cent s up and come [[0.893828]] NOTISSUE
# 253 like design look cabra be ear headset five thousand twenty be pretty comfortable wear twenty four hour day pain ear [[0.8983723]] NOTISSUE
# 254 be amaze quick arrival two original lg cell phone battery fraction price [[0.664253]] NOTISSUE
# 255 worst phone samsung crap crappy samsung 2715 be worst have see [[0.05203788]] ISSUE
# 256 charger work week completely stop charge phone [[0.17205428]] ISSUE
# 257 poor product [[0.12188317]] ISSUE
# 258 need better instruction [[0.6001397]] NOTISSUE
# 259 need two hand operate screen this software interface be decade old compete new software design [[0.70036936]] NOTISSUE
# 260 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.95861226]] NOTISSUE
# 261 steer clear product go genuine palm replacement pen come three pack [[0.31310788]] ISSUE
# 262 do not buy do not but suck [[0.03032626]] ISSUE
# 263 be great product sure beat finger [[0.96301556]] NOTISSUE
# 264 plus seriously do not believe be worth steep price point [[0.12612683]] ISSUE
# 265 case have try normally fall apart month one seem be long haul [[0.13240533]] ISSUE
# 266 disappoint performance [[0.30626288]] ISSUE
# 267 do not make mistake please do not buy phone [[0.06078972]] ISSUE
# 268 phone well be worst have have brand [[0.22808692]] ISSUE
# 269 case be extra originally later discard scratch ear [[0.11817581]] ISSUE
# 270 recommend go different brand cell phone mp player family [[0.920173]] NOTISSUE
# 271 do not bother go store [[0.05729466]] ISSUE
# 272 post detail comment grey black phone have fire red be great color [[0.7707233]] NOTISSUE
# 273 not have problem item order again need [[0.21100083]] ISSUE
# 274 get pay guess [[0.23163418]] ISSUE
# 275 not software do great job this make intone form exist cd internet connection [[0.4715221]] ISSUE
# 276 im surprise be good quality car charger be not review it [[0.9749561]] NOTISSUE
# 277 fabulous [[0.8618738]] NOTISSUE
# 278 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.07059048]] ISSUE
# 279 price cable be excellent [[0.95748824]] NOTISSUE
# 280 disappoint accessory good manufacturer [[0.58287907]] NOTISSUE
# 281 perform awful muffle tinny incoming sound severe echo end call [[0.10540935]] ISSUE
# 282 wind resistant [[0.40621564]] ISSUE
# 283 obviously have terrible customer service get pay for [[0.23941076]] ISSUE
# 284 do not forever [[0.09786054]] ISSUE
# 285 it not overly expensive replace [[0.10667711]] ISSUE
# 286 easy operate sound be better have try [[0.90607595]] NOTISSUE
# 287 contact company tell that unit be warranty not produce receipt be luck [[0.10288208]] ISSUE
# 288 link have way exchange bad phone return unit something [[0.09803574]] ISSUE
# 289 phone be sturdy nokia bar phone be [[0.81899333]] NOTISSUE
# 290 great phone [[0.94656]] NOTISSUE
# 291 place tree case not be not snug be lot extra room side [[0.2542136]] ISSUE
# 292 be please [[0.57669705]] NOTISSUE
# 293 battery be terrible [[0.09583871]] ISSUE
# 294 find product be easy set use [[0.7672402]] NOTISSUE
# 295 earpiece be large heavy it keep fall ear [[0.15959503]] ISSUE
# 296 utter crap sound quality be terrible [[0.02472192]] ISSUE
# 297 charger arrive promise timeframe not work [[0.50424623]] NOTISSUE
# 298 no ear loop need be tiny sound be great [[0.80246747]] NOTISSUE
# 299 finally four time spring latch break not use longer visor [[0.11760624]] ISSUE
# 300 handsfree work fine car try download address book tree reboot overall rate device high [[0.9758356]] NOTISSUE
# 301 talk useless customer service [[0.15178262]] ISSUE
# 302 felt light tinny [[0.2670304]] ISSUE
# 303 do not fit palm tungsten e2 break time try plug in [[0.23556983]] ISSUE
# 304 be happy purchase good quality low price [[0.9946255]] NOTISSUE
# 305 love look feel samsung flipphones [[0.8630046]] NOTISSUE
# 306 well design sharp blue be nice color [[0.9929617]] NOTISSUE
# 307 do everything more [[0.31387278]] ISSUE
# 308 not recommend more [[0.381513]] ISSUE
# 309 nice sound [[0.94127434]] NOTISSUE
# 310 look good picture case be huge disappointment [[0.511278]] NOTISSUE
# 311 jawbone be go replace with [[0.2901642]] ISSUE
# 312 setup go smoothly [[0.6975611]] NOTISSUE
# 313 extremely slow take forever do it [[0.15278697]] ISSUE
# 314 study interest worst sin industrial design [[0.10649119]] ISSUE
# 315 thing happen be track be off [[0.16919246]] ISSUE
# 316 be well make easy access phone have handy detachable belt clip [[0.9537244]] NOTISSUE
# 317 have continue pair periodically keep drop [[0.42102534]] ISSUE
# 318 unload intone party [[0.23902006]] ISSUE
# 319 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.21851866]] ISSUE
# 320 truly awful [[0.26834664]] ISSUE
# 321 work fine motorola twenty five cellphone lot better wear out battery do [[0.831843]] NOTISSUE
# 322 volume ringer be real good you have choice loud one [[0.8504054]] NOTISSUE
# 323 none tone be acceptable [[0.36456794]] ISSUE
# 324 camera color balance be awful [[0.3718457]] ISSUE
# 325 product be clearly not ready prime time do not care cool look tell call be come be worthless [[0.03536354]] ISSUE
# 326 love intone upbeat [[0.75529754]] NOTISSUE
# 327 chinese forgery abound [[0.46363738]] ISSUE
# 328 easy pair samsung cell [[0.7488623]] NOTISSUE
# 329 instruction not explain microphone jack be use [[0.17508563]] ISSUE
# 330 advise not purchase item never work well [[0.45329645]] ISSUE
# 331 bad have pay month service [[0.09685061]] ISSUE
# 332 work well [[0.79769206]] NOTISSUE
# 333 nokia ca 42 usb cable not work phone [[0.19957137]] ISSUE
# 334 clear crisp sound [[0.65610766]] NOTISSUE
# 335 have use smallest earpiece provide stay pretty well [[0.9005013]] NOTISSUE
# 336 biggest complaint have be battery drain superfast [[0.10972264]] ISSUE
# 337 design be ergonomic theory not stand have ear [[0.140429]] ISSUE
# 338 do not buy want use holster [[0.13895203]] ISSUE
# 339 phone take great picture video clip [[0.94539934]] NOTISSUE
# 340 do not make look cool [[0.1178819]] ISSUE
# 341 ear occupy background be not distract all [[0.10951192]] ISSUE
# 342 comfortable fit need headset be comfortable hour time not entire day [[0.9754616]] NOTISSUE
# 343 also phone do not seem accept cbr mp s preferably rip window medium player [[0.12033692]] ISSUE
# 344 beat price these [[0.5899404]] NOTISSUE
# 345 come strong light use light camera shot flash so signal seriously [[0.28860694]] ISSUE
# 346 lightweight work well [[0.94335747]] NOTISSUE
# 347 beware [[0.30373305]] ISSUE
# 348 love cable allow connect mini usb device pc [[0.85478246]] NOTISSUE
# 349 near hear conversation [[0.42629153]] ISSUE
# 350 be cool case open allow screen get scratch up one [[0.20330204]] ISSUE
# 351 buy phone replacement start have regret since [[0.25727907]] ISSUE
# 352 appear actually outperform original battery china come a325 i [[0.36033675]] ISSUE
# 353 store phone number sim [[0.5564614]] NOTISSUE
# 354 last o minute actually try use phone my wife have phone problem [[0.2048504]] ISSUE
# 355 poor quality [[0.17334116]] ISSUE
# 356 cabra ear gel r best [[0.7799168]] NOTISSUE
# 357 not worth it [[0.30850407]] ISSUE
# 358 phone crash completely have get replace [[0.09304776]] ISSUE
# 359 quit work use eighteen month purchase one be best headset have own [[0.42799002]] ISSUE
# 360 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.20773564]] ISSUE
# 361 be great phone [[0.93984425]] NOTISSUE
# 362 simply want small flip phone look extra bell whistle mediocre [[0.08474667]] ISSUE
# 363 good value work fine power usb car wall outlet [[0.9771633]] NOTISSUE
# 364 phone do not slide car grip prevent phone slip hand [[0.09768698]] ISSUE
# 365 be simply best bluetooth headset sound quality [[0.8770133]] NOTISSUE
# 366 think plan one this sure be moto phone me [[0.56536114]] NOTISSUE
# 367 span hour have two people exclaim whoa be new phone tv [[0.38458866]] ISSUE
# 368 have use cord headset freedom wireless be helpful [[0.9273804]] NOTISSUE
# 369 case have pas one year mark show sign wear be 100 functional [[0.29195172]] ISSUE
# 370 that leather be nice soft fit be tight cut face be good shape [[0.97997504]] NOTISSUE
# 371 have everything need not ask more [[0.28661743]] ISSUE
# 372 receive product two day break [[0.31563157]] ISSUE
# 373 product be great make work lot easier go copier wait hold something [[0.97847646]] NOTISSUE
# 374 none size send headset stay ear [[0.3890353]] ISSUE
# 375 t mobile have best customer service anywhere [[0.9109342]] NOTISSUE
# 376 arrive quickly expensive be sell [[0.33082816]] ISSUE
# 377 have try two unit fail two month pro [[0.18186568]] ISSUE
# 378 provide good protection look classy too [[0.885257]] NOTISSUE
# 379 russel good [[0.846863]] NOTISSUE
# 380 tracfonewebsite be user friendly make easy activate etc [[0.73302513]] NOTISSUE
# 381 design be good 4 [[0.90606195]] NOTISSUE
# 382 great reception time [[0.97752863]] NOTISSUE
# 383 highly recommend product [[0.81166923]] NOTISSUE
# 384 not use unit sunglass not good texas [[0.2727678]] ISSUE
# 385 dit not work time nokia 5320 [[0.2673448]] ISSUE
# 386 buy mainly charger break soon purchase [[0.774394]] NOTISSUE
# 387 like loud buzz override conversation phone be you [[0.56022346]] NOTISSUE
# 388 fantastic buy get again phone be [[0.9754607]] NOTISSUE
# 389 stay away store be careful [[0.28661123]] ISSUE
# 390 blunt supertooth hand free phone speaker be awesome [[0.8940276]] NOTISSUE
# 391 item arrive quickly work great phone sound ear plug [[0.941303]] NOTISSUE
# 392 be light have plenty battery capacity be comfortable wear somewhat extend period time [[0.98178804]] NOTISSUE
# 393 disappoint [[0.25917163]] ISSUE
# 394 blue ant be easy use [[0.57498974]] NOTISSUE
# 395 cheap hey work [[0.6465044]] NOTISSUE
# 396 be pleasantly suprised give low cost item [[0.52193713]] NOTISSUE
# 397 camera phone be use dustpan indoors be disposable this [[0.3320339]] ISSUE
# 398 day later puff smoke come phone use [[0.17609999]] ISSUE
# 399 be convenient simple use get job make car ride smoother [[0.8295636]] NOTISSUE
# 400 nano state it my son be disappoint [[0.22702941]] ISSUE
# 401 sound quality be excellent well [[0.99559826]] NOTISSUE
# 402 best headset have use [[0.7743725]] NOTISSUE
# 403 not recommend [[0.34868222]] ISSUE
# 404 have be year carry highest quality anti glare screen protector have find date [[0.68705726]] NOTISSUE
# 405 want [[0.48104805]] ISSUE
# 406 particular model not work motorola q smartphone [[0.6812085]] NOTISSUE
# 407 wont work right at least me [[0.5166653]] NOTISSUE
# 408 addition feel amp look phone be lightweight cheap plastic [[0.83959174]] NOTISSUE
# 409 be out warranty problem reoccure bottom line money else singular not support it [[0.09118403]] ISSUE
# 410 want plantronics five ten be right one have issue me the good [[0.5416857]] NOTISSUE
# 411 crisp clear [[0.56726456]] NOTISSUE
# 412 charge keep go dead minute [[0.16271478]] ISSUE
# 413 cheap plastic creak like old wooden floor [[0.29420805]] ISSUE
# 414 get absolutely horrible reception apartment phone have not have problem [[0.112948]] ISSUE
# 415 reception have be generally good [[0.69621915]] NOTISSUE
# 416 excellent sound battery life inconspicuous boot [[0.99180484]] NOTISSUE
# 417 great bluetooth [[0.96261626]] NOTISSUE
# 418 highly recommend case [[0.77363724]] NOTISSUE
# 419 worthwhile [[0.56574064]] NOTISSUE
# 420 phone get be year old be be slowly break despite care part [[0.11291713]] ISSUE
# 421 be sorry make purchase [[0.59553]] NOTISSUE
# 422 buy hop make bluetooth headset fit better thing make impossible wear [[0.8248194]] NOTISSUE
# 423 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.11532132]] ISSUE
# 424 be horrible [[0.04715571]] ISSUE
# 425 allow possibility double book date time first [[0.22082548]] ISSUE
# 426 work two week break [[0.40699843]] ISSUE
# 427 do not think hold securely belt [[0.27582934]] ISSUE
# 428 be simple use like it [[0.6002171]] NOTISSUE
# 429 be great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.88669693]] NOTISSUE
# 430 use case smell be disgust [[0.03672161]] ISSUE
# 431 not want [[0.22564349]] ISSUE
# 432 two case order another [[0.37477696]] ISSUE
# 433 buy battery coupon amazon be happy purchase [[0.9182243]] NOTISSUE
# 434 internet access be fine rare instance work [[0.81391346]] NOTISSUE
# 435 perfect p [[0.8130716]] NOTISSUE
# 436 five star plus plus [[0.8028274]] NOTISSUE
# 437 good quality bargain buy buy cheap big lot sound awful people end not hear me [[0.99678206]] NOTISSUE
# 438 50 drain [[0.17901233]] ISSUE
# 439 try talk real loud shout telephone get old be tell be not great [[0.3458324]] ISSUE
# 440 good work fine [[0.969837]] NOTISSUE
# 441 price be great deal [[0.95912075]] NOTISSUE
# 442 great price too [[0.9181441]] NOTISSUE
# 443 be wind be completely useless [[0.03595725]] ISSUE
# 444 yes be shiny love it [[0.82322603]] NOTISSUE
# 445 do not work [[0.16199861]] ISSUE
# 446 think be get good deal 7 44 plug phone v see razor [[0.69222593]] NOTISSUE
# 447 reception headset be excellent [[0.9432315]] NOTISSUE
# 448 two thumb seller [[0.29463074]] ISSUE
# 449 have version lg phone work well together good reception range exceed twenty foot line sight [[0.9979663]] NOTISSUE
# 450 improper description have return it [[0.19905342]] ISSUE
# 451 1 work 2 be comfortable [[0.7388584]] NOTISSUE
# 452 battery charge life be long [[0.5117964]] NOTISSUE
# 453 cabra largely fit ear well [[0.4611855]] ISSUE
# 454 battery have no life [[0.3071187]] ISSUE
# 455 check be no feature be disappoint [[0.14652005]] ISSUE
# 456 product be exactly describe [[0.24724084]] ISSUE
# 457 get signal version phone win t [[0.42496282]] ISSUE
# 458 do not do job [[0.05939184]] ISSUE
# 459 recommend it [[0.70514756]] NOTISSUE
# 460 plan order again again [[0.6008693]] NOTISSUE
# 461 be say phone camera be nice cool effect play with video be decent well [[0.95778275]] NOTISSUE
# 462 have be satisfy cell phone day one [[0.34679124]] ISSUE
# 463 keep get better better this be one have have numerous palm too [[0.66404134]] NOTISSUE
# 464 awkward use unreliable [[0.06001386]] ISSUE
# 465 ship time be quick [[0.5341883]] NOTISSUE
# 466 not good have hop [[0.30132368]] ISSUE
# 467 good case [[0.77671677]] NOTISSUE
# 468 do not work [[0.16199861]] ISSUE
# 469 good product [[0.8121148]] NOTISSUE
# 470 unfortunately not work [[0.20266004]] ISSUE
# 471 break two month use [[0.29261383]] ISSUE
# 472 dont buy it [[0.6122821]] NOTISSUE
# 473 father have 265 battery be die [[0.2506434]] ISSUE
# 474 however ear pad come easily one week lose one [[0.11060315]] ISSUE
# 475 call drop phone come will screen go black worst stop ring intermittently [[0.07248341]] ISSUE
# 476 horrible horrible protector [[0.05709148]] ISSUE
# 477 do not like nokia either [[0.08448281]] ISSUE
# 478 reach row be uncomfortable [[0.14437407]] ISSUE
# 479 have buy nokia cell phone week ago be nightmare [[0.13523649]] ISSUE
# 480 take long describe bad customer service experience have be amazon [[0.14247689]] ISSUE
# 481 disappoint thing be be no speakerphone [[0.17436655]] ISSUE
# 482 terrible car not accept cassette [[0.06495833]] ISSUE
# 483 product be useless do not have charge current charge two cellphone [[0.08090628]] ISSUE
# 484 be not say be [[0.19347094]] ISSUE
# 485 stay away q [[0.44543755]] ISSUE
# 486 use dirty [[0.06074341]] ISSUE
# 487 unreliable service t mobile [[0.27026224]] ISSUE
# 488 not good price [[0.49934092]] ISSUE
# 489 buy two charge [[0.53683275]] NOTISSUE
# 490 look nice [[0.8981198]] NOTISSUE
# 491 be excellent tool especially pair phone s auto answer [[0.982227]] NOTISSUE
# 492 have read other s review have not have problem it [[0.13721299]] ISSUE
# 493 product cover important light sensor ear outlet [[0.4789898]] ISSUE
# 494 comfortable hand [[0.7954737]] NOTISSUE
# 495 do not work [[0.16199861]] ISSUE
# 496 poor reliability [[0.15065813]] ISSUE
# 497 work [[0.59562993]] NOTISSUE
# 498 take picture battery drop bar start beep let know din [[0.11386423]] ISSUE
# 499 terrible product waste money [[0.07596716]] ISSUE
# 500 time buy you [[0.7174309]] NOTISSUE
# 501 be waste money [[0.13168947]] ISSUE
# 502 far have work like charm [[0.780759]] NOTISSUE
# 503 have have week far good [[0.60392696]] NOTISSUE
# 504 but case best be download picture laptop ir send picture laptop phone [[0.6544403]] NOTISSUE
# 505 recommend item [[0.6777512]] NOTISSUE
# 506 be be choice headset year great sound good volume good noise cancellation [[0.9986841]] NOTISSUE
# 507 nice case feel good hand [[0.9394794]] NOTISSUE
# 508 item receive be counterfeit [[0.29035598]] ISSUE
# 509 good far probably best bt headset have have [[0.9450462]] NOTISSUE
# 510 work fine [[0.8293548]] NOTISSUE
# 511 receive headset good time be happy it [[0.9793888]] NOTISSUE
# 512 be please see replace well trail swivel holster blackberry flip [[0.22453316]] ISSUE
# 513 sister have one love it [[0.8517606]] NOTISSUE
# 514 good quality [[0.91751176]] NOTISSUE
# 515 be far worst purchase have make amazon [[0.10398959]] ISSUE
# 516 excellent dual purpose headset [[0.95823777]] NOTISSUE
# 517 excellent [[0.92216927]] NOTISSUE
# 518 do not work listen music singular 8125 [[0.25087473]] ISSUE
# 519 seem completely secure hold belt keep phone inside [[0.5322447]] NOTISSUE
# 520 bottom line another worthless cheap gimmick sprint [[0.13758682]] ISSUE
# 521 have trouble volume [[0.20058972]] ISSUE
# 522 good thing be fit comfortably small ear [[0.9609208]] NOTISSUE
# 523 warn do not buy [[0.10285559]] ISSUE
# 524 be pair phone not be happier far [[0.34777376]] ISSUE
# 525 open battery connection be break device be turn off [[0.08463722]] ISSUE
# 526 not want clip go ear cause discomfort [[0.07549879]] ISSUE
# 527 best headset ever [[0.78720206]] NOTISSUE
# 528 do not trust webster do not expect helpful support [[0.12583916]] ISSUE
# 529 be loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.46432126]] ISSUE
# 530 speaker be low quality make ring tone sound cheap [[0.7953808]] NOTISSUE
# 531 fit comfortably come size earn tip [[0.8030913]] NOTISSUE
# 532 bad reception [[0.09661853]] ISSUE
# 533 product be high quality chinese crap [[0.36311415]] ISSUE
# 534 be comfortable ear [[0.73213685]] NOTISSUE
# 535 do not buy product fail [[0.06521919]] ISSUE
# 536 everything product be wrong first [[0.21164289]] ISSUE
# 537 pair two device be easy barely take couple minute start make call voice deal feature [[0.4362657]] ISSUE
# 538 be utterly confuse first cause lose couple very important contact [[0.1642949]] ISSUE
# 539 terrible phone holder [[0.22364855]] ISSUE
# 540 cutout button place perfectly [[0.92571294]] NOTISSUE
# 541 love be able use one headset land line cell [[0.6517983]] NOTISSUE
# 542 problem be ear loop make weak material break easily [[0.06108671]] ISSUE
# 543 not nearly good look amazon picture make look [[0.38347417]] ISSUE
# 544 despite flaw case be exceptional quality well worth additional cost own official oem product [[0.7466434]] NOTISSUE
# 545 stupid be that [[0.1358045]] ISSUE
# 546 hear be drive car usually do not have be loudest set [[0.20102482]] ISSUE
# 547 seller ship quickly cheaper competitor [[0.41955432]] ISSUE
# 548 good show samsung [[0.8054532]] NOTISSUE
# 549 buy ten save a lot money [[0.64844376]] NOTISSUE
# 550 cut make beep beep beep sound say signal fail [[0.05595751]] ISSUE
# 551 not figure [[0.2824082]] ISSUE
# 552 phone sound ok not great ok wife s phone be totally unintelligible not understand word be say it [[0.17394283]] ISSUE
# 553 have take battery phone back restart it [[0.38880056]] ISSUE
# 554 manage bend leaf spring back place metal have stress break drop [[0.07290673]] ISSUE
# 555 leopard print be wonderfully wild [[0.9017162]] NOTISSUE
# 556 work me [[0.725541]] NOTISSUE
# 557 saggy floppy piece junk [[0.24669503]] ISSUE
# 558 better hard plastic case [[0.54265565]] NOTISSUE
# 559 have new problem [[0.3572175]] ISSUE
# 560 happy far [[0.7429403]] NOTISSUE
# 561 cool phone [[0.6567347]] NOTISSUE
# 562 work good [[0.8876762]] NOTISSUE
# 563 motorola finally get voice quality bluetooth headset right [[0.7501448]] NOTISSUE
# 564 loose connection phone be couple foot two [[0.3727778]] ISSUE
# 565 be great recommend [[0.96635747]] NOTISSUE
# 566 make easier keep bluetooth be not wear it [[0.35281235]] ISSUE
# 567 say above pretty useless [[0.12913232]] ISSUE
# 568 never get it [[0.2692972]] ISSUE
# 569 pair headphone be worst have have sound wise [[0.27043232]] ISSUE
# 570 drain weak snap [[0.04749444]] ISSUE
# 571 do not charge singular att eight thousand five twenty five phone [[0.21828312]] ISSUE
# 572 get extra minute carry call not get cut off [[0.07011066]] ISSUE
# 573 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.08033303]] ISSUE
# 574 keep catch cable seat have pull phone turn off [[0.25405484]] ISSUE
# 575 headset fulfil requirement be happy purchase [[0.9223233]] NOTISSUE
# 576 logitech bluetooth headset be 10 [[0.78130263]] NOTISSUE
# 577 like fact rest lightly ear inside [[0.24138595]] ISSUE
# 578 lot webster have be rat good phone do i [[0.43376827]] ISSUE
# 579 have try cable computer pod work fine [[0.7031769]] NOTISSUE
# 580 mic be joke volume be low [[0.10498843]] ISSUE
# 581 be return them [[0.37559387]] ISSUE
# 582 do not maintain connection computer be lap [[0.20190573]] ISSUE
# 583 be easy turn car volume control accessible [[0.5511338]] NOTISSUE
# 584 have have year christmas buy rest family [[0.86659855]] NOTISSUE
# 585 otherwise easy install use clear sound [[0.36612228]] ISSUE
# 586 nice leather [[0.8863394]] NOTISSUE
# 587 have purchase different case [[0.7145239]] NOTISSUE
# 588 be joy use [[0.85074323]] NOTISSUE
# 589 disappoint company [[0.31168208]] ISSUE
# 590 satisfy that [[0.4827996]] ISSUE
# 591 not charge me [[0.21413556]] ISSUE
# 592 be phone get 2005 buy s740 say be wow [[0.6115566]] NOTISSUE
# 593 button small [[0.5757656]] NOTISSUE
# 594 read spec make say wow [[0.6503383]] NOTISSUE
# 595 love it great armband [[0.9664648]] NOTISSUE
# 596 like product motorola be allot clearer ear piece mic [[0.4917228]] ISSUE
# 597 however keypad tinny reach wrong button [[0.18965916]] ISSUE
# 598 exchange sony ericson z five be pretty happy decision [[0.9811638]] NOTISSUE
# 599 be impress price case [[0.50541985]] NOTISSUE
# 600 make easier hold to [[0.4610258]] ISSUE
# 601 use product motor control center be lot high voltage hum equipment work great [[0.9653759]] NOTISSUE
# 602 be pretty easy [[0.848088]] NOTISSUE
# 603 make call certain place [[0.56239593]] NOTISSUE
# 604 however girl be complain time phone do not wake like normal phone do [[0.04175328]] ISSUE
# 605 beautiful style though [[0.94793385]] NOTISSUE
# 606 company charge restock fee not give refund back [[0.10066579]] ISSUE
# 607 be try return refund [[0.23016898]] ISSUE
# 608 plug find not darn thing work [[0.26685363]] ISSUE
# 609 excellent product [[0.9296327]] NOTISSUE
# 610 earn piece break easily [[0.2894317]] ISSUE
# 611 lousy product [[0.19712065]] ISSUE
# 612 phone try hard do everything fail be ability be phone [[0.15776263]] ISSUE
# 613 be best charger have see market yet [[0.86366636]] NOTISSUE
# 614 sweetest phone [[0.78150994]] NOTISSUE
# 615 oh charger seem work fine [[0.8725183]] NOTISSUE
# 616 fit securely ear hook do not need be use sound be better direct ear canal [[0.10592385]] ISSUE
# 617 not volume [[0.2038721]] ISSUE
# 618 echo problem very unsatisfactory [[0.10101384]] ISSUE
# 619 take two video time quality be poor [[0.1110609]] ISSUE
# 620 do not waste money [[0.06030825]] ISSUE
# 621 be go have be negatively review product [[0.1342117]] ISSUE
# 622 adapter do not provide charge current [[0.12422442]] ISSUE
# 623 be hype phone assume be best mistake [[0.190826]] ISSUE
# 624 take picture case sense be cover [[0.3039606]] ISSUE
# 625 phone fall easily [[0.21672495]] ISSUE
# 626 not work people not hear talk [[0.06981106]] ISSUE
# 627 text message feature be tricky use [[0.48263952]] ISSUE
# 628 be disappoint have be charger do not work [[0.12682351]] ISSUE
# 629 painful ear [[0.21130723]] ISSUE
# 630 last one day blow up [[0.16078794]] ISSUE
# 631 disappoint [[0.25917163]] ISSUE
# 632 kind flop around [[0.22654319]] ISSUE
# 633 screen do get smudge easily touch ear face [[0.10348568]] ISSUE
# 634 piece junk lose call phone [[0.2279081]] ISSUE
# 635 item do not match picture [[0.12921512]] ISSUE
# 636 thing disappoint be infra red port ira [[0.28149995]] ISSUE
# 637 not answer call unit never work once [[0.14745633]] ISSUE
# 638 unsatisfactory [[0.14396858]] ISSUE
# 639 product be great [[0.9396618]] NOTISSUE
# 640 have this [[0.47739744]] ISSUE
# 641 have be work good no problem [[0.3454991]] ISSUE
# 642 oh be dangerous [[0.21348722]] ISSUE
# 643 sorry [[0.45255685]] ISSUE
# 644 be sorry [[0.5038754]] NOTISSUE
# 645 pardon [[0.4651876]] ISSUE
# 646 help help [[0.5338085]] NOTISSUE
# 647 no no be dangerous [[0.04287474]] ISSUE
# 648 be extremely dangerous [[0.22206034]] ISSUE
# 649 be dangerous [[0.15846883]] ISSUE
# 650 be dangerous young man [[0.22458728]] ISSUE
# 651 dangerous brutal [[0.03972577]] ISSUE
# 652 honestly be dangerous [[0.14169344]] ISSUE
# 653 work [[0.59562993]] NOTISSUE
# 654 be dead hard work [[0.28003094]] ISSUE
# 655 fact family be mary s wed [[0.72621155]] NOTISSUE
# 656 have be busy [[0.47439912]] ISSUE
# 657 go back again [[0.41773066]] ISSUE
# 658 be be busy [[0.44860247]] ISSUE
# 659 think be yesterday [[0.42702678]] ISSUE
# 660 do think get one [[0.19761905]] ISSUE
# 661 oh yes [[0.64334506]] NOTISSUE
# 662 be one thing want talk [[0.21901067]] ISSUE
# 663 well honestly do not know have not be discussion [[0.12536311]] ISSUE
# 664 course be come tomorrow [[0.43249476]] ISSUE
# 665 have not see think away weekend [[0.09233962]] ISSUE
# 666 hello [[0.60581887]] NOTISSUE
# 667 mean be young man [[0.203025]] ISSUE
# 668 goodbye [[0.5480075]] NOTISSUE
# 669 be alright [[0.5038754]] NOTISSUE
# 670 do need money urgently [[0.30004388]] ISSUE
# 671 be business [[0.43131796]] ISSUE
# 672 be work day [[0.5284394]] NOTISSUE
# 673 work [[0.59562993]] NOTISSUE
# 674 do work [[0.3167596]] ISSUE
# 675 be be work day [[0.45852977]] ISSUE
# 676 work saturday [[0.59562993]] NOTISSUE
# 677 know work [[0.5804155]] NOTISSUE
# 678 horrible customer service [[0.15358266]] ISSUE
# 679 fine product [[0.6895402]] NOTISSUE
# 680 glad pay money it [[0.46235463]] ISSUE
# 681 be worst version adobe illustrator be release version nine [[0.2020113]] ISSUE
# 682 save mysterious reason [[0.23357935]] ISSUE
# 683 crash [[0.18574248]] ISSUE
# 684 open file have be year write scribble untenable save version [[0.1326958]] ISSUE
# 685 assume adobe s customer service be professional quick [[0.6263223]] NOTISSUE
# 686 have call time past two week have have wait minimum twenty three minute speak someone [[0.0868001]] ISSUE
# 687 finally get product send mac version personal computer version purchase [[0.44848147]] ISSUE
# 688 call again wait approximately thirty minute get customer help [[0.14946385]] ISSUE
# 689 have not receive personal computer version [[0.16551936]] ISSUE
# 690 call center service be worst customer service have deal [[0.19095653]] ISSUE
# 691 have deal bad customer service [[0.10838524]] ISSUE
# 692 six extremely frustrate hour [[0.3805857]] ISSUE
# 693 do not have problem software [[0.12275475]] ISSUE
# 694 reverse error be nightmare [[0.02325644]] ISSUE
# 695 pretty do need [[0.50309896]] NOTISSUE
# 696 point customer service rep nice [[0.8580562]] NOTISSUE
# 697 do not have infrastructure provide basic level service [[0.14690576]] ISSUE
# 698 customer support system payroll upgrade product be scary [[0.14513111]] ISSUE
# 699 do not send receipt [[0.06155193]] ISSUE
# 700 receipt get be copy invoice be not format print correctly [[0.12188116]] ISSUE
# 701 be disturb be people suppose be account expert [[0.16481698]] ISSUE
# 702 start look alternative intuit obviously do not understand basic account audit principle [[0.09399045]] ISSUE
# 703 be thoroughly disappoint [[0.23050383]] ISSUE
# 704 be not do business company anymore give bad support [[0.04173393]] ISSUE
# 705 online information be exactly have cd [[0.6052623]] NOTISSUE
# 706 have not send coupon [[0.16022852]] ISSUE
# 707 bad [[0.05241448]] ISSUE
# 708 save money do not subscribe extend service [[0.13841796]] ISSUE
# 709 use customer service technical support give answer be vaguely relate problem [[0.21399152]] ISSUE
# 710 be emailinc time get nowhere [[0.20405254]] ISSUE
# 711 be largest technical software company world [[0.59957427]] NOTISSUE
# 712 have no technical support [[0.22959372]] ISSUE
# 713 worthless product horrible customer service [[0.08608918]] ISSUE
# 714 be unable access internet [[0.1937118]] ISSUE
# 715 no problem system become slow [[0.02847922]] ISSUE
# 716 customer service phone number be not user guide bury webster [[0.47118783]] ISSUE
# 717 reputation become exasperate script suggestion not resolve problem [[0.09654353]] ISSUE
# 718 feel bite fleece overprice subscription renewal year [[0.46250027]] ISSUE
# 719 decide give try [[0.5228973]] NOTISSUE
# 720 installation go smoothly everything seem fine [[0.63104755]] NOTISSUE
# 721 stall blank screen right window [[0.11076684]] ISSUE
# 722 hang forever [[0.45008978]] ISSUE
# 723 well present [[0.72212607]] NOTISSUE
# 724 easy follow along easy revisit previous lesson [[0.6372605]] NOTISSUE
# 725 video illustrate fretboard help see hear song be play [[0.464295]] ISSUE
# 726 not lot depth material [[0.22671846]] ISSUE
# 727 sing be slight destruction sometimes [[0.06770939]] ISSUE
# 728 material song not be everyone like [[0.27612877]] ISSUE
# 729 have find music book useful [[0.9090901]] NOTISSUE
# 730 probably not recommend be source learn guitar [[0.38416472]] ISSUE
# 731 like new look [[0.7118605]] NOTISSUE
# 732 i be have problem make transition [[0.19638363]] ISSUE
# 733 look create doom half life 2 recommend program [[0.45804748]] ISSUE
# 734 want make advance fps game simple pong game recommend dark basic [[0.3273168]] ISSUE
# 735 dark basic professional be probably capable create kind game come with [[0.818371]] NOTISSUE
# 736 have deal bad customer service [[0.10838524]] ISSUE
# 737 dark basic make manipulate d data extremely easy [[0.56903267]] NOTISSUE
# 738 have program yourself scratch [[0.42799965]] ISSUE
# 739 recommend [[0.6371221]] NOTISSUE
# 740 software be easy install easy use [[0.83375967]] NOTISSUE
# 741 be wonderful software [[0.95335895]] NOTISSUE
# 742 buy cd [[0.7910717]] NOTISSUE
# 743 do not waste money subscription merriam webster s webster [[0.13210009]] ISSUE
# 744 software be user friendly [[0.7355705]] NOTISSUE
# 745 be superb [[0.87307674]] NOTISSUE
# 746 try medical dictionary [[0.5267538]] NOTISSUE
# 747 be surprise find offer option strip code [[0.6028417]] NOTISSUE
# 748 compare old earlier version offer major improvement [[0.23830065]] ISSUE
# 749 be evolution [[0.3738048]] ISSUE
# 750 do offer major improvement flexibility previous version [[0.27441525]] ISSUE
# 751 good [[0.8128571]] NOTISSUE
# 752 simple easy use user friendly accurate pronunciation [[0.8917437]] NOTISSUE
# 753 horribly bad [[0.01917391]] ISSUE
# 754 good be able tweak dozen standard compliance [[0.76751125]] NOTISSUE
# 755 default thing not set up do take learn [[0.11583211]] ISSUE
# 756 move p100 fairly advance feature [[0.7560698]] NOTISSUE
# 757 anyhow call para professional version [[0.623284]] NOTISSUE
# 758 have way flexibility functionality version [[0.8376151]] NOTISSUE
# 759 be go bye bye [[0.29021022]] ISSUE
# 760 be please product [[0.5208883]] NOTISSUE
# 761 have trial version instal computer buy it [[0.5926858]] NOTISSUE
# 762 have do be enter code box be be [[0.21589956]] ISSUE
# 763 easy [[0.68851525]] NOTISSUE
# 764 be glad be able install one computer [[0.53018665]] NOTISSUE
# 765 be today best office suite microsoft have own [[0.8103404]] NOTISSUE
# 766 easy use excellent result [[0.8812436]] NOTISSUE
# 767 great sw [[0.9279221]] NOTISSUE
# 768 be easy learn [[0.7194128]] NOTISSUE
# 769 have good graphic [[0.7085902]] NOTISSUE
# 770 help visualize space [[0.540855]] NOTISSUE
# 771 see d [[0.59930253]] NOTISSUE
# 772 have not figure do [[0.11694102]] ISSUE
# 773 difficult change room s house s overall style start give design [[0.5022014]] NOTISSUE
# 774 recently buy version [[0.7478181]] NOTISSUE
# 775 instal software [[0.49945343]] ISSUE
# 776 everything operate well old personal computer [[0.5764395]] NOTISSUE
# 777 run lot faster [[0.36649927]] ISSUE
# 778 access corporate entrant [[0.27026948]] ISSUE
# 779 be awesome [[0.8994138]] NOTISSUE
# 780 give whirl [[0.53855723]] NOTISSUE
# 781 buy product again [[0.7405393]] NOTISSUE
# 782 five star them [[0.6620676]] NOTISSUE
# 783 great company deal [[0.9726972]] NOTISSUE
# 784 agree window improve thier product [[0.37923193]] ISSUE
# 785 linx be not user friendly [[0.37067947]] ISSUE
# 786 compatibility issue kill unix linx [[0.20173916]] ISSUE
# 787 unix be far stable [[0.48181748]] ISSUE
# 788 have access cd version [[0.7222142]] NOTISSUE
# 789 like [[0.5064771]] NOTISSUE
# 790 work well me [[0.88080704]] NOTISSUE
# 791 usually go disc want attempt [[0.12900616]] ISSUE
# 792 be lot cd [[0.7306288]] NOTISSUE
# 793 great program child learn difference [[0.9669807]] NOTISSUE
# 794 fun excellent way learn math [[0.9966313]] NOTISSUE
# 795 child love do too [[0.22470322]] ISSUE
# ...
# 3950 have be go two thousand seven meal have be awesome [[0.86097515]] NOTISSUE
# 3951 server be nice attentive serve staff [[0.97616404]] NOTISSUE
# 3952 cashier be friendly bring food me [[0.71817964]] NOTISSUE
# 3953 work hospitality industry paradise valley have refrain recommend ciob longer [[0.87457675]] NOTISSUE
# 3954 atmosphere be fun [[0.91469175]] NOTISSUE
# 3955 not recommend others [[0.26059365]] ISSUE
# 3956 service be quick to go order like like it [[0.4515908]] ISSUE
# 3957 mean really do get famous fish chip be terrible [[0.03719056]] ISSUE
# 3958 say mouth belly please [[0.3899258]] ISSUE
# 3959 not thing [[0.20570654]] ISSUE
# 3960 two thumb up [[0.39039207]] ISSUE
# 3961 read please do not go there [[0.1153]] ISSUE
# 3962 love grill pizza remind legitimate italian pizza [[0.93457556]] NOTISSUE
# 3963 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99958175]] NOTISSUE
# 3964 have nice atmosphere [[0.90820456]] NOTISSUE
# 3965 tonight have elk file special and suck [[0.42256653]] ISSUE
# 3966 one bite be hook [[0.22239524]] ISSUE
# 3967 order old classic new dish go time sorely disappoint everything [[0.35664788]] ISSUE
# 3968 cute quaint simple honest [[0.71490705]] NOTISSUE
# 3969 chicken be deliciously season have perfect fry outside moist chicken inside [[0.69920754]] NOTISSUE
# 3970 food be great always compliment chef [[0.9823025]] NOTISSUE
# 3971 special thank dylan t recommendation order yummy tummy [[0.99407166]] NOTISSUE
# 3972 awesome selection beer [[0.94770664]] NOTISSUE
# 3973 great food awesome service [[0.99708444]] NOTISSUE
# 3974 one nice thing be add gratuity bill party be larger six 8 not expect tip that [[0.4107835]] ISSUE
# 3975 fly be apple juice fly [[0.29336843]] ISSUE
# 3976 now nan chicken be tasty [[0.8773719]] NOTISSUE
# 3977 service think be good [[0.87848485]] NOTISSUE
# 3978 food be barely lukewarm have be sit wait server bring u [[0.07817917]] ISSUE
# 3979 ryan s bar be definitely one edinburgh establishment not be revisit [[0.30103093]] ISSUE
# 3980 nicest chinese restaurant have be while [[0.8952737]] NOTISSUE
# 3981 overall like food service [[0.490577]] ISSUE
# 3982 serve indian nan bread hummus spicy pine nut sauce be world [[0.90426475]] NOTISSUE
# 3983 probably never come back not recommend it [[0.1543767]] ISSUE
# 3984 friend s pasta bad barely touch it [[0.15041484]] ISSUE
# 3985 try airport experience tasty food speedy friendly service [[0.98361015]] NOTISSUE
# 3986 love decor chinese calligraphy wall paper [[0.9165909]] NOTISSUE
# 3987 never have complain here [[0.18398751]] ISSUE
# 3988 restaurant be clean have family restaurant feel it [[0.85911125]] NOTISSUE
# 3989 be way fry [[0.399059]] ISSUE
# 3990 be not sure long stand be long begin feel awkwardly place [[0.11330827]] ISSUE
# 3991 open sandwich be impress not good way [[0.31063506]] ISSUE
# 3992 not be back [[0.17772096]] ISSUE
# 3993 be warm feel service felt like guest special treat [[0.9696371]] NOTISSUE
# 3994 extensive menu provide lot option breakfast [[0.98389244]] NOTISSUE
# 3995 order vegetarian menu dinner have wide array option choose from [[0.97266823]] NOTISSUE
# 3996 have watch price inflate portion get smaller management attitude grow rapidly [[0.12264007]] ISSUE
# 3997 wonderful little tapa ambience make feel warm fuzzy inside [[0.9984353]] NOTISSUE
# 3998 get enjoy seafood salad fabulous vinaigrette [[0.9985474]] NOTISSUE
# 3999 wonton thin not thick chewy melt mouth [[0.13747814]] ISSUE
# 4000 level five spicy be perfect spice not over helm soup [[0.6946368]] NOTISSUE
# 4001 sit right time server get go be fantastic [[0.5492171]] NOTISSUE
# 4002 main thing not enjoy be crowd be older crowd middle thirty s up [[0.2690961]] ISSUE
# 4003 be town definitely be spot hit again [[0.4690928]] ISSUE
# 4004 have wait thirty minute get drink longer get two area [[0.1291643]] ISSUE
# 4005 be great place eat [[0.96980524]] NOTISSUE
# 4006 jalapeno bacon be soo good [[0.8810223]] NOTISSUE
# 4007 service be poor [[0.09603768]] ISSUE
# 4008 food be good service be good price good [[0.99461114]] NOTISSUE
# 4009 price good [[0.8597131]] NOTISSUE
# 4010 price good [[0.8597131]] NOTISSUE
# 4011 service be good [[0.8698162]] NOTISSUE
# 4012 place be not clean food oh stale [[0.02841088]] ISSUE
# 4013 chicken dish ok beef be like shoe leather [[0.4112996]] ISSUE
# 4014 service be bad [[0.05483458]] ISSUE
# 4015 be happy be here [[0.85127234]] NOTISSUE
# 4016 taste like dirt [[0.16475268]] ISSUE
# 4017 one place phoenix definately go back again [[0.5049619]] NOTISSUE
# 4018 block be amaze [[0.8120011]] NOTISSUE
# 4019 be close house be low key non fancy affordable price good food [[0.9615473]] NOTISSUE
# 4020 hot sour egg flower soup absolutely five star [[0.5628075]] NOTISSUE
# 4021 hashemi be poor quality be soggy tasteless [[0.01745727]] ISSUE
# 4022 great time family dinner sunday night [[0.9967361]] NOTISSUE
# 4023 food be not tasty all not say real traditional hunan style [[0.20364413]] ISSUE
# 4024 bother me be slow service [[0.0944484]] ISSUE
# 4025 flair bartender absolutely amaze [[0.9716196]] NOTISSUE
# 4026 freeze margarita way sugary taste [[0.2964456]] ISSUE
# 4027 good order twice [[0.85698175]] NOTISSUE
# 4028 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.07299326]] ISSUE
# 4029 girlfriend s veal be bad [[0.04191634]] ISSUE
# 4030 unfortunately be not good [[0.26452667]] ISSUE
# 4031 have pretty satisfy experience [[0.8064736]] NOTISSUE
# 4032 join club get awesome offer email [[0.9036048]] NOTISSUE
# 4033 perfect me like beer ice cold case colder [[0.6543544]] NOTISSUE
# 4034 bland flavourless be good way describe barely tepid meat [[0.05075179]] ISSUE
# 4035 chain be no fan of beat place easily [[0.18895604]] ISSUE
# 4036 nacho have [[0.5796969]] NOTISSUE
# 4037 not be come back [[0.16251469]] ISSUE
# 4038 do not have word say place do everything pretty well [[0.16629064]] ISSUE
# 4039 staff be super nice quick crazy crowd downtown jury lawyer court staff [[0.97260195]] NOTISSUE
# 4040 great atmosphere friendly fast service [[0.99876404]] NOTISSUE
# 4041 receive pity be huge have lot meat thumb there [[0.23842755]] ISSUE
# 4042 food arrive be me [[0.4031308]] ISSUE
# 4043 pay 7 85 hot dog fry look like come kid s meal wienerschnitzel be not idea good meal [[0.26591673]] ISSUE
# 4044 classic maine lobster roll be fantastic [[0.98814684]] NOTISSUE
# 4045 brother law work mall eat day guess be sick night too [[0.05632573]] ISSUE
# 4046 good be go have review place twice [[0.85183156]] NOTISSUE
# 4047 chip salsa good salsa be fresh [[0.9908506]] NOTISSUE
# 4048 place be great [[0.95056504]] NOTISSUE
# 4049 mediocre food [[0.12442417]] ISSUE
# 4050 get inside be impress place [[0.51538444]] NOTISSUE
# 4051 be super piss [[0.35692072]] ISSUE
# 4052 service be super friendly [[0.9130705]] NOTISSUE
# 4053 sad little vegetable overcook [[0.07249308]] ISSUE
# 4054 place be nice surprise [[0.91250676]] NOTISSUE
# 4055 live music totally blow [[0.22638306]] ISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                 be look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6           display be excellent camera be good year  NOTISSUE
#  7              7                              battery life be great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10        be embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  be average phone bad battery life operate weak...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18      try handsfree gadget be one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution be far comparably price pho...     ISSUE
#  27            27                                      be great deal  NOTISSUE
#  28            28              excellent product be satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4025        4025                  freeze margarita way sugary taste     ISSUE
#  4026        4026                                   good order twice  NOTISSUE
#  4027        4027  nutshell 1 restaurant smell like combination d...     ISSUE
#  4028        4028                           girlfriend s veal be bad     ISSUE
#  4029        4029                          unfortunately be not good     ISSUE
#  4030        4030                     have pretty satisfy experience  NOTISSUE
#  4031        4031                  join club get awesome offer email  NOTISSUE
#  4032        4032          perfect me like beer ice cold case colder  NOTISSUE
#  4033        4033  bland flavourless be good way describe barely ...     ISSUE
#  4034        4034               chain be no fan of beat place easily     ISSUE
#  4035        4035                                         nacho have  NOTISSUE
#  4036        4036                                   not be come back     ISSUE
#  4037        4037  do not have word say place do everything prett...  NOTISSUE
#  4038        4038  staff be super nice quick crazy crowd downtown...  NOTISSUE
#  4039        4039             great atmosphere friendly fast service  NOTISSUE
#  4040        4040     receive pity be huge have lot meat thumb there  NOTISSUE
#  4041        4041                                  food arrive be me     ISSUE
#  4042        4042  pay 7 85 hot dog fry look like come kid s meal...     ISSUE
#  4043        4043            classic maine lobster roll be fantastic  NOTISSUE
#  4044        4044  brother law work mall eat day guess be sick ni...     ISSUE
#  4045        4045                 good be go have review place twice  NOTISSUE
#  4046        4046                     chip salsa good salsa be fresh  NOTISSUE
#  4047        4047                                     place be great  NOTISSUE
#  4048        4048                                      mediocre food     ISSUE
#  4049        4049                        get inside be impress place  NOTISSUE
#  4050        4050                                      be super piss     ISSUE
#  4051        4051                          service be super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                             place be nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#
#  [4055 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4        ISSUE                 be look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE           display be excellent camera be good year
#  7     NOTISSUE                              battery life be great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE        be embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  be average phone bad battery life operate weak...
#  13    NOTISSUE       clear skye call long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16       ISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE      try handsfree gadget be one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25       ISSUE                                       exactly want
#  26    NOTISSUE  picture resolution be far comparably price pho...
#  27    NOTISSUE                                      be great deal
#  28    NOTISSUE              excellent product be satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4025     ISSUE                  freeze margarita way sugary taste
#  4026  NOTISSUE                                   good order twice
#  4027     ISSUE  nutshell 1 restaurant smell like combination d...
#  4028     ISSUE                           girlfriend s veal be bad
#  4029     ISSUE                          unfortunately be not good
#  4030  NOTISSUE                     have pretty satisfy experience
#  4031  NOTISSUE                  join club get awesome offer email
#  4032  NOTISSUE          perfect me like beer ice cold case colder
#  4033     ISSUE  bland flavourless be good way describe barely ...
#  4034     ISSUE               chain be no fan of beat place easily
#  4035  NOTISSUE                                         nacho have
#  4036     ISSUE                                   not be come back
#  4037     ISSUE  do not have word say place do everything prett...
#  4038  NOTISSUE  staff be super nice quick crazy crowd downtown...
#  4039  NOTISSUE             great atmosphere friendly fast service
#  4040     ISSUE     receive pity be huge have lot meat thumb there
#  4041     ISSUE                                  food arrive be me
#  4042     ISSUE  pay 7 85 hot dog fry look like come kid s meal...
#  4043  NOTISSUE            classic maine lobster roll be fantastic
#  4044     ISSUE  brother law work mall eat day guess be sick ni...
#  4045  NOTISSUE                 good be go have review place twice
#  4046  NOTISSUE                     chip salsa good salsa be fresh
#  4047  NOTISSUE                                     place be great
#  4048     ISSUE                                      mediocre food
#  4049  NOTISSUE                        get inside be impress place
#  4050     ISSUE                                      be super piss
#  4051  NOTISSUE                          service be super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                             place be nice surprise
#  4054     ISSUE                            live music totally blow
#
#  [4055 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4     ISSUE                 be look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2324
# NOTISSUE    1731
# Name: label, dtype: int64

# %% [markdown]
# ### confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1874  153]
#  [ 450 1578]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="red" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8512946979038224
#               precision    recall  f1-score   support
#
#        ISSUE       0.81      0.92      0.86      2027
#     NOTISSUE       0.91      0.78      0.84      2028
#
#    micro avg       0.85      0.85      0.85      4055
#    macro avg       0.86      0.85      0.85      4055
# weighted avg       0.86      0.85      0.85      4055

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_brute.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                     not be happier
# 1     NOTISSUE      ISSUE                 be look headset long time have get
# 2     NOTISSUE      ISSUE   take self portrait outside exterior display cool
# 3     NOTISSUE      ISSUE                                       exactly want
# 4        ISSUE   NOTISSUE  picture resolution be far comparably price pho...
# 5     NOTISSUE      ISSUE                                     prompt service
# 6        ISSUE   NOTISSUE  be stupid have keep buy new charger car charge...
# 7     NOTISSUE      ISSUE            be phone have have have be cheaply make
# 8     NOTISSUE      ISSUE                             do not make mistake do
# 9     NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 10    NOTISSUE      ISSUE               find cell phone right away enter car
# 11    NOTISSUE      ISSUE  do get better reception clarity phone have hav...
# 12    NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 13    NOTISSUE      ISSUE                         be nothing bad say headset
# 14    NOTISSUE      ISSUE                               no buyer remorse one
# 15    NOTISSUE      ISSUE           update procedure be difficult cumbersome
# 16       ISSUE   NOTISSUE                                     like return it
# 17    NOTISSUE      ISSUE  keyboard be worthwhile usefulness be sturdy do...
# 18    NOTISSUE      ISSUE                                      not regret it
# 19    NOTISSUE      ISSUE                                      work describe
# 20    NOTISSUE      ISSUE       sound be clear people talk amaze quality too
# 21    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 22       ISSUE   NOTISSUE                    none new one have work properly
# 23    NOTISSUE      ISSUE             no shift no bubble no peel not scratch
# 24    NOTISSUE      ISSUE                       not be happier new one droid
# 25    NOTISSUE      ISSUE         virgin wireless rock do cheap little phone
# 26    NOTISSUE      ISSUE                            please dont waste money
# 27       ISSUE   NOTISSUE      look good quality headset keep look be not it
# 28    NOTISSUE      ISSUE                        no problem come time expect
# 29       ISSUE   NOTISSUE                                                hat
# ..         ...        ...                                                ...
# 573   NOTISSUE      ISSUE                                 worst martini ever
# 574   NOTISSUE      ISSUE           yellowtail capriccio be melt mouth fresh
# 575   NOTISSUE      ISSUE   night be second time din be happy decide go back
# 576   NOTISSUE      ISSUE            not have be please quality food service
# 577   NOTISSUE      ISSUE             do recommend place go wrong dont place
# 578      ISSUE   NOTISSUE  salad have bland vinaigrette baby green heart ...
# 579      ISSUE   NOTISSUE                new location need complete overhaul
# 580   NOTISSUE      ISSUE                                                rat
# 581      ISSUE   NOTISSUE                  look authentic thai food go where
# 582   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 583   NOTISSUE      ISSUE                               not ask satisfy meal
# 584   NOTISSUE      ISSUE  make drive way north scottsdale be not one bit...
# 585      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 586      ISSUE   NOTISSUE                              be not fun experience
# 587   NOTISSUE      ISSUE     owner use work nob place be similar half price
# 588   NOTISSUE      ISSUE                             promise not disappoint
# 589   NOTISSUE      ISSUE                                       wait go back
# 590      ISSUE   NOTISSUE                           staff spend time talk me
# 591   NOTISSUE      ISSUE          service be quick to go order like like it
# 592   NOTISSUE      ISSUE                             say mouth belly please
# 593   NOTISSUE      ISSUE                                       two thumb up
# 594   NOTISSUE      ISSUE                                   one bite be hook
# 595   NOTISSUE      ISSUE  one nice thing be add gratuity bill party be l...
# 596   NOTISSUE      ISSUE                          overall like food service
# 597   NOTISSUE      ISSUE                           never have complain here
# 598   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 599   NOTISSUE      ISSUE               be town definitely be spot hit again
# 600   NOTISSUE      ISSUE  do not have word say place do everything prett...
# 601   NOTISSUE      ISSUE     receive pity be huge have lot meat thumb there
# 602   NOTISSUE      ISSUE                            live music totally blow
#
# [603 rows x 3 columns]
