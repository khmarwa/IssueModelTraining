# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# Using TensorFlow backend.
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('DATA/data.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #balanced Dataset
# Out:
# ISSUE       2034
# NOTISSUE    2022
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4056, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();
# Out:
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\khmar\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 #'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 #'becomes',
 #'becoming',
 #'been',
 'before',
 'beforehand',
 #'behind',
 #'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 #'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 #'show',
 'side',
 'since',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
"couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
        "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re
# Out:
# C:\Users\khmar\ana\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def replace_word(word):
    # Convert text to lower
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Removing all the tokens with lesser than 3 characters
    #text = gensim.corpora.textcorpus.remove_short(text, minsize=3)
    
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    
    
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        
        ##### Lemmatization
        # Reduce words to their root form
        # Lemmatize verbs by specifying pos
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

##Fixing Word Lengthening
##https://rustyonrampa"ge.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    text = reduce_lengthening(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText(" she'd've I have so 20 soooooo don't i'm  can't servic going grooooooooop")
# Out:
# 'have have twenty soo do not be service go group'

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
#df=df[texts,tags]

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('Data/DATA_preprocessing6.csv')

# %%
####

# %%
DATA_FILE = 'Data/DATA_preprocessing5.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2812, 3)
# (1244, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# ISSUE       1412
# NOTISSUE    1400
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# NOTISSUE    625
# ISSUE       619
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# ISSUE       1412
# NOTISSUE    1400
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
# Out:
# C:\Users\khmar\ana\lib\site-packages\keras_preprocessing\text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2812, 200)
# Shape of test_data tensor: (1244, 200)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3131 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2812, 200)
# Shape of data test tensor: (1244, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : flavourful
# word not found : cosiness
# word not found : shawarrma
# word not found : profiterole
# word not found : ciob
# word not found : 89900
# word not found : barset
# word not found : notslide
# word not found : 5320
# word not found : supertooth
# word not found : emailinc
# word not found : convertor
# word not found : nottranslate
# word not found : appal
# word not found : convolute
# word not found : stylize
# word not found : mesmerise
# word not found : brainsucking
# word not found : infatuate
# word not found : riingtones
# word not found : nomole
# word not found : hydrabrush
# word not found : cheesecurds
# word not found : flavourless
# word not found : douchebaggery
# word not found : untasted
# word not found : smashburger

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 27 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2812 samples, validate on 1244 samples
# Epoch 1/2
# 2812/2812 [==============================] - 29s 10ms/step - loss: 0.5237 - acc: 0.7585 - val_loss: 0.4942 - val_acc: 0.7846
# Epoch 2/2
# 2812/2812 [==============================] - 23s 8ms/step - loss: 0.4121 - acc: 0.8261 - val_loss: 0.4055 - val_acc: 0.8304

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1244/1244 [==============================] - 2s 2ms/step
# loss: 40.55%
# acc: 83.04%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v7.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great product"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.9610605]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.31462824]]
# ISSUE

# %%
text=" very recommend"
text=transformText(text)
print(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# recommend
# [[0.66465586]]
# NOTISSUE

# %%
#predict all data

# %%
input_file ='DATA/DATA_preprocessing5.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text_v7.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.75149596]] NOTISSUE
# 2 love phone [[0.916521]] NOTISSUE
# 3 get well finish product [[0.78837943]] NOTISSUE
# 4 not be happier [[0.2771899]] ISSUE
# 5 look headset long time have get [[0.69288146]] NOTISSUE
# 6 headset start ring no reason [[0.21302007]] ISSUE
# 7 display excellent camera good year [[0.9962231]] NOTISSUE
# 8 battery life great [[0.98158056]] NOTISSUE
# 9 worst phone have have have month [[0.16547227]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.14836124]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.16096665]] ISSUE
# 12 protect phone side [[0.7352834]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.07115526]] ISSUE
# 14 clear skye call long battery life long range [[0.84843165]] NOTISSUE
# 15 solo technology suck [[0.50570554]] NOTISSUE
# 16 great hand free device [[0.9785381]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.90035087]] NOTISSUE
# 18 problem have mention [[0.1153127]] ISSUE
# 19 try handsfree gadget one finally work well [[0.9610742]] NOTISSUE
# 20 magical help [[0.59511715]] NOTISSUE
# 21 worst piece crap version customer service [[0.12538625]] ISSUE
# 22 poor sound quality [[0.1952602]] ISSUE
# 23 best phone market [[0.88059855]] NOTISSUE
# 24 work well [[0.843457]] NOTISSUE
# 25 company ship product promptly work well [[0.6284375]] NOTISSUE
# 26 exactly want [[0.59607655]] NOTISSUE
# 27 picture resolution far comparably price phone offer today [[0.8885425]] NOTISSUE
# 28 great deal [[0.95679814]] NOTISSUE
# 29 excellent product be satisfy purchase [[0.9792631]] NOTISSUE
# 30 highly recommend encourage people give try [[0.8175539]] NOTISSUE
# 31 better expect [[0.7678676]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.30575198]] ISSUE
# 33 great product price [[0.96961075]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.9940749]] NOTISSUE
# 35 disappointment [[0.22343391]] ISSUE
# 36 prompt service [[0.46061602]] ISSUE
# 37 excellent product price [[0.96933347]] NOTISSUE
# 38 please headset [[0.54595184]] NOTISSUE
# 39 do not waste money time [[0.06164458]] ISSUE
# 40 especially love long battery life [[0.9769537]] NOTISSUE
# 41 stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.87263626]] NOTISSUE
# 42 work great [[0.9633322]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.99578226]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice bad service [[0.16353366]] ISSUE
# 45 be look new earpiece [[0.64157003]] NOTISSUE
# 46 be look new earpiece jawbone era awesome too [[0.72481537]] NOTISSUE
# 47 receive white color battery go dead couple hours the original use week last longer the replacement [[0.13392761]] ISSUE
# 48 year battery go completely dead headset [[0.17132308]] ISSUE
# 49 have use phone two year one best [[0.86941904]] NOTISSUE
# 50 awesome new look fall 200 [[0.8457588]] NOTISSUE
# 51 phone have have have be cheaply make [[0.6252911]] NOTISSUE
# 52 att not clear sound distort have yell talk [[0.11200385]] ISSUE
# 53 price good too [[0.75172585]] NOTISSUE
# 54 plastic break easy clip [[0.49245498]] ISSUE
# 55 do not make mistake do [[0.04506306]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.269941]] ISSUE
# 57 be river spine with case fit fine [[0.9095385]] NOTISSUE
# 58 area unit break be not fond magnetic strap [[0.27429137]] ISSUE
# 59 overall be psyched have phone have appointment contact get great reception [[0.9070623]] NOTISSUE
# 60 thing phone work perfectly like it [[0.9712983]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.2436821]] ISSUE
# 62 easy [[0.77727884]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.11271346]] ISSUE
# 64 fantastic earphone [[0.8325108]] NOTISSUE
# 65 find cell phone right away enter car [[0.47717562]] ISSUE
# 66 low quality [[0.45932326]] ISSUE
# 67 do get better reception clarity phone have have before [[0.6511198]] NOTISSUE
# 68 warn stay away [[0.16238149]] ISSUE
# 69 wish return unit get back money [[0.57118094]] NOTISSUE
# 70 awesome device work great [[0.9973826]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.02956901]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.09453305]] ISSUE
# 73 displease [[0.20524223]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.355905]] ISSUE
# 75 make case small difficult install [[0.28345832]] ISSUE
# 76 restore phone like new performance [[0.88620555]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.8101352]] NOTISSUE
# 78 search internet find one be best value [[0.90613]] NOTISSUE
# 79 do not fit [[0.19667962]] ISSUE
# 80 happy product [[0.88312095]] NOTISSUE
# 81 screen size big key pad light well enough camera quality excellent camera phone [[0.983107]] NOTISSUE
# 82 nothing bad say headset [[0.06809582]] ISSUE
# 83 be glad find product amazon hard find not high price [[0.47165984]] ISSUE
# 84 portable work [[0.6396737]] NOTISSUE
# 85 colleague get great reception a little expensive performance great [[0.9879659]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.13813287]] ISSUE
# 87 have have problem phone read memory card turn again [[0.3761447]] ISSUE
# 88 not good wear hat sunglass [[0.33683744]] ISSUE
# 89 timely shipment quality product [[0.4978159]] ISSUE
# 90 nice solid keyboard [[0.9894555]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.9855435]] NOTISSUE
# 92 horrible phone [[0.15305892]] ISSUE
# 93 bt battery junk [[0.40688917]] ISSUE
# 94 recommend others [[0.61053205]] NOTISSUE
# 95 not get software work computer [[0.28260115]] ISSUE
# 96 disappoint [[0.22173728]] ISSUE
# 97 poor voice clarity [[0.44794205]] ISSUE
# 98 battery work great [[0.97425735]] NOTISSUE
# 99 no buyer remorse one [[0.11715785]] ISSUE
# 100 disappoint accessory [[0.19550781]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.08656152]] ISSUE
# 102 look great strong [[0.98167163]] NOTISSUE
# 103 have have mobile service two year now be pretty happy it [[0.98501575]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.08591892]] ISSUE
# 105 disappointment hate go ear [[0.11781578]] ISSUE
# 106 great software motorola [[0.95804626]] NOTISSUE
# 107 delivery time [[0.61938906]] NOTISSUE
# 108 easy use [[0.778749]] NOTISSUE
# 109 uncomfortable ear do house lg 89900 env [[0.4339703]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.46376207]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.9395273]] NOTISSUE
# 112 like return it [[0.7041058]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy do not expect problem [[0.26730835]] ISSUE
# 114 version s bill however difficult understand price plan simple [[0.41994274]] ISSUE
# 115 charge overnight battery work great [[0.92437726]] NOTISSUE
# 116 wil not regret it [[0.14705263]] ISSUE
# 117 love phone [[0.916521]] NOTISSUE
# 118 disappointment [[0.22343391]] ISSUE
# 119 not user friendly [[0.4582155]] ISSUE
# 120 unfortunately ability actually know receive call important feature phone pitiful respect [[0.5773491]] NOTISSUE
# 121 exchange phone have problem [[0.40881902]] ISSUE
# 122 result phone be stick max volume mute [[0.15284665]] ISSUE
# 123 public display affection rock [[0.87202805]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.90364444]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.9960626]] NOTISSUE
# 126 have version two year ago like service [[0.71198803]] NOTISSUE
# 127 pretty piece junk [[0.5127142]] NOTISSUE
# 128 plug wrong size [[0.2642289]] ISSUE
# 129 work describe [[0.43920764]] ISSUE
# 130 save money have have item month now [[0.44866621]] ISSUE
# 131 bad purchase [[0.1119139]] ISSUE
# 132 well im satisfy [[0.89164114]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.7830937]] NOTISSUE
# 134 battery excellent bargain [[0.9736109]] NOTISSUE
# 135 defective crap [[0.06478837]] ISSUE
# 136 have give no star able [[0.4894111]] ISSUE
# 137 wear glass fit fine them [[0.8916398]] NOTISSUE
# 138 sound quality device unacceptable unless quiet area hear nothing [[0.20265299]] ISSUE
# 139 not recommend item anyone [[0.20006411]] ISSUE
# 140 holster arrive not match photo ad [[0.18287505]] ISSUE
# 141 great no problem all [[0.64279604]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.22777171]] ISSUE
# 143 frog phone charm adorable eye catch [[0.9104469]] NOTISSUE
# 144 never know push hard right number time function want not [[0.32691807]] ISSUE
# 145 sound clear people talk amaze quality too [[0.572985]] NOTISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.95271295]] NOTISSUE
# 147 good product well make [[0.9681322]] NOTISSUE
# 148 mobile phone tool have [[0.85107666]] NOTISSUE
# 149 be impress job motorola steadiness phone [[0.79779214]] NOTISSUE
# 150 receive order well ship timeframe everything good work order overall be excite have source [[0.8330384]] NOTISSUE
# 151 phone sturdy waterproof [[0.7648899]] NOTISSUE
# 152 be not impress not recommend item anyone [[0.0956053]] ISSUE
# 153 complaint standard sound volume little low turn 5 of 5 [[0.12570955]] ISSUE
# 154 thank again amazon have thing need good price [[0.9543584]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.21613395]] ISSUE
# 156 have go store buy new nokia phone work great [[0.9716646]] NOTISSUE
# 157 work great [[0.9633322]] NOTISSUE
# 158 ugly [[0.06853841]] ISSUE
# 159 horrible have switch time [[0.12715374]] ISSUE
# 160 noise shield incredible [[0.7553488]] NOTISSUE
# 161 no real improvement [[0.17385368]] ISSUE
# 162 razor battery good buy [[0.97832346]] NOTISSUE
# 163 keep good work amazon [[0.9502572]] NOTISSUE
# 164 refuse refund replace [[0.08400955]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.78125423]] NOTISSUE
# 166 basically throw money window nothing [[0.09547557]] ISSUE
# 167 great case price [[0.94946516]] NOTISSUE
# 168 take one drop six inch kitchen counter crack i be not impress be not laugh [[0.07187775]] ISSUE
# 169 bluetooth range good day ago leave phone trunk get call carry conversation hitch [[0.7216886]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.99461997]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.6235757]] NOTISSUE
# 172 none new one have work properly [[0.36858952]] ISSUE
# 173 be glad purchase it [[0.86151123]] NOTISSUE
# 174 have miss numerous call reason [[0.36014286]] ISSUE
# 175 phone defective people hear use this [[0.33276147]] ISSUE
# 176 do notably product [[0.3073308]] ISSUE
# 177 suck stuff do not work phone [[0.12678812]] ISSUE
# 178 no shift no bubble no peel not scratch nothing i note happier new one droid [[0.14416619]] ISSUE
# 179 worst software use give zero star would [[0.16516815]] ISSUE
# 180 try make call exercise frustration [[0.13383588]] ISSUE
# 181 case flimsy piece plastic have no protection whatsoever [[0.05363893]] ISSUE
# 182 cabra barset happy it sound quality especially outgo better [[0.92670095]] NOTISSUE
# 183 love camera pretty good quality [[0.99766254]] NOTISSUE
# 184 thank great service [[0.99381024]] NOTISSUE
# 185 total package [[0.65680283]] NOTISSUE
# 186 seller understand patient definitely buy again [[0.9015633]] NOTISSUE
# 187 give firefly one star i contact singular at t inform practice [[0.48733068]] ISSUE
# 188 aggravate [[0.14141993]] ISSUE
# 189 great product price [[0.96961075]] NOTISSUE
# 190 have purchase family friend enjoy clarity ease use [[0.9955728]] NOTISSUE
# 191 virgin wireless rock do cheap little phone [[0.7229133]] NOTISSUE
# 192 none work [[0.47287086]] ISSUE
# 193 do notably it [[0.444605]] ISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide off [[0.05411576]] ISSUE
# 195 please do not waste money [[0.08310883]] ISSUE
# 196 all be satisfy purchase [[0.75589705]] NOTISSUE
# 197 look good quality headset keep look nott [[0.933895]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.5275784]] NOTISSUE
# 199 not best one [[0.51643676]] NOTISSUE
# 200 best one [[0.88600487]] NOTISSUE
# 201 disappoint result [[0.08156546]] ISSUE
# 202 cumbersome design [[0.3232903]] ISSUE
# 203 great new package nice work good [[0.99951386]] NOTISSUE
# 204 no problem come time expect [[0.1554291]] ISSUE
# 205 great product [[0.9610605]] NOTISSUE
# 206 piece crap [[0.24603042]] ISSUE
# 207 experience terrible [[0.1900329]] ISSUE
# 208 fourth bluetooth headset [[0.6217634]] NOTISSUE
# 209 comfortable one [[0.933946]] NOTISSUE
# 210 hat [[0.6329307]] NOTISSUE
# 211 fix problem [[0.13325089]] ISSUE
# 212 worst ever [[0.09163389]] ISSUE
# 213 be happy [[0.8279531]] NOTISSUE
# 214 have have no trouble access internet download intone perform function [[0.53762525]] NOTISSUE
# 215 barely hear be constantly say what [[0.19044814]] ISSUE
# 216 battery life highly unacceptable [[0.33058193]] ISSUE
# 217 company joke [[0.31705505]] ISSUE
# 218 do everything description say would [[0.31058028]] ISSUE
# 219 happen call force stop headset [[0.15789834]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.9867379]] NOTISSUE
# 221 version tech support walk procedure none work end have do hard re set wipe data [[0.14253487]] ISSUE
# 222 voice quality signal strength drop call [[0.28074008]] ISSUE
# 223 play louder speaker size price low think quality lack however not [[0.09768245]] ISSUE
# 224 better expect [[0.7678676]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push them [[0.38021696]] ISSUE
# 226 battery hold well [[0.8795262]] NOTISSUE
# 227 difficult on i d recommend avoid product [[0.1869427]] ISSUE
# 228 use two day not easy hear with [[0.4798397]] ISSUE
# 229 get car charger not week charger break i go plug start smoke [[0.20594431]] ISSUE
# 230 sprint terrible customer service [[0.40288526]] ISSUE
# 231 link phone effort [[0.43224418]] ISSUE
# 232 cool [[0.7567638]] NOTISSUE
# 233 easy use [[0.778749]] NOTISSUE
# 234 better new [[0.8393063]] NOTISSUE
# 235 posse get junk have no idea [[0.19328204]] ISSUE
# 236 piece trash [[0.17827407]] ISSUE
# 237 pretty good product [[0.97160184]] NOTISSUE
# 238 great phone [[0.9555412]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.9775547]] NOTISSUE
# 240 research development division obviously know do [[0.6580722]] NOTISSUE
# 241 real killer volume course break [[0.22494067]] ISSUE
# 242 phone work fine now [[0.92994213]] NOTISSUE
# 243 be happy product one [[0.85142416]] NOTISSUE
# 244 poor construction [[0.08853798]] ISSUE
# 245 infuriate [[0.49334857]] ISSUE
# 246 overall recommend phone new walkman [[0.79343176]] NOTISSUE
# 247 sprint charge service [[0.7154658]] NOTISSUE
# 248 cheap feel look cheap [[0.6910189]] NOTISSUE
# 249 fit ear well comfortable on [[0.9870264]] NOTISSUE
# 250 do network europe asia [[0.26683763]] ISSUE
# 251 clip belt definitely make feel like fifty cent s up and come [[0.88785917]] NOTISSUE
# 252 like design look cabra be ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.5482135]] NOTISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.8520252]] NOTISSUE
# 254 worst phone samsung crap crappy samsung 1715 worst have see [[0.14850724]] ISSUE
# 255 charger work week completely stop charge phone [[0.28219798]] ISSUE
# 256 poor product [[0.10338198]] ISSUE
# 257 need better instruction [[0.7933198]] NOTISSUE
# 258 need two hand operate screen this software interface decade old compete new software design [[0.86306673]] NOTISSUE
# 259 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.95053905]] NOTISSUE
# 260 steer clear product go genuine palm replacement pen come three pack [[0.6829619]] NOTISSUE
# 261 do not buy do not but suck [[0.03629363]] ISSUE
# 262 great product sure beat finger [[0.9512673]] NOTISSUE
# 263 plus seriously do not believe worth steep price point [[0.10591058]] ISSUE
# 264 case have try normally fall apart month one seem be long haul [[0.14014286]] ISSUE
# 265 disappoint performance [[0.22897202]] ISSUE
# 266 do normale mistake please do notably phone [[0.1902614]] ISSUE
# 267 phone well be worst have have brand [[0.2977523]] ISSUE
# 268 case extra originally later discard scratch ear [[0.3250762]] ISSUE
# 269 recommend go different brand cell phone mp player family [[0.9270522]] NOTISSUE
# 270 do not bother go store [[0.05612182]] ISSUE
# 271 post detail comment grey black phone have fire red great color [[0.6708656]] NOTISSUE
# 272 not have problem item order again need [[0.18765183]] ISSUE
# 273 get pay guess [[0.2894338]] ISSUE
# 274 not software do great job this make intone form exist cd internet connection [[0.6750579]] NOTISSUE
# 275 im surprise good quality car charger not review it [[0.9704497]] NOTISSUE
# 276 fabulous [[0.9049249]] NOTISSUE
# 277 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.10105433]] ISSUE
# 278 price cable excellent [[0.95306313]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.6077144]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end call [[0.07499457]] ISSUE
# 281 wind resistant [[0.304962]] ISSUE
# 282 obviously have terrible customer service get pay for [[0.2930048]] ISSUE
# 283 do not forever [[0.11068751]] ISSUE
# 284 it not overly expensive replace [[0.08703755]] ISSUE
# 285 easy operate sound better have try [[0.86735487]] NOTISSUE
# 286 contact company tell that unit warranty not produce receipt luck [[0.06884483]] ISSUE
# 287 link have way exchange bad phone return unit something [[0.17743069]] ISSUE
# 288 phone sturdy nokia bar phone be [[0.94739234]] NOTISSUE
# 289 great phone [[0.9555412]] NOTISSUE
# 290 place tree case not not snug lot extra room side [[0.24538018]] ISSUE
# 291 be please [[0.5923473]] NOTISSUE
# 292 battery terrible [[0.11972982]] ISSUE
# 293 find product be easy set use [[0.7250257]] NOTISSUE
# 294 earpiece large heavy it keep fall ear [[0.3483344]] ISSUE
# 295 utter crap sound quality terrible [[0.01805499]] ISSUE
# 296 charger arrive promise timeframe not work [[0.42356604]] ISSUE
# 297 no ear loop need tiny sound great [[0.9102231]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.09824657]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.94082874]] NOTISSUE
# 300 talk useless customer service [[0.15593311]] ISSUE
# 301 felt light tinny [[0.36276174]] ISSUE
# 302 do not fit palm tungsten e2 break time try plug in [[0.25937134]] ISSUE
# 303 be happy purchase good quality low price [[0.96570724]] NOTISSUE
# 304 love look feel samsung flip phone [[0.9211311]] NOTISSUE
# 305 well design sharp blue nice color [[0.9932411]] NOTISSUE
# 306 do everything more [[0.5066909]] NOTISSUE
# 307 not recommend more [[0.38933498]] ISSUE
# 308 nice sound [[0.95088214]] NOTISSUE
# 309 look good picture case huge disappointment [[0.5921333]] NOTISSUE
# 310 jawbone go replace with [[0.4383564]] ISSUE
# 311 setup go smoothly [[0.7771253]] NOTISSUE
# 312 extremely slow take forever do it [[0.162914]] ISSUE
# 313 study interest worst sin industrial design [[0.09797388]] ISSUE
# 314 thing happen track off [[0.27215412]] ISSUE
# 315 well make easy access phone have handy detachable belt clip [[0.9458189]] NOTISSUE
# 316 have continue pair periodically keep drop [[0.5749042]] NOTISSUE
# 317 not unload intone party [[0.14082639]] ISSUE
# 318 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.45346877]] ISSUE
# 319 truly awful [[0.27023634]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear out battery do [[0.7013128]] NOTISSUE
# 321 volume ringer real good you have choice loud one [[0.92846954]] NOTISSUE
# 322 none tone acceptable [[0.21994272]] ISSUE
# 323 camera color balance awful [[0.5488314]] NOTISSUE
# 324 product clearly not ready prime time do netware cool look not tell call come worthless [[0.03977198]] ISSUE
# 325 love intone upbeat [[0.86020416]] NOTISSUE
# 326 chinese forgery abound [[0.56373745]] NOTISSUE
# 327 easy pair samsung cell [[0.9197428]] NOTISSUE
# 328 instruction not explain microphone jack be use [[0.19956873]] ISSUE
# 329 advise not purchase item never work well [[0.37834162]] ISSUE
# 330 bad have pay month service [[0.05259012]] ISSUE
# 331 work well [[0.843457]] NOTISSUE
# 332 nokia ca 42 usb cable not work phone [[0.6467967]] NOTISSUE
# 333 clear crisp sound [[0.7449427]] NOTISSUE
# 334 have use smallest earpiece provide stay pretty well [[0.98065484]] NOTISSUE
# 335 biggest complaint have be battery drain superfast [[0.17165664]] ISSUE
# 336 design be ergonomic theory not stand have ear [[0.26247007]] ISSUE
# 337 do not buy want use holster [[0.23675905]] ISSUE
# 338 phone take great picture video clip [[0.9366845]] NOTISSUE
# 339 do normale look cool [[0.73338646]] NOTISSUE
# 340 ear occupy background not distract all [[0.1233773]] ISSUE
# 341 comfortable fit need headset be comfortable hour time not entire day [[0.88135034]] NOTISSUE
# 342 also phone do not seem accept cbr mp s preferably rip window medium player [[0.32473683]] ISSUE
# 343 not beat price these [[0.32925794]] ISSUE
# 344 come strong light use light camera shot flash so signal seriously [[0.523813]] NOTISSUE
# 345 lightweight work well [[0.96567786]] NOTISSUE
# 346 beware [[0.27579585]] ISSUE
# 347 love cable allow connect mini usb device pc [[0.93711257]] NOTISSUE
# 348 near hear conversation [[0.5501705]] NOTISSUE
# 349 cool case open allow screen get scratch up one [[0.48279247]] ISSUE
# 350 buy phone replacement start have regret since [[0.2710715]] ISSUE
# 351 appear actually outperform original battery china come a325 i [[0.6900816]] NOTISSUE
# 352 not store phone number sim [[0.43322763]] ISSUE
# 353 last o minute actually try use phone my wife have phone problem [[0.31808376]] ISSUE
# 354 poor quality [[0.13483283]] ISSUE
# 355 cabra ear gel r best [[0.84692764]] NOTISSUE
# 356 not worth it [[0.3492888]] ISSUE
# 357 phone crash completely have get replace [[0.10964119]] ISSUE
# 358 quit work have use eighteen month purchase one best headset have own [[0.6700518]] NOTISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.43510714]] ISSUE
# 360 great phone [[0.9555412]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.09311397]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.96063066]] NOTISSUE
# 363 phone do notslide car grip prevent phone slip hand [[0.33179182]] ISSUE
# 364 simply best bluetooth headset sound quality [[0.93613255]] NOTISSUE
# 365 think plan one this sure moto phone me [[0.76885104]] NOTISSUE
# 366 span hour have two people exclaim whoa new phone tv [[0.48283872]] ISSUE
# 367 have use cord headset freedom wireless helpful [[0.9731083]] NOTISSUE
# 368 case have pas one year mark show sign wear 100 functional [[0.40640944]] ISSUE
# 369 that leather nice soft fit tight cut face good shape [[0.95588124]] NOTISSUE
# 370 have everything need task more [[0.84049726]] NOTISSUE
# 371 receive product two day break [[0.29150805]] ISSUE
# 372 product great make work lot easier go copier wait hold something [[0.74076563]] NOTISSUE
# 373 none size send headset stay ear [[0.4755457]] ISSUE
# 374 t mobile have best customer service anywhere [[0.94176215]] NOTISSUE
# 375 arrive quickly expensive be sell [[0.23457189]] ISSUE
# 376 have try two unit fail two month pro [[0.20537436]] ISSUE
# 377 provide good protection look classy too [[0.95707595]] NOTISSUE
# 378 russel good [[0.8712049]] NOTISSUE
# 379 tracfonewebsite user friendly make easy activate etc [[0.8586598]] NOTISSUE
# 380 design good 4 [[0.9343732]] NOTISSUE
# 381 great reception time [[0.972706]] NOTISSUE
# 382 highly recommend product [[0.810189]] NOTISSUE
# 383 house unit sunglass not good texas [[0.4396921]] ISSUE
# 384 dit not work time nokia 5320 [[0.35893315]] ISSUE
# 385 buy mainly charger break soon purchase [[0.7447165]] NOTISSUE
# 386 like loud buzz override conversation phone you [[0.677127]] NOTISSUE
# 387 fantastic buy get again phone [[0.97015476]] NOTISSUE
# 388 stay away store be careful [[0.24624327]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.95478994]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.804536]] NOTISSUE
# 391 light have plenty battery capacity comfortable wear somewhat extend period time [[0.9212689]] NOTISSUE
# 392 disappoint [[0.22173728]] ISSUE
# 393 blue ant easy use [[0.7197229]] NOTISSUE
# 394 cheap hey work [[0.7687411]] NOTISSUE
# 395 pleasantly suprised give low cost item [[0.55271596]] NOTISSUE
# 396 camera phone be use dustpan indoors have be disposable this [[0.709026]] NOTISSUE
# 397 day later puff smoke come phone use [[0.2074507]] ISSUE
# 398 convenient simple use get job make car ride smoother [[0.7190252]] NOTISSUE
# 399 nano state it my son disappoint [[0.4815401]] ISSUE
# 400 sound quality excellent well [[0.990303]] NOTISSUE
# 401 best headset have use [[0.8448314]] NOTISSUE
# 402 not recommend [[0.32930464]] ISSUE
# 403 have be year carry highest quality anti glare screen protector have find date [[0.7482137]] NOTISSUE
# 404 want [[0.57386523]] NOTISSUE
# 405 particular model not work motorola q smartphone [[0.68769497]] NOTISSUE
# 406 wont work right at least me [[0.8271199]] NOTISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.9330395]] NOTISSUE
# 408 out warranty problem reoccure bottom line money else singular not support it [[0.10551473]] ISSUE
# 409 want plantronics five ten be right one have issue me the good [[0.9108984]] NOTISSUE
# 410 crisp clear [[0.778196]] NOTISSUE
# 411 charge keep go dead minute [[0.159578]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.5613497]] NOTISSUE
# 413 get absolutely horrible reception apartment phone have not have problem [[0.10314]] ISSUE
# 414 reception have be generally good [[0.81592625]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.96577036]] NOTISSUE
# 416 great bluetooth [[0.9739629]] NOTISSUE
# 417 highly recommend case [[0.7831561]] NOTISSUE
# 418 worthwhile [[0.5420151]] NOTISSUE
# 419 phone get be year old be slowly break despite care part [[0.17928357]] ISSUE
# 420 be sorry make purchase [[0.2057205]] ISSUE
# 421 buy hop make bluetooth headset fit better thing make impossible wear [[0.7956208]] NOTISSUE
# 422 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.28295723]] ISSUE
# 423 horrible [[0.06099176]] ISSUE
# 424 allow possibility double book date time first [[0.3150967]] ISSUE
# 425 work two week break [[0.35619634]] ISSUE
# 426 do not think hold securely belt [[0.28585368]] ISSUE
# 427 simple use like it [[0.85982573]] NOTISSUE
# 428 great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.7355276]] NOTISSUE
# 429 not use case smell disgust [[0.03694206]] ISSUE
# 430 not want [[0.2420326]] ISSUE
# 431 two case order another [[0.48457423]] ISSUE
# 432 buy battery coupon amazon be happy purchase [[0.9265433]] NOTISSUE
# 433 internet access fine rare instance work [[0.8733019]] NOTISSUE
# 434 perfect p [[0.8299729]] NOTISSUE
# 435 five star plus plus [[0.84270775]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end other me [[0.83452123]] NOTISSUE
# 437 50 drain [[0.2154178]] ISSUE
# 438 try talk real loud shout telephone get old tell not great [[0.32842547]] ISSUE
# 439 good work fine [[0.97578716]] NOTISSUE
# 440 price great deal [[0.95984584]] NOTISSUE
# 441 great price too [[0.90684676]] NOTISSUE
# 442 wind completely useless [[0.06517906]] ISSUE
# 443 yes shiny love it [[0.98531556]] NOTISSUE
# 444 do not work [[0.15608484]] ISSUE
# 445 think get good deal 7 44 plug phone v see razor [[0.715623]] NOTISSUE
# 446 reception headset excellent [[0.9486349]] NOTISSUE
# 447 two thumb seller [[0.49005535]] ISSUE
# 448 have version lg phone work well together good reception range exceed twenty foot line sight [[0.95136654]] NOTISSUE
# 449 improper description have return it [[0.19270127]] ISSUE
# 450 1 work 2 comfortable [[0.8676215]] NOTISSUE
# 451 battery charge life long [[0.65598017]] NOTISSUE
# 452 cabra largely fit ear well [[0.6251004]] NOTISSUE
# 453 battery have no life [[0.48818347]] ISSUE
# 454 check no feature disappoint [[0.1744778]] ISSUE
# 455 product exactly describe [[0.3282586]] ISSUE
# 456 get signal version phone wo not [[0.17954223]] ISSUE
# 457 do not job [[0.12822115]] ISSUE
# 458 recommend it [[0.7955698]] NOTISSUE
# 459 plan order again again [[0.54680115]] NOTISSUE
# 460 be say phone camera nice cool effect play with video decent well [[0.9643026]] NOTISSUE
# 461 have be satisfy cell phone day one [[0.6900553]] NOTISSUE
# 462 keep get better better this one have have numerous palm too [[0.74082136]] NOTISSUE
# 463 awkward use unreliable [[0.04717254]] ISSUE
# 464 ship time quick [[0.5869412]] NOTISSUE
# 465 not good have hop [[0.28571805]] ISSUE
# 466 good case [[0.86700004]] NOTISSUE
# 467 do network [[0.2828226]] ISSUE
# 468 good product [[0.88981026]] NOTISSUE
# 469 unfortunately not work [[0.14913613]] ISSUE
# 470 break two month use [[0.24020351]] ISSUE
# 471 dont buy it [[0.844456]] NOTISSUE
# 472 father have -265 battery die [[0.3712628]] ISSUE
# 473 however ear pad come easily one week lose one [[0.25426713]] ISSUE
# 474 call drop phone come will screen go black worst stop ring intermittently [[0.05040885]] ISSUE
# 475 horrible horrible protector [[0.04838271]] ISSUE
# 476 do notice nokia either [[0.1390258]] ISSUE
# 477 reach row uncomfortable [[0.21967193]] ISSUE
# 478 have buy nokia cell phone week ago nightmare [[0.23291713]] ISSUE
# 479 take long describe bad customer service experience have be amazon [[0.14051569]] ISSUE
# 480 disappoint thing no speakerphone [[0.19435124]] ISSUE
# 481 terrible car not accept cassette [[0.05970024]] ISSUE
# 482 product useless do not have charge current charge two cellphone [[0.11333129]] ISSUE
# 483 not say be [[0.14765054]] ISSUE
# 484 stay away q [[0.4523185]] ISSUE
# 485 use dirty [[0.10950641]] ISSUE
# 486 unreliable service t mobile [[0.23121783]] ISSUE
# 487 not good price [[0.5056621]] NOTISSUE
# 488 buy two charge [[0.63390106]] NOTISSUE
# 489 look nice [[0.9416997]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.9745127]] NOTISSUE
# 491 have read review have note problem it [[0.36473668]] ISSUE
# 492 product cover important light sensor ear outlet [[0.6018747]] NOTISSUE
# 493 comfortable hand [[0.9193997]] NOTISSUE
# 494 do not work [[0.15608484]] ISSUE
# 495 poor reliability [[0.1319116]] ISSUE
# 496 work [[0.6396737]] NOTISSUE
# 497 take picture battery drop bar start beep let know din [[0.23591185]] ISSUE
# 498 terrible product waste money [[0.06854057]] ISSUE
# 499 time buy you [[0.80909437]] NOTISSUE
# 500 waste money [[0.17370293]] ISSUE
# 501 far have work like charm [[0.8615459]] NOTISSUE
# 502 have have week far good [[0.7214088]] NOTISSUE
# 503 but case best be download picture laptop ir send picture laptop phone [[0.8394454]] NOTISSUE
# 504 recommend item [[0.7201882]] NOTISSUE
# 505 be choice headset year great sound good volume good noise cancellation [[0.9384725]] NOTISSUE
# 506 nice case feel good hand [[0.9784319]] NOTISSUE
# 507 item receive counterfeit [[0.35723945]] ISSUE
# 508 good far probably best bt headset have have [[0.8787174]] NOTISSUE
# 509 work fine [[0.8472946]] NOTISSUE
# 510 receive headset good time happy it [[0.99421185]] NOTISSUE
# 511 please see replace well trail swivel holster blackberry flip [[0.7492271]] NOTISSUE
# 512 sister have one love it [[0.96279407]] NOTISSUE
# 513 good quality [[0.92272466]] NOTISSUE
# 514 far worst purchase have make amazon [[0.12960084]] ISSUE
# 515 excellent dual purpose headset [[0.9572068]] NOTISSUE
# 516 excellent [[0.9409101]] NOTISSUE
# 517 do not work listen music singular 8125 [[0.3532418]] ISSUE
# 518 seem completely secure hold belt keep phone inside [[0.7502934]] NOTISSUE
# 519 bottom line another worthless cheap gimmick sprint [[0.1715055]] ISSUE
# 520 have trouble volume [[0.3140906]] ISSUE
# 521 good thing fit comfortably small ear [[0.9483386]] NOTISSUE
# 522 warn do not buy [[0.10243059]] ISSUE
# 523 be pair phone not be happier far [[0.37872607]] ISSUE
# 524 open battery connection break device turn off [[0.16008124]] ISSUE
# 525 not want clip go ear cause discomfort [[0.10344385]] ISSUE
# 526 best headset ever [[0.83473974]] NOTISSUE
# 527 do not trust webster do not expect helpful support [[0.17554028]] ISSUE
# 528 loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.45419556]] ISSUE
# 529 speaker low quality make ring tone sound cheap [[0.45520386]] ISSUE
# 530 fit comfortably come size earn tip [[0.8562414]] NOTISSUE
# 531 bad reception [[0.06147827]] ISSUE
# 532 product high quality chinese crap [[0.26649657]] ISSUE
# 533 comfortable ear [[0.8513998]] NOTISSUE
# 534 do notably product fail [[0.1169586]] ISSUE
# 535 everything product wrong first [[0.27851748]] ISSUE
# 536 pair two device easy barely take couple minute start make call voice deal feature [[0.66631216]] NOTISSUE
# 537 utterly confuse first cause lose couple very important contact [[0.16245203]] ISSUE
# 538 terrible phone holder [[0.23468345]] ISSUE
# 539 cutout button place perfectly [[0.95545673]] NOTISSUE
# 540 love be able use one headset land line cell [[0.87644017]] NOTISSUE
# 541 problem ear loop make weak material break easily [[0.0568323]] ISSUE
# 542 not nearly good look amazon picture make look [[0.49366915]] ISSUE
# 543 despite flaw case exceptional quality well worth additional cost own official oem product [[0.27442232]] ISSUE
# 544 stupid that [[0.09768216]] ISSUE
# 545 hear be drive car usually do steven have loudest set [[0.3425302]] ISSUE
# 546 seller ship quickly cheaper competitor [[0.64343965]] NOTISSUE
# 547 good show samsung [[0.9373247]] NOTISSUE
# 548 buy ten save a lot money [[0.7050356]] NOTISSUE
# 549 cut make beep beep beep sound say signal fail [[0.05779443]] ISSUE
# 550 configure [[0.5679323]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word be say it [[0.21460932]] ISSUE
# 552 have take battery phone back restart it [[0.70322007]] NOTISSUE
# 553 manage bend leaf spring back place metal have stress break drop [[0.19853258]] ISSUE
# 554 leopard print wonderfully wild [[0.8775249]] NOTISSUE
# 555 work me [[0.79559064]] NOTISSUE
# 556 saggy floppy piece junk [[0.14218713]] ISSUE
# 557 better hard plastic case [[0.6991653]] NOTISSUE
# 558 have new problem [[0.36645597]] ISSUE
# 559 happy far [[0.8131159]] NOTISSUE
# 560 cool phone [[0.78984356]] NOTISSUE
# 561 work good [[0.9193876]] NOTISSUE
# 562 motorola finally get voice quality bluetooth headset right [[0.91654503]] NOTISSUE
# 563 loose connection phone couple foot two [[0.4177204]] ISSUE
# 564 great recommend [[0.97367054]] NOTISSUE
# 565 make easier keep bluetooth be not wear it [[0.62940264]] NOTISSUE
# 566 say above pretty useless [[0.19944857]] ISSUE
# 567 never get it [[0.45736158]] ISSUE
# 568 pair headphone worst have have sound wise [[0.43720624]] ISSUE
# 569 drain weak snap [[0.05112067]] ISSUE
# 570 do not charge singular att eight thousand five twenty five phone [[0.33856484]] ISSUE
# 571 get extra minute carry call not get cut off [[0.05167929]] ISSUE
# 572 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.07408118]] ISSUE
# 573 keep catch cable seat have pull phone turn off [[0.43334743]] ISSUE
# 574 headset fulfil requirement be happy purchase [[0.9417966]] NOTISSUE
# 575 logitech bluetooth headset 10 [[0.8549726]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.4772913]] ISSUE
# 577 lot webster have be rat good phone do i [[0.5696585]] NOTISSUE
# 578 have try cable computer pod work fine [[0.80931896]] NOTISSUE
# 579 mic joke volume low [[0.22952957]] ISSUE
# 580 be return them [[0.40577942]] ISSUE
# 581 do not maintain connection computer lap [[0.25248337]] ISSUE
# 582 easy turn car volume control accessible [[0.8792223]] NOTISSUE
# 583 have have year christmas buy rest family [[0.8637398]] NOTISSUE
# 584 otherwise easy install use clear sound [[0.35104364]] ISSUE
# 585 nice leather [[0.94157314]] NOTISSUE
# 586 have purchase different case [[0.78662753]] NOTISSUE
# 587 joy use [[0.94092333]] NOTISSUE
# 588 disappoint company [[0.24083889]] ISSUE
# 589 satisfy that [[0.6791243]] NOTISSUE
# 590 not charge me [[0.23902458]] ISSUE
# 591 phone get 2005 buy s740 say wow [[0.7565878]] NOTISSUE
# 592 button small [[0.7193276]] NOTISSUE
# 593 read spec make say wow [[0.47368345]] ISSUE
# 594 love it great armband [[0.97374785]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.67062235]] NOTISSUE
# 596 however keypad tinny reach wrong button [[0.19706641]] ISSUE
# 597 exchange sony ericson z five be pretty happy decision [[0.9872801]] NOTISSUE
# 598 impress price case [[0.6107058]] NOTISSUE
# 599 make easier hold to [[0.5068525]] NOTISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.95538205]] NOTISSUE
# 601 pretty easy [[0.9364767]] NOTISSUE
# 602 make call certain place [[0.44960555]] ISSUE
# 603 however girl complain time phone do netware like normal phone do [[0.09048332]] ISSUE
# 604 beautiful style though [[0.96676576]] NOTISSUE
# 605 company charge restock fee not give refund back [[0.07544621]] ISSUE
# 606 be try return refund [[0.20305899]] ISSUE
# 607 plug find not darn thing work [[0.32187703]] ISSUE
# 608 excellent product [[0.95874286]] NOTISSUE
# 609 earn piece break easily [[0.30480635]] ISSUE
# 610 lousy product [[0.17288308]] ISSUE
# 611 phone try hard do everything fail ability be phone [[0.3748049]] ISSUE
# 612 best charger have see market yet [[0.9383786]] NOTISSUE
# 613 sweetest phone [[0.6016272]] NOTISSUE
# 614 oh charger seem work fine [[0.92569077]] NOTISSUE
# 615 fit securely ear hook do not need be use sound better direct ear canal [[0.35656998]] ISSUE
# 616 not volume [[0.27445987]] ISSUE
# 617 echo problem very unsatisfactory [[0.09226265]] ISSUE
# 618 take two video time quality poor [[0.14930822]] ISSUE
# 619 do not waste money [[0.06896161]] ISSUE
# 620 be go have be negatively review product [[0.29669175]] ISSUE
# 621 adapter do not provide charge current [[0.1362646]] ISSUE
# 622 hype phone assume best mistake [[0.37266785]] ISSUE
# 623 take picture case sense cover [[0.55496716]] NOTISSUE
# 624 phone fall easily [[0.2899863]] ISSUE
# 625 network people not hear talk [[0.186949]] ISSUE
# 626 text message feature tricky use [[0.59741706]] NOTISSUE
# 627 be disappoint have charger do network [[0.19543934]] ISSUE
# 628 painful ear [[0.24476378]] ISSUE
# 629 last one day blow up [[0.15640488]] ISSUE
# 630 disappoint [[0.22173728]] ISSUE
# 631 kind flop around [[0.25376987]] ISSUE
# 632 screen do get smudge easily touch ear face [[0.28186426]] ISSUE
# 633 piece junk lose call phone [[0.30225113]] ISSUE
# 634 item do not match picture [[0.0948634]] ISSUE
# 635 thing disappoint infra red port ira [[0.24043423]] ISSUE
# 636 not answer call unit never work once [[0.1455805]] ISSUE
# 637 unsatisfactory [[0.12676975]] ISSUE
# 638 product great [[0.9442655]] NOTISSUE
# 639 have this [[0.564189]] NOTISSUE
# 640 have be work good no problem [[0.41660574]] ISSUE
# 641 oh dangerous [[0.3138767]] ISSUE
# 642 sorry [[0.16125414]] ISSUE
# 643 be sorry [[0.14898776]] ISSUE
# 644 pardon [[0.6467057]] NOTISSUE
# 645 help help [[0.66113055]] NOTISSUE
# 646 no no dangerous [[0.04137152]] ISSUE
# 647 extremely dangerous [[0.21508299]] ISSUE
# 648 dangerous [[0.1646123]] ISSUE
# 649 dangerous young man [[0.44044417]] ISSUE
# 650 dangerous brutal [[0.1646123]] ISSUE
# 651 honestly dangerous [[0.1692698]] ISSUE
# 652 work [[0.6396737]] NOTISSUE
# 653 dead hard work [[0.34110782]] ISSUE
# 654 fact family mary wed [[0.7504398]] NOTISSUE
# 655 have be busy [[0.5308606]] NOTISSUE
# 656 go back again [[0.512273]] NOTISSUE
# 657 be be busy [[0.4646592]] ISSUE
# 658 think yesterday [[0.55676746]] NOTISSUE
# 659 do think get one [[0.40064278]] ISSUE
# 660 oh yes [[0.83002657]] NOTISSUE
# 661 one thing want talk [[0.4568006]] ISSUE
# 662 well honestly do not know have noreen discussion [[0.29806685]] ISSUE
# 663 course be come tomorrow [[0.52480847]] NOTISSUE
# 664 have noreen think away weekend [[0.29684448]] ISSUE
# 665 hello [[0.72778237]] NOTISSUE
# 666 mean young man [[0.48636016]] ISSUE
# 667 goodbye [[0.6814034]] NOTISSUE
# 668 alright [[0.49334857]] ISSUE
# 669 do need money urgently [[0.37386394]] ISSUE
# 670 business [[0.50793135]] NOTISSUE
# 671 work day [[0.6467231]] NOTISSUE
# 672 work [[0.6396737]] NOTISSUE
# 673 do work [[0.38825536]] ISSUE
# 674 be work day [[0.5571462]] NOTISSUE
# 675 work saturday [[0.6325274]] NOTISSUE
# 676 know work [[0.69612926]] NOTISSUE
# 677 horrible customer service [[0.12287775]] ISSUE
# 678 fine product [[0.7551512]] NOTISSUE
# 679 glad pay money it [[0.6155689]] NOTISSUE
# 680 worst version adobe illustrator be release version nine [[0.25405326]] ISSUE
# 681 not save mysterious reason [[0.10968054]] ISSUE
# 682 crash [[0.14989574]] ISSUE
# 683 open file have be year write scribble untenable save version [[0.1647799]] ISSUE
# 684 assume adobe customer service be professional quick [[0.87009287]] NOTISSUE
# 685 have call time past two week have have wait minimum twenty three minute speak someone [[0.09339132]] ISSUE
# 686 finally get product send mac version personal computer version purchase [[0.7997946]] NOTISSUE
# 687 call again wait approximately thirty minute get customer help [[0.117713]] ISSUE
# 688 have not receive personal computer version [[0.38560987]] ISSUE
# 689 call center service worst customer service have deal [[0.15993044]] ISSUE
# 690 have deal bad customer service [[0.10898662]] ISSUE
# 691 six extremely frustrate hour [[0.2845257]] ISSUE
# 692 do not have problem software [[0.10038871]] ISSUE
# 693 reverse error be nightmare [[0.01772078]] ISSUE
# 694 pretty do need [[0.70496416]] NOTISSUE
# 695 point customer service rep nice [[0.84981626]] NOTISSUE
# 696 do not have infrastructure provide basic level service [[0.24758808]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.23372547]] ISSUE
# 698 do not send receipt [[0.06792329]] ISSUE
# 699 receipt get copy invoice not format print correctly [[0.10104518]] ISSUE
# 700 disturb people suppose be account expert [[0.19165902]] ISSUE
# 701 start look alternative intuit obviously do not understand basic account audit principle [[0.19223768]] ISSUE
# 702 thoroughly disappoint [[0.23143546]] ISSUE
# 703 be not do business company anymore give bad support [[0.04512833]] ISSUE
# 704 online information exactly have cd [[0.70224]] NOTISSUE
# 705 have not send coupon [[0.17790233]] ISSUE
# 706 bad [[0.04779548]] ISSUE
# 707 save money do not subscribe extend service [[0.09235946]] ISSUE
# 708 use customer service technical support give answer vaguely relate problem [[0.2336946]] ISSUE
# 709 be emailinc time get nowhere [[0.26331082]] ISSUE
# 710 largest technical software company world [[0.6578963]] NOTISSUE
# 711 have no technical support [[0.32717896]] ISSUE
# 712 worthless product horrible customer service [[0.05021504]] ISSUE
# 713 unable access internet [[0.3997982]] ISSUE
# 714 no problem system become slow [[0.02319478]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.33331153]] ISSUE
# 716 reputation become exasperate script suggestion not resolve problem [[0.07241815]] ISSUE
# 717 feel bite fleece over price subscription renewal year [[0.42269734]] ISSUE
# 718 decide give try [[0.6479318]] NOTISSUE
# 719 installation go smoothly everything seem fine [[0.7890407]] NOTISSUE
# 720 stall blank screen right window [[0.17922153]] ISSUE
# 721 hang forever [[0.5319337]] NOTISSUE
# 722 well present [[0.801198]] NOTISSUE
# 723 easy follow along easy revisit previous lesson [[0.6190604]] NOTISSUE
# 724 video illustrate fretboard help see hear song be play [[0.90291166]] NOTISSUE
# 725 not lot depth material [[0.272339]] ISSUE
# 726 sing be slight destruction sometimes [[0.11968269]] ISSUE
# 727 material song not be everyone like [[0.34425652]] ISSUE
# 728 have find music book useful [[0.961488]] NOTISSUE
# 729 probably not recommend be source learn guitar [[0.21486676]] ISSUE
# 730 like new look [[0.7970812]] NOTISSUE
# 731 i be have problem make transition [[0.40792012]] ISSUE
# 732 look create doom half life 2 not recommend program [[0.2835302]] ISSUE
# 733 want make advance fps game simple pong game recommend dark basic [[0.6542901]] NOTISSUE
# 734 dark basic professional probably capable create kind game come with [[0.9257055]] NOTISSUE
# 735 have deal bad customer service [[0.10898662]] ISSUE
# 736 dark basic make manipulate d data extremely easy [[0.6258145]] NOTISSUE
# 737 have program yourself scratch [[0.49068904]] ISSUE
# 738 recommend [[0.66465586]] NOTISSUE
# 739 software easy install easy use [[0.93258506]] NOTISSUE
# 740 wonderful software [[0.9761972]] NOTISSUE
# 741 buy cd [[0.8274857]] NOTISSUE
# 742 do not waste money subscription merriam webster webster [[0.12064193]] ISSUE
# 743 software user friendly [[0.8831801]] NOTISSUE
# 744 superb [[0.88433254]] NOTISSUE
# 745 try medical dictionary [[0.63748336]] NOTISSUE
# 746 surprise find offer option strip code [[0.878541]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.38061705]] ISSUE
# 748 evolution [[0.46007225]] ISSUE
# 749 do offer major improvement flexibility previous version [[0.48773268]] ISSUE
# 750 good [[0.87067837]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.9273974]] NOTISSUE
# 752 horribly bad [[0.04779548]] ISSUE
# 753 good be able tweak dozen standard compliance [[0.74960715]] NOTISSUE
# 754 default thing not set up do take learn [[0.10878658]] ISSUE
# 755 move p100 fairly advance feature [[0.85607743]] NOTISSUE
# 756 anyhow have call para professional version [[0.74645144]] NOTISSUE
# 757 have way flexibility functionality version [[0.925388]] NOTISSUE
# 758 go bye bye [[0.4971899]] ISSUE
# 759 be please product [[0.53699124]] NOTISSUE
# 760 have trial version instal computer buy it [[0.7692329]] NOTISSUE
# 761 have do enter code box [[0.1472186]] ISSUE
# 762 easy [[0.77727884]] NOTISSUE
# 763 be glad able install one computer [[0.70178646]] NOTISSUE
# 764 today best office suite microsoft have own [[0.906768]] NOTISSUE
# 765 easy use excellent result [[0.9280138]] NOTISSUE
# 766 great sw [[0.9424126]] NOTISSUE
# 767 easy learn [[0.8512894]] NOTISSUE
# 768 have good graphic [[0.76716727]] NOTISSUE
# 769 help visualize space [[0.76496303]] NOTISSUE
# 770 see d [[0.61664844]] NOTISSUE
# 771 have configure do [[0.43046635]] ISSUE
# 772 difficult change room be house overall style start give design [[0.31418076]] ISSUE
# 773 recently buy version [[0.8454966]] NOTISSUE
# 774 instal software [[0.5322737]] NOTISSUE
# 775 everything operate well old personal computer [[0.8063186]] NOTISSUE
# 776 run lot faster [[0.42331833]] ISSUE
# 777 access corporate entrant [[0.50410527]] NOTISSUE
# 778 awesome [[0.9159411]] NOTISSUE
# 779 give whirl [[0.6563783]] NOTISSUE
# 780 have buy product again [[0.74692154]] NOTISSUE
# 781 five star them [[0.7370483]] NOTISSUE
# 782 great company deal [[0.96470535]] NOTISSUE
# 783 agree window improve thier product [[0.39970365]] ISSUE
# 784 linx not user friendly [[0.54402083]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.2783675]] ISSUE
# 786 unix far stable [[0.43552533]] ISSUE
# 787 have access cd version [[0.88135767]] NOTISSUE
# 788 like [[0.61055297]] NOTISSUE
# 789 work well me [[0.9130137]] NOTISSUE
# 790 usually go disc want attempt [[0.10122023]] ISSUE
# 791 lot cd [[0.79698163]] NOTISSUE
# 792 great program child learn difference [[0.95660335]] NOTISSUE
# 793 fun excellent way learn math [[0.99594104]] NOTISSUE
# 794 child love do too [[0.55789304]] NOTISSUE
# 795 fun way keep brain work [[0.97000164]] NOTISSUE
# 796 marvelous [[0.9150704]] NOTISSUE
# 797 memory improvement software marvelous [[0.93257624]] NOTISSUE
# 798 help improve memory provide motivate game [[0.8647637]] NOTISSUE
# 799 highly recommend [[0.7852011]] NOTISSUE
# 800 great [[0.9424126]] NOTISSUE
# 801 love software [[0.90723044]] NOTISSUE
# 802 word new disturb get high score [[0.18097603]] ISSUE
# 803 have be symantec customer year [[0.71292657]] NOTISSUE
# 804 year product get better better [[0.77518094]] NOTISSUE
# 805 not use product purpose [[0.20143911]] ISSUE
# 806 anti virus find problem personal computer fix you [[0.23697197]] ISSUE
# 807 anti virus clean unneeded file [[0.09916919]] ISSUE
# ...
# 3949 chip come drip grease not edible [[0.11794958]] ISSUE
# 3950 normally impress strip steak [[0.6653874]] NOTISSUE
# 3951 have be go two thousand seven meal have be awesome [[0.8153593]] NOTISSUE
# 3952 server nice attentive serve staff [[0.9911669]] NOTISSUE
# 3953 cashier friendly bring food me [[0.88126683]] NOTISSUE
# 3954 work hospitality industry paradise valley have refrain recommend ciob longer [[0.90135604]] NOTISSUE
# 3955 atmosphere fun [[0.9197181]] NOTISSUE
# 3956 not recommend others [[0.24979673]] ISSUE
# 3957 service quick to go order like like it [[0.6912594]] NOTISSUE
# 3958 mean really do get famous fish chip terrible [[0.08730789]] ISSUE
# 3959 say mouth belly please [[0.4357205]] ISSUE
# 3960 not thing [[0.2135607]] ISSUE
# 3961 two thumb up [[0.51497406]] NOTISSUE
# 3962 read please do no-go there [[0.14381011]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.9880998]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99827707]] NOTISSUE
# 3965 have nice atmosphere [[0.930179]] NOTISSUE
# 3966 tonight have elk file special and suck [[0.3809005]] ISSUE
# 3967 one bite hook [[0.25758594]] ISSUE
# 3968 order old classic new dish go time sorely disappoint everything [[0.2655178]] ISSUE
# 3969 cute quaint simple honest [[0.74948347]] NOTISSUE
# 3970 chicken deliciously season have perfect fry outside moist chicken inside [[0.7140864]] NOTISSUE
# 3971 food great always compliment chef [[0.99574053]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.98833036]] NOTISSUE
# 3973 awesome selection beer [[0.97302383]] NOTISSUE
# 3974 great food awesome service [[0.9963213]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger six 8 not expect tip that [[0.4259409]] ISSUE
# 3976 fly apple juice fly [[0.33028537]] ISSUE
# 3977 now nan chicken tasty [[0.9501954]] NOTISSUE
# 3978 service think good [[0.9035124]] NOTISSUE
# 3979 food barely lukewarm have be sit wait server bring u [[0.08391318]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.4001893]] ISSUE
# 3981 nicest chinese restaurant have be while [[0.9186159]] NOTISSUE
# 3982 overall like food service [[0.6398976]] NOTISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.9032738]] NOTISSUE
# 3984 probably never come back not recommend it [[0.24195665]] ISSUE
# 3985 friend pasta bad barely touch it [[0.27267545]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.9859744]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.9495915]] NOTISSUE
# 3988 never have complain here [[0.14140202]] ISSUE
# 3989 restaurant clean have family restaurant feel it [[0.92416114]] NOTISSUE
# 3990 way fry [[0.6221106]] NOTISSUE
# 3991 be not sure long stand long begin feel awkwardly place [[0.18409272]] ISSUE
# 3992 open sandwich impress not good way [[0.33825636]] ISSUE
# 3993 not be back [[0.16722842]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.9773856]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.9827969]] NOTISSUE
# 3996 order vegetarian menu dinner have wide array option choose from [[0.9607943]] NOTISSUE
# 3997 have watch price inflate portion get smaller management attitude grow rapidly [[0.21246737]] ISSUE
# 3998 wonderful little tapa ambience make feel warm fuzzy inside [[0.97409874]] NOTISSUE
# 3999 get enjoy seafood salad fabulous vinaigrette [[0.99786574]] NOTISSUE
# 4000 wonton thin not thick chewy melt mouth [[0.14179382]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.93010914]] NOTISSUE
# 4002 sit right time server get go fantastic [[0.8185363]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s up [[0.44444445]] ISSUE
# 4004 be town definitely be spot hit again [[0.5552423]] NOTISSUE
# 4005 have wait thirty minute get drink longer get two area [[0.14393908]] ISSUE
# 4006 great place eat [[0.97038615]] NOTISSUE
# 4007 jalapeno bacon soo good [[0.967246]] NOTISSUE
# 4008 service poor [[0.09776087]] ISSUE
# 4009 food good service good price good [[0.99410135]] NOTISSUE
# 4010 price good [[0.8928829]] NOTISSUE
# 4011 price good [[0.8928829]] NOTISSUE
# 4012 service good [[0.8908756]] NOTISSUE
# 4013 place not clean food oh stale [[0.06484635]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.6465342]] NOTISSUE
# 4015 service bad [[0.0553344]] ISSUE
# 4016 be happy be here [[0.8665561]] NOTISSUE
# 4017 taste like dirt [[0.28731757]] ISSUE
# 4018 one place phoenix definately go back again [[0.5333671]] NOTISSUE
# 4019 block amaze [[0.8476463]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.9030484]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.5185295]] NOTISSUE
# 4022 hashemi poor quality be soggy tasteless [[0.01385686]] ISSUE
# 4023 great time family dinner sunday night [[0.9816051]] NOTISSUE
# 4024 food not tasty all not say real traditional hunan style [[0.19788675]] ISSUE
# 4025 bother me slow service [[0.06614272]] ISSUE
# 4026 flair bartender absolutely amaze [[0.9876831]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.6225175]] NOTISSUE
# 4028 good order twice [[0.87522554]] NOTISSUE
# 4029 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.04589274]] ISSUE
# 4030 girlfriend veal bad [[0.0582312]] ISSUE
# 4031 unfortunately not good [[0.24550694]] ISSUE
# 4032 have pretty satisfy experience [[0.91628987]] NOTISSUE
# 4033 join club get awesome offer email [[0.9428373]] NOTISSUE
# 4034 perfect me like beer ice cold case colder [[0.80028397]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.04975519]] ISSUE
# 4036 chain be no fan of beat place easily [[0.25650078]] ISSUE
# 4037 nacho have [[0.57376903]] NOTISSUE
# 4038 not be come back [[0.1574885]] ISSUE
# 4039 do not have word say place do everything pretty well [[0.40506774]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.95638984]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.9957279]] NOTISSUE
# 4042 receive pity huge have lot meat thumb there [[0.4128404]] ISSUE
# 4043 food arrive me [[0.47818074]] ISSUE
# 4044 pay 7 85 hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.20805398]] ISSUE
# 4045 classic maine lobster roll fantastic [[0.9855929]] NOTISSUE
# 4046 brother law work mall eat day guess sick night too [[0.04056231]] ISSUE
# 4047 good be go have review place twice [[0.8147178]] NOTISSUE
# 4048 chip salsa good salsa fresh [[0.9926045]] NOTISSUE
# 4049 place great [[0.9662752]] NOTISSUE
# 4050 mediocre food [[0.11789887]] ISSUE
# 4051 get inside be impress place [[0.6577543]] NOTISSUE
# 4052 service super friendly [[0.91953874]] NOTISSUE
# 4053 sad little vegetable overcook [[0.05511024]] ISSUE
# 4054 place nice surprise [[0.971854]] NOTISSUE
# 4055 live music totally blow [[0.31728283]] ISSUE
# 4056 low quality sound [[0.50926083]] NOTISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                    look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6                 display excellent camera good year  NOTISSUE
#  7              7                                 battery life great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10           embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  average phone bad battery life operate weak ne...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18         try handsfree gadget one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution far comparably price phone ...     ISSUE
#  27            27                                         great deal  NOTISSUE
#  28            28              excellent product be satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4026        4026                  freeze margarita way sugary taste     ISSUE
#  4027        4027                                   good order twice  NOTISSUE
#  4028        4028  nutshell 1 restaurant smell like combination d...     ISSUE
#  4029        4029                                girlfriend veal bad     ISSUE
#  4030        4030                             unfortunately not good     ISSUE
#  4031        4031                     have pretty satisfy experience  NOTISSUE
#  4032        4032                  join club get awesome offer email  NOTISSUE
#  4033        4033          perfect me like beer ice cold case colder  NOTISSUE
#  4034        4034  bland flavourless good way describe barely tep...     ISSUE
#  4035        4035               chain be no fan of beat place easily     ISSUE
#  4036        4036                                         nacho have  NOTISSUE
#  4037        4037                                   not be come back     ISSUE
#  4038        4038  do not have word say place do everything prett...  NOTISSUE
#  4039        4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040        4040             great atmosphere friendly fast service  NOTISSUE
#  4041        4041        receive pity huge have lot meat thumb there  NOTISSUE
#  4042        4042                                     food arrive me     ISSUE
#  4043        4043  pay 7 85 hot dog fry look like come kid meal w...     ISSUE
#  4044        4044               classic maine lobster roll fantastic  NOTISSUE
#  4045        4045  brother law work mall eat day guess sick night...     ISSUE
#  4046        4046                 good be go have review place twice  NOTISSUE
#  4047        4047                        chip salsa good salsa fresh  NOTISSUE
#  4048        4048                                        place great  NOTISSUE
#  4049        4049                                      mediocre food     ISSUE
#  4050        4050                        get inside be impress place  NOTISSUE
#  4051        4051                             service super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                                place nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#  4055        4055                                  low quality sound     ISSUE
#
#  [4056 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4     NOTISSUE                    look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE       clear skye call long battery life long range
#  14    NOTISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE         try handsfree gadget one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25    NOTISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE              excellent product be satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4026  NOTISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell 1 restaurant smell like combination d...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                     have pretty satisfy experience
#  4032  NOTISSUE                  join club get awesome offer email
#  4033  NOTISSUE          perfect me like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE               chain be no fan of beat place easily
#  4036  NOTISSUE                                         nacho have
#  4037     ISSUE                                   not be come back
#  4038     ISSUE  do not have word say place do everything prett...
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE        receive pity huge have lot meat thumb there
#  4042     ISSUE                                     food arrive me
#  4043     ISSUE  pay 7 85 hot dog fry look like come kid meal w...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE  brother law work mall eat day guess sick night...
#  4046  NOTISSUE                 good be go have review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050  NOTISSUE                        get inside be impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#  4055  NOTISSUE                                  low quality sound
#
#  [4056 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4  NOTISSUE                    look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2047
# NOTISSUE    2009
# Name: label, dtype: int64

# %% [markdown]
# ### confessin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1754  277]
#  [ 293 1732]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="red" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8594674556213018
#               precision    recall  f1-score   support
#
#        ISSUE       0.86      0.86      0.86      2031
#     NOTISSUE       0.86      0.86      0.86      2025
#
#    micro avg       0.86      0.86      0.86      4056
#    macro avg       0.86      0.86      0.86      4056
# weighted avg       0.86      0.86      0.86      4056

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_v7.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                     not be happier
# 1        ISSUE   NOTISSUE                               solo technology suck
# 2        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 3     NOTISSUE      ISSUE                                     prompt service
# 4        ISSUE   NOTISSUE  stupid have keep buy new charger car charger c...
# 5     NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 6     NOTISSUE      ISSUE               find cell phone right away enter car
# 7        ISSUE   NOTISSUE                    wish return unit get back money
# 8     NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 9     NOTISSUE      ISSUE  have get defect not risk buy again build quali...
# 10    NOTISSUE      ISSUE                            nothing bad say headset
# 11    NOTISSUE      ISSUE  be glad find product amazon hard find not high...
# 12    NOTISSUE      ISSUE                    timely shipment quality product
# 13    NOTISSUE      ISSUE                               no buyer remorse one
# 14    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 15       ISSUE   NOTISSUE                                     like return it
# 16    NOTISSUE      ISSUE  keyboard worthwhile usefulness sturdy do not e...
# 17    NOTISSUE      ISSUE                                  wil not regret it
# 18       ISSUE   NOTISSUE  unfortunately ability actually know receive ca...
# 19       ISSUE   NOTISSUE                                  pretty piece junk
# 20    NOTISSUE      ISSUE                                      work describe
# 21    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 22       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 23    NOTISSUE      ISSUE  no shift no bubble no peel not scratch nothing...
# 24       ISSUE   NOTISSUE           look good quality headset keep look nott
# 25       ISSUE   NOTISSUE      plantronincs continue use flaw charger design
# 26       ISSUE   NOTISSUE                                       not best one
# 27    NOTISSUE      ISSUE                        no problem come time expect
# 28       ISSUE   NOTISSUE                           fourth bluetooth headset
# 29       ISSUE   NOTISSUE                                                hat
# ..         ...        ...                                                ...
# 540   NOTISSUE      ISSUE              yellowtail capriccio melt mouth fresh
# 541   NOTISSUE      ISSUE            not have be please quality food service
# 542   NOTISSUE      ISSUE             do recommend place go wrong dont place
# 543      ISSUE   NOTISSUE                  know not like restaurant all here
# 544      ISSUE   NOTISSUE  salad have bland vinaigrette baby green heart ...
# 545      ISSUE   NOTISSUE                new location need complete overhaul
# 546   NOTISSUE      ISSUE                                                rat
# 547      ISSUE   NOTISSUE                  look authentic thai food go where
# 548      ISSUE   NOTISSUE   pale color instead nice character have no flavor
# 549   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 550   NOTISSUE      ISSUE  make drive way north scottsdale not one bite d...
# 551      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 552   NOTISSUE      ISSUE  prove dead wrong sushi bar not quality great s...
# 553      ISSUE   NOTISSUE                                 not fun experience
# 554   NOTISSUE      ISSUE                          promise wo not disappoint
# 555   NOTISSUE      ISSUE                                   not wait go back
# 556      ISSUE   NOTISSUE                           staff spend time talk me
# 557      ISSUE   NOTISSUE                       normally impress strip steak
# 558   NOTISSUE      ISSUE                             say mouth belly please
# 559   NOTISSUE      ISSUE                                      one bite hook
# 560   NOTISSUE      ISSUE  one nice thing add gratuity bill party larger ...
# 561   NOTISSUE      ISSUE                           never have complain here
# 562      ISSUE   NOTISSUE                                            way fry
# 563   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 564      ISSUE   NOTISSUE             chicken dish ok beef like shoe leather
# 565      ISSUE   NOTISSUE                  freeze margarita way sugary taste
# 566   NOTISSUE      ISSUE  do not have word say place do everything prett...
# 567   NOTISSUE      ISSUE        receive pity huge have lot meat thumb there
# 568   NOTISSUE      ISSUE                            live music totally blow
# 569      ISSUE   NOTISSUE                                  low quality sound
#
# [570 rows x 3 columns]
