# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import Adam
#
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
print("import done")
# Out:
# import done

# %%
#https://github.com/debadridtt/A-Review-of-Different-Word-Embeddings-for-Sentiment-Classification-using-Deep-Learning/blob/master/LSTM%20Experiment.ipynb

# %% [markdown]
# ### Loading the data

# %%
import os
DATA_FILE = os.path.abspath('DATA/data.csv')
df = pd.read_csv(DATA_FILE,delimiter=';',encoding='UTF-8')
print(df.head())
# Out:
#                                                 text     label
# 0  I had ordered a data cable, got a very well fi...  NOTISSUE
# 1                                   Love This Phone.  NOTISSUE
# 2                I get a very well finished product.  NOTISSUE
# 3                            I could not be happier.  NOTISSUE
# 4  I was looking for this headset for a long time...  NOTISSUE

# %%
df['label'].value_counts() #imbalanced Dataset
# Out:
# NOTISSUE    2030
# ISSUE       2025
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (4055, 2)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Target variable
sns.factorplot(x="label", data=df, kind="count", size=6, aspect=1.5)
plt.show();

# %% [markdown]
# ###  Preprocessing the Data

# %%
# List stop words
STOP_WORDS ={
 'a',
 'about',
 'above',
 'across',
 'after',
 'afterwards',
 'against',
 'all',
 'almost',
 'alone',
 'along',
 'already',
 'also',
 'although',
 'always',
 'am',
 'among',
 'amongst',
 'amount',
 'an',
 'and',
 'another',
 'any',
 'anyhow',
 'anyone',
 'anything',
 'anyway',
 'anywhere',
 'are',
 'around',
 'as',
 'at',
 #'became',
 'because',
 #'become',
 'becomes',
 'becoming',
 'been',
 'before',
 'beforehand',
 'behind',
 'being',
 'below',
 'beside',
 'besides',
 'between',
 'beyond',
 'both',
 'bottom',
 'but',
 'by',
 'ca',
 #'call',
 'can',
 'cannot',
 'could',
 'did',
 #'do',
 #'does',
 #'doing',
 'done',
 'down',
 'due',
 'during',
 'each',
 'either',
 'eleven',
 'else',
 'elsewhere',
 'empty',
 'enough',
 'even',
 'ever',
 'every',
 'everyone',
 'everything',
 'everywhere',
 'except',
 'few',
 'first',
 'for',
 'former',
 'formerly',
 'from',
 'front',
 'full',
 'further',
 #'had',
 #'has',
 #'have',
 'he',
 'hence',
 'her',
 'here',
 'hereafter',
 'hereby',
 'herein',
 'hereupon',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'however',
 'hundred',
 'i',
 'if',
 'in',
 'indeed',
 'into',
 'is',
 'it',
 'its',
 'itself',
 'just',
 'last',
 'latter',
 'latterly',
 'least',
 'less',
 #'made',
 #'make',
 'many',
 'may',
 'me',
 'meanwhile',
 'might',
 'mine',
 'more',
 'moreover',
 'most',
 'mostly',
 'move',
 'much',
 'must',
 'my',
 'myself',
 'name',
 'namely',
 'neither',
 'nevertheless',
 'next',
 'noone',
 'nor',
 'now',
 'nowhere',
 'of',
 'off',
 'often',
 'on',
 'once',
 'only',
 'onto',
 'or',
 'other',
 'others',
 'otherwise',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 'part',
 'per',
 'perhaps',
 'put',
 'quite',
 'rather',
 're',
 'really',
 'regarding',
 'same',
 #'say',
 #'see',
 #'seem',
 #'seemed',
 #'seeming',
 #'seems',
 'serious',
 'several',
 'she',
 'should',
 'show',
 'side',
 'since',
 'six',
 'sixty',
 'so',
 'some',
 'somehow',
 'someone',
 'something',
 'sometime',
 'sometimes',
 'somewhere',
 'still',
 'such',
 #'take',
 'than',
 'that',
 'the',
 'their',
 'them',
 'themselves',
 'then',
 'thence',
 'there',
 'thereafter',
 'thereby',
 'therefore',
 'therein',
 'thereupon',
 'these',
 'they',
 'third',
 'this',
 'those',
 'though',
 'three',
 'through',
 'throughout',
 'thru',
 'thus',
 'to',
 'together',
 'too',
 'top',
 #'toward',
 #'towards',
 'twelve',
 'under',
 'unless',
 'until',
 'up',
 'upon',
 'us',
 #'used',
 'using',
 'various',
 'very',
 'via',
 'was',
 'we',
 'were',
 'what',
 'whatever',
 'when',
 'whence',
 'whenever',
 'where',
 'whereafter',
 'whereas',
 'whereby',
 'wherein',
 'whereupon',
 'wherever',
 'whether',
 'which',
 'while',
 'whither',
 'who',
 'whoever',
 'whole',
 'whom',
 'whose',
 'why',
 'will',
 'with',
 'within',
 'without',
 'would',
 'yet',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves'}

# %%
switcher = {
        "couldn't": "could not",
        "couldn": "could not",
        "won't": "will not",
        "won": "will not",
        "mustn't": "must not",
        "mustn": "must not",
        "that'll": "that will",
        "shouldn't": "should not",
        "shouldn": "should not",
        "should've": "should have",
        "haven't": "have not",
        "haven": "have not",
        "hadn't": "have not",
        "hadn": "have not",
        "hasn't": "have not",
        "hasn": "have not",
        "didn't": "do not",
        "didn": "do not",
        "doesn't": "do not",
        "doesn": "do not",
        "don't": "do not",
        "don": "do not", 
        "isn't": "be not",
        "you'd":"you would",
        "you've":"you have",
        "you're":"you are",
        "you'll":"you will",
        "she's":"she is",
        "she'd":"she would",
        "she'll":"she will",
        "he's":"he is",
        "he'd":"he would",
        "he'll":"he will",
        "it's":"it is",
        "it'd":"it would",
        "it'll":"it will",
        "aren't":"are not",
        "aren":"are not",
        "weren't":"were not",
        "weren":"were not",
        "wouldn't":"would not",
        "wouldn":"would not",
        "needn't":"need not",
        "needn":"need not",
        "wasn't":"was not",
        "wasn":"was not",
        "mightn't":"might not",
        "mightn":"might not",
        "shan't":"shall not",
        "shan":"shall not", 
        "can't":"can not",
        "i'm":"i am",
        "i'd":"i would",
        "i'll":"i will",
        "i've":"i have",
        "we're":"we are",
        "we'd":"we would",
        "we'll":"we will",
        "we've":"we have",
        "they're":"they are",
        "they'd":"they would",
        "they'll":"they will",
        "they've":"they have",
        "let's":"let us",
        "how's":"how is",
        "here's":"here is",
        "what's":"what is",
        "there's":"there is",
        'awsm': 'awesome',
        "aamof": "as a matter of fact",
        "abt": "about",
        "abt2": "about to",
        "ac": "air conditioning",
        "ace": "solo winner",
        "ack": "acknowledged",
        "admin": "administrator",
        "thr": "there",
        "frm": "from",
        "aggro": "aggression",
        "agl": "angel",
        "dob": "date of birth",
        "ai": "artificial intelligence",
        "aiic": "as if i care",
        "aka": "also known as",
        "alap": "as long as possible",
        "alol": "actually laughing out loud",
        "ama": "ask me anything",
        "amap": "as much as possible",
        "amazn": "amazing",
        "ammo": "ammunition",
        "ams": "ask me something",
        "anon": "anonymous",
        "asap": "as soon as possible",
        "asat": "as simple as that",
        "awks": "awkward",
        "awl": "always with love",
        "ayk": "as you know",
        "azm": "awesome",
        "b": "be",
        "b&w": "black and white",
        "b-day": "birthday",
        "bday": "birthday",
        "bcoz": "because",
        "bcos": "because",
        "bcz": "because",
        "bf": "boyfriend",
        "btw": "between",
        "b4": "before",
        "bai": "bye",
        "bb": "bye bye",
        "bc": "abuse",
        "mc": "abuse",
        "bcc": "blind carbon copy",
        "bff": "best friends forever",
        "biz": "business",
        "bk": "back",
        "bo": "back off",
        "bro": "brother",
        "btwn": "between",
        "c": "see",
        "char": "character",
        "combo": "combination",
        "cu": "see you",
        "cu2": "see you too",
        "cu2mr": "see you tomorrow",
        "cya": "see ya",
        "cyal8r": "see you later",
        "cyb": "call you back",
        "cye": "check your e-mail",
        "cyf": "check your facebook",
        "cyfb": "check your facebook",
        "cyl": "catch ya later",
        "cym": "check your myspace",
        "cyo": "see you online",
        "d8": "date",
        "da": "the",
        "dece": "decent",
        "ded": "dead",
        "dept": "department",
        "dis": "this",
        "ditto": "same",
        "diva": "rude woman",
        "dk": "don't know",
        "dlm": "don't leave me",
        "dm": "direct message",
        "dnd": "do not disturb",
        "dno": "don't know",
        "dnt": "don't",
        "e1": "everyone",
        "eg": "for example",
        "emc2": "genius",
        "emo": "emotional",
        "enuf": "enough",
        "eod": "end of discussion",
        "eof": "end of file",
        "eom": "end of message",
        "eta": "estimated time of arrival",
        "every1": "everyone",
        "evs": "whatever",
        "exp": "experience",
        "f": "female",
        "f2f": "face to face",
        "f2p": "free to play",
        "f2t": "free to talk",
        "f9": "fine",
        "fab": "fabulous",
        "fail": "failure",
        "faq": "frequently asked questions",
        "fav": "favorite",
        "fave": "favorite",
        "favs": "favorites",
        "fb": "facebook",
        "fbc": "facebook chat",
        "fbf": "facebook friend",
        "fml": "family",
        "fn": "fine",
        "fo": "freaking out",
        "fri": "friday",
        "frnd": "friend",
        "fu": "fuck you",
        "fugly": "fucking ugly",
        "gf": "girlfriend",
        "g1": "good one",
        "g2b": "going to bed",
        "g2cu": "good to see you",
        "g2g": "good to go",
        "g4i": "go for it",
        "g4n": "good for nothing",
        "g4u": "good for you",
        "g9": "goodnight",
        "ga": "go ahead",
        "ge": "good evening",
        "gl": "good luck",
        "gm": "good morning",
        "gn": "goodnight",
        "gonna": "going to",
        "goon": "idiot",
        "gorge": "gorgeous",
        "gr8": "great",
        "grats": "congratulations",
        "gratz": "congratulations",
        "grl": "girl",
        "gt2t": "got time to talk",
        "gtg": "good to go",
        "gud": "good",
        "gv": "give",
        "gvn": "given",
        "gw": "good work",
        "h/o": "hold on",
        "h/p": "hold please",
        "h/t": "hat tip",
        "h/u": "hook up",
        "h2cus": "hope to see you soon",
        "h4u": "hot for you",
        "h4x0r": "hacker",
        "h4x0rz": "hackers",
        "h8": "hate",
        "h8r": "hater",
        "h8t": "hate",
        "ha": "hello again",
        "haha": "laughing",
        "hai": "hi",
        "hak": "hugs and kisses",
        "han": "how about now?",
        "hav": "have",
        "hax": "hacks",
        "haxor": "hacker",
        "hay": "how are you",
        "hb2u": "happy birthday to you",
        "hbbd": "happy belated birthday",
        "hbd": "happy birthday",
        "hc": "how cool",
        "hcit": "how cool is that",
        "hehe": "laughing",
        "hf": "have fun",
        "hi5": "high five",
        "hig": "how's it going?",
        "hih": "hope it helps",
        "ho": "hold on",
        "hoc": "house of cards",
        "hof": "hall of fame",
        "holla": "holler",
        "hom": "hit or miss",
        "hood": "neighborhood",
        "hoops": "basketball",
        "hottie": "attractive person",
        "hr": "human resources",
        "hru": "how are you",
        "hry": "hurry",
        "hubby": "husband",
        "hwk": "homework",
        "hwp": "height weight proportionate",
        "hwu": "hey, what's up?",
        "hxc": "hardcore",
        "h^": "hook up",
        "i8": "i ate",
        "i8u": "i hate you",
        "ia": "i agree",
        "iab": "in a bit",
        "iac": "in any case",
        "iad": "it all depends",
        "iae": "in any event",
        "iag": "it's all good",
        "iagw": "in a good way",
        "iail": "i am in love",
        "iam": "in a minute",
        "ic": "i see",
        "id10t": "idiot",
        "idc": "i don't care",
        "idd": "indeed",
        "idi": "i doubt it",
        "idk": "i don't know",
        "idky": "i don't know why",
        "idmb": "i'll do my best",
        "idn": "i don't know",
        "idnk": "i do not know",
        "idr": "i don't remember",
        "idt": "i don't think",
        "idts": "i don't think so",
        "idtt": "i'll drink to that",
        "idu": "i don't understand",
        "ie": "that is",
        "ig2p": "i got to pee",
        "iggy": "ignored",
        "ight": "alright",
        "igi": "i get it",
        "ign": "in-game name",
        "igtp": "i get the point",
        "ih8u": "i hate you",
        "ihu": "i hate you",
        "ihy": "i hate you",
        "ii": "i'm impressed",
        "iiok": "if i only knew",
        "iir": "if i remember",
        "iirc": "if i remember correctly",
        "iit": "i'm impressed too",
        "iiuc": "if i understand correctly",
        "ik": "i know",
        "ikhyf": "i know how you feel",
        "ikr": "i know, right?",
        "ikwum": "i know what you mean",
        "ikwym": "i know what you mean",
        "ikyd": "i know you did",
        "ilu": "i like you",
        "ilu2": "i love you too",
        "ilub": "i love you baby",
        "ilyk": "i'll let you know",
        "ilyl": "i love you lots",
        "ilysm": "i love you so much",
        "ima": "i'm",
        "imma": "i'm gonna",
        "imo": "in my opinion",
        "imy": "i miss you",
        "inb4": "in before",
        "inc": "incoming",
        "indie": "independent",
        "info": "information",
        "init": "initialize",
        "ipo": "initial public offering",
        "ir": "in room",
        "ir8": "irate",
        "irdk": "i really don't know",
        "irl": "in real life",
        "iyo": "in your opinion",
        "iyq": "i like you",
        "j/k": "just kidding",
        "j/p": "just playing",
        "j/w": "just wondering",
        "j2lyk": "just to let you know",
        "j4f": "just for fun",
        "j4g": "just for grins",
        "jas": "just a second",
        "jb/c": "just because",
        "joshing": "joking",
        "k": "ok",
        "k3u": "i love you",
        "kappa": "sarcasm",
        "kek": "korean laugh",
        "keke": "korean laugh",
        "kewl": "cool",
        "kewt": "cute",
        "kfc": "kentucky fried chicken",
        "kgo": "ok, go",
        "kik": "laughing out loud",
        "kinda": "kind of",
        "kk": "ok",
        "kl": "kool",
        "km": "kiss me",
        "kma": "kiss my ass",
        "knp": "ok, no problem",
        "kw": "know",
        "kwl": "cool",
        "l2m": "listening to music",
        "l2p": "learn to play",
        "l33t": "leet",
        "l8": "late",
        "l8er": "later",
        "l8r": "later",
        "la": "laughing a lot",
        "laf": "laugh",
        "laffing": "laughing",
        "lafs": "love at first sight",
        "lam": "leave a message",
        "lamer": "lame person",
        "legit": "legitimate",
        "lemeno": "let me know",
        "lil": "little",
        "lk": "like",
        "llol": "literally laughing out loud",
        "lmho": "laughing my head off",
        "loi": "laughing on the inside",
        "lola": "love often, laugh a lot",
        "lolol": "lots of laugh out louds",
        "lolz": "laugh out louds",
        "ltr": "later",
        "lulz": "lol",
        "luv": "love",
        "luzr": "loser",
        "lv": "love",
        "ly": "love ya",
        "lya": "love you always",
        "lyk": "let you know",
        "lyn": "lying",
        "lysm": "love you so much",
        "m": "male",
        "mcd": "mcdonald's",
        "mcds": "mcdonald's",
        "md@u": "mad at you",
        "me2": "me too",
        "meh": "whatever",
        "mf": "mother fucker",
        "mfb": "mother fucking bitch",
        "mgmt": "management",
        "mid": "middle",
        "mil": "mother-in-law",
        "min": "minute",
        "mins": "minutes",
        "mk": "okay",
        "mkay": "ok",
        "mmk": "ok",
        "mms": "multimedia messaging service",
        "mng": "manage",
        "mngr": "manager",
        "mod": "modification",
        "mofo": "mother fucking",
        "mojo": "attractive talent",
        "moss": "chill",
        "ms": "miss",
        "msg": "message",
        "mtg": "meeting",
        "mth": "month",
        "mu": "miss you",
        "mu@": "meet you at",
        "muah": "kiss",
        "mula": "money",
        "mwa": "kiss",
        "mwah": "kiss",
        "n/m": "nevermind",
        "n/m/h": "nothing much here",
        "n/r": "no reserve",
        "n00b": "newbie",
        "n1": "nice one",
        "n1c": "no one cares",
        "n2m": "not too much",
        "n2mh": "not too much here",
        "n2w": "not to worry",
        "n64": "nintendo 64",
        "n8kd": "naked",
        "nac": "not a chance",
        "nah": "no",
        "nal": "nationality",
        "narc": "tattle tale",
        "nark": "informant",
        "naw": "no",
        "nb": "not bad",
        "nbd": "no big deal",
        "nbjf": "no brag, just fact",
        "nd": "and",
        "ne": "any",
        "ne1": "anyone",
        "ne1er": "anyone here",
        "neh": "no",
        "nemore": "anymore",
        "neva": "never",
        "neway": "anyway",
        "newaze": "anyways",
        "newb": "newbie",
        "nite": "night",
        "nn2r": "no need to reply",
        "nnito": "not necessarily in that order",
        "nnto": "no need to open",
        "nntr": "no need to reply",
        "no1": "no one",
        "noob": "newbie",
        "nooblet": "young newbie",
        "nooblord": "ultimate newbie",
        "notch": "minecraft creator",
        "nottie": "unattractive person",
        "np": "no problem",
        "nub": "newbie",
        "nuff": "enough",
        "nufn": "nothing",
        "num": "tasty",
        "nvm": "nevermind",
        "nvr": "never",
        "nvrm": "nevermind",
        "nw": "no way",
        "nxt": "next",
        "o4u": "only for you",
        "obtw": "oh, by the way",
        "obv": "obviously",
        "obvi": "obviously",
        "oc": "of course",
        "ohemgee": "oh my gosh",
        "oic": "oh, i see",
        "oicn": "oh, i see now",
        "oiy": "hi",
        "omg": "oh my god",
        "onl": "online",
        "onoz": "oh no",
        "orly": "oh really",
        "otay": "okay",
        "otw": "on the way",
        "outta": "out of",
        "ovie": "overlord",
        "ownage": "completely owned",
        "p/d": "per day",
        "p/m": "per month",
        "p/y": "per year",
        "p911": "parent alert!",
        "p@h": "parents at home",
        "pc": "personal computer",
        "pda": "public display of affection",
        "pic": "picture",
        "pj": "poor joke",
        "pl8": "plate",
        "pld": "played",
        "pls": "please",
        "plz": "please",
        "plzrd": "please read",
        "pov": "point of view",
        "ppl": "people",
        "ppp": "peace",
        "prof": "professor",
        "prolly": "probably",
        "promo": "promotion",
        "props": "recognition",
        "prot": "protection",
        "prvt": "private",
        "ps": "postscript",
        "ps2": "playstation 2",
        "ps3": "playstation 3",
        "psa": "public service announcement",
        "psog": "pure stroke of genius",
        "psp": "playstation portable",
        "ptm": "please tell me",
        "pwd": "password",
        "psd": "password",
        "pswd": "password",
        "pwnd": "owned",
        "pwned": "owned",
        "pwnt": "owned",
        "q4u": "question for you",
        "qfe": "quoted for emphasis",
        "qft": "quoted for truth",
        "qq": "quick question",
        "qqn": "looking",
        "qrg": "quick reference guide",
        "qt": "cutie",
        "qtpi": "cutie pie",
        "r": "are",
        "r8": "rate",
        "rdy": "ready",
        "re": "replay",
        "rehi": "hi again",
        "rents": "parents",
        "rep": "reputation",
        "resq": "rescue",
        "rgd": "regard",
        "rgds": "regards",
        "ridic": "ridiculous",
        "rip": "rest in peace",
        "rl": "real life",
        "rlrt": "real life retweet",
        "rly": "really",
        "rm": "room",
        "rn": "run",
        "rnt": "aren't",
        "rof": "laughing",
        "rofl": "laughing",
        "roflmao": "laughing",
        "roflol": "laughing out loud",
        "rolf": "laughing",
        "ru": "are you",
        "ruc": "are you coming?",
        "rut": "are you there?",
        "rx": "prescription",
        "s/o": "sold out",
        "s/u": "shut up",
        "s/w": "software",
        "s2r": "send to receive",
        "s2s": "sorry to say",
        "s2u": "same to you",
        "samzd": "still amazed",
        "sd": "sweet dreams",
        "sec": "second",
        "sho": "sure",
        "sh^": "shut up",
        "siul8r": "see you later",
        "siv": "bad goaltender",
        "sk8": "skate",
        "sk8r": "skater",
        "sly": "still love you",
        "smf": "so much fun",
        "smooch": "kiss",
        "sorta": "sort of",
        "spec": "specialization",
        "spk": "speak",
        "spkr": "speaker",
        "srry": "sorry",
        "srs": "serious",
        "srsly": "seriously",
        "sry": "sorry",
        "stpd": "stupid",
        "str": "strength",
        "str8": "straight",
        "sup": "what's up",
        "syl": "see you later",
        "sync": "synchronize",
        "t2go": "time to go",
        "t2m": "talk to me",
        "t2u": "talk to you",
        "t2ul": "talk to you later",
        "t2ul8er": "talk to you later",
        "t2ul8r": "talk to you later",
        "t4lmk": "thanks for letting me know",
        "t4p": "thanks for posting",
        "t4t": "thanks for trade",
        "tc": "take care",
        "teh": "the",
        "teme": "tell me",
        "tg": "thank goodness",
        "thnq": "thank you",
        "tho": "though",
        "thru": "through",
        "tht": "that",
        "thx": "thanks",
        "tl": "tell",
        "tlk": "talk",
        "tlkin": "talking",
        "tlking": "talking",
        "tomoz": "tomorrow",
        "tq": "thank you",
        "tqvm": "thank you very much",
        "tru": "true",
        "ttl": "talk to you later",
        "ttly": "totally",
        "ttul": "talk to you later",
        "tty": "talk to you",
        "tu": "thank you",
        "tude": "attitude",
        "tx": "thanks",
        "txt": "text",
        "txtin": "texting",
        "ty": "thank you",
        "tyfa": "thank you for asking",
        "tyl": "thank you lord",
        "tym": "thank you much",
        "tyt": "take your time",
        "tyvm": "thank you very much",
        "u": "you",
        "u-ok": "you ok?",
        "u/l": "upload",
        "u2": "you too",
        "u2u": "up to you",
        "uok": "you ok?",
        "ur": "your",
        "ut": "you there?",
        "veggies": "vegetables",
        "vry": "very",
        "vs": "versus",
        "w/": "with",
        "w/b": "welcome back",
        "w/e": "whatever",
        "w/o": "without",
        "w2f": "way too funny",
        "w2g": "way to go",
        "w2k": "windows 2000",
        "w4u": "wait for you",
        "w8": "wait",
        "w84m": "wait for me",
        "w8am": "wait a minute",
        "w8ing": "waiting",
        "w8n": "waiting",
        "wa": "what",
        "waa": "crying",
        "wack": "strange",
        "wan2": "want to",
        "wannabe": "want to be",
        "wat": "what",
        "watev": "whatever",
        "watevs": "whatever",
        "wlcm": "welcome",
        "wha": "what",
        "whipped": "tired",
        "wht": "what",
        "wk": "week",
        "wknd": "weekend",
        "wtf": "what the fuck",
        "wtg": "way to go",
        "wup": "what's up?",
        "ya": "yes",
        "yeap": "yes",
        "yep": "yes",
        "yepperz": "yes",
        "yesh": "yes",
        "yo": "hi",
        "yr": "your",
        "yrs": "years",
        "yt": "you there?",
        "yt?": "you there?",
        "yup": "yes",
        "yupz": "ok",
        "zzz": "sleeping",
        "ain't": "is not", "aren't": "are not","can't": "cannot", 
        "can't've": "cannot have", "'cause": "because", "could've": "could have", 
        "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
        "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
        "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
        "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
        "he'll've": "he will have", "he's": "he is", "how'd": "how did", 
        "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
        "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
        "I'll've": "I will have","I'm": "I am", "I've": "I have", 
        "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
        "i'll've": "i will have","i'm": "i am", "i've": "i have", 
        "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
        "it'll": "it will", "it'll've": "it will have","it's": "it is", 
        "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
        "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
        "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                    "here's": "here is",
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have"
}

# %%
import nltk
import inflect
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import parsing
from gensim.parsing.preprocessing import split_alphanum
from spellchecker import SpellChecker
import re

# %%
def replace_word(word):
    # Convert text to lower
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    #stops = set(stopwords.words("english"))

    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Removing all the tokens with lesser than 3 characters
    #text = gensim.corpora.textcorpus.remove_short(text, minsize=3)
    
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    
    
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        
        ##### Lemmatization
        # Reduce words to their root form
        # Lemmatize verbs by specifying pos
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    return text

# %%
def replace_word(word):
    word = word.lower()
    word = word.split()
    for i in range(len(word)):
        word[i] = switcher.get(word[i], word[i])
    word = " ".join(word)
    return word

def replace_numbers(word):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    word = word.split()
    for i in range(len(word)):
        if word[i].isdigit():
            word[i] = p.number_to_words(word[i])
    word = " ".join(word)
    return word
def transformText(text):
    text = split_alphanum(text)
    # Convert text to lower
    text = text.lower()
    text = replace_word(text)
    text = replace_numbers(text)
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in STOP_WORDS]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # remove html markup
    text = re.sub("(<.*?>)","",text)
    # Correct words
    spell = SpellChecker()
    misspelled = text.split()
    wordnet_lemmatizer = WordNetLemmatizer()
    for i in range(len(misspelled)):
        # Get the one `most likely` answer
        word = spell.correction(misspelled[i])
        misspelled[i]=word
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="v")
        misspelled[i] = wordnet_lemmatizer.lemmatize(misspelled[i], pos="n")
    text = " ".join(misspelled)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Strip all the numerics
    #text = gensim.parsing.preprocessing.strip_numeric(text)
    return text

# %%
transformText("I have so 2  soo servic going groop")
# Out:
# 'have two soo service go group'

# %%
df['text'] = df['text'].map(transformText)
texts= df['text']
tags= df['label']

# %%
#df['text'] = df['text'].map(lambda x: transformText(x))

# %%
df=df[texts,tags]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-8a09c3838e60> in <module>
# ----> 1 df=df[texts,tags]
#
# ~\ana\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\ana\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       have order data cable get well finish work pro...
# 1                                              love phone
# 2                                 get well finish product
# 3                                          not be happier
# 4                         look headset long time have get
# 5                            headset start ring no reason
# 6                      display excellent camera good year
# 7                                      battery life great
# 8                        worst phone have have have month
# 9       not good item work start have problem auto rev...
# 10               embarrass ear hurt try push ear plug ear
# 11                                     protect phone side
# 12      average phone bad battery life operate weak ne...
# 13           clear skye call long battery life long range
# 14                                   solo technology suck
# 15                                 great hand free device
# 16       take self portrait outside exterior display cool
# 17                                   problem have mention
# 18             try handsfree gadget one finally work well
# 19                                           magical help
# 20              worst piece crap version customer service
# 21                                     poor sound quality
# 22                                      best phone market
# 23                                              work well
# 24                company ship product promptly work well
# 25                                           exactly want
# 26      picture resolution far comparably price phone ...
# 27                                             great deal
# 28                     excellent product satisfy purchase
# 29             highly recommend encourage people give try
#                               ...
# 4025                     flair bartender absolutely amaze
# 4026                    freeze margarita way sugary taste
# 4027                                     good order twice
# 4028    nutshell 1 restaurant smell like combination d...
# 4029                                  girlfriend veal bad
# 4030                               unfortunately not good
# 4031                       have pretty satisfy experience
# 4032                    join club get awesome offer email
# 4033            perfect me like beer ice cold case colder
# 4034    bland flavourless good way describe barely tep...
# 4035                    chain no fan of beat place easily
# 4036                                           nacho have
# 4037                                     not be come back
# 4038            do not have word say place do pretty well
# 4039    staff super nice quick crazy crowd downtown ju...
# 4040               great atmosphere friendly fast service
# 4041          receive pity huge have lot meat thumb there
# 4042                                       food arrive me
# 4043    pay 7 85 hot dog fry look like come kid meal w...
# 4044                 classic maine lobster roll fantastic
# 4045    brother law work mall eat day guess sick night...
# 4046                      good go have review place twice
# 4047                          chip salsa good salsa fresh
# 4048                                          place great
# 4049                                        mediocre food
# 4050                          get inside be impress place
# 4051                               service super friendly
# 4052                        sad little vegetable overcook
# 4053                                  place nice surprise
# 4054                              live music totally blow
# Name: text, Length: 4055, dtype: object, 0       NOTISSUE
# 1       NOTISSUE
# 2       NOTISSUE
# 3       NOTISSUE
# 4       NOTISSUE
# 5          ISSUE
# 6       NOTISSUE
# 7       NOTISSUE
# 8          ISSUE
# 9          ISSUE
# 10         ISSUE
# 11      NOTISSUE
# 12         ISSUE
# 13      NOTISSUE
# 14         ISSUE
# 15      NOTISSUE
# 16      NOTISSUE
# 17         ISSUE
# 18      NOTISSUE
# 19      NOTISSUE
# 20         ISSUE
# 21         ISSUE
# 22      NOTISSUE
# 23      NOTISSUE
# 24      NOTISSUE
# 25      NOTISSUE
# 26         ISSUE
# 27      NOTISSUE
# 28      NOTISSUE
# 29      NOTISSUE
#           ...
# 4025    NOTISSUE
# 4026       ISSUE
# 4027    NOTISSUE
# 4028       ISSUE
# 4029       ISSUE
# 4030       ISSUE
# 4031    NOTISSUE
# 4032    NOTISSUE
# 4033    NOTISSUE
# 4034       ISSUE
# 4035       ISSUE
# 4036    NOTISSUE
# 4037       ISSUE
# 4038    NOTISSUE
# 4039    NOTISSUE
# 4040    NOTISSUE
# 4041    NOTISSUE
# 4042       ISSUE
# 4043       ISSUE
# 4044    NOTISSUE
# 4045       ISSUE
# 4046    NOTISSUE
# 4047    NOTISSUE
# 4048    NOTISSUE
# 4049       ISSUE
# 4050    NOTISSUE
# 4051    NOTISSUE
# 4052       ISSUE
# 4053    NOTISSUE
# 4054    NOTISSUE
# Name: label, Length: 4055, dtype: object)' is an invalid key

# %%
# dictionary of lists  
dict = {'text': texts , 'label': tags } 
     
df = pd.DataFrame(dict) 
  
# saving the dataframe 
df.to_csv('Data/DATA_preprocessing3.csv')

# %%
####

# %%
DATA_FILE = 'Data/DATA_preprocessing3.csv'
df = pd.read_csv(DATA_FILE,delimiter=',',encoding='UTF-8')

# %%
msk = np.random.rand(len(df)) < 0.7 # Splitting into train(70%) and test(30%) randomly

# %%
train_df=df[msk]
test_df=df[~msk]

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2844, 3)
# (1211, 3)

# %%
print('Checking target values for train data:\n')
print(train_df['label'].value_counts(),'\n')
print('Checking target values for test data:\n')
print(test_df['label'].value_counts())
# Out:
# Checking target values for train data:
#
# NOTISSUE    1440
# ISSUE       1404
# Name: label, dtype: int64
#
# Checking target values for test data:
#
# ISSUE       621
# NOTISSUE    590
# Name: label, dtype: int64

# %%
train_df['label'].value_counts()
# Out:
# NOTISSUE    1440
# ISSUE       1404
# Name: label, dtype: int64

# %%
x_train=train_df['text']
y_train=train_df['label']
x_test=test_df['text']
y_test=test_df['label']

# %% [markdown]
# ### GLOVE EMBEDDING 300

# %%
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200
maxlen = 120  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

# %%
texts_train = x_train.astype(str)
texts_test = x_test.astype(str)

# %%
tokenizer = Tokenizer(nb_words=MAX_NB_WORDS, char_level=False)
tokenizer.fit_on_texts(texts_train)
sequences = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH, padding="pre",
                          truncating="post")

# %%
print('Shape of data tensor:', data.shape)
print('Shape of test_data tensor:', test_data.shape)
# Out:
# Shape of data tensor: (2844, 200)
# Shape of test_data tensor: (1211, 200)

# %%
import pickle
file_tok = 'LSTM_token_glove_300d_DATA_wit_text_processing.sav'
pickle.dump(tokenizer, open(file_tok, 'wb'))

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 3118 unique tokens.

# %%
#pad sequences are used to bring all sentences to same size.
# pad sequences with 0s
x_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
x_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', x_train.shape)
print('Shape of data test tensor:', x_test.shape)
# Out:
# Shape of data tensor: (2844, 200)
# Shape of data test tensor: (1211, 200)

# %%
y_train = y_train.map({"NOTISSUE": 1, "ISSUE" : 0 })
y_test = y_test.map({"NOTISSUE": 1, "ISSUE" : 0 })

# %%
# load the whole embedding into memory
embeddings_index = {}
f = open('C:/Users/khmar/Desktop/GLOVE/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 300))
#Found 1489 unique tokens : word_index
#print(len(word_index) + 1) #### 1490 
#print(word_index.items()) ### unique tokens : words :word_index
#print('embedding_matrix',embedding_matrix)
out_of_vocab={}
for word, i in word_index.items():
    #print(i)
    embedding_vector = embeddings_index.get(word)
    #print('embedding_vector' ,embedding_vector )
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        #print('word: ', word)
        embedding_matrix[i] = embedding_vector
        #print('embedding_matrix :',embedding_matrix[i] )
        # words not found in embedding index will be all-zeros.
    if embedding_vector is  None:
        print('word not found :',word)
        out_of_vocab[i] = word
# Out:
# word not found : overprice
# word not found : flavourful
# word not found : cosiness
# word not found : 4810
# word not found : untasted
# word not found : profiterole
# word not found : soooooo
# word not found : ciob
# word not found : 49900
# word not found : tk50
# word not found : barset
# word not found : 9e715
# word not found : flipphones
# word not found : notupload
# word not found : notslide
# word not found : tracfonewebsite
# word not found : supertooth
# word not found : notgreat
# word not found : 8125
# word not found : s740
# word not found : notwaste
# word not found : notknow
# word not found : emailinc
# word not found : bs2000
# word not found : soooooooo
# word not found : convertor
# word not found : nottranslate
# word not found : norber
# word not found : stylize
# word not found : nomish
# word not found : mesmerise
# word not found : appal
# word not found : hydrabrush
# word not found : cheesecurds
# word not found : notclosed
# word not found : notfresh
# word not found : douchebaggery
# word not found : chipolte
# word not found : albondigas
# word not found : smashburger
# word not found : flavourless

# %%
f'There are {len(out_of_vocab)} out of vocab '
# Out:
# 'There are 41 out of vocab '

# %%
model_glove= Sequential()
model_glove.add(Embedding(len(word_index) + 1,
                            300,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False))
model_glove.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2,input_shape=(1,)))
model_glove.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_glove.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model_glove.fit(data, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(test_data, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\khmar\ana\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2844 samples, validate on 1211 samples
# Epoch 1/2
# 2844/2844 [==============================] - 26s 9ms/step - loss: 0.5243 - acc: 0.7525 - val_loss: 0.4449 - val_acc: 0.8051
# Epoch 2/2
# 2844/2844 [==============================] - 23s 8ms/step - loss: 0.3964 - acc: 0.8288 - val_loss: 0.4140 - val_acc: 0.8241

# %%
scores = model_glove.evaluate(x_test, y_test,
                            batch_size=batch_size)
print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1211/1211 [==============================] - 3s 2ms/step
# loss: 41.40%
# acc: 82.41%

# %%
#without amelioration()
#scores = model_glove.evaluate(x_test, y_test,
                            #batch_size=batch_size)
#print("%s: %.2f%%" % (model_glove.metrics_names[0], scores[0] * 100))
#print("%s: %.2f%%" % (model_glove.metrics_names[1], scores[1] * 100))
# Out:
# 1234/1234 [==============================] - 3s 2ms/step
# loss: 42.44%
# acc: 81.44%

# %%
# Save the model
model_glove.save('Model/LSTM_model_glove_300_DATA_with_text_processing_v2.sav')

# %% [markdown]
# ### Prediction

# %%
##one text prediction!

# %%
def prediction(input_file,output_file):
    df= pd.DataFrame(columns=['label', 'text'])
    data = pd.read_csv(input_file,delimiter=',')
    inputt=data.text
    x_input = inputt.values
    ind=0
    for i in x_input:
        ind=ind+1
        text=np.array([i])
        seq= tokenizer.texts_to_sequences(text)
        sequences_matrix = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
        proba = model_glove.predict(sequences_matrix)
        class_pred = model_glove.predict_classes(sequences_matrix)
        classe=prediction_classe(class_pred)
        print(ind,i,proba,classe)
        df=df.append({'label':classe, 'text':i},ignore_index=True)
    df.to_csv(output_file,sep=';')
    return data,df

def prediction_classe(class_pred):
    if class_pred==0 :
        classe='ISSUE' 
    if class_pred==1 :
        classe='NOTISSUE'

    return classe

# %%
text="great prodoct"
#text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.93311286]]
# NOTISSUE

# %%
text="I have a problem can you help me"
text=transformText(text)
text=np.array([text])
sequences= tokenizer.texts_to_sequences(text)
sequences_matrix = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
proba = model_glove.predict(sequences_matrix)
print(proba)
class_pred = model_glove.predict_classes(sequences_matrix)
print(prediction_classe(class_pred))
# Out:
# [[0.36391354]]
# ISSUE

# %%
#predict all data

# %%
input_file ='DATA/DATA_preprocessing3.csv'
output_file ='Model/LSTM_data_pred_glove_300_with_text.csv'
prediction(input_file,output_file)
# Out:
# 1 have order data cable get well finish work product [[0.63028085]] NOTISSUE
# 2 love phone [[0.9196784]] NOTISSUE
# 3 get well finish product [[0.7483461]] NOTISSUE
# 4 not be happier [[0.35460734]] ISSUE
# 5 look headset long time have get [[0.56241465]] NOTISSUE
# 6 headset start ring no reason [[0.22432882]] ISSUE
# 7 display excellent camera good year [[0.99949205]] NOTISSUE
# 8 battery life great [[0.97426313]] NOTISSUE
# 9 worst phone have have have month [[0.13900925]] ISSUE
# 10 not good item work start have problem auto reverse tape player [[0.1489791]] ISSUE
# 11 embarrass ear hurt try push ear plug ear [[0.05188036]] ISSUE
# 12 protect phone side [[0.5848833]] NOTISSUE
# 13 average phone bad battery life operate weak network [[0.02879475]] ISSUE
# 14 clear skye call long battery life long range [[0.7830487]] NOTISSUE
# 15 solo technology suck [[0.2992838]] ISSUE
# 16 great hand free device [[0.99048537]] NOTISSUE
# 17 take self portrait outside exterior display cool [[0.669665]] NOTISSUE
# 18 problem have mention [[0.16032113]] ISSUE
# 19 try handsfree gadget one finally work well [[0.94946116]] NOTISSUE
# 20 magical help [[0.50173694]] NOTISSUE
# 21 worst piece crap version customer service [[0.04864231]] ISSUE
# 22 poor sound quality [[0.15005729]] ISSUE
# 23 best phone market [[0.92176795]] NOTISSUE
# 24 work well [[0.8275267]] NOTISSUE
# 25 company ship product promptly work well [[0.6569247]] NOTISSUE
# 26 exactly want [[0.55708]] NOTISSUE
# 27 picture resolution far comparably price phone offer today [[0.83040005]] NOTISSUE
# 28 great deal [[0.96137697]] NOTISSUE
# 29 excellent product satisfy purchase [[0.99132943]] NOTISSUE
# 30 highly recommend encourage people give try [[0.9271655]] NOTISSUE
# 31 better expect [[0.82391465]] NOTISSUE
# 32 earpiece leave right thing not stay ear [[0.24877927]] ISSUE
# 33 great product price [[0.98561805]] NOTISSUE
# 34 sound good reasonably price effective simple [[0.99946576]] NOTISSUE
# 35 disappointment [[0.1799673]] ISSUE
# 36 prompt service [[0.40622896]] ISSUE
# 37 excellent product price [[0.9906743]] NOTISSUE
# 38 please headset [[0.60884]] NOTISSUE
# 39 do not waste money time [[0.0473171]] ISSUE
# 40 especially love long battery life [[0.9823356]] NOTISSUE
# 41 stupid have keep buy new charger car charger cradle headphone car kit time new phone come out [[0.983374]] NOTISSUE
# 42 work great [[0.9551463]] NOTISSUE
# 43 plantronics bluetooth excellent buy [[0.9970687]] NOTISSUE
# 44 come version singular have nicer cell phone thing notice bad service [[0.28609037]] ISSUE
# 45 be look new earpiece [[0.5644371]] NOTISSUE
# 46 be look new earpiece jawbone era awesome too [[0.7727569]] NOTISSUE
# 47 receive white color battery go dead couple hoursthe original use week last longer thereplacement [[0.36442596]] ISSUE
# 48 year battery go completely dead headset [[0.23757178]] ISSUE
# 49 have use phone two year one best [[0.9337554]] NOTISSUE
# 50 awesome new look fall 2000 [[0.9320388]] NOTISSUE
# 51 phone have have have cheaply make [[0.6838845]] NOTISSUE
# 52 att not clear sound distort have yell talk [[0.02286124]] ISSUE
# 53 price good too [[0.7698703]] NOTISSUE
# 54 plastic break easy clip [[0.51923174]] NOTISSUE
# 55 do not make mistake do [[0.05487691]] ISSUE
# 56 oh forget mention weird color effect have phone [[0.28950408]] ISSUE
# 57 river spine with case fit fine [[0.93506426]] NOTISSUE
# 58 area unit break not fond magnetic strap [[0.16525045]] ISSUE
# 59 overall psyched have phone have appointment contact get great reception [[0.98135155]] NOTISSUE
# 60 thing phone work perfectly like it [[0.9707079]] NOTISSUE
# 61 note phone s appearance look bland especially black model [[0.16632476]] ISSUE
# 62 easy [[0.769354]] NOTISSUE
# 63 sanyo have survive dozen drop blackton ill effect [[0.22445051]] ISSUE
# 64 fantastic earphone [[0.91852987]] NOTISSUE
# 65 find cell phone right away enter car [[0.4193306]] ISSUE
# 66 low quality [[0.5106992]] NOTISSUE
# 67 do get better reception clarity phone have have before [[0.67148155]] NOTISSUE
# 68 warn stay away [[0.1213093]] ISSUE
# 69 wish return unit get back money [[0.4675478]] ISSUE
# 70 awesome device work great [[0.9989064]] NOTISSUE
# 71 use talk one one 1 2 hour battery be literally drain die [[0.0270253]] ISSUE
# 72 do not find it bad again unit come one arpad only i not recommend anyone [[0.12603647]] ISSUE
# 73 displease [[0.1779991]] ISSUE
# 74 have get defect not risk buy again build quality alone [[0.306095]] ISSUE
# 75 make case small difficult install [[0.35770148]] ISSUE
# 76 restore phone like new performance [[0.83756465]] NOTISSUE
# 77 recommend purchase cabra x 10 series two work flawlessly moto q go figure [[0.94230527]] NOTISSUE
# 78 search internet find one be best value [[0.9624675]] NOTISSUE
# 79 do not fit [[0.23181911]] ISSUE
# 80 happy product [[0.9285275]] NOTISSUE
# 81 screen size big key pad light well enough camera quality excellent camera phone [[0.99953854]] NOTISSUE
# 82 nothing bad say headset [[0.07410801]] ISSUE
# 83 glad find product amazon hard find not high price [[0.94488245]] NOTISSUE
# 84 portable work [[0.77953005]] NOTISSUE
# 85 colleague get great reception a little expensive performance great [[0.99845266]] NOTISSUE
# 86 fully charge go bed turn blue tooth wi fi notice have twenty leave morning [[0.11972068]] ISSUE
# 87 have have problem phone read memory card turn again [[0.4620986]] ISSUE
# 88 not good wear hat sunglass [[0.4349301]] ISSUE
# 89 timely shipment quality product [[0.6538011]] NOTISSUE
# 90 nice solid keyboard [[0.9960258]] NOTISSUE
# 91 well make fit surefire x2 perfectly [[0.99691594]] NOTISSUE
# 92 horrible phone [[0.09097432]] ISSUE
# 93 bt battery junk [[0.44012585]] ISSUE
# 94 recommend others [[0.57145035]] NOTISSUE
# 95 cant get software work computer [[0.41908705]] ISSUE
# 96 disappoint [[0.25518695]] ISSUE
# 97 poor voice clarity [[0.30467567]] ISSUE
# 98 battery work great [[0.9693728]] NOTISSUE
# 99 no buyer remorse one [[0.31217387]] ISSUE
# 100 disappoint accessoryone [[0.25518695]] ISSUE
# 101 find inexcusable probably be return phone change carrier [[0.04567031]] ISSUE
# 102 look great strong [[0.9827352]] NOTISSUE
# 103 have have mobile service two year now pretty happy it [[0.9984267]] NOTISSUE
# 104 update procedure difficult cumbersome [[0.06749479]] ISSUE
# 105 disappointment hate go ear [[0.0536266]] ISSUE
# 106 great software motorola [[0.97987765]] NOTISSUE
# 107 delivery time [[0.53181493]] NOTISSUE
# 108 easy use [[0.75075907]] NOTISSUE
# 109 uncomfortable ear do house lg .49900 env [[0.30554286]] ISSUE
# 110 volume switch rocket unit destination unknown [[0.4473032]] ISSUE
# 111 hold charge long time reasonably comfortable long wear condition quality sound tremendous [[0.9757633]] NOTISSUE
# 112 like return it [[0.55543065]] NOTISSUE
# 113 keyboard worthwhile usefulness sturdy do not expect problem [[0.7738085]] NOTISSUE
# 114 version s bill however difficult understand price plan simple [[0.2947036]] ISSUE
# 115 charge overnight battery work great [[0.8881553]] NOTISSUE
# 116 wo not regret it [[0.05666002]] ISSUE
# 117 love phone [[0.9196784]] NOTISSUE
# 118 disappointment [[0.1799673]] ISSUE
# 119 not user friendly [[0.5731239]] NOTISSUE
# 120 unfortunately ability actually know receive call important feature phone pitiful respect [[0.64934593]] NOTISSUE
# 121 exchange phone have problem [[0.53031707]] NOTISSUE
# 122 result phone stick max volume mute [[0.2501876]] ISSUE
# 123 public display affection rock [[0.85726964]] NOTISSUE
# 124 super charge use small hybrid palmtop camera cellphone excel role [[0.9891599]] NOTISSUE
# 125 definitely recommend cabra tk50 v look comfort clarity great price [[0.9966893]] NOTISSUE
# 126 have version two year ago like service [[0.8179407]] NOTISSUE
# 127 pretty piece junk [[0.41220534]] ISSUE
# 128 plug wrong size [[0.24788389]] ISSUE
# 129 work describe [[0.39517078]] ISSUE
# 130 save money have have item month now [[0.36753234]] ISSUE
# 131 bad purchase [[0.10159286]] ISSUE
# 132 well im satisfy [[0.87460357]] NOTISSUE
# 133 bose noise cancel amaze important nec commuter [[0.82574534]] NOTISSUE
# 134 battery excellent bargain [[0.98178047]] NOTISSUE
# 135 defective crap [[0.04345584]] ISSUE
# 136 have give no star able [[0.5481328]] NOTISSUE
# 137 wear glass fit fine them [[0.78653294]] NOTISSUE
# 138 sound quality device unacceptable unless quiet area hear nothing [[0.41246217]] ISSUE
# 139 not recommend item anyone [[0.1843383]] ISSUE
# 140 holster arrive not match photo ad [[0.15555018]] ISSUE
# 141 great no problem all [[0.792072]] NOTISSUE
# 142 earlier review note plug charger nothing happen [[0.27300128]] ISSUE
# 143 frog phone charm adorable eye catch [[0.93949026]] NOTISSUE
# 144 never know push hard right number time function want not [[0.32391307]] ISSUE
# 145 sound clear people talk amaze quality too [[0.76299167]] NOTISSUE
# 146 get aluminum case new palm v work well it have protect handheld perfectly far [[0.990333]] NOTISSUE
# 147 good product well make [[0.98643094]] NOTISSUE
# 148 mobile phone tool have [[0.9118892]] NOTISSUE
# 149 impress job motorola steadiness phone [[0.52364516]] NOTISSUE
# 150 receive order well ship timeframe good work order overall excite have source [[0.96124023]] NOTISSUE
# 151 phone sturdy waterproof [[0.77162766]] NOTISSUE
# 152 not impress not recommend item anyone [[0.0803865]] ISSUE
# 153 complaint standard sound volume little low turn 5 of 5 [[0.08682624]] ISSUE
# 154 thank again amazon have thing need good price [[0.9966798]] NOTISSUE
# 155 end slide edge pant back pocket instead [[0.20847987]] ISSUE
# 156 have go store buy new nokia phone work great [[0.9857734]] NOTISSUE
# 157 work great [[0.9551463]] NOTISSUE
# 158 ugly [[0.07300218]] ISSUE
# 159 horrible have switch time [[0.0581835]] ISSUE
# 160 noise shield incredible [[0.66053635]] NOTISSUE
# 161 no real improvement [[0.24084394]] ISSUE
# 162 razor battery good buy [[0.9809188]] NOTISSUE
# 163 keep good work amazon [[0.9853528]] NOTISSUE
# 164 refuse refund replace [[0.06357504]] ISSUE
# 165 unfortunately easy accidentally activate gentle touch button accidentally touch phone face listen [[0.85837775]] NOTISSUE
# 166 basically throw money window nothing [[0.06963748]] ISSUE
# 167 great case price [[0.9664522]] NOTISSUE
# 168 take one drop inch kitchen counter crack i not impress not laugh [[0.0401098]] ISSUE
# 169 bluetooth range good day ago leave phone trunk get call carry conversation hitch [[0.9930971]] NOTISSUE
# 170 small sleek impressive look practical setup ample storage place [[0.99935967]] NOTISSUE
# 171 largely channel sound directly ear seem increase sound volume clarity [[0.73380756]] NOTISSUE
# 172 none new one have work properly [[0.6067342]] NOTISSUE
# 173 glad purchase it [[0.91340876]] NOTISSUE
# 174 have miss numerous call reason [[0.42197758]] ISSUE
# 175 phone defective people hear use this [[0.20451984]] ISSUE
# 176 do notably product [[0.3444814]] ISSUE
# 177 suck stuff do not work phone [[0.16206162]] ISSUE
# 178 no shift no bubble no peel not scratch nothing i note happier new one droid [[0.21713375]] ISSUE
# 179 worst software use give zero star would [[0.07210091]] ISSUE
# 180 try make call exercise frustration [[0.09882846]] ISSUE
# 181 case flimsy piece plastic have no protection whatsoever [[0.14057432]] ISSUE
# 182 cabra barset happy it sound quality especially outgo better [[0.98413587]] NOTISSUE
# 183 love camera pretty good quality [[0.9997013]] NOTISSUE
# 184 thank great service [[0.9969171]] NOTISSUE
# 185 total package [[0.6477559]] NOTISSUE
# 186 seller understand patient definitely buy again [[0.88823456]] NOTISSUE
# 187 give firefly one star i contact singular at t inform practice [[0.73866683]] NOTISSUE
# 188 aggravate [[0.14728811]] ISSUE
# 189 great product price [[0.98561805]] NOTISSUE
# 190 have purchase family friend enjoy clarity ease use [[0.9990025]] NOTISSUE
# 191 virgin wireless rock do cheap little phone [[0.7686186]] NOTISSUE
# 192 none work [[0.49216732]] ISSUE
# 193 do notably it [[0.3763189]] ISSUE
# 194 muddy low quality sound case wire s insert poorly super glue slide off [[0.03052358]] ISSUE
# 195 please dont waste money [[0.16773643]] ISSUE
# 196 all satisfy purchase [[0.71305615]] NOTISSUE
# 197 look good quality headset keep look nott [[0.985058]] NOTISSUE
# 198 plantronincs continue use flaw charger design [[0.7302883]] NOTISSUE
# 199 notte best one [[0.877759]] NOTISSUE
# 200 best one [[0.88495696]] NOTISSUE
# 201 disappoint result [[0.07833418]] ISSUE
# 202 cumbersome design [[0.33685675]] ISSUE
# 203 great new package nice work good [[0.99990356]] NOTISSUE
# 204 no problem come time expect [[0.25271863]] ISSUE
# 205 great product [[0.9662117]] NOTISSUE
# 206 piece crap [[0.13078131]] ISSUE
# 207 experience terrible [[0.13566408]] ISSUE
# 208 fourth bluetooth headset [[0.7006251]] NOTISSUE
# 209 comfortable one [[0.9277053]] NOTISSUE
# 210 hat [[0.585632]] NOTISSUE
# 211 fix problem [[0.16733673]] ISSUE
# 212 worst ever [[0.09009115]] ISSUE
# 213 happy [[0.8924216]] NOTISSUE
# 214 have have no trouble access internet download intone perform function [[0.7117543]] NOTISSUE
# 215 barely hear constantly say what [[0.12147676]] ISSUE
# 216 battery life highly unacceptable [[0.41273302]] ISSUE
# 217 company joke [[0.23580097]] ISSUE
# 218 do description say would [[0.14720742]] ISSUE
# 219 happen call force stop headset [[0.20661844]] ISSUE
# 220 work great car charger especially plug two adapter time [[0.99926716]] NOTISSUE
# 221 version tech support walk procedure none work end have do hard re set wipe data [[0.20843256]] ISSUE
# 222 voice quality signal strength drop call [[0.60735196]] NOTISSUE
# 223 play louder speaker size price low think quality lack however not [[0.21804985]] ISSUE
# 224 better expect [[0.82391465]] NOTISSUE
# 225 feel poorly construct menu difficult navigate button recess difficult push them [[0.16801654]] ISSUE
# 226 battery hold well [[0.8339292]] NOTISSUE
# 227 difficult on i d recommend avoid product [[0.22109044]] ISSUE
# 228 use two day not easy hear with [[0.5123165]] NOTISSUE
# 229 get car charger not week charger break i go plug start smoke [[0.1467506]] ISSUE
# 230 sprint terrible customer service [[0.22853702]] ISSUE
# 231 link phone effort [[0.41297272]] ISSUE
# 232 cool [[0.70863074]] NOTISSUE
# 233 easy use [[0.75075907]] NOTISSUE
# 234 better new [[0.816599]] NOTISSUE
# 235 posse get junk have no idea [[0.14845042]] ISSUE
# 236 piece trash [[0.13360134]] ISSUE
# 237 pretty good product [[0.98160285]] NOTISSUE
# 238 great phone [[0.96288675]] NOTISSUE
# 239 price amazon excellent product highly recommend [[0.9981341]] NOTISSUE
# 240 research development division obviously know do [[0.9265997]] NOTISSUE
# 241 real killer volume course break [[0.25487077]] ISSUE
# 242 phone work fine now [[0.8483742]] NOTISSUE
# 243 happy product one [[0.9428834]] NOTISSUE
# 244 poor construction [[0.06053004]] ISSUE
# 245 infuriate [[0.28470936]] ISSUE
# 246 overall recommend phone new walkman [[0.82488525]] NOTISSUE
# 247 sprint charge service [[0.619764]] NOTISSUE
# 248 cheap feel look cheap [[0.36837786]] ISSUE
# 249 fit ear well comfortable on [[0.9856776]] NOTISSUE
# 250 do network europe asia [[0.2290138]] ISSUE
# 251 clip belt definitely make feel like fifty cent s up and come [[0.9583721]] NOTISSUE
# 252 like design look cabra be ear headset five thousand twenty pretty comfortable wear twenty four hour day pain ear [[0.9161851]] NOTISSUE
# 253 amaze quick arrival two original lg cell phone battery fraction price [[0.9811048]] NOTISSUE
# 254 worst phone samsung crap crappy samsung 9e715 worst have see [[0.06273302]] ISSUE
# 255 charger work week completely stop charge phone [[0.19845767]] ISSUE
# 256 poor product [[0.07757588]] ISSUE
# 257 need better instruction [[0.74989516]] NOTISSUE
# 258 need two hand operate screen this software interface decade old compete new software design [[0.990442]] NOTISSUE
# 259 work well pair tree seven w skye headset personal computer use usb bluetooth transceiver [[0.99789375]] NOTISSUE
# 260 steer clear product go genuine palm replacement pen come three pack [[0.88270336]] NOTISSUE
# 261 do not buy do not but suck [[0.03807059]] ISSUE
# 262 great product sure beat finger [[0.9915944]] NOTISSUE
# 263 plus seriously do not believe worth steep price point [[0.10693753]] ISSUE
# 264 case have try normally fall apart month one seem be long haul [[0.0531163]] ISSUE
# 265 disappoint performance [[0.28993613]] ISSUE
# 266 do normale mistake please do notably phone [[0.15570618]] ISSUE
# 267 phone well be worst have have brand [[0.38321236]] ISSUE
# 268 case extra originally later discard scratch ear [[0.24166039]] ISSUE
# 269 recommend go different brand cell phone mp player family [[0.96937346]] NOTISSUE
# 270 do not bother go store [[0.06448336]] ISSUE
# 271 post detail comment grey black phone have fire red great color [[0.81399727]] NOTISSUE
# 272 not have problem item order again need [[0.16579656]] ISSUE
# 273 get pay guess [[0.23773783]] ISSUE
# 274 not software do great job this make intone form exist cd internet connection [[0.84823054]] NOTISSUE
# 275 im surprise good quality car charger not review it [[0.99798524]] NOTISSUE
# 276 fabulous [[0.8723259]] NOTISSUE
# 277 however bt headset currently not good real time game like first person shooter audio delay mess up [[0.36260837]] ISSUE
# 278 price cable excellent [[0.9507403]] NOTISSUE
# 279 disappoint accessory good manufacturer [[0.546202]] NOTISSUE
# 280 perform awful muffle tinny incoming sound severe echo end call [[0.06438953]] ISSUE
# 281 wind resistant [[0.39364204]] ISSUE
# 282 obviously have terrible customer service get pay for [[0.08777599]] ISSUE
# 283 do not forever [[0.12347788]] ISSUE
# 284 it not overly expensive replace [[0.10577575]] ISSUE
# 285 easy operate sound better have try [[0.978004]] NOTISSUE
# 286 contact company tell that unit warranty notproduce receipt luck [[0.17917877]] ISSUE
# 287 link have way exchange bad phone return unit something [[0.18924442]] ISSUE
# 288 phone sturdy nokia bar phone be [[0.94494843]] NOTISSUE
# 289 great phone [[0.96288675]] NOTISSUE
# 290 place tree case not not snug lot extra room side [[0.22850822]] ISSUE
# 291 please [[0.58589625]] NOTISSUE
# 292 battery terrible [[0.08140901]] ISSUE
# 293 find product be easy set use [[0.7316056]] NOTISSUE
# 294 earpiece large heavy it keep fall ear [[0.3039353]] ISSUE
# 295 utter crap sound quality terrible [[0.00494743]] ISSUE
# 296 charger arrive promise timeframe not work [[0.4974608]] ISSUE
# 297 no ear loop need tiny sound great [[0.86431336]] NOTISSUE
# 298 finally four time spring latch break not use longer visor [[0.12537707]] ISSUE
# 299 handsfree work fine car try download address book tree reboot overall rate device high [[0.9878445]] NOTISSUE
# 300 talk useless customer service [[0.10710254]] ISSUE
# 301 felt light tinny [[0.27893394]] ISSUE
# 302 do not fit palm tungsten e2 break time try plug in [[0.12884796]] ISSUE
# 303 happy purchase good quality low price [[0.99902034]] NOTISSUE
# 304 love look feel samsung flipphones [[0.9719453]] NOTISSUE
# 305 well design sharp blue nice color [[0.99794143]] NOTISSUE
# 306 do more [[0.42095467]] ISSUE
# 307 not recommend more [[0.3646886]] ISSUE
# 308 nice sound [[0.96782345]] NOTISSUE
# 309 look good picture case huge disappointment [[0.7134642]] NOTISSUE
# 310 jawbone go replace with [[0.43542975]] ISSUE
# 311 setup go smoothly [[0.5394746]] NOTISSUE
# 312 extremely slow take forever do it [[0.13656467]] ISSUE
# 313 study interest worst sin industrial design [[0.09814136]] ISSUE
# 314 thing happen track off [[0.2708238]] ISSUE
# 315 well make easy access phone have handy detachable belt clip [[0.99618655]] NOTISSUE
# 316 have continue pair periodically keep drop [[0.7304875]] NOTISSUE
# 317 not upload intone party [[0.16942768]] ISSUE
# 318 bluetooth do not work phone lock up screen flash make call randomly pocket lock [[0.5423125]] NOTISSUE
# 319 truly awful [[0.22514227]] ISSUE
# 320 work fine motorola twenty five cellphone lot better wear out battery do [[0.89224166]] NOTISSUE
# 321 volume ringer real good you have choice loud one [[0.9949955]] NOTISSUE
# 322 none tone acceptable [[0.23732561]] ISSUE
# 323 camera color balance awful [[0.61982304]] NOTISSUE
# 324 product clearly not ready prime time do netware cool look nostell call come worthless [[0.04709689]] ISSUE
# 325 love intone upbeat [[0.9593722]] NOTISSUE
# 326 chinese forgery abound [[0.512083]] NOTISSUE
# 327 easy pair samsung cell [[0.95872754]] NOTISSUE
# 328 instruction notexplain microphone jack be use [[0.5196206]] NOTISSUE
# 329 advise not purchase item never work well [[0.44541082]] ISSUE
# 330 bad have pay month service [[0.04206402]] ISSUE
# 331 work well [[0.8275267]] NOTISSUE
# 332 nokia ca 42 usb cable not work phone [[0.66165996]] NOTISSUE
# 333 clear crisp sound [[0.8071998]] NOTISSUE
# 334 have use smallest earpiece provide stay pretty well [[0.99301964]] NOTISSUE
# 335 biggest complaint have be battery drain superfast [[0.14542757]] ISSUE
# 336 design be ergonomic theory not stand have ear [[0.3055855]] ISSUE
# 337 do not buy want use holster [[0.23011802]] ISSUE
# 338 phone take great picture video clip [[0.9749859]] NOTISSUE
# 339 do normale look cool [[0.69492686]] NOTISSUE
# 340 ear occupy background not distract all [[0.10794221]] ISSUE
# 341 comfortable fit need headset be comfortable hour time not entire day [[0.9883456]] NOTISSUE
# 342 also phone do not seem accept cbr mp s preferably rip window medium player [[0.23050277]] ISSUE
# 343 norbert price these [[0.6695816]] NOTISSUE
# 344 come strong light use light camera shot flash so signal seriously [[0.96595144]] NOTISSUE
# 345 lightweight work well [[0.9590743]] NOTISSUE
# 346 beware [[0.32873473]] ISSUE
# 347 love cable allow connect mini usb device pc [[0.9920769]] NOTISSUE
# 348 near hear conversation [[0.4944202]] ISSUE
# 349 cool case open allow screen get scratch up one [[0.4794851]] ISSUE
# 350 buy phone replacement start have regret since [[0.2510447]] ISSUE
# 351 appear actually outperform original battery china come a325 i [[0.47499153]] ISSUE
# 352 dottore phone number sim [[0.661633]] NOTISSUE
# 353 last o minute actually try use phone my wife have phone problem [[0.34073532]] ISSUE
# 354 poor quality [[0.11359807]] ISSUE
# 355 cabra ear gel r best [[0.7904471]] NOTISSUE
# 356 not worth it [[0.28435552]] ISSUE
# 357 phone crash completely have get replace [[0.07397041]] ISSUE
# 358 quit work have use eighteen month purchase one best headset have own [[0.82242143]] NOTISSUE
# 359 unfortunately not recharge phone four s despite connect multiple power source mac external battery wall outlet etc [[0.61466044]] NOTISSUE
# 360 great phone [[0.96288675]] NOTISSUE
# 361 simply want small flip phone look extra bell whistle mediocre [[0.04973722]] ISSUE
# 362 good value work fine power usb car wall outlet [[0.9919594]] NOTISSUE
# 363 phone do not slide car grip prevent phone slip hand [[0.07340527]] ISSUE
# 364 simply best bluetooth headset sound quality [[0.9814649]] NOTISSUE
# 365 think plan one this sure moto phone me [[0.7643123]] NOTISSUE
# 366 span hour have two people exclaim whoa new phone tv [[0.7274487]] NOTISSUE
# 367 have use cord headset freedom wireless helpful [[0.99118]] NOTISSUE
# 368 case have pas one year mark show sign wear 100 functional [[0.61837435]] NOTISSUE
# 369 that leather nice soft fit tight cut face good shape [[0.99468285]] NOTISSUE
# 370 have need task more [[0.80157965]] NOTISSUE
# 371 receive product two day break [[0.34763423]] ISSUE
# 372 product great make work lot easier go copier wait hold something [[0.9883526]] NOTISSUE
# 373 none size send headset stay ear [[0.57539517]] NOTISSUE
# 374 t mobile have best customer service anywhere [[0.9875366]] NOTISSUE
# 375 arrive quickly expensive sell [[0.24041626]] ISSUE
# 376 have try two unit fail two month pro [[0.3285303]] ISSUE
# 377 provide good protection look classy too [[0.99439174]] NOTISSUE
# 378 russel good [[0.8595474]] NOTISSUE
# 379 website user friendly make easy activate etc [[0.9796552]] NOTISSUE
# 380 design good 4 [[0.94325286]] NOTISSUE
# 381 great reception time [[0.9838749]] NOTISSUE
# 382 highly recommend product [[0.89103776]] NOTISSUE
# 383 house unit sunglass not good texas [[0.59622604]] NOTISSUE
# 384 dit not work time nokia 5320 [[0.37894675]] ISSUE
# 385 buy mainly charger break soon purchase [[0.8055135]] NOTISSUE
# 386 like loud buzz override conversation phone you [[0.87528926]] NOTISSUE
# 387 fantastic buy get again phone [[0.9875721]] NOTISSUE
# 388 stay away store be careful [[0.3685725]] ISSUE
# 389 blunt supertooth hand free phone speaker awesome [[0.93096066]] NOTISSUE
# 390 item arrive quickly work great phone sound ear plug [[0.8984819]] NOTISSUE
# 391 light have plenty battery capacity comfortable wear somewhat extend period time [[0.99202514]] NOTISSUE
# 392 disappoint [[0.25518695]] ISSUE
# 393 blue ant easy use [[0.7366002]] NOTISSUE
# 394 cheap hey work [[0.7413057]] NOTISSUE
# 395 pleasantly suprised give low cost item [[0.43370676]] ISSUE
# 396 camera phone be use dustpan indoors have be disposable this [[0.789995]] NOTISSUE
# 397 day later puff smoke come phone use [[0.23624973]] ISSUE
# 398 convenient simple use get job make car ride smoother [[0.96525526]] NOTISSUE
# 399 nano state it my son disappoint [[0.42415735]] ISSUE
# 400 sound quality excellent well [[0.99741346]] NOTISSUE
# 401 best headset have use [[0.93152714]] NOTISSUE
# 402 not recommend [[0.34904924]] ISSUE
# 403 have year carry highest quality anti glare screen protector have find date [[0.93013865]] NOTISSUE
# 404 want [[0.52103674]] NOTISSUE
# 405 particular model not work motorola q smartphone [[0.7228666]] NOTISSUE
# 406 wont work right at least me [[0.6078919]] NOTISSUE
# 407 addition feel amp look phone lightweight cheap plastic [[0.8342321]] NOTISSUE
# 408 out warranty problem reoccure bottom line money else singular not support it [[0.05999373]] ISSUE
# 409 want plantronics five ten be right one have issue me the good [[0.93368137]] NOTISSUE
# 410 crisp clear [[0.7448058]] NOTISSUE
# 411 charge keep go dead minute [[0.11764231]] ISSUE
# 412 cheap plastic creak like old wooden floor [[0.20674023]] ISSUE
# 413 get absolutely horrible reception apartment phone have not have problem [[0.08684458]] ISSUE
# 414 reception have generally good [[0.84987104]] NOTISSUE
# 415 excellent sound battery life inconspicuous boot [[0.9960406]] NOTISSUE
# 416 great bluetooth [[0.97995925]] NOTISSUE
# 417 highly recommend case [[0.83794403]] NOTISSUE
# 418 worthwhile [[0.5596063]] NOTISSUE
# 419 phone get be year old slowly break despite care part [[0.08356471]] ISSUE
# 420 sorry make purchase [[0.16109742]] ISSUE
# 421 buy hop make bluetooth headset fit better thing make impossible wear [[0.9781878]] NOTISSUE
# 422 tree t mobile refuse replace again force buy phone kind upgrade discount [[0.17349395]] ISSUE
# 423 horrible [[0.04125882]] ISSUE
# 424 allow possibility double book date time first [[0.20592673]] ISSUE
# 425 work two week break [[0.39252394]] ISSUE
# 426 do nothing hold securely belt [[0.35559544]] ISSUE
# 427 simple use like it [[0.8154264]] NOTISSUE
# 428 great tool entertainment communication data management oh be sure use activesync 4 2 optimal data synchronization result [[0.99824893]] NOTISSUE
# 429 house case smell disgust [[0.04845973]] ISSUE
# 430 not want [[0.23714058]] ISSUE
# 431 two case order another [[0.38963377]] ISSUE
# 432 buy battery coupon amazon happy purchase [[0.98715985]] NOTISSUE
# 433 internet access fine rare instance work [[0.89773065]] NOTISSUE
# 434 perfect p [[0.8352525]] NOTISSUE
# 435 five star plus plus [[0.90868175]] NOTISSUE
# 436 good quality bargain buy buy cheap big lot sound awful people end other me [[0.99652797]] NOTISSUE
# 437 50 drain [[0.19731611]] ISSUE
# 438 try talk real loud shout telephone get old tell not great [[0.2192424]] ISSUE
# 439 good work fine [[0.9742309]] NOTISSUE
# 440 price great deal [[0.9682028]] NOTISSUE
# 441 great price too [[0.9440952]] NOTISSUE
# 442 wind completely useless [[0.03186164]] ISSUE
# 443 yes shiny love it [[0.989419]] NOTISSUE
# 444 do not work [[0.18178743]] ISSUE
# 445 think get good deal 7 44 plug phone v see razor [[0.70859957]] NOTISSUE
# 446 reception headset excellent [[0.97504187]] NOTISSUE
# 447 two thumb seller [[0.61385083]] NOTISSUE
# 448 have version lg phone work well together good reception range exceed twenty foot line sight [[0.9992092]] NOTISSUE
# 449 improper description have return it [[0.12251054]] ISSUE
# 450 1 work 2 comfortable [[0.8141777]] NOTISSUE
# 451 battery charge life long [[0.38626662]] ISSUE
# 452 cabra largely fit ear well [[0.43596512]] ISSUE
# 453 battery have no life [[0.48421144]] ISSUE
# 454 check no feature disappoint [[0.32471064]] ISSUE
# 455 product exactly describe [[0.35738152]] ISSUE
# 456 get signal version phone wo not [[0.12414539]] ISSUE
# 457 do not job [[0.11164705]] ISSUE
# 458 recommend it [[0.6824756]] NOTISSUE
# 459 plan order again again [[0.34428638]] ISSUE
# 460 say phone camera nice cool effect play with video decent well [[0.99873704]] NOTISSUE
# 461 have satisfy cell phone day one [[0.58890915]] NOTISSUE
# 462 keep get better better this one have have numerous palm too [[0.96422756]] NOTISSUE
# 463 awkward use unreliable [[0.0336496]] ISSUE
# 464 ship time quick [[0.45836052]] ISSUE
# 465 not good have hop [[0.47581917]] ISSUE
# 466 good case [[0.8586974]] NOTISSUE
# 467 do network [[0.2521103]] ISSUE
# 468 good product [[0.908772]] NOTISSUE
# 469 unfortunately not work [[0.15580572]] ISSUE
# 470 break two month use [[0.25368914]] ISSUE
# 471 dont buy it [[0.7131117]] NOTISSUE
# 472 father have 4265 battery die [[0.350812]] ISSUE
# 473 however ear pad come easily one week lose one [[0.19789113]] ISSUE
# 474 call drop phone come will screen go black worst stop ring intermittently [[0.06255984]] ISSUE
# 475 horrible horrible protector [[0.02429548]] ISSUE
# 476 do notice nokia either [[0.13946244]] ISSUE
# 477 reach row uncomfortable [[0.23109044]] ISSUE
# 478 have buy nokia cell phone week ago nightmare [[0.34488395]] ISSUE
# 479 take long describe bad customer service experience have amazon [[0.17194195]] ISSUE
# 480 disappoint thing no speakerphone [[0.11845571]] ISSUE
# 481 terrible car not accept cassette [[0.05330709]] ISSUE
# 482 product useless do not have charge current charge two cellphone [[0.09357005]] ISSUE
# 483 not say be [[0.15193723]] ISSUE
# 484 stay away q [[0.5662729]] NOTISSUE
# 485 use dirty [[0.07092688]] ISSUE
# 486 unreliable service t mobile [[0.23695664]] ISSUE
# 487 not good price [[0.6014665]] NOTISSUE
# 488 buy two charge [[0.56876224]] NOTISSUE
# 489 look nice [[0.92230475]] NOTISSUE
# 490 excellent tool especially pair phone auto answer [[0.9990103]] NOTISSUE
# 491 have read review have note problem it [[0.4154257]] ISSUE
# 492 product cover important light sensor ear outlet [[0.6234433]] NOTISSUE
# 493 comfortable hand [[0.9075318]] NOTISSUE
# 494 do not work [[0.18178743]] ISSUE
# 495 poor reliability [[0.10288575]] ISSUE
# 496 work [[0.5782628]] NOTISSUE
# 497 take picture battery drop bar start beep let know din [[0.13973656]] ISSUE
# 498 terrible product waste money [[0.0342478]] ISSUE
# 499 time buy you [[0.6860596]] NOTISSUE
# 500 waste money [[0.12407906]] ISSUE
# 501 far have work like charm [[0.86810356]] NOTISSUE
# 502 have have week far good [[0.8039046]] NOTISSUE
# 503 but case best be download picture laptop ir send picture laptop phone [[0.9229389]] NOTISSUE
# 504 recommend item [[0.62086993]] NOTISSUE
# 505 choice headset year great sound good volume good noise cancellation [[0.99895763]] NOTISSUE
# 506 nice case feel good hand [[0.9801002]] NOTISSUE
# 507 item receive counterfeit [[0.41262075]] ISSUE
# 508 good far probably best bt headset have have [[0.99276394]] NOTISSUE
# 509 work fine [[0.79128176]] NOTISSUE
# 510 receive headset good time happy it [[0.996518]] NOTISSUE
# 511 please see replace well trail swivel holster blackberry flip [[0.6758331]] NOTISSUE
# 512 sister have one love it [[0.9592756]] NOTISSUE
# 513 good quality [[0.95285404]] NOTISSUE
# 514 far worst purchase have make amazon [[0.21210086]] ISSUE
# 515 excellent dual purpose headset [[0.97970116]] NOTISSUE
# 516 excellent [[0.94911987]] NOTISSUE
# 517 do not work listen music singular 8125 [[0.40165752]] ISSUE
# 518 seem completely secure hold belt keep phone inside [[0.6040919]] NOTISSUE
# 519 bottom line another worthless cheap gimmick sprint [[0.06663627]] ISSUE
# 520 have trouble volume [[0.43642715]] ISSUE
# 521 good thing fit comfortably small ear [[0.99202913]] NOTISSUE
# 522 warn do not buy [[0.09041941]] ISSUE
# 523 pair phone not be happier far [[0.6791382]] NOTISSUE
# 524 open battery connection break device turn off [[0.15911528]] ISSUE
# 525 not want clip go ear cause discomfort [[0.07979017]] ISSUE
# 526 best headset ever [[0.93821335]] NOTISSUE
# 527 do not trust webster do not expect helpful support [[0.17050438]] ISSUE
# 528 loud glad say plantronics five ten maintain flawless connection cell no static normal use [[0.96766794]] NOTISSUE
# 529 speaker low quality make ring tone sound cheap [[0.6891599]] NOTISSUE
# 530 fit comfortably come size earn tip [[0.9349685]] NOTISSUE
# 531 bad reception [[0.07188889]] ISSUE
# 532 product high quality chinese crap [[0.28359914]] ISSUE
# 533 comfortable ear [[0.87262464]] NOTISSUE
# 534 do notably product fail [[0.13439219]] ISSUE
# 535 product wrong first [[0.21051925]] ISSUE
# 536 pair two device easy barely take couple minute start make call voice deal feature [[0.9859159]] NOTISSUE
# 537 utterly confuse first cause lose couple very important contact [[0.12759773]] ISSUE
# 538 terrible phone holder [[0.1242482]] ISSUE
# 539 cutout button place perfectly [[0.9625699]] NOTISSUE
# 540 love able use one headset land line cell [[0.9629854]] NOTISSUE
# 541 problem ear loop make weak material break easily [[0.0301946]] ISSUE
# 542 not nearly good look amazon picture make look [[0.6340057]] NOTISSUE
# 543 despite flaw case exceptional quality well worth additional cost own official oem product [[0.8469684]] NOTISSUE
# 544 stupid that [[0.06723349]] ISSUE
# 545 hear drive car usually do steven have loudest set [[0.44216973]] ISSUE
# 546 seller ship quickly cheaper competitor [[0.5239126]] NOTISSUE
# 547 good show samsung [[0.96028167]] NOTISSUE
# 548 buy ten save a lot money [[0.5962833]] NOTISSUE
# 549 cut make beep beep beep sound say signal fail [[0.03613788]] ISSUE
# 550 configure [[0.58751535]] NOTISSUE
# 551 phone sound ok not great ok wife phone totally unintelligible not understand word say it [[0.38552374]] ISSUE
# 552 have take battery phone back restart it [[0.4222957]] ISSUE
# 553 manage bend leaf spring back place metal have stress break drop [[0.12257767]] ISSUE
# 554 leopard print wonderfully wild [[0.9672549]] NOTISSUE
# 555 work me [[0.7393941]] NOTISSUE
# 556 saggy floppy piece junk [[0.1765323]] ISSUE
# 557 better hard plastic case [[0.6493408]] NOTISSUE
# 558 have new problem [[0.48306027]] ISSUE
# 559 happy far [[0.89763373]] NOTISSUE
# 560 cool phone [[0.7918516]] NOTISSUE
# 561 work good [[0.9056727]] NOTISSUE
# 562 motorola finally get voice quality bluetooth headset right [[0.9411731]] NOTISSUE
# 563 loose connection phone couple foot two [[0.46542794]] ISSUE
# 564 great recommend [[0.96970046]] NOTISSUE
# 565 make easier keep bluetooth not wear it [[0.5868485]] NOTISSUE
# 566 say above pretty useless [[0.14622235]] ISSUE
# 567 never get it [[0.3286893]] ISSUE
# 568 pair headphone worst have have sound wise [[0.6444818]] NOTISSUE
# 569 drain weak snap [[0.03721034]] ISSUE
# 570 do not charge singular att eight thousand five twenty five phone [[0.24114336]] ISSUE
# 571 get extra minute carry call not get cut off [[0.02823308]] ISSUE
# 572 however year lipton start get loose wobbly eventually screen go black not receive place call [[0.05928731]] ISSUE
# 573 keep catch cable seat have pull phone turn off [[0.22301762]] ISSUE
# 574 headset fulfil requirement happy purchase [[0.96331316]] NOTISSUE
# 575 logitech bluetooth headset 10 [[0.7823663]] NOTISSUE
# 576 like fact rest lightly ear inside [[0.34051153]] ISSUE
# 577 lot webster have rat good phone do i [[0.9062236]] NOTISSUE
# 578 have try cable computer pod work fine [[0.719049]] NOTISSUE
# 579 mic joke volume low [[0.21711248]] ISSUE
# 580 return them [[0.3364994]] ISSUE
# 581 do not maintain connection computer lap [[0.25626725]] ISSUE
# 582 easy turn car volume control accessible [[0.9285577]] NOTISSUE
# 583 have have year christmas buy rest family [[0.8920921]] NOTISSUE
# 584 otherwise easy install use clear sound [[0.4721797]] ISSUE
# 585 nice leather [[0.9435947]] NOTISSUE
# 586 have purchase different case [[0.8527277]] NOTISSUE
# 587 joy use [[0.9188526]] NOTISSUE
# 588 disappoint company [[0.24919344]] ISSUE
# 589 satisfy that [[0.47824422]] ISSUE
# 590 not charge me [[0.18684603]] ISSUE
# 591 phone get 2005 buy s740 say wow [[0.78458697]] NOTISSUE
# 592 button small [[0.68199646]] NOTISSUE
# 593 read spec make say wow [[0.6917216]] NOTISSUE
# 594 love it great armband [[0.99306893]] NOTISSUE
# 595 like product motorola allot clearer ear piece mic [[0.51446927]] NOTISSUE
# 596 however keypad tinny reach wrong button [[0.2683064]] ISSUE
# 597 exchange sony ericson z five pretty happy decision [[0.99679935]] NOTISSUE
# 598 impress price case [[0.493289]] ISSUE
# 599 make easier hold to [[0.27594942]] ISSUE
# 600 use product motor control center lot high voltage hum equipment work great [[0.9924549]] NOTISSUE
# 601 pretty easy [[0.9353617]] NOTISSUE
# 602 make call certain place [[0.2998172]] ISSUE
# 603 however girl complain time phone do netware like normal phone do [[0.06921746]] ISSUE
# 604 beautiful style though [[0.98506814]] NOTISSUE
# 605 company charge restock fee not give refund back [[0.07294931]] ISSUE
# 606 try return refund [[0.21963]] ISSUE
# 607 plug find not darn thing work [[0.32759342]] ISSUE
# 608 excellent product [[0.9768629]] NOTISSUE
# 609 earn piece break easily [[0.28482515]] ISSUE
# 610 lousy product [[0.13386638]] ISSUE
# 611 phone try hard do fail ability be phone [[0.21403319]] ISSUE
# 612 best charger have see market yet [[0.98801315]] NOTISSUE
# 613 sweetest phone [[0.5692972]] NOTISSUE
# 614 oh charger seem work fine [[0.891645]] NOTISSUE
# 615 fit securely ear hook do not need be use sound better direct ear canal [[0.33711153]] ISSUE
# 616 not volume [[0.30016813]] ISSUE
# 617 echo problem very unsatisfactory [[0.1519455]] ISSUE
# 618 take two video time quality poor [[0.1825957]] ISSUE
# 619 do not waste money [[0.06350958]] ISSUE
# 620 go have be negatively review product [[0.17931479]] ISSUE
# 621 adapter do not provide charge current [[0.18969955]] ISSUE
# 622 hype phone assume best mistake [[0.32218114]] ISSUE
# 623 take picture case sense cover [[0.29619384]] ISSUE
# 624 phone fall easily [[0.25118798]] ISSUE
# 625 network people not hear talk [[0.10883904]] ISSUE
# 626 text message feature tricky use [[0.6407365]] NOTISSUE
# 627 disappoint have charger do network [[0.23534977]] ISSUE
# 628 painful ear [[0.16665305]] ISSUE
# 629 last one day blow up [[0.08212992]] ISSUE
# 630 disappoint [[0.25518695]] ISSUE
# 631 kind flop around [[0.18149696]] ISSUE
# 632 screen do get smudge easily touch ear face [[0.23477404]] ISSUE
# 633 piece junk lose call phone [[0.13571021]] ISSUE
# 634 item do not match picture [[0.12280507]] ISSUE
# 635 thing disappoint infra red port ira [[0.33959776]] ISSUE
# 636 not answer call unit never work once [[0.13159138]] ISSUE
# 637 unsatisfactory [[0.1422043]] ISSUE
# 638 product great [[0.94169736]] NOTISSUE
# 639 have this [[0.5287629]] NOTISSUE
# 640 have work good no problem [[0.734901]] NOTISSUE
# 641 oh dangerous [[0.26846406]] ISSUE
# 642 sorry [[0.13278586]] ISSUE
# 643 sorry [[0.13278586]] ISSUE
# 644 pardon [[0.49463874]] ISSUE
# 645 help help [[0.53002226]] NOTISSUE
# 646 no no dangerous [[0.04378446]] ISSUE
# 647 extremely dangerous [[0.24222454]] ISSUE
# 648 dangerous [[0.14717859]] ISSUE
# 649 dangerous young man [[0.30822924]] ISSUE
# 650 dangerous brutal [[0.02718815]] ISSUE
# 651 honestly dangerous [[0.1863005]] ISSUE
# 652 work [[0.5782628]] NOTISSUE
# 653 dead hard work [[0.2727525]] ISSUE
# 654 fact family mary wed [[0.68715]] NOTISSUE
# 655 have busy [[0.6412662]] NOTISSUE
# 656 go back again [[0.44117373]] ISSUE
# 657 busy [[0.6042363]] NOTISSUE
# 658 think yesterday [[0.5392972]] NOTISSUE
# 659 do think get one [[0.35906804]] ISSUE
# 660 oh yes [[0.7869898]] NOTISSUE
# 661 one thing want talk [[0.4821509]] ISSUE
# 662 well honestly do not know have noreen discussion [[0.5676041]] NOTISSUE
# 663 course be come tomorrow [[0.46206352]] ISSUE
# 664 have noreen think away weekend [[0.26867905]] ISSUE
# 665 hello [[0.7252548]] NOTISSUE
# 666 mean young man [[0.2708735]] ISSUE
# 667 goodbye [[0.64245766]] NOTISSUE
# 668 alright [[0.75438297]] NOTISSUE
# 669 do need money urgently [[0.33976305]] ISSUE
# 670 business [[0.4626131]] ISSUE
# 671 work day [[0.5090104]] NOTISSUE
# 672 work [[0.5782628]] NOTISSUE
# 673 do work [[0.39133856]] ISSUE
# 674 work day [[0.5090104]] NOTISSUE
# 675 work saturday [[0.54499984]] NOTISSUE
# 676 know work [[0.64628834]] NOTISSUE
# 677 horrible customer service [[0.0800067]] ISSUE
# 678 fine product [[0.7006945]] NOTISSUE
# 679 glad pay money it [[0.5544237]] NOTISSUE
# 680 worst version adobe illustrator be release version nine [[0.22795904]] ISSUE
# 681 not save mysterious reason [[0.07415545]] ISSUE
# 682 crash [[0.1828633]] ISSUE
# 683 open file have year write scribble untenable save version [[0.11328928]] ISSUE
# 684 assume adobe customer service be professional quick [[0.780646]] NOTISSUE
# 685 have call time past two week have have wait minimum twenty three minute speak someone [[0.10182431]] ISSUE
# 686 finally get product send mac version personal computer version purchase [[0.71229714]] NOTISSUE
# 687 call again wait approximately thirty minute get customer help [[0.09943212]] ISSUE
# 688 have not receive personal computer version [[0.42621216]] ISSUE
# 689 call center service worst customer service have deal [[0.12240515]] ISSUE
# 690 have deal bad customer service [[0.12163315]] ISSUE
# 691 extremely frustrate hour [[0.22562617]] ISSUE
# 692 do not have problem software [[0.2269645]] ISSUE
# 693 reverse error be nightmare [[0.00940085]] ISSUE
# 694 pretty do need [[0.7353749]] NOTISSUE
# 695 point customer service rep nice [[0.8997559]] NOTISSUE
# 696 do not have infrastructure provide basic level service [[0.26625767]] ISSUE
# 697 customer support system payroll upgrade product scary [[0.31025922]] ISSUE
# 698 do not send receipt [[0.11498179]] ISSUE
# 699 receipt get copy invoice not format print correctly [[0.19517316]] ISSUE
# 700 disturb people suppose be account expert [[0.1521544]] ISSUE
# 701 start look alternative intuit obviously do not understand basic account audit principle [[0.19108228]] ISSUE
# 702 thoroughly disappoint [[0.24240698]] ISSUE
# 703 not do business company anymore give bad support [[0.04059342]] ISSUE
# 704 online information exactly have cd [[0.8942141]] NOTISSUE
# 705 have not send coupon [[0.21586564]] ISSUE
# 706 bad [[0.03820586]] ISSUE
# 707 save money do not subscribe extend service [[0.08909131]] ISSUE
# 708 use customer service technical support give answer vaguely relate problem [[0.39961332]] ISSUE
# 709 emailinc time get nowhere [[0.27607736]] ISSUE
# 710 largest technical software company world [[0.7709462]] NOTISSUE
# 711 have no technical support [[0.3475804]] ISSUE
# 712 worthless product horrible customer service [[0.02961406]] ISSUE
# 713 unable access internet [[0.24969436]] ISSUE
# 714 no problem system become slow [[0.01772198]] ISSUE
# 715 customer service phone number not user guide bury webster [[0.5124251]] NOTISSUE
# 716 reputation become exasperate script suggestion not resolve problem [[0.05631404]] ISSUE
# 717 feel bite fleece overprice subscription renewal year [[0.22612348]] ISSUE
# 718 decide give try [[0.39392257]] ISSUE
# 719 installation go smoothly seem fine [[0.5199762]] NOTISSUE
# 720 stall blank screen right window [[0.63290066]] NOTISSUE
# 721 hang forever [[0.50986576]] NOTISSUE
# 722 well present [[0.807868]] NOTISSUE
# 723 easy follow along easy revisit previous lesson [[0.92177725]] NOTISSUE
# 724 video illustrate fretboard help see hear song be play [[0.8610494]] NOTISSUE
# 725 not lot depth material [[0.15353234]] ISSUE
# 726 sing be slight destruction sometimes [[0.06919086]] ISSUE
# 727 material song not be everyone like [[0.3066123]] ISSUE
# 728 have find music book useful [[0.97442824]] NOTISSUE
# 729 probably not recommend be source learn guitar [[0.3856205]] ISSUE
# 730 like new look [[0.7487131]] NOTISSUE
# 731 i have problem make transition [[0.4589642]] ISSUE
# 732 look create doom half life 2 normally recommend program [[0.38936105]] ISSUE
# 733 want make advance fps game simple pong game recommend dark basic [[0.56691945]] NOTISSUE
# 734 dark basic professional probably capable create kind game come with [[0.995854]] NOTISSUE
# 735 have deal bad customer service [[0.12163315]] ISSUE
# 736 dark basic make manipulate d data extremely easy [[0.85077834]] NOTISSUE
# 737 have program yourself scratch [[0.51256675]] NOTISSUE
# 738 recommend [[0.6351528]] NOTISSUE
# 739 software easy install easy use [[0.9736516]] NOTISSUE
# 740 wonderful software [[0.9854775]] NOTISSUE
# 741 buy cd [[0.85125715]] NOTISSUE
# 742 do not waste money subscription merriam webster webster [[0.15338966]] ISSUE
# 743 software user friendly [[0.94665295]] NOTISSUE
# 744 superb [[0.8788652]] NOTISSUE
# 745 try medical dictionary [[0.4073214]] ISSUE
# 746 surprise find offer option strip code [[0.8541549]] NOTISSUE
# 747 compare old earlier version offer major improvement [[0.42823333]] ISSUE
# 748 evolution [[0.4747603]] ISSUE
# 749 do offer major improvement flexibility previous version [[0.713334]] NOTISSUE
# 750 good [[0.8595474]] NOTISSUE
# 751 simple easy use user friendly accurate pronunciation [[0.9960394]] NOTISSUE
# 752 horribly bad [[0.00920636]] ISSUE
# 753 good able tweak dozen standard compliance [[0.963537]] NOTISSUE
# 754 default thing not set up do take learn [[0.12903619]] ISSUE
# 755 move bs2000 fairly advance feature [[0.73445183]] NOTISSUE
# 756 anyhow have call para professional version [[0.8497199]] NOTISSUE
# 757 have way flexibility functionality version [[0.9698352]] NOTISSUE
# 758 go bye bye [[0.71903604]] NOTISSUE
# 759 please product [[0.5699506]] NOTISSUE
# 760 have trial version instal computer buy it [[0.520431]] NOTISSUE
# 761 have do enter code box [[0.21350156]] ISSUE
# 762 easy [[0.769354]] NOTISSUE
# 763 glad able install one computer [[0.928304]] NOTISSUE
# 764 today best office suite microsoft have own [[0.93409383]] NOTISSUE
# 765 easy use excellent result [[0.9736789]] NOTISSUE
# 766 great sw [[0.93311286]] NOTISSUE
# 767 easy learn [[0.85493684]] NOTISSUE
# 768 have good graphic [[0.8445307]] NOTISSUE
# 769 help visualize space [[0.7497335]] NOTISSUE
# 770 see d [[0.6123248]] NOTISSUE
# 771 have configure do [[0.55410826]] NOTISSUE
# 772 difficult change room be house overall style start give design [[0.2216366]] ISSUE
# 773 recently buy version [[0.8549373]] NOTISSUE
# 774 instal software [[0.61590457]] NOTISSUE
# 775 operate well old personal computer [[0.85283613]] NOTISSUE
# 776 run lot faster [[0.3780281]] ISSUE
# 777 access corporate entrant [[0.49309042]] ISSUE
# 778 awesome [[0.9019289]] NOTISSUE
# 779 give whirl [[0.42169514]] ISSUE
# 780 have buy product again [[0.7470073]] NOTISSUE
# 781 five star them [[0.698168]] NOTISSUE
# 782 great company deal [[0.9771688]] NOTISSUE
# 783 agree window improve thier product [[0.34648585]] ISSUE
# 784 linx not user friendly [[0.66640365]] NOTISSUE
# 785 compatibility issue kill unix linx [[0.2583269]] ISSUE
# 786 unix far stable [[0.76941156]] NOTISSUE
# 787 have access cd version [[0.9378078]] NOTISSUE
# 788 like [[0.58492607]] NOTISSUE
# 789 work well me [[0.9145372]] NOTISSUE
# 790 usually go disc want attempt [[0.09757386]] ISSUE
# 791 lot cd [[0.86411625]] NOTISSUE
# 792 great program child learn difference [[0.9866216]] NOTISSUE
# 793 fun excellent way learn math [[0.9993218]] NOTISSUE
# 794 child love do too [[0.51624465]] NOTISSUE
# 795 fun way keep brain work [[0.9923137]] NOTISSUE
# 796 marvelous [[0.8972656]] NOTISSUE
# 797 memory improvement software marvelous [[0.9773196]] NOTISSUE
# 798 help improve memory provide motivate game [[0.941587]] NOTISSUE
# 799 highly recommend [[0.8402346]] NOTISSUE
# 800 great [[0.93311286]] NOTISSUE
# 801 love software [[0.9321131]] NOTISSUE
# 802 word new disturb get high score [[0.08877432]] ISSUE
# 803 have symantec customer year [[0.82540625]] NOTISSUE
# 804 year product get better better [[0.8553258]] NOTISSUE
# 805 not use product purpose [[0.21083371]] ISSUE
# 806 anti virus find problem personal computer fix you [[0.32633805]] ISSUE
# 807 anti virus clean unneeded file [[0.08588192]] ISSUE
# 808 roll back system certain date problem occur [[0.10785665]] ISSUE
# 809 good program beginner experience family historian [[0.9967554]] NOTISSUE
# 810 program joy use [[0.94942504]] NOTISSUE
# 811 design make thing simple user [[0.93505526]] NOTISSUE
# ...
# 3948 anyways food definitely not fill all price pay expect more [[0.22741243]] ISSUE
# 3949 chip come drip grease not edible [[0.14378574]] ISSUE
# 3950 normally impress strip steak [[0.54510427]] NOTISSUE
# 3951 have go two thousand seven meal have awesome [[0.9831371]] NOTISSUE
# 3952 server nice attentive serve staff [[0.99547714]] NOTISSUE
# 3953 cashier friendly bring food me [[0.90336686]] NOTISSUE
# 3954 work hospitality industry paradise valley have refrain recommend ciob longer [[0.9226757]] NOTISSUE
# 3955 atmosphere fun [[0.9531561]] NOTISSUE
# 3956 not recommend others [[0.25570005]] ISSUE
# 3957 service quick to go order like like it [[0.5117528]] NOTISSUE
# 3958 mean really do get famous fish chip terrible [[0.04231236]] ISSUE
# 3959 say mouth belly please [[0.42035484]] ISSUE
# 3960 not thing [[0.23471372]] ISSUE
# 3961 two thumb up [[0.50347656]] NOTISSUE
# 3962 read please do no-go there [[0.17557202]] ISSUE
# 3963 love grill pizza remind legitimate italian pizza [[0.9752093]] NOTISSUE
# 3964 pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough [[0.99980503]] NOTISSUE
# 3965 have nice atmosphere [[0.9714469]] NOTISSUE
# 3966 tonight have elk file special and suck [[0.4072839]] ISSUE
# 3967 one bite hook [[0.17114045]] ISSUE
# 3968 order old classic new dish go time sorely disappoint everything [[0.2589015]] ISSUE
# 3969 cute quaint simple honest [[0.8362869]] NOTISSUE
# 3970 chicken deliciously season have perfect fry outside moist chicken inside [[0.88694185]] NOTISSUE
# 3971 food great always compliment chef [[0.9985348]] NOTISSUE
# 3972 special thank dylan t recommendation order yummy tummy [[0.9921938]] NOTISSUE
# 3973 awesome selection beer [[0.9744961]] NOTISSUE
# 3974 great food awesome service [[0.9983038]] NOTISSUE
# 3975 one nice thing add gratuity bill party larger 8 not expect tip that [[0.8310668]] NOTISSUE
# 3976 fly apple juice fly [[0.4708047]] ISSUE
# 3977 now nan chicken tasty [[0.88561386]] NOTISSUE
# 3978 service think good [[0.8950107]] NOTISSUE
# 3979 food barely lukewarm have sit wait server bring u [[0.0680709]] ISSUE
# 3980 ryan bar definitely one edinburgh establishment wo note revisit [[0.6166846]] NOTISSUE
# 3981 nicest chinese restaurant have while [[0.97964555]] NOTISSUE
# 3982 overall like food service [[0.56914353]] NOTISSUE
# 3983 serve indian nan bread hummus spicy pine nut sauce world [[0.85500586]] NOTISSUE
# 3984 probably never come back not recommend it [[0.21522067]] ISSUE
# 3985 friend pasta bad barely touch it [[0.15834281]] ISSUE
# 3986 try airport experience tasty food speedy friendly service [[0.996181]] NOTISSUE
# 3987 love decor chinese calligraphy wall paper [[0.9442442]] NOTISSUE
# 3988 never have complain here [[0.12404726]] ISSUE
# 3989 restaurant clean have family restaurant feel it [[0.9357256]] NOTISSUE
# 3990 way fry [[0.60595673]] NOTISSUE
# 3991 not sure long stand long begin feel awkwardly place [[0.06990835]] ISSUE
# 3992 open sandwich impress not good way [[0.3632461]] ISSUE
# 3993 not be back [[0.13691548]] ISSUE
# 3994 warm feel service felt like guest special treat [[0.95904297]] NOTISSUE
# 3995 extensive menu provide lot option breakfast [[0.9934782]] NOTISSUE
# 3996 order vegetarian menu dinner have wide array option choose from [[0.9894511]] NOTISSUE
# 3997 have watch price inflate portion get smaller management attitude grow rapidly [[0.26700246]] ISSUE
# 3998 wonderful little tapa ambience make feel warm fuzzy inside [[0.99842644]] NOTISSUE
# 3999 get enjoy seafood salad fabulous vinaigrette [[0.9979127]] NOTISSUE
# 4000 wonton thin not thick chewy melt mouth [[0.11440384]] ISSUE
# 4001 level five spicy perfect spice hoover helm soup [[0.9651217]] NOTISSUE
# 4002 sit right time server get go fantastic [[0.76261955]] NOTISSUE
# 4003 main thing not enjoy crowd older crowd middle thirty s up [[0.81708723]] NOTISSUE
# 4004 town definitely be spot hit again [[0.63665247]] NOTISSUE
# 4005 have wait thirty minute get drink longer get two area [[0.12211031]] ISSUE
# 4006 great place eat [[0.97376347]] NOTISSUE
# 4007 jalapeno bacon soon good [[0.91447836]] NOTISSUE
# 4008 service poor [[0.07499007]] ISSUE
# 4009 food good service good price good [[0.9985941]] NOTISSUE
# 4010 price good [[0.90044457]] NOTISSUE
# 4011 price good [[0.90044457]] NOTISSUE
# 4012 service good [[0.8837027]] NOTISSUE
# 4013 place not clean food oh stale [[0.0380049]] ISSUE
# 4014 chicken dish ok beef like shoe leather [[0.516697]] NOTISSUE
# 4015 service bad [[0.04542723]] ISSUE
# 4016 happy be here [[0.9365944]] NOTISSUE
# 4017 taste like dirt [[0.19741806]] ISSUE
# 4018 one place phoenix definately go back again [[0.87202394]] NOTISSUE
# 4019 block amaze [[0.7672547]] NOTISSUE
# 4020 close house low key non fancy affordable price good food [[0.97932416]] NOTISSUE
# 4021 hot sour egg flower soup absolutely five star [[0.68704706]] NOTISSUE
# 4022 hashemi poor quality soggy tasteless [[0.00919055]] ISSUE
# 4023 great time family dinner sunday night [[0.99417603]] NOTISSUE
# 4024 food not tasty all not say real traditional hunan style [[0.20505504]] ISSUE
# 4025 bother me slow service [[0.06484395]] ISSUE
# 4026 flair bartender absolutely amaze [[0.9739932]] NOTISSUE
# 4027 freeze margarita way sugary taste [[0.46938214]] ISSUE
# 4028 good order twice [[0.85637677]] NOTISSUE
# 4029 nutshell 1 restaurant smell like combination dirty fish market sewer [[0.13205174]] ISSUE
# 4030 girlfriend veal bad [[0.04574375]] ISSUE
# 4031 unfortunately not good [[0.26123878]] ISSUE
# 4032 have pretty satisfy experience [[0.9313773]] NOTISSUE
# 4033 join club get awesome offer email [[0.9725873]] NOTISSUE
# 4034 perfect me like beer ice cold case colder [[0.9320659]] NOTISSUE
# 4035 bland flavourless good way describe barely tepid meat [[0.03926834]] ISSUE
# 4036 chain no fan of beat place easily [[0.44066873]] ISSUE
# 4037 nacho have [[0.62823063]] NOTISSUE
# 4038 not be come back [[0.14159803]] ISSUE
# 4039 do not have word say place do pretty well [[0.32620108]] ISSUE
# 4040 staff super nice quick crazy crowd downtown jury lawyer court staff [[0.9957267]] NOTISSUE
# 4041 great atmosphere friendly fast service [[0.9997123]] NOTISSUE
# 4042 receive pity huge have lot meat thumb there [[0.26485774]] ISSUE
# 4043 food arrive me [[0.45545557]] ISSUE
# 4044 pay 7 85 hot dog fry look like come kid meal wienerschnitzel not idea good meal [[0.86216867]] NOTISSUE
# 4045 classic maine lobster roll fantastic [[0.9856661]] NOTISSUE
# 4046 brother law work mall eat day guess sick night too [[0.0316063]] ISSUE
# 4047 good go have review place twice [[0.95193034]] NOTISSUE
# 4048 chip salsa good salsa fresh [[0.99682534]] NOTISSUE
# 4049 place great [[0.9542093]] NOTISSUE
# 4050 mediocre food [[0.10212404]] ISSUE
# 4051 get inside be impress place [[0.41102394]] ISSUE
# 4052 service super friendly [[0.96238744]] NOTISSUE
# 4053 sad little vegetable overcook [[0.06199418]] ISSUE
# 4054 place nice surprise [[0.9723808]] NOTISSUE
# 4055 live music totally blow [[0.2842467]] ISSUE
# (      Unnamed: 0                                               text     label
#  0              0  have order data cable get well finish work pro...  NOTISSUE
#  1              1                                         love phone  NOTISSUE
#  2              2                            get well finish product  NOTISSUE
#  3              3                                     not be happier  NOTISSUE
#  4              4                    look headset long time have get  NOTISSUE
#  5              5                       headset start ring no reason     ISSUE
#  6              6                 display excellent camera good year  NOTISSUE
#  7              7                                 battery life great  NOTISSUE
#  8              8                   worst phone have have have month     ISSUE
#  9              9  not good item work start have problem auto rev...     ISSUE
#  10            10           embarrass ear hurt try push ear plug ear     ISSUE
#  11            11                                 protect phone side  NOTISSUE
#  12            12  average phone bad battery life operate weak ne...     ISSUE
#  13            13       clear skye call long battery life long range  NOTISSUE
#  14            14                               solo technology suck     ISSUE
#  15            15                             great hand free device  NOTISSUE
#  16            16   take self portrait outside exterior display cool  NOTISSUE
#  17            17                               problem have mention     ISSUE
#  18            18         try handsfree gadget one finally work well  NOTISSUE
#  19            19                                       magical help  NOTISSUE
#  20            20          worst piece crap version customer service     ISSUE
#  21            21                                 poor sound quality     ISSUE
#  22            22                                  best phone market  NOTISSUE
#  23            23                                          work well  NOTISSUE
#  24            24            company ship product promptly work well  NOTISSUE
#  25            25                                       exactly want  NOTISSUE
#  26            26  picture resolution far comparably price phone ...     ISSUE
#  27            27                                         great deal  NOTISSUE
#  28            28                 excellent product satisfy purchase  NOTISSUE
#  29            29         highly recommend encourage people give try  NOTISSUE
#  ...          ...                                                ...       ...
#  4025        4025                   flair bartender absolutely amaze  NOTISSUE
#  4026        4026                  freeze margarita way sugary taste     ISSUE
#  4027        4027                                   good order twice  NOTISSUE
#  4028        4028  nutshell 1 restaurant smell like combination d...     ISSUE
#  4029        4029                                girlfriend veal bad     ISSUE
#  4030        4030                             unfortunately not good     ISSUE
#  4031        4031                     have pretty satisfy experience  NOTISSUE
#  4032        4032                  join club get awesome offer email  NOTISSUE
#  4033        4033          perfect me like beer ice cold case colder  NOTISSUE
#  4034        4034  bland flavourless good way describe barely tep...     ISSUE
#  4035        4035                  chain no fan of beat place easily     ISSUE
#  4036        4036                                         nacho have  NOTISSUE
#  4037        4037                                   not be come back     ISSUE
#  4038        4038          do not have word say place do pretty well  NOTISSUE
#  4039        4039  staff super nice quick crazy crowd downtown ju...  NOTISSUE
#  4040        4040             great atmosphere friendly fast service  NOTISSUE
#  4041        4041        receive pity huge have lot meat thumb there  NOTISSUE
#  4042        4042                                     food arrive me     ISSUE
#  4043        4043  pay 7 85 hot dog fry look like come kid meal w...     ISSUE
#  4044        4044               classic maine lobster roll fantastic  NOTISSUE
#  4045        4045  brother law work mall eat day guess sick night...     ISSUE
#  4046        4046                    good go have review place twice  NOTISSUE
#  4047        4047                        chip salsa good salsa fresh  NOTISSUE
#  4048        4048                                        place great  NOTISSUE
#  4049        4049                                      mediocre food     ISSUE
#  4050        4050                        get inside be impress place  NOTISSUE
#  4051        4051                             service super friendly  NOTISSUE
#  4052        4052                      sad little vegetable overcook     ISSUE
#  4053        4053                                place nice surprise  NOTISSUE
#  4054        4054                            live music totally blow  NOTISSUE
#
#  [4055 rows x 3 columns],
#           label                                               text
#  0     NOTISSUE  have order data cable get well finish work pro...
#  1     NOTISSUE                                         love phone
#  2     NOTISSUE                            get well finish product
#  3        ISSUE                                     not be happier
#  4     NOTISSUE                    look headset long time have get
#  5        ISSUE                       headset start ring no reason
#  6     NOTISSUE                 display excellent camera good year
#  7     NOTISSUE                                 battery life great
#  8        ISSUE                   worst phone have have have month
#  9        ISSUE  not good item work start have problem auto rev...
#  10       ISSUE           embarrass ear hurt try push ear plug ear
#  11    NOTISSUE                                 protect phone side
#  12       ISSUE  average phone bad battery life operate weak ne...
#  13    NOTISSUE       clear skye call long battery life long range
#  14       ISSUE                               solo technology suck
#  15    NOTISSUE                             great hand free device
#  16    NOTISSUE   take self portrait outside exterior display cool
#  17       ISSUE                               problem have mention
#  18    NOTISSUE         try handsfree gadget one finally work well
#  19    NOTISSUE                                       magical help
#  20       ISSUE          worst piece crap version customer service
#  21       ISSUE                                 poor sound quality
#  22    NOTISSUE                                  best phone market
#  23    NOTISSUE                                          work well
#  24    NOTISSUE            company ship product promptly work well
#  25    NOTISSUE                                       exactly want
#  26    NOTISSUE  picture resolution far comparably price phone ...
#  27    NOTISSUE                                         great deal
#  28    NOTISSUE                 excellent product satisfy purchase
#  29    NOTISSUE         highly recommend encourage people give try
#  ...        ...                                                ...
#  4025  NOTISSUE                   flair bartender absolutely amaze
#  4026     ISSUE                  freeze margarita way sugary taste
#  4027  NOTISSUE                                   good order twice
#  4028     ISSUE  nutshell 1 restaurant smell like combination d...
#  4029     ISSUE                                girlfriend veal bad
#  4030     ISSUE                             unfortunately not good
#  4031  NOTISSUE                     have pretty satisfy experience
#  4032  NOTISSUE                  join club get awesome offer email
#  4033  NOTISSUE          perfect me like beer ice cold case colder
#  4034     ISSUE  bland flavourless good way describe barely tep...
#  4035     ISSUE                  chain no fan of beat place easily
#  4036  NOTISSUE                                         nacho have
#  4037     ISSUE                                   not be come back
#  4038     ISSUE          do not have word say place do pretty well
#  4039  NOTISSUE  staff super nice quick crazy crowd downtown ju...
#  4040  NOTISSUE             great atmosphere friendly fast service
#  4041     ISSUE        receive pity huge have lot meat thumb there
#  4042     ISSUE                                     food arrive me
#  4043  NOTISSUE  pay 7 85 hot dog fry look like come kid meal w...
#  4044  NOTISSUE               classic maine lobster roll fantastic
#  4045     ISSUE  brother law work mall eat day guess sick night...
#  4046  NOTISSUE                    good go have review place twice
#  4047  NOTISSUE                        chip salsa good salsa fresh
#  4048  NOTISSUE                                        place great
#  4049     ISSUE                                      mediocre food
#  4050     ISSUE                        get inside be impress place
#  4051  NOTISSUE                             service super friendly
#  4052     ISSUE                      sad little vegetable overcook
#  4053  NOTISSUE                                place nice surprise
#  4054     ISSUE                            live music totally blow
#
#  [4055 rows x 2 columns])

# %%
data_predict= pd.read_csv(output_file ,delimiter=';',encoding='UTF-8')
print(data_predict.head())
# Out:
#    Unnamed: 0     label                                               text
# 0           0  NOTISSUE  have order data cable get well finish work pro...
# 1           1  NOTISSUE                                         love phone
# 2           2  NOTISSUE                            get well finish product
# 3           3     ISSUE                                     not be happier
# 4           4  NOTISSUE                    look headset long time have get

# %%
data_predict['label'].value_counts()
# Out:
# ISSUE       2032
# NOTISSUE    2023
# Name: label, dtype: int64

# %% [markdown]
# ### confussin matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(df.label,data_predict.label)
print(cm)
# Out:
# [[1726  299]
#  [ 306 1724]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_true = df.label, y_pred = data_predict.label)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(cf, annot=True, fmt="d",linewidths=.5, center = 90, vmax = 200)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
# This utility function is from the sklearn docs: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(df.label, data_predict.label)
plt.figure(figsize=(24,20))
plot_confusion_matrix(cnf_matrix, classes=['ISSUE','NOTISSUE'], title="Confusion matrix")
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

print('accuracy %s' % accuracy_score(data_predict.label, df.label))
print(classification_report(df.label, data_predict.label,target_names=['ISSUE','NOTISSUE']))
# Out:
# accuracy 0.8508014796547472
#               precision    recall  f1-score   support
#
#        ISSUE       0.85      0.85      0.85      2025
#     NOTISSUE       0.85      0.85      0.85      2030
#
#    micro avg       0.85      0.85      0.85      4055
#    macro avg       0.85      0.85      0.85      4055
# weighted avg       0.85      0.85      0.85      4055

# %%
def false_pos_neg(input_file,output_file,falses_file):
    diff= pd.DataFrame(columns=['true_label','pred_label', 'Text'])
    data = pd.read_csv(input_file,delimiter=',')
    data_pred = pd.read_csv(output_file,delimiter=';')
    t_labels = data.label
    p_labels = data_pred.label
    
    label=data.text.values
    t_label = t_labels.values
    p_label = p_labels.values
    for i in range(len(t_label)):
        if t_label[i]!=p_label[i]:
            diff = diff.append({'true_label':t_label[i],'pred_label':p_label[i], 'Text':label[i]},ignore_index=True)
    diff.to_csv(falses_file,sep=';')
    return diff

# %%
falses_file='Data/false_pred_glove300_with_text_preprocessing_v2.csv'
diff=false_pos_neg(input_file,output_file,falses_file)
print(diff)
# Out:
#     true_label pred_label                                               Text
# 0     NOTISSUE      ISSUE                                     not be happier
# 1        ISSUE   NOTISSUE  picture resolution far comparably price phone ...
# 2     NOTISSUE      ISSUE                                     prompt service
# 3        ISSUE   NOTISSUE  stupid have keep buy new charger car charger c...
# 4        ISSUE   NOTISSUE                            plastic break easy clip
# 5     NOTISSUE      ISSUE                             do not make mistake do
# 6     NOTISSUE      ISSUE  sanyo have survive dozen drop blackton ill effect
# 7     NOTISSUE      ISSUE               find cell phone right away enter car
# 8        ISSUE   NOTISSUE                                        low quality
# 9     NOTISSUE      ISSUE  do not find it bad again unit come one arpad o...
# 10    NOTISSUE      ISSUE  have get defect not risk buy again build quali...
# 11    NOTISSUE      ISSUE                            nothing bad say headset
# 12    NOTISSUE      ISSUE                               no buyer remorse one
# 13    NOTISSUE      ISSUE              update procedure difficult cumbersome
# 14       ISSUE   NOTISSUE                                     like return it
# 15    NOTISSUE      ISSUE                                   wo not regret it
# 16       ISSUE   NOTISSUE                                  not user friendly
# 17       ISSUE   NOTISSUE  unfortunately ability actually know receive ca...
# 18       ISSUE   NOTISSUE                        exchange phone have problem
# 19    NOTISSUE      ISSUE                                      work describe
# 20       ISSUE   NOTISSUE                             have give no star able
# 21    NOTISSUE      ISSUE                          not recommend item anyone
# 22    NOTISSUE      ISSUE            end slide edge pant back pocket instead
# 23       ISSUE   NOTISSUE  unfortunately easy accidentally activate gentl...
# 24       ISSUE   NOTISSUE                    none new one have work properly
# 25    NOTISSUE      ISSUE  no shift no bubble no peel not scratch nothing...
# 26       ISSUE   NOTISSUE  give firefly one star i contact singular at t ...
# 27    NOTISSUE      ISSUE                            please dont waste money
# 28       ISSUE   NOTISSUE           look good quality headset keep look nott
# 29       ISSUE   NOTISSUE      plantronincs continue use flaw charger design
# ..         ...        ...                                                ...
# 575      ISSUE   NOTISSUE  salad have bland vinaigrette baby green heart ...
# 576   NOTISSUE      ISSUE                                                rat
# 577      ISSUE   NOTISSUE                  look authentic thai food go where
# 578      ISSUE   NOTISSUE                   extremely crumb pretty tasteless
# 579      ISSUE   NOTISSUE   pale color instead nice character have no flavor
# 580   NOTISSUE      ISSUE                       be regular stop trip phoenix
# 581   NOTISSUE      ISSUE  make drive way north scottsdale not one bite d...
# 582      ISSUE   NOTISSUE  best luck rude non customer service focus new ...
# 583      ISSUE   NOTISSUE          grandmother make roast chicken better one
# 584      ISSUE   NOTISSUE                place have lot promise fail deliver
# 585      ISSUE   NOTISSUE                                  fry rice dry well
# 586      ISSUE   NOTISSUE                                 not fun experience
# 587      ISSUE   NOTISSUE                                       dont go here
# 588   NOTISSUE      ISSUE                          promise wo not disappoint
# 589   NOTISSUE      ISSUE                                   not wait go back
# 590      ISSUE   NOTISSUE  have say place walk expect be amaze quickly di...
# 591      ISSUE   NOTISSUE                       normally impress strip steak
# 592   NOTISSUE      ISSUE                             say mouth belly please
# 593   NOTISSUE      ISSUE                                      one bite hook
# 594      ISSUE   NOTISSUE  ryan bar definitely one edinburgh establishmen...
# 595   NOTISSUE      ISSUE                           never have complain here
# 596      ISSUE   NOTISSUE                                            way fry
# 597   NOTISSUE      ISSUE             wonton thin not thick chewy melt mouth
# 598      ISSUE   NOTISSUE  main thing not enjoy crowd older crowd middle ...
# 599      ISSUE   NOTISSUE             chicken dish ok beef like shoe leather
# 600   NOTISSUE      ISSUE          do not have word say place do pretty well
# 601   NOTISSUE      ISSUE        receive pity huge have lot meat thumb there
# 602      ISSUE   NOTISSUE  pay 7 85 hot dog fry look like come kid meal w...
# 603   NOTISSUE      ISSUE                        get inside be impress place
# 604   NOTISSUE      ISSUE                            live music totally blow
#
# [605 rows x 3 columns]
